# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
# FUNC_ANNOT = "pathway"
# FUNC_ANNOT = "COG"
FUNC_ANNOT = "regulon"

# %%
all_muts_df = pd.read_pickle("./data/GYD_df.pkl")
display(len(all_muts_df),
#         muts_df.head()
       )


# # Below are the COGs that got multiple hits with GYD
# '''
# Lipid transport and metabolism
# Cell cycle control, cell division, chromosome partitioning
# Transcription
# Amino acid transport and metabolism
# Secondary metabolites biosynthesis, transport and catabolism
# Cell wall/membrane/envelope biogenesis
# Posttranslational modification, protein turnover, chaperones
# Replication, recombination and repair
# Signal transduction mechanisms
# Cell motility
# Defense mechanisms
# Inorganic ion transport and metabolism
# Intracellular trafficking, secretion, and vesicular transport
# Coenzyme transport and metabolism
# Energy production and conversion
# Translation, ribosomal structure and biogenesis
# Carbohydrate transport and metabolism
# Nucleotide transport and metabolism
# '''


# out_df = pd.DataFrame()
# df = muts_df.copy()
# for _, r in df.iterrows():
#     for c in r["operons"]:
#         try:
#             # GYD
#             if "rpoB" in c["name"] or "rpoC" in c["name"] or "rph" in c["name"]:
#                 out_df = out_df.append(r, ignore_index=True)
#                 break
# #             if "ptsHI-crr" in c["name"]:
# #                 out_df = out_df.append(r, ignore_index=True)
# #                 break
#             # PGI
# #             if "pnt" in c["name"]:
# #                 out_df = out_df.append(r, ignore_index=True)
# #                 break
#         except:
#             print("feature annotation bug with", c)

# muts_df = out_df
# display(len(muts_df))
# Out:
# 163

# %%
# This is for filtering out mutations with genomic features statistically associated to specific conditions
muts_df = pd.DataFrame()
for _, mut in all_muts_df.iterrows():
    for feat in mut["genomic features"]:
        if 'glycerol(2.5)' in feat['significantly associated conditions']:
            muts_df = muts_df.append(mut)
            # need to break since a mutation could have more than one feature
            # which are associated with a condition,
            # therefore adding a duplicate entry.
            break
display(len(muts_df), muts_df.head())
# Out:
# 91
#                                               COG links  \
# 1682  {'Nucleotide transport and metabolism': ['ECK1...
# 1683  {'Energy production and conversion': ['ECK1200...
# 1686                {'Transcription': ['ECK120014937']}
# 1688  {'Carbohydrate transport and metabolism': ['EC...
# 1691  {'Energy production and conversion': ['ECK1200...
#
#                                                    COGs  \
# 1682  [{'name': 'Nucleotide transport and metabolism...
# 1683  [{'name': 'Energy production and conversion', ...
# 1686  [{'name': 'Transcription', 'mutation set count...
# 1688  [{'name': 'Carbohydrate transport and metaboli...
# 1691  [{'name': 'Energy production and conversion', ...
#
#                     Details     Mut ID Mutation Type   Position RBS  \
# 1682        R665S (CGT→AGT)  1103591.0           SNP  3993145.0  {}
# 1683         S59Y (TCC→TAC)  1103607.0           SNP  4117047.0  {}
# 1686  intergenic (‑93/‑505)  1105393.0           MOB  1293015.0  {}
# 1688         I34T (ATC→ACC)  1105329.0           SNP  2535934.0  {}
# 1691        N229H (AAC→CAC)  1104408.0           SNP  4116538.0  {}
#
#      Reference Seq RegulonDB Gene Sequence Change TFBS TSS  ale  \
# 1682     NC_000913           cyaA             C→A   {}  {}  1.0
# 1683     NC_000913           glpK             G→T   {}  {}  1.0
# 1686     NC_000913        hns/tdk   IS1 (+) +8 bp   {}  {}  2.0
# 1688     NC_000913            crr             T→C   {}  {}  2.0
# 1691     NC_000913           glpK             T→G   {}  {}  2.0
#
#      attenuator terminator base-media  carbon-source cis-regulatory RNA  \
# 1682                    {}         M9  glycerol(2.5)                 {}
# 1683                    {}         M9  glycerol(2.5)                 {}
# 1686                    {}         M9  glycerol(2.5)                 {}
# 1688                    {}         M9  glycerol(2.5)                 {}
# 1691                    {}         M9  glycerol(2.5)                 {}
#
#       coding  disrupt  exp  flask            gene  gene count  genetic  \
# 1682     1.0      0.0  GYD  280.0  {ECK120000166}         1.0      1.0
# 1683     1.0      0.0  GYD  280.0  {ECK120000391}         1.0      1.0
# 1686     0.0      1.0  GYD  182.0              {}         1.0      0.0
# 1688     1.0      0.0  GYD  182.0  {ECK120000161}         1.0      1.0
# 1691     1.0      0.0  GYD  182.0  {ECK120000391}         1.0      1.0
#
#                                 genetic feature links  \
# 1682               {'ECK120000166': ['ECK120000166']}
# 1683               {'ECK120000391': ['ECK120000391']}
# 1686  {'ECK120000450/ECK120000983': ['ECK120010201']}
# 1688               {'ECK120000161': ['ECK120000161']}
# 1691               {'ECK120000391': ['ECK120000391']}
#
#                                        genetic features  \
# 1682  [{'name': 'cyaA', 'RegulonDB ID': 'ECK12000016...
# 1683  [{'name': 'glpK', 'RegulonDB ID': 'ECK12000039...
# 1686  [{'RegulonDB ID': 'ECK120000450/ECK120000983',...
# 1688  [{'name': 'crr', 'RegulonDB ID': 'ECK120000161...
# 1691  [{'name': 'glpK', 'RegulonDB ID': 'ECK12000039...
#
#                                        genomic features index  isolate  \
# 1682  [{'name': 'cyaA', 'RegulonDB ID': 'ECK12000016...   126      0.0
# 1683  [{'name': 'glpK', 'RegulonDB ID': 'ECK12000039...    94      0.0
# 1686  [{'name': 'hnsp', 'RegulonDB ID': 'ECK12001020...   130      1.0
# 1688  [{'name': 'crr', 'RegulonDB ID': 'ECK120000161...    95      0.0
# 1691  [{'name': 'glpK', 'RegulonDB ID': 'ECK12000039...    16      1.0
#
#       mutation size mutation target annotation nitrogen-source  \
# 1682            1.0                       cyaA        NH4Cl(1)
# 1683            1.0                       glpK        NH4Cl(1)
# 1686            0.0                    hns/tdk        NH4Cl(1)
# 1688            1.0                        crr        NH4Cl(1)
# 1691            1.0                       glpK        NH4Cl(1)
#
#                                          operon links  \
# 1682               {'ECK120014835': ['ECK120000166']}
# 1683               {'ECK120014723': ['ECK120000391']}
# 1686  {'ECK120014937': ['ECK120000450/ECK120000983']}
# 1688               {'ECK120014520': ['ECK120000161']}
# 1691               {'ECK120014723': ['ECK120000391']}
#
#                                                 operons  oriC  \
# 1682  [{'name': 'cyaA', 'RegulonDB ID': 'ECK12001483...   0.0
# 1683  [{'name': 'glpFKX', 'RegulonDB ID': 'ECK120014...   0.0
# 1686  [{'name': 'hns', 'RegulonDB ID': 'ECK120014937...   0.0
# 1688  [{'name': 'ptsHI-crr', 'RegulonDB ID': 'ECK120...   0.0
# 1691  [{'name': 'glpFKX', 'RegulonDB ID': 'ECK120014...   0.0
#
#                                       pathway links  \
# 1682        {'Purine metabolism': ['ECK120014835']}
# 1683  {'Glycerolipid metabolism': ['ECK120014723']}
# 1686                                             {}
# 1688                                             {}
# 1691  {'Glycerolipid metabolism': ['ECK120014723']}
#
#                                                pathways phosphorous-source  \
# 1682  [{'name': 'Purine metabolism', 'mutation set c...          KH2PO4(3)
# 1683  [{'name': 'Glycerolipid metabolism', 'mutation...          KH2PO4(3)
# 1686                                                 []          KH2PO4(3)
# 1688                                                 []          KH2PO4(3)
# 1691  [{'name': 'Glycerolipid metabolism', 'mutation...          KH2PO4(3)
#
#       presence        promoter  pseudogene               range  \
# 1682       1.0              {}         0.0  (3993145, 3993145)
# 1683       1.0              {}         0.0  (4117047, 4117047)
# 1686       1.0  {ECK120010201}         0.0  (1293015, 1293015)
# 1688       1.0              {}         0.0  (2535934, 2535934)
# 1691       1.0              {}         0.0  (4116538, 4116538)
#
#                                         regulator links  \
# 1682                                  {'CRP': ['cyaA']}
# 1683            {'CRP': ['glpFKX'], 'GlpR': ['glpFKX']}
# 1686  {'GadX': ['hns'], 'H-NS': ['hns'], 'CspA': ['h...
# 1688  {'CRP': ['ptsHI-crr'], 'Mlc': ['ptsHI-crr'], '...
# 1691            {'CRP': ['glpFKX'], 'GlpR': ['glpFKX']}
#
#                                              regulators  repaired  \
# 1682  [{'name': 'CRP', 'mutation set count': 72.0, '...       0.0
# 1683  [{'name': 'CRP', 'mutation set count': 72.0, '...       0.0
# 1686  [{'name': 'GadX', 'mutation set count': 6.0, '...       0.0
# 1688  [{'name': 'CRP', 'mutation set count': 72.0, '...       0.0
# 1691  [{'name': 'CRP', 'mutation set count': 72.0, '...       0.0
#
#      strain-description sulfur-source      supplement taxonomy-id  tech_rep  \
# 1682              BOP27   MgSO4(0.24)  trace elements      511145       1.0
# 1683              BOP27   MgSO4(0.24)  trace elements      511145       1.0
# 1686              BOP27   MgSO4(0.24)  trace elements      511145       1.0
# 1688              BOP27   MgSO4(0.24)  trace elements      511145       1.0
# 1691              BOP27   MgSO4(0.24)  trace elements      511145       1.0
#
#      temperature terminator
# 1682  37 celsius         {}
# 1683  37 celsius         {}
# 1686  37 celsius         {}
# 1688  37 celsius         {}
# 1691  37 celsius         {}

# %%
# processing to help a cleaner order of features.
# sorts mutations by position so that mutations to proximal features will be inserted into flow_df next to each other.
muts_df = muts_df.sort_values(by="Position")
muts_df.head()
# Out:
#                                               COG links  \
# 1763  {'Amino acid transport and metabolism': ['ECK1...
# 1737  {'Amino acid transport and metabolism': ['ECK1...
# 1738  {'Amino acid transport and metabolism': ['ECK1...
# 1782                                                 {}
# 1832                                                 {}
#
#                                                    COGs               Details  \
# 1763  [{'name': 'Amino acid transport and metabolism...  intergenic (‑58/+35)
# 1737  [{'name': 'Amino acid transport and metabolism...  intergenic (‑58/+35)
# 1738  [{'name': 'Amino acid transport and metabolism...  intergenic (‑61/+32)
# 1782                                                 []  intergenic (+40/+36)
# 1832                                                 []  intergenic (+46/+30)
#
#          Mut ID Mutation Type   Position RBS Reference Seq RegulonDB Gene  \
# 1763   317489.0           SNP    83587.0  {}     NC_000913      leuA/leuL
# 1737   317489.0           SNP    83587.0  {}     NC_000913      leuA/leuL
# 1738   317490.0           SNP    83590.0  {}     NC_000913      leuA/leuL
# 1782  1105347.0           SNP  1018977.0  {}     NC_000913      matP/ompA
# 1832   570538.0           SNP  1018983.0  {}     NC_000913      matP/ompA
#
#      Sequence Change TFBS TSS   ale attenuator terminator base-media  \
# 1763             A→C   {}  {}  14.0        {ECK125143560}         M9
# 1737             A→C   {}  {}  10.0        {ECK125143560}         M9
# 1738             G→T   {}  {}  10.0        {ECK125143560}         M9
# 1782             C→A   {}  {}  20.0                    {}         M9
# 1832             A→T   {}  {}  35.0                    {}         M9
#
#       carbon-source cis-regulatory RNA  coding  disrupt  exp  flask gene  \
# 1763  glycerol(2.5)     {ECK120001253}     0.0      0.0  GYD   68.0   {}
# 1737  glycerol(2.5)     {ECK120001253}     0.0      0.0  GYD  106.0   {}
# 1738  glycerol(2.5)     {ECK120001253}     0.0      0.0  GYD  106.0   {}
# 1782  glycerol(2.5)                 {}     0.0      0.0  GYD   33.0   {}
# 1832  glycerol(2.5)                 {}     0.0      0.0  GYD    9.0   {}
#
#       gene count  genetic                              genetic feature links  \
# 1763         1.0      0.0    {'ECK120001204/ECK120001253': ['ECK125143560']}
# 1737         1.0      0.0    {'ECK120001204/ECK120001253': ['ECK125143560']}
# 1738         1.0      0.0    {'ECK120001204/ECK120001253': ['ECK125143560']}
# 1782         1.0      0.0  {'ECK120002403/ECK120000662': ['ECK120002403/E...
# 1832         1.0      0.0  {'ECK120002403/ECK120000662': ['ECK120002403/E...
#
#                                        genetic features  \
# 1763  [{'RegulonDB ID': 'ECK120001204/ECK120001253',...
# 1737  [{'RegulonDB ID': 'ECK120001204/ECK120001253',...
# 1738  [{'RegulonDB ID': 'ECK120001204/ECK120001253',...
# 1782  [{'RegulonDB ID': 'ECK120002403/ECK120000662',...
# 1832  [{'RegulonDB ID': 'ECK120002403/ECK120000662',...
#
#                                        genomic features index  isolate  \
# 1763  [{'name': 'leuLABCD attenuator terminator', 'R...    27      0.0
# 1737  [{'name': 'leuLABCD attenuator terminator', 'R...    27      0.0
# 1738  [{'name': 'leuLABCD attenuator terminator', 'R...    28      0.0
# 1782  [{'RegulonDB ID': 'ECK120002403/ECK120000662',...    81      0.0
# 1832  [{'RegulonDB ID': 'ECK120002403/ECK120000662',...   135      0.0
#
#       mutation size mutation target annotation nitrogen-source  \
# 1763            1.0                  leuA/leuL        NH4Cl(1)
# 1737            1.0                  leuA/leuL        NH4Cl(1)
# 1738            1.0                  leuA/leuL        NH4Cl(1)
# 1782            1.0                  matP/ompA        NH4Cl(1)
# 1832            1.0                  matP/ompA        NH4Cl(1)
#
#                                          operon links  \
# 1763  {'ECK120014726': ['ECK120001204/ECK120001253']}
# 1737  {'ECK120014726': ['ECK120001204/ECK120001253']}
# 1738  {'ECK120014726': ['ECK120001204/ECK120001253']}
# 1782                                               {}
# 1832                                               {}
#
#                                                 operons  oriC  \
# 1763  [{'name': 'leuLABCD', 'RegulonDB ID': 'ECK1200...   0.0
# 1737  [{'name': 'leuLABCD', 'RegulonDB ID': 'ECK1200...   0.0
# 1738  [{'name': 'leuLABCD', 'RegulonDB ID': 'ECK1200...   0.0
# 1782                                                 []   0.0
# 1832                                                 []   0.0
#
#                                           pathway links  \
# 1763  {'Valine, leucine and isoleucine biosynthesis'...
# 1737  {'Valine, leucine and isoleucine biosynthesis'...
# 1738  {'Valine, leucine and isoleucine biosynthesis'...
# 1782                                                 {}
# 1832                                                 {}
#
#                                                pathways phosphorous-source  \
# 1763  [{'name': 'Valine, leucine and isoleucine bios...          KH2PO4(3)
# 1737  [{'name': 'Valine, leucine and isoleucine bios...          KH2PO4(3)
# 1738  [{'name': 'Valine, leucine and isoleucine bios...          KH2PO4(3)
# 1782                                                 []          KH2PO4(3)
# 1832                                                 []          KH2PO4(3)
#
#       presence promoter  pseudogene               range  \
# 1763      0.50       {}         0.0      (83587, 83587)
# 1737      0.59       {}         0.0      (83587, 83587)
# 1738      0.59       {}         0.0      (83590, 83590)
# 1782      0.67       {}         0.0  (1018977, 1018977)
# 1832      0.56       {}         0.0  (1018983, 1018983)
#
#              regulator links  \
# 1763  {'LeuO': ['leuLABCD']}
# 1737  {'LeuO': ['leuLABCD']}
# 1738  {'LeuO': ['leuLABCD']}
# 1782                      {}
# 1832                      {}
#
#                                              regulators  repaired  \
# 1763  [{'name': 'LeuO', 'mutation set count': 4.0, '...       0.0
# 1737  [{'name': 'LeuO', 'mutation set count': 4.0, '...       0.0
# 1738  [{'name': 'LeuO', 'mutation set count': 4.0, '...       0.0
# 1782                                                 []       0.0
# 1832                                                 []       0.0
#
#      strain-description sulfur-source      supplement taxonomy-id  tech_rep  \
# 1763              BOP27   MgSO4(0.24)  trace elements      511145       1.0
# 1737              BOP27   MgSO4(0.24)  trace elements      511145       1.0
# 1738              BOP27   MgSO4(0.24)  trace elements      511145       1.0
# 1782              BOP27   MgSO4(0.24)  trace elements      511145       1.0
# 1832              BOP27   MgSO4(0.24)  trace elements      511145       1.0
#
#      temperature      terminator
# 1763  37 celsius  {ECK120034959}
# 1737  37 celsius  {ECK120034959}
# 1738  37 celsius  {ECK120034959}
# 1782  37 celsius              {}
# 1832  37 celsius              {}

# %%
# # Specific to the AVA publication
# muts_df = muts_df[muts_df["mutation target annotation"].str.contains("pnt")]
# muts_df

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
#     if "CRP" in r["regulator links"].keys():
#         temp_df = temp_df.append(r)
# muts_df = temp_df

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
#     if "GlpR" in r["regulator links"].keys():
#         temp_df = temp_df.append(r)
# muts_df = temp_df
# len(muts_df)

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
#     if "Mlc" in r["regulator links"].keys():
#         temp_df = temp_df.append(r)
# muts_df = temp_df
# len(muts_df)

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
# #     if "Nucleotide transport and metabolism" in r["COG links"].keys() \
#     if "cyaA" in r["RegulonDB Gene"]:
#         temp_df = temp_df.append(r)
# muts_df = temp_df
# len(muts_df)

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
#     if "Glycerolipid metabolism" in r["pathway links"].keys():
#         temp_df = temp_df.append(r)
# muts_df = temp_df
# len(muts_df)

# %%
# df = muts_df.copy()
# df["significantly associated condition set"] = df["significantly associated condition set"].apply(
#     lambda x: str(x))
# display(df["significantly associated condition set"].unique())


# # GYD
# muts_df = muts_df[
#     (muts_df["significantly associated condition set"]=={'glycerol(2.5)'})
#     | (muts_df["significantly associated condition set"]=={'glycerol(2.5)', "BOP27"})
# ]

# # SER
# # muts_df = muts_df[
# #     muts_df["significantly associated condition set"] == {'ΔsdaA ΔsdaB ΔtdcG ΔglyA', 'L-Serine'}]

# # # GLU
# # muts_df = muts_df[
# #     muts_df["significantly associated condition set"]=={'glucose(2)'}]



# # muts_df = muts_df[
# #     muts_df["significantly associated condition set"]==set()]


# # muts_df = muts_df[
# #     muts_df["significantly associated condition set"]=={'log', '511145', 'M9'}]


# display(len(muts_df), muts_df.head())

# %%
col_l = [
    "Mutation Type",
    "disrupt",
    "repaired",
    "genomic features",
    "genetic features",
    "genetic feature links",
    "operons",
    "operon links",
    "regulators",
    "regulator links",
    "COGs",
    "COG links",
    "pathways",
    "pathway links",
    "RegulonDB Gene"  # for debugging
]

annot_df = muts_df.copy()
annot_df = annot_df[col_l]
# annot_df["mutation effect"] = annot_df.apply(lambda mut_row:"repaired" if mut_row["repaired"] else ("disrupt" if mut_row["disrupt"] else "unknown"), axis=1)


display(annot_df.shape, annot_df.head())
# Out:
# (91, 15)
#      Mutation Type  disrupt  repaired  \
# 1763           SNP      0.0       0.0
# 1737           SNP      0.0       0.0
# 1738           SNP      0.0       0.0
# 1782           SNP      0.0       0.0
# 1832           SNP      0.0       0.0
#
#                                        genomic features  \
# 1763  [{'name': 'leuLABCD attenuator terminator', 'R...
# 1737  [{'name': 'leuLABCD attenuator terminator', 'R...
# 1738  [{'name': 'leuLABCD attenuator terminator', 'R...
# 1782  [{'RegulonDB ID': 'ECK120002403/ECK120000662',...
# 1832  [{'RegulonDB ID': 'ECK120002403/ECK120000662',...
#
#                                        genetic features  \
# 1763  [{'RegulonDB ID': 'ECK120001204/ECK120001253',...
# 1737  [{'RegulonDB ID': 'ECK120001204/ECK120001253',...
# 1738  [{'RegulonDB ID': 'ECK120001204/ECK120001253',...
# 1782  [{'RegulonDB ID': 'ECK120002403/ECK120000662',...
# 1832  [{'RegulonDB ID': 'ECK120002403/ECK120000662',...
#
#                                   genetic feature links  \
# 1763    {'ECK120001204/ECK120001253': ['ECK125143560']}
# 1737    {'ECK120001204/ECK120001253': ['ECK125143560']}
# 1738    {'ECK120001204/ECK120001253': ['ECK125143560']}
# 1782  {'ECK120002403/ECK120000662': ['ECK120002403/E...
# 1832  {'ECK120002403/ECK120000662': ['ECK120002403/E...
#
#                                                 operons  \
# 1763  [{'name': 'leuLABCD', 'RegulonDB ID': 'ECK1200...
# 1737  [{'name': 'leuLABCD', 'RegulonDB ID': 'ECK1200...
# 1738  [{'name': 'leuLABCD', 'RegulonDB ID': 'ECK1200...
# 1782                                                 []
# 1832                                                 []
#
#                                          operon links  \
# 1763  {'ECK120014726': ['ECK120001204/ECK120001253']}
# 1737  {'ECK120014726': ['ECK120001204/ECK120001253']}
# 1738  {'ECK120014726': ['ECK120001204/ECK120001253']}
# 1782                                               {}
# 1832                                               {}
#
#                                              regulators  \
# 1763  [{'name': 'LeuO', 'mutation set count': 4.0, '...
# 1737  [{'name': 'LeuO', 'mutation set count': 4.0, '...
# 1738  [{'name': 'LeuO', 'mutation set count': 4.0, '...
# 1782                                                 []
# 1832                                                 []
#
#              regulator links  \
# 1763  {'LeuO': ['leuLABCD']}
# 1737  {'LeuO': ['leuLABCD']}
# 1738  {'LeuO': ['leuLABCD']}
# 1782                      {}
# 1832                      {}
#
#                                                    COGs  \
# 1763  [{'name': 'Amino acid transport and metabolism...
# 1737  [{'name': 'Amino acid transport and metabolism...
# 1738  [{'name': 'Amino acid transport and metabolism...
# 1782                                                 []
# 1832                                                 []
#
#                                               COG links  \
# 1763  {'Amino acid transport and metabolism': ['ECK1...
# 1737  {'Amino acid transport and metabolism': ['ECK1...
# 1738  {'Amino acid transport and metabolism': ['ECK1...
# 1782                                                 {}
# 1832                                                 {}
#
#                                                pathways  \
# 1763  [{'name': 'Valine, leucine and isoleucine bios...
# 1737  [{'name': 'Valine, leucine and isoleucine bios...
# 1738  [{'name': 'Valine, leucine and isoleucine bios...
# 1782                                                 []
# 1832                                                 []
#
#                                           pathway links RegulonDB Gene
# 1763  {'Valine, leucine and isoleucine biosynthesis'...      leuA/leuL
# 1737  {'Valine, leucine and isoleucine biosynthesis'...      leuA/leuL
# 1738  {'Valine, leucine and isoleucine biosynthesis'...      leuA/leuL
# 1782                                                 {}      matP/ompA
# 1832                                                 {}      matP/ompA

# %%
# Just removing all "Function unknown" links since connections to this COG isn't useful.
for i, r in annot_df.iterrows():
    if "Function unknown" in r["COG links"].keys():
        del r["COG links"]["Function unknown"]

# %%
mut_type_feat_effect_counts = dict()
genomic_feat_counts = dict()
genetic_feat_counts = dict()
operon_counts = dict()
COG_counts = dict()
regulator_counts = dict()
pathway_counts = dict()
# Using the individual feature columns rather than link columns because this guarantees considering all linked and non-linked features
# for each of these levels, except genomic features.
for _, r in annot_df.iterrows():
    
    for genomic_feat in r["genomic features"]:
        
        # These are usually exclusive of each other per feature.
        # There is a design problem here: A multi-feature mutation could disrupt feature (gene) and repair another. Need to measure the predicted effect per feature rather than mutation to enable this (considering a design bug fix).
        effect = ""
        if r["disrupt"]: effect = "disrupt"
        if r["repaired"]: effect = "repair"
            
        mut_type_feat_effect = genomic_feat["name"] + ' ' + r["Mutation Type"] + ' ' + effect
        if mut_type_feat_effect not in mut_type_feat_effect_counts.keys():
            mut_type_feat_effect_counts[mut_type_feat_effect] = 0
        mut_type_feat_effect_counts[mut_type_feat_effect] += 1
    
    for genomic_feat in r["genomic features"]:
        genomic_feat_annot = genomic_feat["RegulonDB ID"] #+ ' ' + r["Mutation Type"]
        if genomic_feat_annot not in genomic_feat_counts.keys():
            genomic_feat_counts[genomic_feat_annot] = 0
        genomic_feat_counts[genomic_feat_annot] += 1

    for genetic_feat, links in r["genetic feature links"].items():
        if genetic_feat not in genetic_feat_counts.keys():
            genetic_feat_counts[genetic_feat] = 0
        genetic_feat_counts[genetic_feat] += len(links)

    # count the operons according to the amount of links from genes since an operon is only included if its gene is hit.
    for operon, links in r["operon links"].items():
        if operon not in operon_counts.keys():
            operon_counts[operon] = 0
        operon_counts[operon] += len(links)

    # count the COGs according to the amount of links from operons since a COG is only included if linked to a mutated operon (its genes)
    for COG, links in r["COG links"].items():
        if COG not in COG_counts.keys():
            COG_counts[COG] = 0
        COG_counts[COG] += len(links)
        
    for reg, links in r["regulator links"].items():
        if reg not in regulator_counts.keys():
            regulator_counts[reg] = 0
        regulator_counts[reg] += len(links)
        
    for pathway, links in r["pathway links"].items():
        if pathway not in pathway_counts.keys():
            pathway_counts[pathway] = 0
        pathway_counts[pathway] += len(links)

# %%
operon_df = pd.read_csv("./data/RegulonDB10/operon.txt", sep="\t", comment='#', header=None)
operon_df.columns = [
    "OPERON_ID",
    "OPERON_NAME",
    "FIRSTGENEPOSLEFT",
    "LASTGENEPOSRIGHT",
    "REGULATIONPOSLEFT",
    "REGULATIONPOSRIGHT",
    "OPERON_STRAND",
    "OPERON_INTERNAL_COMMENT",
    "KEY_ID_ORG"]
operon_df["range"] = operon_df.apply(lambda row: (row["REGULATIONPOSLEFT"], row["REGULATIONPOSRIGHT"]), axis=1)

# %%
# # For development. Delete when NB is stable.
# for _, r in annot_df.iterrows():
#     for genomic_feat_d in r["genomic features"]:
        
#         effect = ""
#         if r["disrupt"]: effect = "disrupt"
#         if r["repaired"]: effect = "repair"
            
#         mut_type_feat_effect = genomic_feat_d["name"] + ' ' + r["Mutation Type"] + ' ' + effect
#         mut_type_feat_effect = str(mut_type_feat_effect_counts[mut_type_feat_effect]) + ' ' + mut_type_feat_effect
            
#         genomic_feat_annot = ""
#         if genomic_feat_d["significant"]: genomic_feat_annot += "*"
#         genomic_feat_annot += str(genomic_feat_counts[genomic_feat_d["RegulonDB ID"]]) + ' '
#         genomic_feat_annot += str(genomic_feat_d["name"])
    
            
#         display(genomic_feat_annot + ' #### ' + mut_type_feat_effect)
# #         display(mut_type_feat_effect, "################################", r)

# %%
# operon names can be the same as a gene, which is problemmatic for floweaver
def _adjust_name_for_floweaver(operon):
    return operon + ' '


def _get_feat_d(json, RegulonDB_ID=None, name=None):
    feat_d = dict()
    for d in json:
        if (RegulonDB_ID and d["RegulonDB ID"] == RegulonDB_ID) or (name and d["name"] == name):
            feat_d = d
            break
    return feat_d


# Will probably have to put elsewhere at some point due to annotation work (count, significance)
mut_feat_effects = list()
genomic_feats = list()
genetic_feats = list()
operons = list()
COGs = list()
regulators = list()
pathways = list()


flow_df = pd.DataFrame()
for _, r in annot_df.iterrows():
    

    for genomic_feat_d in r["genomic features"]:
        
        effect = ""
        if r["disrupt"]: effect = "disrupt"
        if r["repaired"]: effect = "repair"    
        mut_type_feat_effect = genomic_feat_d["name"] + ' ' + r["Mutation Type"] + ' ' + effect
        mut_type_feat_effect = str(mut_type_feat_effect_counts[mut_type_feat_effect]) + ' ' + mut_type_feat_effect
        mut_feat_effects.append(mut_type_feat_effect)
            
        genomic_feat_annot = ""
        mut_count = genomic_feat_counts[genomic_feat_d["RegulonDB ID"]]
        if genomic_feat_d["significant"] and mut_count > 1: genomic_feat_annot += "*"
        genomic_feat_annot += str(mut_count) + ' '
        genomic_feat_annot += str(genomic_feat_d["name"])
        flow_row = {
            "source": genomic_feat_annot,
            "target": mut_type_feat_effect,
#                 "type": r["mutation effect"],
            "type": "unknown",
            "value": 1
        }
        flow_df = flow_df.append(flow_row, ignore_index=True)
        
    
    
    for genetic_feat_ID, genomic_feat_set in r["genetic feature links"].items():
        genetic_feat_d = _get_feat_d(RegulonDB_ID=genetic_feat_ID, json=r["genetic features"])
        genetic_feat_annot = ""
        mut_count = genetic_feat_counts[genetic_feat_ID]
        if genetic_feat_d["significant"] and mut_count > 1: genetic_feat_annot += "*"
        genetic_feat_annot += str(mut_count) + ' '
        genetic_feat_annot += str(genetic_feat_d["name"])
        genetic_feats.append(genetic_feat_annot)
        for genomic_feat_ID in genomic_feat_set:
            genomic_feat_d = _get_feat_d(RegulonDB_ID=genomic_feat_ID, json=r["genomic features"])
            k = genomic_feat_ID #+ ' ' + r["Mutation Type"]
            genomic_feat_annot = ""
            mut_count = genomic_feat_counts[k]
            if genomic_feat_d["significant"] and mut_count > 1: genomic_feat_annot += "*"
            genomic_feat_annot += str(mut_count) + ' '
            genomic_feat_annot += str(genomic_feat_d["name"]) #+ ' ' + r["Mutation Type"]
#             if r["disrupt"]: genomic_feat_annot += " disrupt"
#             if r["repaired"]: genomic_feat_annot += " repair"
            genomic_feats.append(genomic_feat_annot)
            flow_row = {
                "source": genetic_feat_annot,
                "target": genomic_feat_annot,
#                 "type": r["mutation effect"],
                "type": "unknown",
                "value": 1
            }
            flow_df = flow_df.append(flow_row, ignore_index=True)
    
    
    for operon_id, gen_targs in r["operon links"].items():
        operon_d = _get_feat_d(RegulonDB_ID=operon_id, json=r["operons"])
        operon_name = _adjust_name_for_floweaver(operon_d["name"])
        operon_annot = ""
        mut_count = operon_counts[operon_id]
        if operon_d["significant"] and mut_count > 1: operon_annot += "*"
        operon_annot += str(mut_count) + ' '
        operon_annot += operon_name
        operons.append(operon_annot)
        for genetic_feat_ID in gen_targs:
            genetic_feat_d = _get_feat_d(RegulonDB_ID=genetic_feat_ID, json=r["genetic features"])
            genetic_feat_annot = ""
            mut_count = genetic_feat_counts[genetic_feat_ID]
            if genetic_feat_d["significant"] and mut_count > 1: genetic_feat_annot += "*"
            genetic_feat_annot += str(mut_count) + ' '
            genetic_feat_annot += str(genetic_feat_d["name"])
            genetic_feats.append(genetic_feat_annot)
            flow_row = {
                "source": operon_annot,
                "target": genetic_feat_annot,
#                 "type": r["mutation effect"],
                "type": "unknown",
                "value": 1
            }
            flow_df = flow_df.append(flow_row, ignore_index=True)
            
            
    if FUNC_ANNOT == "pathway":
        for pathway, ops in r["pathway links"].items():
#             if pathway == "Glycerolipid metabolism":  # for GYD Glycerolipid metabolism.
            pathway_feat_d = _get_feat_d(name=pathway, json=r["pathways"])
            pathway_annot = ""
            mut_count = pathway_counts[pathway]
            if pathway_feat_d["significant"] and mut_count > 1: pathway_annot += "*"
            pathway_annot += str(mut_count) + ' ' + pathway_feat_d["name"]
            pathways.append(pathway_annot)
            for operon_id in ops:
                op_feat_d = _get_feat_d(RegulonDB_ID=operon_id, json=r["operons"])
                operon_name = operon_df[operon_df["OPERON_ID"]==operon].iloc[0]["OPERON_NAME"]
                operon_name = _adjust_name_for_floweaver(op_feat_d["name"])
                operon_annot = ""
                mut_count = operon_counts[op_feat_d["RegulonDB ID"]]
                if op_feat_d["significant"] and mut_count > 1: operon_annot += "*"
                operon_annot += str(mut_count) + ' '
                operon_annot += operon_name
                operons.append(operon_annot)
                flow_row = {
                    "source": pathway_annot,
                    "target": operon_annot,
#                     "type": r["mutation effect"],
                    "type": "unknown",
                    "value": 1
                }
                flow_df = flow_df.append(flow_row, ignore_index=True)
            
            
    if FUNC_ANNOT == "regulon":
        for regulator, ops in r["regulator links"].items():
#             if regulator == "CRP":  # for GYD CRP fig
#             if regulator == "GlpR":  # for GYD GlpR fig
#             if regulator == "Mlc":  # for GYD Mlc fig
            reg_feat_d = _get_feat_d(name=regulator, json=r["regulators"])
            reg_annot = ""
            mut_count = regulator_counts[regulator]
            if reg_feat_d["significant"] and mut_count > 1: reg_annot += "*"
            reg_annot += str(mut_count) + ' ' + reg_feat_d["name"]
            regulators.append(reg_annot)
            for operon_name in ops:
                op_feat_d = _get_feat_d(name=operon_name, json=r["operons"])
                operon_name = _adjust_name_for_floweaver(op_feat_d["name"])
                operon_annot = ""
                mut_count = operon_counts[op_feat_d["RegulonDB ID"]]
                if op_feat_d["significant"] and mut_count > 1: operon_annot += "*"
                operon_annot += str(mut_count) + ' '
                operon_annot += operon_name
                operons.append(operon_annot)
                flow_row = {
                    "source": reg_annot,
                    "target": operon_annot,
#                     "type": r["mutation effect"],
                    "type": "unknown",
                    "value": 1
                }
                flow_df = flow_df.append(flow_row, ignore_index=True)

                
    if FUNC_ANNOT == "COG":
        for COG, ops in r["COG links"].items():
#             if COG == "Nucleotide transport and metabolism":
            COG_feat_d = _get_feat_d(name=COG, json=r["COGs"])
            COG_annot = ""
            mut_count = COG_counts[COG]
            if COG_feat_d["significant"] and mut_count > 1: COG_annot += "*"
            COG_annot += str(mut_count) + ' ' + COG_feat_d["name"]
            COGs.append(COG_annot)
            for operon_id in ops:
                op_feat_d = _get_feat_d(RegulonDB_ID=operon_id, json=r["operons"])
                operon_name = operon_df[operon_df["OPERON_ID"]==operon].iloc[0]["OPERON_NAME"]
                operon_name = _adjust_name_for_floweaver(op_feat_d["name"])
                operon_annot = ""
                mut_count = operon_counts[op_feat_d["RegulonDB ID"]]
                if op_feat_d["significant"] and mut_count > 1: operon_annot += "*"
                operon_annot += str(mut_count) + ' '
                operon_annot += operon_name
                operons.append(operon_annot)
                flow_row = {
                    "source": COG_annot,
                    "target": operon_annot,
#                     "type": r["mutation effect"],
                    "type": "unknown",
                    "value": 1
                }
                flow_df = flow_df.append(flow_row, ignore_index=True)

    
display(flow_df[:20])
# Out:
#                                source                                 target  \
# 0   *3 leuLABCD attenuator terminator  3 leuLABCD attenuator terminator SNP
# 1                        *3 leuA/leuL      *3 leuLABCD attenuator terminator
# 2                         3 leuLABCD                            *3 leuA/leuL
# 3                              3 LeuO                            3 leuLABCD
# 4   *3 leuLABCD attenuator terminator  3 leuLABCD attenuator terminator SNP
# 5                        *3 leuA/leuL      *3 leuLABCD attenuator terminator
# 6                         3 leuLABCD                            *3 leuA/leuL
# 7                              3 LeuO                            3 leuLABCD
# 8   *3 leuLABCD attenuator terminator  3 leuLABCD attenuator terminator SNP
# 9                        *3 leuA/leuL      *3 leuLABCD attenuator terminator
# 10                        3 leuLABCD                            *3 leuA/leuL
# 11                             3 LeuO                            3 leuLABCD
# 12                       *3 matP/ompA                       3 matP/ompA SNP
# 13                       *3 matP/ompA                           *3 matP/ompA
# 14                       *3 matP/ompA                       3 matP/ompA SNP
# 15                       *3 matP/ompA                           *3 matP/ompA
# 16                       *3 matP/ompA                       3 matP/ompA SNP
# 17                       *3 matP/ompA                           *3 matP/ompA
# 18                *2 opgGH terminator                2 opgGH terminator SNP
# 19      *2 yceK attenuator terminator      2 yceK attenuator terminator SNP
#
#        type  value
# 0   unknown    1.0
# 1   unknown    1.0
# 2   unknown    1.0
# 3   unknown    1.0
# 4   unknown    1.0
# 5   unknown    1.0
# 6   unknown    1.0
# 7   unknown    1.0
# 8   unknown    1.0
# 9   unknown    1.0
# 10  unknown    1.0
# 11  unknown    1.0
# 12  unknown    1.0
# 13  unknown    1.0
# 14  unknown    1.0
# 15  unknown    1.0
# 16  unknown    1.0
# 17  unknown    1.0
# 18  unknown    1.0
# 19  unknown    1.0

# %%
# Specific to the GYD fig of the AVA paper.
flow_df = flow_df[~(flow_df["target"].str.contains("1 pdxK"))]

# %%
# processing to help a cleaner order of features.
# remove duplicates but maintains the order established above
def remove_duplicates(feats):
    l = list()
    for x in feats:
        if x not in l:
            l.append(x)
    return l

mut_feat_effects = remove_duplicates(mut_feat_effects)
genomic_feats = remove_duplicates(genomic_feats)
genetic_feats = remove_duplicates(genetic_feats)
operons = remove_duplicates(operons)
pathways = remove_duplicates(pathways)
regulators = remove_duplicates(regulators)
COGs = remove_duplicates(COGs)

# %%
from ipysankeywidget import SankeyWidget
from floweaver import *


nodes = {
    "mutation": ProcessGroup(mut_feat_effects, title="mutation"),
    "genomic feature": ProcessGroup(genomic_feats, title="genomic feature"),
    "genetic feature": ProcessGroup(genetic_feats, title="genetic feature"),
    "operon": ProcessGroup(operons, title="operon"),
}

l = []
if FUNC_ANNOT == "pathway":
    l = pathways
if FUNC_ANNOT == "regulon":
    l = regulators
if FUNC_ANNOT == "COG":
    l = COGs
nodes[FUNC_ANNOT] = ProcessGroup(l, title=FUNC_ANNOT)


# !!! These partition DFs need to have accessible variables (ex: mut_type_partition) accessible external to the nodes
# otherwise floweaver will crash during its rendering step.
mutation_partition = Partition.Simple("process", mut_feat_effects)
nodes["mutation"].partition = mutation_partition

genomic_feat_partition = Partition.Simple("process", genomic_feats)
nodes["genomic feature"].partition = genomic_feat_partition

genetic_feat_partition = Partition.Simple("process", genetic_feats)
nodes["genetic feature"].partition = genetic_feat_partition

operon_partition = Partition.Simple("process", operons)
nodes["operon"].partition = operon_partition

nodes[FUNC_ANNOT].partition = Partition.Simple("process", l)


# The order that the labels is entered into the bundles is explicit. Don't arbitrarily give an order.
bundles = [
    Bundle(
        "genomic feature",
        "mutation"
    ),
    Bundle(
        "genetic feature",
        "genomic feature",
    ),
    Bundle(
        "operon",
        "genetic feature",
    ),
    Bundle(
        FUNC_ANNOT,
        "operon",
    ),
]


ordering = [
    [FUNC_ANNOT],
    ["operon"],
    ["genetic feature"],
    ["genomic feature"],
    ["mutation"]
]

#
# mut_effect_partition = Partition.Simple(
#     "type", ["unknown", "disrupt", "repaired"])
sdd = SankeyDefinition(nodes,
                       bundles,
                       ordering,
#                        flow_partition=mut_effect_partition
                      )


# p_d = {"disrupt": "#C44E52", "unknown": "#6BAAD3", "repaired": "#55A868"}
p_d = {"disrupt": "#6BAAD3", "unknown": "#6BAAD3", "repaired": "#6BAAD3"}
# size = dict(width=3000, height=4000)
size = dict(width=1500, height=1000)
# size = dict(width=1600, height=1000)
# size = dict(width=1350, height=800)
# size = dict(width=1600, height=500)
# size = dict(width=1100, height=300)
# size = dict(width=1350, height=300)
# size = dict(width=1000, height=200)
# size = dict(width=1200, height=300)  # for GYD GlpR mutflow fig
results = weave(sdd,
                flow_df,
                palette=p_d,
                ).to_widget(
    margins=dict(left=400, right=350),
    **size)
results.auto_save_svg("mutflow.svg")
results.auto_save_png("mutflow.png")
results
# Out:
# SankeyWidget(groups=[{'id': 'regulon', 'type': 'process', 'title': 'regulon', 'nodes': ['regulon^3 LeuO', 'reg…
