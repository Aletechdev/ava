# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
# FUNC_ANNOT = "pathway"
# FUNC_ANNOT = "COG"
FUNC_ANNOT = "regulon"

# %%
muts_df = pd.read_pickle("./data/GYD_df.pkl")
display(len(muts_df),
#         muts_df.head()
       )


# # Below are the COGs that got multiple hits with GYD
# '''
# Lipid transport and metabolism
# Cell cycle control, cell division, chromosome partitioning
# Transcription
# Amino acid transport and metabolism
# Secondary metabolites biosynthesis, transport and catabolism
# Cell wall/membrane/envelope biogenesis
# Posttranslational modification, protein turnover, chaperones
# Replication, recombination and repair
# Signal transduction mechanisms
# Cell motility
# Defense mechanisms
# Inorganic ion transport and metabolism
# Intracellular trafficking, secretion, and vesicular transport
# Coenzyme transport and metabolism
# Energy production and conversion
# Translation, ribosomal structure and biogenesis
# Carbohydrate transport and metabolism
# Nucleotide transport and metabolism
# '''


# out_df = pd.DataFrame()
# df = muts_df.copy()
# for _, r in df.iterrows():
#     for c in r["operons"]:
#         try:
#             # GYD
#             if "rpoB" in c["name"] or "rpoC" in c["name"] or "rph" in c["name"]:
#                 out_df = out_df.append(r, ignore_index=True)
#                 break
# #             if "ptsHI-crr" in c["name"]:
# #                 out_df = out_df.append(r, ignore_index=True)
# #                 break
#             # PGI
# #             if "pnt" in c["name"]:
# #                 out_df = out_df.append(r, ignore_index=True)
# #                 break
#         except:
#             print("feature annotation bug with", c)

# muts_df = out_df
# display(len(muts_df))
# Out:
# 148

# %%
# processing to help a cleaner order of features.
# sorts mutations by position so that mutations to proximal features will be inserted into flow_df next to each other.
muts_df = muts_df.sort_values(by="Position")
muts_df.head()
# Out:
#     index                  Details mutation target annotation Mutation Type  \
# 694     7    intergenic (+74/‑188)                  carB/caiF           DEL
# 712    27     intergenic (‑58/+35)                  leuA/leuL           SNP
# 686    27     intergenic (‑58/+35)                  leuA/leuL           SNP
# 687    28     intergenic (‑61/+32)                  leuA/leuL           SNP
# 675    44  coding (314‑317/597 nt)                       yadK           MOB
#
#      Position Reference Seq Sequence Change  ale  exp  flask  isolate  \
# 694     34112     NC_000913           Δ1 bp   12  GYD    114        0
# 712     83587     NC_000913             A→C   14  GYD     68        0
# 686     83587     NC_000913             A→C   10  GYD    106        0
# 687     83590     NC_000913             G→T   10  GYD    106        0
# 675    151283     NC_000913   IS5 (–) +4 bp    7  GYD    106        1
#
#      presence  tech_rep  coding             range gene RegulonDB ID  \
# 694      1.00         1   False    (34112, 34112)                {}
# 712      0.50         1   False    (83587, 83587)                {}
# 686      0.59         1   False    (83587, 83587)                {}
# 687      0.59         1   False    (83590, 83590)                {}
# 675      1.00         1    True  (151283, 151283)    {ECK120002200}
#
#                                       genetic features   oriC  pseudogene  \
# 694  [{'RegulonDB ID': 'ECK120000131/ECK120002708',...  False       False
# 712  [{'RegulonDB ID': 'ECK120001204/ECK120001253',...  False       False
# 686  [{'RegulonDB ID': 'ECK120001204/ECK120001253',...  False       False
# 687  [{'RegulonDB ID': 'ECK120001204/ECK120001253',...  False       False
# 675  [{'name': 'yadK', 'RegulonDB ID': 'ECK12000220...  False       False
#
#     TFBS promoter RBS attenuator terminator      terminator  genetic  \
# 694   {}       {}  {}                    {}  {ECK125257016}    False
# 712   {}       {}  {}        {ECK125143560}  {ECK120034959}    False
# 686   {}       {}  {}        {ECK125143560}  {ECK120034959}    False
# 687   {}       {}  {}        {ECK125143560}  {ECK120034959}    False
# 675   {}       {}  {}                    {}              {}     True
#
#                                       genomic features  \
# 694  [{'name': 'carAB terminator', 'RegulonDB ID': ...
# 712  [{'name': 'leuLABCD attenuator terminator', 'R...
# 686  [{'name': 'leuLABCD attenuator terminator', 'R...
# 687  [{'name': 'leuLABCD attenuator terminator', 'R...
# 675  [{'name': 'yadK', 'RegulonDB ID': 'ECK12000220...
#
#                                genetic feature links  \
# 694  {'ECK120000131/ECK120002708': ['ECK125257016']}
# 712  {'ECK120001204/ECK120001253': ['ECK125143560']}
# 686  {'ECK120001204/ECK120001253': ['ECK125143560']}
# 687  {'ECK120001204/ECK120001253': ['ECK125143560']}
# 675               {'ECK120002200': ['ECK120002200']}
#
#                                                operons  \
# 694  [{'name': 'carAB', 'RegulonDB ID': 'ECK1200149...
# 712  [{'name': 'leuLABCD', 'RegulonDB ID': 'ECK1200...
# 686  [{'name': 'leuLABCD', 'RegulonDB ID': 'ECK1200...
# 687  [{'name': 'leuLABCD', 'RegulonDB ID': 'ECK1200...
# 675  [{'name': 'yadMLKC', 'RegulonDB ID': 'ECK12003...
#
#                                         operon links  \
# 694  {'ECK120014911': ['ECK120000131/ECK120002708']}
# 712  {'ECK120014726': ['ECK120001204/ECK120001253']}
# 686  {'ECK120014726': ['ECK120001204/ECK120001253']}
# 687  {'ECK120014726': ['ECK120001204/ECK120001253']}
# 675               {'ECK120030520': ['ECK120002200']}
#
#                                             regulators  \
# 694  [{'name': 'ArgR', 'significantly associated co...
# 712  [{'name': 'LeuO', 'significantly associated co...
# 686  [{'name': 'LeuO', 'significantly associated co...
# 687  [{'name': 'LeuO', 'significantly associated co...
# 675                                                 []
#
#                                        regulator links temperature  \
# 694  {'Fis': ['carAB'], 'RutR': ['carAB'], 'IHF': [...  37 celsius
# 712                             {'LeuO': ['leuLABCD']}  37 celsius
# 686                             {'LeuO': ['leuLABCD']}  37 celsius
# 687                             {'LeuO': ['leuLABCD']}  37 celsius
# 675                                                 {}  37 celsius
#
#      carbon-source                   supplement strain-description  \
# 694  glycerol(2.5)  NaCl(0.5g/L) trace elements                 WT
# 712  glycerol(2.5)  NaCl(0.5g/L) trace elements                 WT
# 686  glycerol(2.5)  NaCl(0.5g/L) trace elements                 WT
# 687  glycerol(2.5)  NaCl(0.5g/L) trace elements                 WT
# 675  glycerol(2.5)  NaCl(0.5g/L) trace elements                 WT
#
#     taxonomy-id base-media nitrogen-source      phosphorous-source  \
# 694      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 712      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 686      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 687      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 675      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
#
#     sulfur-source calcium-source  \
# 694   MgSO4(0.24)     CaCl2(0.1)
# 712   MgSO4(0.24)     CaCl2(0.1)
# 686   MgSO4(0.24)     CaCl2(0.1)
# 687   MgSO4(0.24)     CaCl2(0.1)
# 675   MgSO4(0.24)     CaCl2(0.1)
#
#                                                   COGs  \
# 694  [{'name': 'Amino acid transport and metabolism...
# 712  [{'name': 'Amino acid transport and metabolism...
# 686  [{'name': 'Amino acid transport and metabolism...
# 687  [{'name': 'Amino acid transport and metabolism...
# 675  [{'name': 'Cell motility', 'mutation set count...
#
#                                              COG links  \
# 694  {'Amino acid transport and metabolism': ['ECK1...
# 712  {'Amino acid transport and metabolism': ['ECK1...
# 686  {'Amino acid transport and metabolism': ['ECK1...
# 687  {'Amino acid transport and metabolism': ['ECK1...
# 675                {'Cell motility': ['ECK120030520']}
#
#                                               pathways  \
# 694  [{'name': 'Pyrimidine metabolism', 'mutation s...
# 712  [{'name': 'Valine, leucine and isoleucine bios...
# 686  [{'name': 'Valine, leucine and isoleucine bios...
# 687  [{'name': 'Valine, leucine and isoleucine bios...
# 675                                                 []
#
#                                          pathway links
# 694  {'Pyrimidine metabolism': ['ECK120014911', 'EC...
# 712  {'Valine, leucine and isoleucine biosynthesis'...
# 686  {'Valine, leucine and isoleucine biosynthesis'...
# 687  {'Valine, leucine and isoleucine biosynthesis'...
# 675                                                 {}

# %%
# # Specific to the AVA publication
# muts_df = muts_df[muts_df["mutation target annotation"].str.contains("pnt")]
# muts_df

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
#     if "CRP" in r["regulator links"].keys():
#         temp_df = temp_df.append(r)
# muts_df = temp_df

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
#     if "GlpR" in r["regulator links"].keys():
#         temp_df = temp_df.append(r)
# muts_df = temp_df
# len(muts_df)

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
#     if "Mlc" in r["regulator links"].keys():
#         temp_df = temp_df.append(r)
# muts_df = temp_df
# len(muts_df)

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
# #     if "Nucleotide transport and metabolism" in r["COG links"].keys() \
#     if "crr" in r["RegulonDB Gene"]:
#         temp_df = temp_df.append(r)
# muts_df = temp_df
# len(muts_df)

# %%
muts_df.head()
# Out:
#     index                  Details mutation target annotation Mutation Type  \
# 694     7    intergenic (+74/‑188)                  carB/caiF           DEL
# 712    27     intergenic (‑58/+35)                  leuA/leuL           SNP
# 686    27     intergenic (‑58/+35)                  leuA/leuL           SNP
# 687    28     intergenic (‑61/+32)                  leuA/leuL           SNP
# 675    44  coding (314‑317/597 nt)                       yadK           MOB
#
#      Position Reference Seq Sequence Change  ale  exp  flask  isolate  \
# 694     34112     NC_000913           Δ1 bp   12  GYD    114        0
# 712     83587     NC_000913             A→C   14  GYD     68        0
# 686     83587     NC_000913             A→C   10  GYD    106        0
# 687     83590     NC_000913             G→T   10  GYD    106        0
# 675    151283     NC_000913   IS5 (–) +4 bp    7  GYD    106        1
#
#      presence  tech_rep  coding             range gene RegulonDB ID  \
# 694      1.00         1   False    (34112, 34112)                {}
# 712      0.50         1   False    (83587, 83587)                {}
# 686      0.59         1   False    (83587, 83587)                {}
# 687      0.59         1   False    (83590, 83590)                {}
# 675      1.00         1    True  (151283, 151283)    {ECK120002200}
#
#                                       genetic features   oriC  pseudogene  \
# 694  [{'RegulonDB ID': 'ECK120000131/ECK120002708',...  False       False
# 712  [{'RegulonDB ID': 'ECK120001204/ECK120001253',...  False       False
# 686  [{'RegulonDB ID': 'ECK120001204/ECK120001253',...  False       False
# 687  [{'RegulonDB ID': 'ECK120001204/ECK120001253',...  False       False
# 675  [{'name': 'yadK', 'RegulonDB ID': 'ECK12000220...  False       False
#
#     TFBS promoter RBS attenuator terminator      terminator  genetic  \
# 694   {}       {}  {}                    {}  {ECK125257016}    False
# 712   {}       {}  {}        {ECK125143560}  {ECK120034959}    False
# 686   {}       {}  {}        {ECK125143560}  {ECK120034959}    False
# 687   {}       {}  {}        {ECK125143560}  {ECK120034959}    False
# 675   {}       {}  {}                    {}              {}     True
#
#                                       genomic features  \
# 694  [{'name': 'carAB terminator', 'RegulonDB ID': ...
# 712  [{'name': 'leuLABCD attenuator terminator', 'R...
# 686  [{'name': 'leuLABCD attenuator terminator', 'R...
# 687  [{'name': 'leuLABCD attenuator terminator', 'R...
# 675  [{'name': 'yadK', 'RegulonDB ID': 'ECK12000220...
#
#                                genetic feature links  \
# 694  {'ECK120000131/ECK120002708': ['ECK125257016']}
# 712  {'ECK120001204/ECK120001253': ['ECK125143560']}
# 686  {'ECK120001204/ECK120001253': ['ECK125143560']}
# 687  {'ECK120001204/ECK120001253': ['ECK125143560']}
# 675               {'ECK120002200': ['ECK120002200']}
#
#                                                operons  \
# 694  [{'name': 'carAB', 'RegulonDB ID': 'ECK1200149...
# 712  [{'name': 'leuLABCD', 'RegulonDB ID': 'ECK1200...
# 686  [{'name': 'leuLABCD', 'RegulonDB ID': 'ECK1200...
# 687  [{'name': 'leuLABCD', 'RegulonDB ID': 'ECK1200...
# 675  [{'name': 'yadMLKC', 'RegulonDB ID': 'ECK12003...
#
#                                         operon links  \
# 694  {'ECK120014911': ['ECK120000131/ECK120002708']}
# 712  {'ECK120014726': ['ECK120001204/ECK120001253']}
# 686  {'ECK120014726': ['ECK120001204/ECK120001253']}
# 687  {'ECK120014726': ['ECK120001204/ECK120001253']}
# 675               {'ECK120030520': ['ECK120002200']}
#
#                                             regulators  \
# 694  [{'name': 'ArgR', 'significantly associated co...
# 712  [{'name': 'LeuO', 'significantly associated co...
# 686  [{'name': 'LeuO', 'significantly associated co...
# 687  [{'name': 'LeuO', 'significantly associated co...
# 675                                                 []
#
#                                        regulator links temperature  \
# 694  {'Fis': ['carAB'], 'RutR': ['carAB'], 'IHF': [...  37 celsius
# 712                             {'LeuO': ['leuLABCD']}  37 celsius
# 686                             {'LeuO': ['leuLABCD']}  37 celsius
# 687                             {'LeuO': ['leuLABCD']}  37 celsius
# 675                                                 {}  37 celsius
#
#      carbon-source                   supplement strain-description  \
# 694  glycerol(2.5)  NaCl(0.5g/L) trace elements                 WT
# 712  glycerol(2.5)  NaCl(0.5g/L) trace elements                 WT
# 686  glycerol(2.5)  NaCl(0.5g/L) trace elements                 WT
# 687  glycerol(2.5)  NaCl(0.5g/L) trace elements                 WT
# 675  glycerol(2.5)  NaCl(0.5g/L) trace elements                 WT
#
#     taxonomy-id base-media nitrogen-source      phosphorous-source  \
# 694      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 712      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 686      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 687      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 675      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
#
#     sulfur-source calcium-source  \
# 694   MgSO4(0.24)     CaCl2(0.1)
# 712   MgSO4(0.24)     CaCl2(0.1)
# 686   MgSO4(0.24)     CaCl2(0.1)
# 687   MgSO4(0.24)     CaCl2(0.1)
# 675   MgSO4(0.24)     CaCl2(0.1)
#
#                                                   COGs  \
# 694  [{'name': 'Amino acid transport and metabolism...
# 712  [{'name': 'Amino acid transport and metabolism...
# 686  [{'name': 'Amino acid transport and metabolism...
# 687  [{'name': 'Amino acid transport and metabolism...
# 675  [{'name': 'Cell motility', 'mutation set count...
#
#                                              COG links  \
# 694  {'Amino acid transport and metabolism': ['ECK1...
# 712  {'Amino acid transport and metabolism': ['ECK1...
# 686  {'Amino acid transport and metabolism': ['ECK1...
# 687  {'Amino acid transport and metabolism': ['ECK1...
# 675                {'Cell motility': ['ECK120030520']}
#
#                                               pathways  \
# 694  [{'name': 'Pyrimidine metabolism', 'mutation s...
# 712  [{'name': 'Valine, leucine and isoleucine bios...
# 686  [{'name': 'Valine, leucine and isoleucine bios...
# 687  [{'name': 'Valine, leucine and isoleucine bios...
# 675                                                 []
#
#                                          pathway links
# 694  {'Pyrimidine metabolism': ['ECK120014911', 'EC...
# 712  {'Valine, leucine and isoleucine biosynthesis'...
# 686  {'Valine, leucine and isoleucine biosynthesis'...
# 687  {'Valine, leucine and isoleucine biosynthesis'...
# 675                                                 {}

# %%
temp_df = pd.DataFrame()
for i, r in muts_df.iterrows():
    for o in r["operons"]:
        if "ptsHI-crr" in o["name"]:
#             display(o)
            temp_df = temp_df.append(r)
muts_df = temp_df
len(muts_df)
# Out:
# 11

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
#     if "Glycerolipid metabolism" in r["pathway links"].keys():
#         temp_df = temp_df.append(r)
# muts_df = temp_df
# len(muts_df)

# %%
# df = muts_df.copy()
# df["significantly associated condition set"] = df["significantly associated condition set"].apply(
#     lambda x: str(x))
# display(df["significantly associated condition set"].unique())


# # GYD
# muts_df = muts_df[
#     (muts_df["significantly associated condition set"]=={'glycerol(2.5)'})
#     | (muts_df["significantly associated condition set"]=={'glycerol(2.5)', "BOP27"})
# ]

# # SER
# # muts_df = muts_df[
# #     muts_df["significantly associated condition set"] == {'ΔsdaA ΔsdaB ΔtdcG ΔglyA', 'L-Serine'}]

# # # GLU
# # muts_df = muts_df[
# #     muts_df["significantly associated condition set"]=={'glucose(2)'}]



# # muts_df = muts_df[
# #     muts_df["significantly associated condition set"]==set()]


# # muts_df = muts_df[
# #     muts_df["significantly associated condition set"]=={'log', '511145', 'M9'}]


# display(len(muts_df), muts_df.head())

# %%
col_l = [
    "Mutation Type",
#     "disrupt",
#     "repaired",
    "genomic features",
    "genetic features",
    "genetic feature links",
    "operons",
    "operon links",
    "regulators",
    "regulator links",
    "COGs",
    "COG links",
    "pathways",
    "pathway links",
#     "RegulonDB Gene"  # for debugging
]

annot_df = muts_df.copy()
annot_df = annot_df[col_l]
# annot_df["mutation effect"] = annot_df.apply(lambda mut_row:"repaired" if mut_row["repaired"] else ("disrupt" if mut_row["disrupt"] else "unknown"), axis=1)


display(annot_df.shape, annot_df.head())
# Out:
# (11, 12)
#     Mutation Type                                   genomic features  \
# 637           SNP  [{'name': 'crr', 'RegulonDB ID': 'ECK120000161...
# 750           SNP  [{'name': 'crr', 'RegulonDB ID': 'ECK120000161...
# 732           SNP  [{'name': 'crr', 'RegulonDB ID': 'ECK120000161...
# 722           SNP  [{'name': 'crr', 'RegulonDB ID': 'ECK120000161...
# 729           SNP  [{'name': 'crr', 'RegulonDB ID': 'ECK120000161...
#
#                                       genetic features  \
# 637  [{'name': 'crr', 'RegulonDB ID': 'ECK120000161...
# 750  [{'name': 'crr', 'RegulonDB ID': 'ECK120000161...
# 732  [{'name': 'crr', 'RegulonDB ID': 'ECK120000161...
# 722  [{'name': 'crr', 'RegulonDB ID': 'ECK120000161...
# 729  [{'name': 'crr', 'RegulonDB ID': 'ECK120000161...
#
#                   genetic feature links  \
# 637  {'ECK120000161': ['ECK120000161']}
# 750  {'ECK120000161': ['ECK120000161']}
# 732  {'ECK120000161': ['ECK120000161']}
# 722  {'ECK120000161': ['ECK120000161']}
# 729  {'ECK120000161': ['ECK120000161']}
#
#                                                operons  \
# 637  [{'name': 'ptsHI-crr', 'RegulonDB ID': 'ECK120...
# 750  [{'name': 'ptsHI-crr', 'RegulonDB ID': 'ECK120...
# 732  [{'name': 'ptsHI-crr', 'RegulonDB ID': 'ECK120...
# 722  [{'name': 'ptsHI-crr', 'RegulonDB ID': 'ECK120...
# 729  [{'name': 'ptsHI-crr', 'RegulonDB ID': 'ECK120...
#
#                            operon links  \
# 637  {'ECK120014520': ['ECK120000161']}
# 750  {'ECK120014520': ['ECK120000161']}
# 732  {'ECK120014520': ['ECK120000161']}
# 722  {'ECK120014520': ['ECK120000161']}
# 729  {'ECK120014520': ['ECK120000161']}
#
#                                             regulators  \
# 637  [{'name': 'CRP', 'significantly associated con...
# 750  [{'name': 'CRP', 'significantly associated con...
# 732  [{'name': 'CRP', 'significantly associated con...
# 722  [{'name': 'CRP', 'significantly associated con...
# 729  [{'name': 'CRP', 'significantly associated con...
#
#                                        regulator links  \
# 637  {'CRP': ['ptsHI-crr'], 'Cra': ['ptsHI-crr'], '...
# 750  {'CRP': ['ptsHI-crr'], 'Cra': ['ptsHI-crr'], '...
# 732  {'CRP': ['ptsHI-crr'], 'Cra': ['ptsHI-crr'], '...
# 722  {'CRP': ['ptsHI-crr'], 'Cra': ['ptsHI-crr'], '...
# 729  {'CRP': ['ptsHI-crr'], 'Cra': ['ptsHI-crr'], '...
#
#                                                   COGs  \
# 637  [{'name': 'Carbohydrate transport and metaboli...
# 750  [{'name': 'Carbohydrate transport and metaboli...
# 732  [{'name': 'Carbohydrate transport and metaboli...
# 722  [{'name': 'Carbohydrate transport and metaboli...
# 729  [{'name': 'Carbohydrate transport and metaboli...
#
#                                              COG links pathways pathway links
# 637  {'Carbohydrate transport and metabolism': ['EC...       []            {}
# 750  {'Carbohydrate transport and metabolism': ['EC...       []            {}
# 732  {'Carbohydrate transport and metabolism': ['EC...       []            {}
# 722  {'Carbohydrate transport and metabolism': ['EC...       []            {}
# 729  {'Carbohydrate transport and metabolism': ['EC...       []            {}

# %%
# Just removing all "Function unknown" links since connections to this COG isn't useful.
for i, r in annot_df.iterrows():
    if "Function unknown" in r["COG links"].keys():
        del r["COG links"]["Function unknown"]

# %%
mut_type_feat_effect_counts = dict()
genomic_feat_counts = dict()
genetic_feat_counts = dict()
operon_counts = dict()
COG_counts = dict()
regulator_counts = dict()
pathway_counts = dict()
# Using the individual feature columns rather than link columns because this guarantees considering all linked and non-linked features
# for each of these levels, except genomic features.
for _, r in annot_df.iterrows():
    
    for genomic_feat in r["genomic features"]:
        
        # These are usually exclusive of each other per feature.
        # There is a design problem here: A multi-feature mutation could disrupt feature (gene) and repair another. Need to measure the predicted effect per feature rather than mutation to enable this (considering a design bug fix).
        effect = ""
#         if r["disrupt"]: effect = "disrupt"
#         if r["repaired"]: effect = "repair"
            
        mut_type_feat_effect = genomic_feat["name"] + ' ' + r["Mutation Type"] + ' ' + effect
        if mut_type_feat_effect not in mut_type_feat_effect_counts.keys():
            mut_type_feat_effect_counts[mut_type_feat_effect] = 0
        mut_type_feat_effect_counts[mut_type_feat_effect] += 1
    
    for genomic_feat in r["genomic features"]:
        genomic_feat_annot = genomic_feat["RegulonDB ID"] #+ ' ' + r["Mutation Type"]
        if genomic_feat_annot not in genomic_feat_counts.keys():
            genomic_feat_counts[genomic_feat_annot] = 0
        genomic_feat_counts[genomic_feat_annot] += 1

    for genetic_feat, links in r["genetic feature links"].items():
        if genetic_feat not in genetic_feat_counts.keys():
            genetic_feat_counts[genetic_feat] = 0
        genetic_feat_counts[genetic_feat] += len(links)

    # count the operons according to the amount of links from genes since an operon is only included if its gene is hit.
    for operon, links in r["operon links"].items():
        if operon not in operon_counts.keys():
            operon_counts[operon] = 0
        operon_counts[operon] += len(links)

    # count the COGs according to the amount of links from operons since a COG is only included if linked to a mutated operon (its genes)
    for COG, links in r["COG links"].items():
        if COG not in COG_counts.keys():
            COG_counts[COG] = 0
        COG_counts[COG] += len(links)
        
    for reg, links in r["regulator links"].items():
        if reg not in regulator_counts.keys():
            regulator_counts[reg] = 0
        regulator_counts[reg] += len(links)
        
    for pathway, links in r["pathway links"].items():
        if pathway not in pathway_counts.keys():
            pathway_counts[pathway] = 0
        pathway_counts[pathway] += len(links)

# %%
operon_df = pd.read_csv("./data/RegulonDB10/operon.txt", sep="\t", comment='#', header=None)
operon_df.columns = [
    "OPERON_ID",
    "OPERON_NAME",
    "FIRSTGENEPOSLEFT",
    "LASTGENEPOSRIGHT",
    "REGULATIONPOSLEFT",
    "REGULATIONPOSRIGHT",
    "OPERON_STRAND",
    "OPERON_INTERNAL_COMMENT",
    "KEY_ID_ORG"]
operon_df["range"] = operon_df.apply(lambda row: (row["REGULATIONPOSLEFT"], row["REGULATIONPOSRIGHT"]), axis=1)

# %%
# # For development. Delete when NB is stable.
# for _, r in annot_df.iterrows():
#     for genomic_feat_d in r["genomic features"]:
        
#         effect = ""
#         if r["disrupt"]: effect = "disrupt"
#         if r["repaired"]: effect = "repair"
            
#         mut_type_feat_effect = genomic_feat_d["name"] + ' ' + r["Mutation Type"] + ' ' + effect
#         mut_type_feat_effect = str(mut_type_feat_effect_counts[mut_type_feat_effect]) + ' ' + mut_type_feat_effect
            
#         genomic_feat_annot = ""
#         if genomic_feat_d["significantly enriched"]: genomic_feat_annot += "*"
#         genomic_feat_annot += str(genomic_feat_counts[genomic_feat_d["RegulonDB ID"]]) + ' '
#         genomic_feat_annot += str(genomic_feat_d["name"])
    
            
#         display(genomic_feat_annot + ' #### ' + mut_type_feat_effect)
# #         display(mut_type_feat_effect, "################################", r)

# %%
# operon names can be the same as a gene, which is problemmatic for floweaver
def _adjust_name_for_floweaver(operon):
    return operon + ' '


def _get_feat_d(json, RegulonDB_ID=None, name=None):
    feat_d = dict()
    for d in json:
        if (RegulonDB_ID and d["RegulonDB ID"] == RegulonDB_ID) or (name and d["name"] == name):
            feat_d = d
            break
    return feat_d


# Will probably have to put elsewhere at some point due to annotation work (count, significance)
mut_feat_effects = list()
genomic_feats = list()
genetic_feats = list()
operons = list()
COGs = list()
regulators = list()
pathways = list()


flow_df = pd.DataFrame()
for _, r in annot_df.iterrows():
    

    for genomic_feat_d in r["genomic features"]:
        
        effect = ""
#         if r["disrupt"]: effect = "disrupt"
#         if r["repaired"]: effect = "repair"    
        mut_type_feat_effect = genomic_feat_d["name"] + ' ' + r["Mutation Type"] + ' ' + effect
        mut_type_feat_effect = str(mut_type_feat_effect_counts[mut_type_feat_effect]) + ' ' + mut_type_feat_effect
        mut_feat_effects.append(mut_type_feat_effect)
            
        genomic_feat_annot = ""
        mut_count = genomic_feat_counts[genomic_feat_d["RegulonDB ID"]]
        if genomic_feat_d["significantly enriched"] and mut_count > 1: genomic_feat_annot += "*"
        genomic_feat_annot += str(mut_count) + ' '
        genomic_feat_annot += str(genomic_feat_d["name"])
        flow_row = {
            "source": genomic_feat_annot,
            "target": mut_type_feat_effect,
#                 "type": r["mutation effect"],
            "type": "unknown",
            "value": 1
        }
        flow_df = flow_df.append(flow_row, ignore_index=True)
        
    
    
    for genetic_feat_ID, genomic_feat_set in r["genetic feature links"].items():
        genetic_feat_d = _get_feat_d(RegulonDB_ID=genetic_feat_ID, json=r["genetic features"])
        genetic_feat_annot = ""
        mut_count = genetic_feat_counts[genetic_feat_ID]
        if genetic_feat_d["significantly enriched"] and mut_count > 1: genetic_feat_annot += "*"
        genetic_feat_annot += str(mut_count) + ' '
        genetic_feat_annot += str(genetic_feat_d["name"])
        genetic_feats.append(genetic_feat_annot)
        for genomic_feat_ID in genomic_feat_set:
            genomic_feat_d = _get_feat_d(RegulonDB_ID=genomic_feat_ID, json=r["genomic features"])
            k = genomic_feat_ID #+ ' ' + r["Mutation Type"]
            genomic_feat_annot = ""
            mut_count = genomic_feat_counts[k]
            if genomic_feat_d["significantly enriched"] and mut_count > 1: genomic_feat_annot += "*"
            genomic_feat_annot += str(mut_count) + ' '
            genomic_feat_annot += str(genomic_feat_d["name"]) #+ ' ' + r["Mutation Type"]
#             if r["disrupt"]: genomic_feat_annot += " disrupt"
#             if r["repaired"]: genomic_feat_annot += " repair"
            genomic_feats.append(genomic_feat_annot)
            flow_row = {
                "source": genetic_feat_annot,
                "target": genomic_feat_annot,
#                 "type": r["mutation effect"],
                "type": "unknown",
                "value": 1
            }
            flow_df = flow_df.append(flow_row, ignore_index=True)
    
    
    for operon_id, gen_targs in r["operon links"].items():
        operon_d = _get_feat_d(RegulonDB_ID=operon_id, json=r["operons"])
        operon_name = _adjust_name_for_floweaver(operon_d["name"])
        operon_annot = ""
        mut_count = operon_counts[operon_id]
        if operon_d["significantly enriched"] and mut_count > 1: operon_annot += "*"
        operon_annot += str(mut_count) + ' '
        operon_annot += operon_name
        operons.append(operon_annot)
        for genetic_feat_ID in gen_targs:
            genetic_feat_d = _get_feat_d(RegulonDB_ID=genetic_feat_ID, json=r["genetic features"])
            genetic_feat_annot = ""
            mut_count = genetic_feat_counts[genetic_feat_ID]
            if genetic_feat_d["significantly enriched"] and mut_count > 1: genetic_feat_annot += "*"
            genetic_feat_annot += str(mut_count) + ' '
            genetic_feat_annot += str(genetic_feat_d["name"])
            genetic_feats.append(genetic_feat_annot)
            flow_row = {
                "source": operon_annot,
                "target": genetic_feat_annot,
#                 "type": r["mutation effect"],
                "type": "unknown",
                "value": 1
            }
            flow_df = flow_df.append(flow_row, ignore_index=True)
            
            
    if FUNC_ANNOT == "pathway":
        for pathway, ops in r["pathway links"].items():
#             if pathway == "Glycerolipid metabolism":  # for GYD Glycerolipid metabolism.
            pathway_feat_d = _get_feat_d(name=pathway, json=r["pathways"])
            pathway_annot = ""
            mut_count = pathway_counts[pathway]
            if pathway_feat_d["significantly enriched"] and mut_count > 1: pathway_annot += "*"
            pathway_annot += str(mut_count) + ' ' + pathway_feat_d["name"]
            pathways.append(pathway_annot)
            for operon_id in ops:
                op_feat_d = _get_feat_d(RegulonDB_ID=operon_id, json=r["operons"])
                operon_name = operon_df[operon_df["OPERON_ID"]==operon].iloc[0]["OPERON_NAME"]
                operon_name = _adjust_name_for_floweaver(op_feat_d["name"])
                operon_annot = ""
                mut_count = operon_counts[op_feat_d["RegulonDB ID"]]
                if op_feat_d["significantly enriched"] and mut_count > 1: operon_annot += "*"
                operon_annot += str(mut_count) + ' '
                operon_annot += operon_name
                operons.append(operon_annot)
                flow_row = {
                    "source": pathway_annot,
                    "target": operon_annot,
#                     "type": r["mutation effect"],
                    "type": "unknown",
                    "value": 1
                }
                flow_df = flow_df.append(flow_row, ignore_index=True)
            
            
    if FUNC_ANNOT == "regulon":
        for regulator, ops in r["regulator links"].items():
#             if regulator == "CRP":  # for GYD CRP fig
#             if regulator == "GlpR":  # for GYD GlpR fig
#             if regulator == "Mlc":  # for GYD Mlc fig
            reg_feat_d = _get_feat_d(name=regulator, json=r["regulators"])
            reg_annot = ""
            mut_count = regulator_counts[regulator]
            if reg_feat_d["significantly enriched"] and mut_count > 1: reg_annot += "*"
            reg_annot += str(mut_count) + ' ' + reg_feat_d["name"]
            regulators.append(reg_annot)
            for operon_name in ops:
                op_feat_d = _get_feat_d(name=operon_name, json=r["operons"])
                operon_name = _adjust_name_for_floweaver(op_feat_d["name"])
                operon_annot = ""
                mut_count = operon_counts[op_feat_d["RegulonDB ID"]]
                if op_feat_d["significantly enriched"] and mut_count > 1: operon_annot += "*"
                operon_annot += str(mut_count) + ' '
                operon_annot += operon_name
                operons.append(operon_annot)
                flow_row = {
                    "source": reg_annot,
                    "target": operon_annot,
#                     "type": r["mutation effect"],
                    "type": "unknown",
                    "value": 1
                }
                flow_df = flow_df.append(flow_row, ignore_index=True)

                
    if FUNC_ANNOT == "COG":
        for COG, ops in r["COG links"].items():
#             if COG == "Nucleotide transport and metabolism":
            COG_feat_d = _get_feat_d(name=COG, json=r["COGs"])
            COG_annot = ""
            mut_count = COG_counts[COG]
            if COG_feat_d["significantly enriched"] and mut_count > 1: COG_annot += "*"
            COG_annot += str(mut_count) + ' ' + COG_feat_d["name"]
            COGs.append(COG_annot)
            for operon_id in ops:
                op_feat_d = _get_feat_d(RegulonDB_ID=operon_id, json=r["operons"])
                operon_name = operon_df[operon_df["OPERON_ID"]==operon].iloc[0]["OPERON_NAME"]
                operon_name = _adjust_name_for_floweaver(op_feat_d["name"])
                operon_annot = ""
                mut_count = operon_counts[op_feat_d["RegulonDB ID"]]
                if op_feat_d["significantly enriched"] and mut_count > 1: operon_annot += "*"
                operon_annot += str(mut_count) + ' '
                operon_annot += operon_name
                operons.append(operon_annot)
                flow_row = {
                    "source": COG_annot,
                    "target": operon_annot,
#                     "type": r["mutation effect"],
                    "type": "unknown",
                    "value": 1
                }
                flow_df = flow_df.append(flow_row, ignore_index=True)

    
display(flow_df[:20])
# Out:
#             source          target     type  value
# 0          *10 crr     10 crr SNP   unknown    1.0
# 1          *10 crr         *10 crr  unknown    1.0
# 2   *11 ptsHI-crr          *10 crr  unknown    1.0
# 3          *11 CRP  *11 ptsHI-crr   unknown    1.0
# 4           11 Cra  *11 ptsHI-crr   unknown    1.0
# 5          *11 Mlc  *11 ptsHI-crr   unknown    1.0
# 6         *11 NagC  *11 ptsHI-crr   unknown    1.0
# 7          *10 crr     10 crr SNP   unknown    1.0
# 8          *10 crr         *10 crr  unknown    1.0
# 9   *11 ptsHI-crr          *10 crr  unknown    1.0
# 10         *11 CRP  *11 ptsHI-crr   unknown    1.0
# 11          11 Cra  *11 ptsHI-crr   unknown    1.0
# 12         *11 Mlc  *11 ptsHI-crr   unknown    1.0
# 13        *11 NagC  *11 ptsHI-crr   unknown    1.0
# 14         *10 crr     10 crr SNP   unknown    1.0
# 15         *10 crr         *10 crr  unknown    1.0
# 16  *11 ptsHI-crr          *10 crr  unknown    1.0
# 17         *11 CRP  *11 ptsHI-crr   unknown    1.0
# 18          11 Cra  *11 ptsHI-crr   unknown    1.0
# 19         *11 Mlc  *11 ptsHI-crr   unknown    1.0

# %%
# processing to help a cleaner order of features.
# remove duplicates but maintains the order established above
def remove_duplicates(feats):
    l = list()
    for x in feats:
        if x not in l:
            l.append(x)
    return l

mut_feat_effects = remove_duplicates(mut_feat_effects)
genomic_feats = remove_duplicates(genomic_feats)
genetic_feats = remove_duplicates(genetic_feats)
operons = remove_duplicates(operons)
pathways = remove_duplicates(pathways)
regulators = remove_duplicates(regulators)
COGs = remove_duplicates(COGs)

# %%
from ipysankeywidget import SankeyWidget
from floweaver import *


nodes = {
    "mutation": ProcessGroup(mut_feat_effects, title="mutation"),
    "genomic feature": ProcessGroup(genomic_feats, title="genomic feature"),
    "genetic feature": ProcessGroup(genetic_feats, title="genetic feature"),
    "operon": ProcessGroup(operons, title="operon"),
}

l = []
if FUNC_ANNOT == "pathway":
    l = pathways
if FUNC_ANNOT == "regulon":
    l = regulators
if FUNC_ANNOT == "COG":
    l = COGs
nodes[FUNC_ANNOT] = ProcessGroup(l, title=FUNC_ANNOT)


# !!! These partition DFs need to have accessible variables (ex: mut_type_partition) accessible external to the nodes
# otherwise floweaver will crash during its rendering step.
mutation_partition = Partition.Simple("process", mut_feat_effects)
nodes["mutation"].partition = mutation_partition

genomic_feat_partition = Partition.Simple("process", genomic_feats)
nodes["genomic feature"].partition = genomic_feat_partition

genetic_feat_partition = Partition.Simple("process", genetic_feats)
nodes["genetic feature"].partition = genetic_feat_partition

operon_partition = Partition.Simple("process", operons)
nodes["operon"].partition = operon_partition

nodes[FUNC_ANNOT].partition = Partition.Simple("process", l)


# The order that the labels is entered into the bundles is explicit. Don't arbitrarily give an order.
bundles = [
    Bundle(
        "genomic feature",
        "mutation"
    ),
    Bundle(
        "genetic feature",
        "genomic feature",
    ),
    Bundle(
        "operon",
        "genetic feature",
    ),
    Bundle(
        FUNC_ANNOT,
        "operon",
    ),
]


ordering = [
    [FUNC_ANNOT],
    ["operon"],
    ["genetic feature"],
    ["genomic feature"],
    ["mutation"]
]

#
# mut_effect_partition = Partition.Simple(
#     "type", ["unknown", "disrupt", "repaired"])
sdd = SankeyDefinition(nodes,
                       bundles,
                       ordering,
#                        flow_partition=mut_effect_partition
                      )


# p_d = {"disrupt": "#C44E52", "unknown": "#6BAAD3", "repaired": "#55A868"}
p_d = {"disrupt": "#6BAAD3", "unknown": "#6BAAD3", "repaired": "#6BAAD3"}
size = dict(width=1200, height=200)
results = weave(sdd,
                flow_df,
                palette=p_d,
                ).to_widget(
    margins=dict(left=400, right=350),
    **size)
results.auto_save_svg("mutflow.svg")
results.auto_save_png("mutflow.png")
results
# Out:
# SankeyWidget(groups=[{'id': 'regulon', 'type': 'process', 'title': 'regulon', 'nodes': ['regulon^*11 CRP', 're…
