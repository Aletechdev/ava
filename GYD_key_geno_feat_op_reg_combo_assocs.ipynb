# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
GYD_key_geno_feat_assoc_odds = pd.read_pickle("./data/GYD_key_geno_feat_assoc_odds.pkl")
GYD_key_geno_feat_assoc_odds
# Out:
# condition                                           NaCl(0.5g/L) trace elements  \
# mutated features
# crr                                                                    2.152919
# cyaA                                                                   2.158561
# glpFKX TFBS                                                            0.000000
# glpK                                                                   2.162180
# glxK/allE                                                              0.000000
# hisLGDCBHAFI attenuator terminator                                     0.000000
# hnsp                                                                   0.000000
# leuLABCD attenuator terminator                                         0.000000
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...                     0.000000
# mstA/C0614                                                             0.000000
# opgGH terminator                                                       0.000000
# rpoB                                                                   1.617209
# rpsMKD-rpoA-rplQ terminator                                            0.000000
# yceK attenuator terminator                                             0.000000
# yhdNp                                                                  0.000000
#
# condition                                           glycerol(2.5)  37 celsius  \
# mutated features
# crr                                                     19.854978           0
# cyaA                                                    26.112210           0
# glpFKX TFBS                                             29.535645           0
# glpK                                                    31.520690           0
# glxK/allE                                               29.535645           0
# hisLGDCBHAFI attenuator terminator                      25.485022           0
# hnsp                                                     9.253680           0
# leuLABCD attenuator terminator                          21.669390           0
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...      29.535645           0
# mstA/C0614                                              29.535645           0
# opgGH terminator                                        29.535645           0
# rpoB                                                     0.000000           0
# rpsMKD-rpoA-rplQ terminator                             29.535645           0
# yceK attenuator terminator                              29.535645           0
# yhdNp                                                   29.535645           0
#
# condition                                           WT  511145  M9  NH4Cl(1)  \
# mutated features
# crr                                                  0       0   0         0
# cyaA                                                 0       0   0         0
# glpFKX TFBS                                          0       0   0         0
# glpK                                                 0       0   0         0
# glxK/allE                                            0       0   0         0
# hisLGDCBHAFI attenuator terminator                   0       0   0         0
# hnsp                                                 0       0   0         0
# leuLABCD attenuator terminator                       0       0   0         0
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...   0       0   0         0
# mstA/C0614                                           0       0   0         0
# opgGH terminator                                     0       0   0         0
# rpoB                                                 0       0   0         0
# rpsMKD-rpoA-rplQ terminator                          0       0   0         0
# yceK attenuator terminator                           0       0   0         0
# yhdNp                                                0       0   0         0
#
# condition                                           KH2PO4(3) Na2HPO4(6.8)  \
# mutated features
# crr                                                                      0
# cyaA                                                                     0
# glpFKX TFBS                                                              0
# glpK                                                                     0
# glxK/allE                                                                0
# hisLGDCBHAFI attenuator terminator                                       0
# hnsp                                                                     0
# leuLABCD attenuator terminator                                           0
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...                       0
# mstA/C0614                                                               0
# opgGH terminator                                                         0
# rpoB                                                                     0
# rpsMKD-rpoA-rplQ terminator                                              0
# yceK attenuator terminator                                               0
# yhdNp                                                                    0
#
# condition                                           MgSO4(0.24)  CaCl2(0.1)
# mutated features
# crr                                                           0           0
# cyaA                                                          0           0
# glpFKX TFBS                                                   0           0
# glpK                                                          0           0
# glxK/allE                                                     0           0
# hisLGDCBHAFI attenuator terminator                            0           0
# hnsp                                                          0           0
# leuLABCD attenuator terminator                                0           0
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...            0           0
# mstA/C0614                                                    0           0
# opgGH terminator                                              0           0
# rpoB                                                          0           0
# rpsMKD-rpoA-rplQ terminator                                   0           0
# yceK attenuator terminator                                    0           0
# yhdNp                                                         0           0

# %%
GYD_key_reg_assoc_odds = pd.read_pickle("./data/GYD_key_reg_assoc_odds.pkl")
GYD_key_reg_assoc_odds.index += " regulon"
GYD_key_reg_assoc_odds
# Out:
# condition         NaCl(0.5g/L) trace elements  glycerol(2.5)  37 celsius  WT  \
# mutated features
# CRP regulon                          0.000000       3.066811           0   0
# CspA regulon                         1.917600       6.190711           0   0
# GlpR regulon                         2.537002      30.877297           0   0
# Mlc regulon                          0.000000       9.024254           0   0
# NagC regulon                         1.490787       3.490577           0   0
#
# condition         511145  M9  NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)  MgSO4(0.24)  \
# mutated features
# CRP regulon            0   0         0                       0            0
# CspA regulon           0   0         0                       0            0
# GlpR regulon           0   0         0                       0            0
# Mlc regulon            0   0         0                       0            0
# NagC regulon           0   0         0                       0            0
#
# condition         CaCl2(0.1)
# mutated features
# CRP regulon                0
# CspA regulon               0
# GlpR regulon               0
# Mlc regulon                0
# NagC regulon               0

# %%
GYD_key_op_assoc_odds = pd.read_pickle("./data/GYD_key_operon_assoc_odds.pkl")
GYD_key_op_assoc_odds.index += " operon"
GYD_key_op_assoc_odds
# Out:
# condition            NaCl(0.5g/L) trace elements  glycerol(2.5)  37 celsius  \
# mutated features
# cyaA operon                             1.968394      23.554745           0
# glpFKX operon                           2.057905      30.503344           0
# hisLGDCBHAFI operon                     0.000000      18.058271           0
# hns operon                              0.000000       5.718900           0
# leuLABCD operon                         0.000000      11.105922           0
# ptsHI-crr operon                        2.049352      16.024893           0
# yceK operon                             0.000000      27.417379           0
# yhdN-zntR operon                        0.000000      17.620879           0
# ynaI operon                             0.000000      13.057725           0
#
# condition            WT  511145  M9  NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)  \
# mutated features
# cyaA operon           0       0   0         0                       0
# glpFKX operon         0       0   0         0                       0
# hisLGDCBHAFI operon   0       0   0         0                       0
# hns operon            0       0   0         0                       0
# leuLABCD operon       0       0   0         0                       0
# ptsHI-crr operon      0       0   0         0                       0
# yceK operon           0       0   0         0                       0
# yhdN-zntR operon      0       0   0         0                       0
# ynaI operon           0       0   0         0                       0
#
# condition            MgSO4(0.24)  CaCl2(0.1)
# mutated features
# cyaA operon                    0           0
# glpFKX operon                  0           0
# hisLGDCBHAFI operon            0           0
# hns operon                     0           0
# leuLABCD operon                0           0
# ptsHI-crr operon               0           0
# yceK operon                    0           0
# yhdN-zntR operon               0           0
# ynaI operon                    0           0

# %%
odds_df = pd.concat([
    GYD_key_geno_feat_assoc_odds,
    GYD_key_reg_assoc_odds,
    GYD_key_op_assoc_odds
])
odds_df
# Out:
# condition                                           NaCl(0.5g/L) trace elements  \
# mutated features
# crr                                                                    2.152919
# cyaA                                                                   2.158561
# glpFKX TFBS                                                            0.000000
# glpK                                                                   2.162180
# glxK/allE                                                              0.000000
# hisLGDCBHAFI attenuator terminator                                     0.000000
# hnsp                                                                   0.000000
# leuLABCD attenuator terminator                                         0.000000
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...                     0.000000
# mstA/C0614                                                             0.000000
# opgGH terminator                                                       0.000000
# rpoB                                                                   1.617209
# rpsMKD-rpoA-rplQ terminator                                            0.000000
# yceK attenuator terminator                                             0.000000
# yhdNp                                                                  0.000000
# CRP regulon                                                            0.000000
# CspA regulon                                                           1.917600
# GlpR regulon                                                           2.537002
# Mlc regulon                                                            0.000000
# NagC regulon                                                           1.490787
# cyaA operon                                                            1.968394
# glpFKX operon                                                          2.057905
# hisLGDCBHAFI operon                                                    0.000000
# hns operon                                                             0.000000
# leuLABCD operon                                                        0.000000
# ptsHI-crr operon                                                       2.049352
# yceK operon                                                            0.000000
# yhdN-zntR operon                                                       0.000000
# ynaI operon                                                            0.000000
#
# condition                                           glycerol(2.5)  37 celsius  \
# mutated features
# crr                                                     19.854978           0
# cyaA                                                    26.112210           0
# glpFKX TFBS                                             29.535645           0
# glpK                                                    31.520690           0
# glxK/allE                                               29.535645           0
# hisLGDCBHAFI attenuator terminator                      25.485022           0
# hnsp                                                     9.253680           0
# leuLABCD attenuator terminator                          21.669390           0
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...      29.535645           0
# mstA/C0614                                              29.535645           0
# opgGH terminator                                        29.535645           0
# rpoB                                                     0.000000           0
# rpsMKD-rpoA-rplQ terminator                             29.535645           0
# yceK attenuator terminator                              29.535645           0
# yhdNp                                                   29.535645           0
# CRP regulon                                              3.066811           0
# CspA regulon                                             6.190711           0
# GlpR regulon                                            30.877297           0
# Mlc regulon                                              9.024254           0
# NagC regulon                                             3.490577           0
# cyaA operon                                             23.554745           0
# glpFKX operon                                           30.503344           0
# hisLGDCBHAFI operon                                     18.058271           0
# hns operon                                               5.718900           0
# leuLABCD operon                                         11.105922           0
# ptsHI-crr operon                                        16.024893           0
# yceK operon                                             27.417379           0
# yhdN-zntR operon                                        17.620879           0
# ynaI operon                                             13.057725           0
#
# condition                                           WT  511145  M9  NH4Cl(1)  \
# mutated features
# crr                                                  0       0   0         0
# cyaA                                                 0       0   0         0
# glpFKX TFBS                                          0       0   0         0
# glpK                                                 0       0   0         0
# glxK/allE                                            0       0   0         0
# hisLGDCBHAFI attenuator terminator                   0       0   0         0
# hnsp                                                 0       0   0         0
# leuLABCD attenuator terminator                       0       0   0         0
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...   0       0   0         0
# mstA/C0614                                           0       0   0         0
# opgGH terminator                                     0       0   0         0
# rpoB                                                 0       0   0         0
# rpsMKD-rpoA-rplQ terminator                          0       0   0         0
# yceK attenuator terminator                           0       0   0         0
# yhdNp                                                0       0   0         0
# CRP regulon                                          0       0   0         0
# CspA regulon                                         0       0   0         0
# GlpR regulon                                         0       0   0         0
# Mlc regulon                                          0       0   0         0
# NagC regulon                                         0       0   0         0
# cyaA operon                                          0       0   0         0
# glpFKX operon                                        0       0   0         0
# hisLGDCBHAFI operon                                  0       0   0         0
# hns operon                                           0       0   0         0
# leuLABCD operon                                      0       0   0         0
# ptsHI-crr operon                                     0       0   0         0
# yceK operon                                          0       0   0         0
# yhdN-zntR operon                                     0       0   0         0
# ynaI operon                                          0       0   0         0
#
# condition                                           KH2PO4(3) Na2HPO4(6.8)  \
# mutated features
# crr                                                                      0
# cyaA                                                                     0
# glpFKX TFBS                                                              0
# glpK                                                                     0
# glxK/allE                                                                0
# hisLGDCBHAFI attenuator terminator                                       0
# hnsp                                                                     0
# leuLABCD attenuator terminator                                           0
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...                       0
# mstA/C0614                                                               0
# opgGH terminator                                                         0
# rpoB                                                                     0
# rpsMKD-rpoA-rplQ terminator                                              0
# yceK attenuator terminator                                               0
# yhdNp                                                                    0
# CRP regulon                                                              0
# CspA regulon                                                             0
# GlpR regulon                                                             0
# Mlc regulon                                                              0
# NagC regulon                                                             0
# cyaA operon                                                              0
# glpFKX operon                                                            0
# hisLGDCBHAFI operon                                                      0
# hns operon                                                               0
# leuLABCD operon                                                          0
# ptsHI-crr operon                                                         0
# yceK operon                                                              0
# yhdN-zntR operon                                                         0
# ynaI operon                                                              0
#
# condition                                           MgSO4(0.24)  CaCl2(0.1)
# mutated features
# crr                                                           0           0
# cyaA                                                          0           0
# glpFKX TFBS                                                   0           0
# glpK                                                          0           0
# glxK/allE                                                     0           0
# hisLGDCBHAFI attenuator terminator                            0           0
# hnsp                                                          0           0
# leuLABCD attenuator terminator                                0           0
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...            0           0
# mstA/C0614                                                    0           0
# opgGH terminator                                              0           0
# rpoB                                                          0           0
# rpsMKD-rpoA-rplQ terminator                                   0           0
# yceK attenuator terminator                                    0           0
# yhdNp                                                         0           0
# CRP regulon                                                   0           0
# CspA regulon                                                  0           0
# GlpR regulon                                                  0           0
# Mlc regulon                                                   0           0
# NagC regulon                                                  0           0
# cyaA operon                                                   0           0
# glpFKX operon                                                 0           0
# hisLGDCBHAFI operon                                           0           0
# hns operon                                                    0           0
# leuLABCD operon                                               0           0
# ptsHI-crr operon                                              0           0
# yceK operon                                                   0           0
# yhdN-zntR operon                                              0           0
# ynaI operon                                                   0           0

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 100
sns.set_context("paper")
sns.set_style("white")

g = sns.clustermap(
    odds_df,
    linewidths=0.1,
#     cmap="coolwarm",
#     xticklabels=False,
#     yticklabels=False,
#     figsize=(2,4.5)
#     figsize=(4,2)
)

# Fix for recent matplotlib/seaborn issue
g.ax_heatmap.set_ylim(len(odds_df)+0, -0)

# g.cax.set_visible(False)
g.ax_row_dendrogram.set_visible(False)
g.ax_col_dendrogram.set_visible(False)

# g.fig.suptitle("Significantly mutated genetic features\nand their significantly associated conditions")
g.cax.set_title("odds\nratio")

g.ax_heatmap.set_title(
    "Overlap of associated conditions\nwith mutated genetic features",
)
# g.cax.yaxis.set_ticks_position("left")
g.ax_heatmap.yaxis.set_ticks_position("left")
# g.cax.yaxis.set_label_position("left")
g.ax_heatmap.yaxis.set_label_position("left")

# dendro_box = g.ax_row_dendrogram.get_position()
# dendro_box.x0-=0.2
# dendro_box.x1-=0.2
# g.cax.set_position(dendro_box)


# g.clustermap.set_xticklabels(
#     g.get_xticklabels(),
#     rotation=45,
#     horizontalalignment='right',
#     verticalalignment='center',
#     rotation_mode='anchor'
# )
# g.clustermap.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')
# g.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.setp(
    g.ax_heatmap.get_xticklabels(),
#         horizontalalignment='right',
#     verticalalignment='center',
#     rotation_mode='anchor',
    rotation=45
)
# plt.savefig("fig.svg", format="svg")
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# display(g.dendrogram_row.reordered_ind, g.dendrogram_col.reordered_ind)
l = list(odds_df.index[g.dendrogram_row.reordered_ind])
odds_df = odds_df.reindex(l)  # reorganizing rows

# %%
odds_df.columns
# Out:
# Index(['NaCl(0.5g/L) trace elements', 'glycerol(2.5)', '37 celsius', 'WT',
#        '511145', 'M9', 'NH4Cl(1)', 'KH2PO4(3) Na2HPO4(6.8)', 'MgSO4(0.24)',
#        'CaCl2(0.1)'],
#       dtype='object', name='condition')

# %%
# # in case I want to automatically wrap text.
# import numpy as np
# import textwrap
# mean_length = np.mean([len(i) for i in odds_df.columns])
# mean_length
# ["\n".join(textwrap.wrap(i,mean_length)) for i in odds_df.columns]


# odds_df = odds_df.set_axis(
# ['glycerol(2.5g/L) carbon\nsource',
#  '37 celsius',
#  'BOP27 starting strain',
#  'M9 minimal media',
#  'NH4Cl(1g/L) nitrogen\nsource',
#  'KH2PO4(2g/L) phosphorus\nsource',
#  'MgSO4(0.24g/L) sulfur\nsource'],
#     axis=1,
#     inplace=False
# )

# %%
conds_d = {
    'glycerol(2.5)': 'C',
    'WT': 'S',
    '37 celsius': 'T',
    'M9': "M",
    'NH4Cl(1)': 'N',
    'KH2PO4(3) Na2HPO4(6.8)': 'P',
    'MgSO4(0.24)': 'Su',
    'CaCl2(0.1)': 'Ca',
    '511145': 'O',
    "NaCl(0.5g/L) trace elements": 'Sp'
}


leg = 'C: glycerol(2.5g/L) carbon source\n' + \
    'S: WT starting strain\n' + \
    'T: 37 Celsius\n' + \
    'M: M9 minimal media\n' + \
    'N: NH4Cl(1g/L) nitrogen source\n' + \
    'P: KH2PO4(3g/L) & Na2HPO4(6.8g/L) phosphorus source\n' + \
    'Su: MgSO4(0.24g/L) sulfur source\n' + \
    'Ca: CaCl2(0.1g/L) calcium source\n' + \
    'O: $\it{E. coli}$ K-12 MG1655\n' + \
    'Sp: NaCl(0.5g/L) & trace elements'
leg
# Out:
# 'C: glycerol(2.5g/L) carbon source\nS: WT starting strain\nT: 37 Celsius\nM: M9 minimal media\nN: NH4Cl(1g/L) nitrogen source\nP: KH2PO4(3g/L) & Na2HPO4(6.8g/L) phosphorus source\nSu: MgSO4(0.24g/L) sulfur source\nCa: CaCl2(0.1g/L) calcium source\nO: $\\it{E. coli}$ K-12 MG1655\nSp: NaCl(0.5g/L) & trace elements'

# %%
df = odds_df.copy()
df = df.rename(columns=conds_d)
df
# Out:
# condition                                                 Sp          C  T  S  \
# mutated features
# hnsp                                                0.000000   9.253680  0  0
# Mlc regulon                                         0.000000   9.024254  0  0
# leuLABCD operon                                     0.000000  11.105922  0  0
# ynaI operon                                         0.000000  13.057725  0  0
# rpoB                                                1.617209   0.000000  0  0
# CRP regulon                                         0.000000   3.066811  0  0
# NagC regulon                                        1.490787   3.490577  0  0
# CspA regulon                                        1.917600   6.190711  0  0
# hns operon                                          0.000000   5.718900  0  0
# cyaA                                                2.158561  26.112210  0  0
# hisLGDCBHAFI attenuator terminator                  0.000000  25.485022  0  0
# yceK operon                                         0.000000  27.417379  0  0
# yhdNp                                               0.000000  29.535645  0  0
# yceK attenuator terminator                          0.000000  29.535645  0  0
# rpsMKD-rpoA-rplQ terminator                         0.000000  29.535645  0  0
# opgGH terminator                                    0.000000  29.535645  0  0
# mstA/C0614                                          0.000000  29.535645  0  0
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...  0.000000  29.535645  0  0
# glpFKX TFBS                                         0.000000  29.535645  0  0
# glxK/allE                                           0.000000  29.535645  0  0
# glpK                                                2.162180  31.520690  0  0
# GlpR regulon                                        2.537002  30.877297  0  0
# glpFKX operon                                       2.057905  30.503344  0  0
# leuLABCD attenuator terminator                      0.000000  21.669390  0  0
# cyaA operon                                         1.968394  23.554745  0  0
# crr                                                 2.152919  19.854978  0  0
# ptsHI-crr operon                                    2.049352  16.024893  0  0
# hisLGDCBHAFI operon                                 0.000000  18.058271  0  0
# yhdN-zntR operon                                    0.000000  17.620879  0  0
#
# condition                                           O  M  N  P  Su  Ca
# mutated features
# hnsp                                                0  0  0  0   0   0
# Mlc regulon                                         0  0  0  0   0   0
# leuLABCD operon                                     0  0  0  0   0   0
# ynaI operon                                         0  0  0  0   0   0
# rpoB                                                0  0  0  0   0   0
# CRP regulon                                         0  0  0  0   0   0
# NagC regulon                                        0  0  0  0   0   0
# CspA regulon                                        0  0  0  0   0   0
# hns operon                                          0  0  0  0   0   0
# cyaA                                                0  0  0  0   0   0
# hisLGDCBHAFI attenuator terminator                  0  0  0  0   0   0
# yceK operon                                         0  0  0  0   0   0
# yhdNp                                               0  0  0  0   0   0
# yceK attenuator terminator                          0  0  0  0   0   0
# rpsMKD-rpoA-rplQ terminator                         0  0  0  0   0   0
# opgGH terminator                                    0  0  0  0   0   0
# mstA/C0614                                          0  0  0  0   0   0
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...  0  0  0  0   0   0
# glpFKX TFBS                                         0  0  0  0   0   0
# glxK/allE                                           0  0  0  0   0   0
# glpK                                                0  0  0  0   0   0
# GlpR regulon                                        0  0  0  0   0   0
# glpFKX operon                                       0  0  0  0   0   0
# leuLABCD attenuator terminator                      0  0  0  0   0   0
# cyaA operon                                         0  0  0  0   0   0
# crr                                                 0  0  0  0   0   0
# ptsHI-crr operon                                    0  0  0  0   0   0
# hisLGDCBHAFI operon                                 0  0  0  0   0   0
# yhdN-zntR operon                                    0  0  0  0   0   0

# %%
# filtering for paper
df = df[df.index.isin([
    "CRP regulon", "GlpR regulon", "Mlc regulon", "NagC regulon",
    "glpFKX operon", "ptsHI-crr operon", "cyaA operon",
    "glpK", "cyaA", "crr",
])]
df
# Out:
# condition               Sp          C  T  S  O  M  N  P  Su  Ca
# mutated features
# Mlc regulon       0.000000   9.024254  0  0  0  0  0  0   0   0
# CRP regulon       0.000000   3.066811  0  0  0  0  0  0   0   0
# NagC regulon      1.490787   3.490577  0  0  0  0  0  0   0   0
# cyaA              2.158561  26.112210  0  0  0  0  0  0   0   0
# glpK              2.162180  31.520690  0  0  0  0  0  0   0   0
# GlpR regulon      2.537002  30.877297  0  0  0  0  0  0   0   0
# glpFKX operon     2.057905  30.503344  0  0  0  0  0  0   0   0
# cyaA operon       1.968394  23.554745  0  0  0  0  0  0   0   0
# crr               2.152919  19.854978  0  0  0  0  0  0   0   0
# ptsHI-crr operon  2.049352  16.024893  0  0  0  0  0  0   0   0

# %%
df = df.rename(index={
    'crr': '$\it{crr}$',
    'glpK': '$\it{glpK}$',
    'cyaA': '$\it{cyaA}$',
})

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.rcParams["figure.dpi"] = 100
sns.set_context("paper")
sns.set_style("white")

plt.figure(
#     figsize=(3, 3.5)
#     figsize=(6, 1.5)
#     figsize=(2.3, 4)
    figsize=(2.3, 2)
)

# re-ordering columns
l = df.columns.tolist()
l.remove("C")
l = ['C'] + l
df = df[l]
df = df.applymap(lambda v: np.log(v) if v > 0 else v)  # get log-odds


ax = sns.heatmap(
    df,
    linewidths=0.1,
#     cmap="coolwarm",
    cbar_kws={
        #         "shrink": 0.8,
        "label": "assocation\nlog odds ratio"
    }
)

plt.ylabel('key mutated\nfeatures')
plt.xlabel('conditions')

# fix for seaborn/matplotlib bug
b, t = plt.ylim()  # discover the values for bottom and top
b += 0.5  # Add 0.5 to the bottom
t -= 0.5  # Subtract 0.5 from the top
plt.ylim(b, t)  # update the ylim(bottom, top) values


bbox_props = dict(
    boxstyle="round",
    fc="w",
    ec="0.5",
    #     alpha=0.9
)
ax.annotate(
    leg,
#     xy=(-1.3, -1),
    xy=(-1, -1.3),
    xycoords='axes fraction',
    #             textcoords='offset points',
    #             size=14,
    bbox=bbox_props
)

ax.set_xticklabels(
    ax.get_xticklabels(),
    #     rotation=45,
    #     horizontalalignment='right',
    verticalalignment='center',
    #     rotation_mode='anchor'
    #     position='top'
)

# ax.xaxis.set_ticks_position('top')
# ax.xaxis.set_label_position('top')
ax.xaxis.set_ticks_position('top')
ax.tick_params(axis='y', which='both', length=0)
ax.tick_params(axis='x', which='both', length=2, top=False)

plt.savefig("./figs/f4b.svg", format="svg")
plt.show()

# %%
# # in case I want to automatically wrap text.
# import textwrap
# mean_length = np.mean([len(i) for i in odds_df.columns])
# mean_length
# ["\n".join(textwrap.wrap(i,mean_length)) for i in odds_df.columns]


odds_df = odds_df.rename(columns={
    'glycerol(2.5)': 'glycerol(2.5g/L)\ncarbon source',
    'BOP27': 'BOP27\nstarting strain',
    '37 celsius': '37 Celsius',
     'M9': "M9\nminimal media",
     'NH4Cl(1)': 'NH4Cl(1g/L)\nnitrogen source',
     'KH2PO4(2)': 'KH2PO4(2g/L)\nphosphorus source',
     'MgSO4(0.24)': 'MgSO4(0.24g/L)\nsulfur source'
})
odds_df
# Out:
# condition                                           NaCl(0.5g/L) trace elements  \
# mutated features
# hnsp                                                                   0.000000
# Mlc regulon                                                            0.000000
# leuLABCD operon                                                        0.000000
# ynaI operon                                                            0.000000
# rpoB                                                                   1.617209
# CRP regulon                                                            0.000000
# NagC regulon                                                           1.490787
# CspA regulon                                                           1.917600
# hns operon                                                             0.000000
# cyaA                                                                   2.158561
# hisLGDCBHAFI attenuator terminator                                     0.000000
# yceK operon                                                            0.000000
# yhdNp                                                                  0.000000
# yceK attenuator terminator                                             0.000000
# rpsMKD-rpoA-rplQ terminator                                            0.000000
# opgGH terminator                                                       0.000000
# mstA/C0614                                                             0.000000
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...                     0.000000
# glpFKX TFBS                                                            0.000000
# glxK/allE                                                              0.000000
# glpK                                                                   2.162180
# GlpR regulon                                                           2.537002
# glpFKX operon                                                          2.057905
# leuLABCD attenuator terminator                                         0.000000
# cyaA operon                                                            1.968394
# crr                                                                    2.152919
# ptsHI-crr operon                                                       2.049352
# hisLGDCBHAFI operon                                                    0.000000
# yhdN-zntR operon                                                       0.000000
#
# condition                                           glycerol(2.5g/L)\ncarbon source  \
# mutated features
# hnsp                                                                       9.253680
# Mlc regulon                                                                9.024254
# leuLABCD operon                                                           11.105922
# ynaI operon                                                               13.057725
# rpoB                                                                       0.000000
# CRP regulon                                                                3.066811
# NagC regulon                                                               3.490577
# CspA regulon                                                               6.190711
# hns operon                                                                 5.718900
# cyaA                                                                      26.112210
# hisLGDCBHAFI attenuator terminator                                        25.485022
# yceK operon                                                               27.417379
# yhdNp                                                                     29.535645
# yceK attenuator terminator                                                29.535645
# rpsMKD-rpoA-rplQ terminator                                               29.535645
# opgGH terminator                                                          29.535645
# mstA/C0614                                                                29.535645
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...                        29.535645
# glpFKX TFBS                                                               29.535645
# glxK/allE                                                                 29.535645
# glpK                                                                      31.520690
# GlpR regulon                                                              30.877297
# glpFKX operon                                                             30.503344
# leuLABCD attenuator terminator                                            21.669390
# cyaA operon                                                               23.554745
# crr                                                                       19.854978
# ptsHI-crr operon                                                          16.024893
# hisLGDCBHAFI operon                                                       18.058271
# yhdN-zntR operon                                                          17.620879
#
# condition                                           37 Celsius  WT  511145  \
# mutated features
# hnsp                                                         0   0       0
# Mlc regulon                                                  0   0       0
# leuLABCD operon                                              0   0       0
# ynaI operon                                                  0   0       0
# rpoB                                                         0   0       0
# CRP regulon                                                  0   0       0
# NagC regulon                                                 0   0       0
# CspA regulon                                                 0   0       0
# hns operon                                                   0   0       0
# cyaA                                                         0   0       0
# hisLGDCBHAFI attenuator terminator                           0   0       0
# yceK operon                                                  0   0       0
# yhdNp                                                        0   0       0
# yceK attenuator terminator                                   0   0       0
# rpsMKD-rpoA-rplQ terminator                                  0   0       0
# opgGH terminator                                             0   0       0
# mstA/C0614                                                   0   0       0
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...           0   0       0
# glpFKX TFBS                                                  0   0       0
# glxK/allE                                                    0   0       0
# glpK                                                         0   0       0
# GlpR regulon                                                 0   0       0
# glpFKX operon                                                0   0       0
# leuLABCD attenuator terminator                               0   0       0
# cyaA operon                                                  0   0       0
# crr                                                          0   0       0
# ptsHI-crr operon                                             0   0       0
# hisLGDCBHAFI operon                                          0   0       0
# yhdN-zntR operon                                             0   0       0
#
# condition                                           M9\nminimal media  \
# mutated features
# hnsp                                                                0
# Mlc regulon                                                         0
# leuLABCD operon                                                     0
# ynaI operon                                                         0
# rpoB                                                                0
# CRP regulon                                                         0
# NagC regulon                                                        0
# CspA regulon                                                        0
# hns operon                                                          0
# cyaA                                                                0
# hisLGDCBHAFI attenuator terminator                                  0
# yceK operon                                                         0
# yhdNp                                                               0
# yceK attenuator terminator                                          0
# rpsMKD-rpoA-rplQ terminator                                         0
# opgGH terminator                                                    0
# mstA/C0614                                                          0
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...                  0
# glpFKX TFBS                                                         0
# glxK/allE                                                           0
# glpK                                                                0
# GlpR regulon                                                        0
# glpFKX operon                                                       0
# leuLABCD attenuator terminator                                      0
# cyaA operon                                                         0
# crr                                                                 0
# ptsHI-crr operon                                                    0
# hisLGDCBHAFI operon                                                 0
# yhdN-zntR operon                                                    0
#
# condition                                           NH4Cl(1g/L)\nnitrogen source  \
# mutated features
# hnsp                                                                           0
# Mlc regulon                                                                    0
# leuLABCD operon                                                                0
# ynaI operon                                                                    0
# rpoB                                                                           0
# CRP regulon                                                                    0
# NagC regulon                                                                   0
# CspA regulon                                                                   0
# hns operon                                                                     0
# cyaA                                                                           0
# hisLGDCBHAFI attenuator terminator                                             0
# yceK operon                                                                    0
# yhdNp                                                                          0
# yceK attenuator terminator                                                     0
# rpsMKD-rpoA-rplQ terminator                                                    0
# opgGH terminator                                                               0
# mstA/C0614                                                                     0
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...                             0
# glpFKX TFBS                                                                    0
# glxK/allE                                                                      0
# glpK                                                                           0
# GlpR regulon                                                                   0
# glpFKX operon                                                                  0
# leuLABCD attenuator terminator                                                 0
# cyaA operon                                                                    0
# crr                                                                            0
# ptsHI-crr operon                                                               0
# hisLGDCBHAFI operon                                                            0
# yhdN-zntR operon                                                               0
#
# condition                                           KH2PO4(3) Na2HPO4(6.8)  \
# mutated features
# hnsp                                                                     0
# Mlc regulon                                                              0
# leuLABCD operon                                                          0
# ynaI operon                                                              0
# rpoB                                                                     0
# CRP regulon                                                              0
# NagC regulon                                                             0
# CspA regulon                                                             0
# hns operon                                                               0
# cyaA                                                                     0
# hisLGDCBHAFI attenuator terminator                                       0
# yceK operon                                                              0
# yhdNp                                                                    0
# yceK attenuator terminator                                               0
# rpsMKD-rpoA-rplQ terminator                                              0
# opgGH terminator                                                         0
# mstA/C0614                                                               0
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...                       0
# glpFKX TFBS                                                              0
# glxK/allE                                                                0
# glpK                                                                     0
# GlpR regulon                                                             0
# glpFKX operon                                                            0
# leuLABCD attenuator terminator                                           0
# cyaA operon                                                              0
# crr                                                                      0
# ptsHI-crr operon                                                         0
# hisLGDCBHAFI operon                                                      0
# yhdN-zntR operon                                                         0
#
# condition                                           MgSO4(0.24g/L)\nsulfur source  \
# mutated features
# hnsp                                                                            0
# Mlc regulon                                                                     0
# leuLABCD operon                                                                 0
# ynaI operon                                                                     0
# rpoB                                                                            0
# CRP regulon                                                                     0
# NagC regulon                                                                    0
# CspA regulon                                                                    0
# hns operon                                                                      0
# cyaA                                                                            0
# hisLGDCBHAFI attenuator terminator                                              0
# yceK operon                                                                     0
# yhdNp                                                                           0
# yceK attenuator terminator                                                      0
# rpsMKD-rpoA-rplQ terminator                                                     0
# opgGH terminator                                                                0
# mstA/C0614                                                                      0
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...                              0
# glpFKX TFBS                                                                     0
# glxK/allE                                                                       0
# glpK                                                                            0
# GlpR regulon                                                                    0
# glpFKX operon                                                                   0
# leuLABCD attenuator terminator                                                  0
# cyaA operon                                                                     0
# crr                                                                             0
# ptsHI-crr operon                                                                0
# hisLGDCBHAFI operon                                                             0
# yhdN-zntR operon                                                                0
#
# condition                                           CaCl2(0.1)
# mutated features
# hnsp                                                         0
# Mlc regulon                                                  0
# leuLABCD operon                                              0
# ynaI operon                                                  0
# rpoB                                                         0
# CRP regulon                                                  0
# NagC regulon                                                 0
# CspA regulon                                                 0
# hns operon                                                   0
# cyaA                                                         0
# hisLGDCBHAFI attenuator terminator                           0
# yceK operon                                                  0
# yhdNp                                                        0
# yceK attenuator terminator                                   0
# rpsMKD-rpoA-rplQ terminator                                  0
# opgGH terminator                                             0
# mstA/C0614                                                   0
# metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuat...           0
# glpFKX TFBS                                                  0
# glxK/allE                                                    0
# glpK                                                         0
# GlpR regulon                                                 0
# glpFKX operon                                                0
# leuLABCD attenuator terminator                               0
# cyaA operon                                                  0
# crr                                                          0
# ptsHI-crr operon                                             0
# hisLGDCBHAFI operon                                          0
# yhdN-zntR operon                                             0

# %%
odds_df = odds_df.set_axis(
['glycerol(2.5g/L) carbon\nsource',
 '37 celsius',
 'BOP27 starting strain',
 'M9 minimal media',
 'NH4Cl(1g/L) nitrogen\nsource',
 'KH2PO4(2g/L) phosphorus\nsource',
 'MgSO4(0.24g/L) sulfur\nsource',
 'CaCl2(0.1g/L) calcium source',
 "WT",
 "511145"
],
    axis=1,
    inplace=False
)

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 100
sns.set_context("paper")
sns.set_style("white")

plt.figure(
    figsize=(3, 3.5)
#     figsize=(6, 1.5)
#     figsize=(1.8, 1.5)
)
ax = sns.heatmap(
        odds_df.T,
    linewidths=0.1,
    cmap="coolwarm",
)

plt.xlabel('key mutated\nfeatures')
plt.ylabel('conditions')

# fix for seaborn/matplotlib bug
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values

ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right',
    verticalalignment='center',
    rotation_mode='anchor'
)

plt.savefig("fig.svg", format="svg")
plt.show()

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 100
sns.set_context("paper")
sns.set_style("white")

plt.figure(
#     figsize=(3, 3.5)
#     figsize=(6, 1.5)
    figsize=(7, 2)
)
ax = sns.heatmap(
    odds_df,
    linewidths=0.1,
    cmap="coolwarm",
)

plt.ylabel('key mutated\nfeatures')
plt.xlabel('conditions')

# fix for seaborn/matplotlib bug
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values

ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
#     horizontalalignment='right',
#     verticalalignment='center',
#     rotation_mode='anchor'
)

plt.savefig("fig.svg", format="svg")
plt.show()

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 100
sns.set_context("paper")
sns.set_style("white")

g = sns.clustermap(
    odds_df,
    linewidths=0.1,
    cmap="coolwarm",
#     xticklabels=False,
#     yticklabels=False,
#     figsize=(6,6)
#     figsize=(4,2)
)

# Fix for recent matplotlib/seaborn issue
g.ax_heatmap.set_ylim(len(odds_df)+0, -0)

# g.cax.set_visible(False)
g.ax_row_dendrogram.set_visible(False)
g.ax_col_dendrogram.set_visible(False)

# g.fig.suptitle("Significantly mutated genetic features\nand their significantly associated conditions")
g.cax.set_title("odds\nratio")

g.ax_heatmap.set_title(
    "Overlap of associated conditions\nwith mutated genetic features",
)
# g.cax.yaxis.set_ticks_position("left")
g.ax_heatmap.yaxis.set_ticks_position("left")
# g.cax.yaxis.set_label_position("left")
g.ax_heatmap.yaxis.set_label_position("left")

dendro_box = g.ax_row_dendrogram.get_position()
dendro_box.x0-=0.2
dendro_box.x1-=0.2
g.cax.set_position(dendro_box)


# g.clustermap.set_xticklabels(
#     g.get_xticklabels(),
#     rotation=45,
#     horizontalalignment='right',
#     verticalalignment='center',
#     rotation_mode='anchor'
# )
# g.clustermap.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')
# g.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.setp(
    g.ax_heatmap.get_xticklabels(),
#         horizontalalignment='right',
#     verticalalignment='center',
#     rotation_mode='anchor',
    rotation=45
)
# plt.savefig("fig.svg", format="svg")
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
