# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import pandas as pd
import seaborn as sns
from IPython.display import display
import os, sys, itertools, csv
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from util.gene import get_coding_genetic_target_len_d, get_intergenic_len_d
from util.genome import get_feature_hit_set
from util.params import ENRICH_ALPHA, MULTI_HYP_CORR_METHOD
pd.options.display.max_columns = 100

# %%
assoc_muts_df = pd.read_pickle("./data/6_df.pkl")
display(assoc_muts_df.shape, assoc_muts_df.head())
# Out:
# (46, 41)
#      index          Details mutation target annotation Mutation Type  \
# 1232     4  R121C (CGC→TGC)                       xylR           SNP
# 1233     5             None                        rph           DEL
# 1234     6  L770R (CTC→CGC)                       rpoC           SNP
# 1235     9  G164A (GGC→GCC)                       dnaG           SNP
# 1236     5             None                        rph           DEL
#
#       Position Reference Seq Sequence Change  ale      exp  flask  isolate  \
# 1232   3735339           NaN             C→T    1  SSW_XYL    116        1
# 1233   3815859           NaN          Δ82 bp    1  SSW_XYL    116        1
# 1234   4187658           NaN             T→G    1  SSW_XYL    116        1
# 1235   3211597           NaN             G→C    2  SSW_XYL    109        1
# 1236   3815859           NaN          Δ82 bp    2  SSW_XYL    109        1
#
#       presence  tech_rep  coding               range gene RegulonDB ID  \
# 1232       1.0         1    True  (3735339, 3735339)    {ECK120002449}
# 1233       1.0         1    True  (3815859, 3815940)    {ECK120000854}
# 1234       1.0         1    True  (4187658, 4187658)    {ECK120000886}
# 1235       1.0         1    True  (3211597, 3211597)    {ECK120000233}
# 1236       1.0         1    True  (3815859, 3815940)    {ECK120000854}
#
#                                        genetic features   oriC  pseudogene  \
# 1232  [{'name': 'xylR', 'RegulonDB ID': 'ECK12000244...  False       False
# 1233  [{'name': 'rph', 'RegulonDB ID': 'ECK120000854...  False       False
# 1234  [{'name': 'rpoC', 'RegulonDB ID': 'ECK12000088...  False       False
# 1235  [{'name': 'dnaG', 'RegulonDB ID': 'ECK12000023...  False       False
# 1236  [{'name': 'rph', 'RegulonDB ID': 'ECK120000854...  False       False
#
#      TFBS promoter RBS attenuator terminator terminator  genetic  \
# 1232   {}       {}  {}                    {}         {}     True
# 1233   {}       {}  {}        {ECK125144791}         {}     True
# 1234   {}       {}  {}                    {}         {}     True
# 1235   {}       {}  {}                    {}         {}     True
# 1236   {}       {}  {}        {ECK125144791}         {}     True
#
#                                        genomic features  \
# 1232  [{'name': 'xylR', 'RegulonDB ID': 'ECK12000244...
# 1233  [{'name': 'rph-pyrE attenuator terminator', 'R...
# 1234  [{'name': 'rpoC', 'RegulonDB ID': 'ECK12000088...
# 1235  [{'name': 'dnaG', 'RegulonDB ID': 'ECK12000023...
# 1236  [{'name': 'rph-pyrE attenuator terminator', 'R...
#
#                                   genetic feature links  \
# 1232                 {'ECK120002449': ['ECK120002449']}
# 1233  {'ECK120000854': ['ECK125144791', 'ECK12000085...
# 1234                 {'ECK120000886': ['ECK120000886']}
# 1235                 {'ECK120000233': ['ECK120000233']}
# 1236  {'ECK120000854': ['ECK125144791', 'ECK12000085...
#
#                                                 operons  \
# 1232  [{'name': 'xylFGHR', 'RegulonDB ID': 'ECK12001...
# 1233  [{'name': 'rph-pyrE', 'RegulonDB ID': 'ECK1200...
# 1234  [{'name': 'rplKAJL-rpoBC', 'RegulonDB ID': 'EC...
# 1235  [{'name': 'rpsU-dnaG-rpoD', 'RegulonDB ID': 'E...
# 1236  [{'name': 'rph-pyrE', 'RegulonDB ID': 'ECK1200...
#
#                                            operon links  \
# 1232                 {'ECK120014482': ['ECK120002449']}
# 1233  {'ECK120014627': ['ECK120000854', 'ECK12000085...
# 1234                 {'ECK120016992': ['ECK120000886']}
# 1235                 {'ECK120014515': ['ECK120000233']}
# 1236  {'ECK120014627': ['ECK120000854', 'ECK12000085...
#
#                                              regulators  \
# 1232  [{'name': 'Fis', 'significantly associated con...
# 1233                                                 []
# 1234                                                 []
# 1235  [{'name': 'LexA', 'significantly associated co...
# 1236                                                 []
#
#                                         regulator links temperature  \
# 1232  {'ArcA': ['xylFGHR'], 'Fis': ['xylFGHR'], 'CRP...  37 celsius
# 1233                                                 {}  37 celsius
# 1234                                                 {}  37 celsius
# 1235                       {'LexA': ['rpsU-dnaG-rpoD']}  37 celsius
# 1236                                                 {}  37 celsius
#
#      carbon-source                   supplement strain-description  \
# 1232     xylose(4)  NaCl(0.5g/L) trace elements                 WT
# 1233     xylose(4)  NaCl(0.5g/L) trace elements                 WT
# 1234     xylose(4)  NaCl(0.5g/L) trace elements                 WT
# 1235     xylose(4)  NaCl(0.5g/L) trace elements                 WT
# 1236     xylose(4)  NaCl(0.5g/L) trace elements                 WT
#
#      taxonomy-id base-media nitrogen-source      phosphorous-source  \
# 1232      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 1233      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 1234      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 1235      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 1236      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
#
#      sulfur-source calcium-source
# 1232   MgSO4(0.24)     CaCl2(0.1)
# 1233   MgSO4(0.24)     CaCl2(0.1)
# 1234   MgSO4(0.24)     CaCl2(0.1)
# 1235   MgSO4(0.24)     CaCl2(0.1)
# 1236   MgSO4(0.24)     CaCl2(0.1)

# %% [markdown]
# # Build genetic feature links dictionary for mutflow

# %%
# # Now in NB 2.2.1. Remove cell becuause obsolete
# def get_genetic_links_d(mut_row):
#     gen_trgt_d = dict()
#     feat_df = pd.DataFrame()
#     for feat_d in mut_row["genomic features"]:
#         feat_df = feat_df.append(feat_d, ignore_index=True)
#     for gen_trgt in mut_row["genetic features"]:
#         gen_trgt_d[gen_trgt["RegulonDB ID"]] = list(get_feature_hit_set(gen_trgt["range"], feat_df, "range", "RegulonDB ID"))
#     return gen_trgt_d


# assoc_muts_df["genetic feature links"] = assoc_muts_df.apply(get_genetic_links_d, axis=1)
# assoc_muts_df.head()

# %% [markdown]
# # Significance study (level specific)

# %%
from util.feature import get_feat_mut_cnt_df_from_links
comp_mut_df = get_feat_mut_cnt_df_from_links(assoc_muts_df, "genetic features", "genetic feature links")
comp_mut_df
# Out:
#                           length observed mutation count          name
# ECK120002449                1179                       2          xylR
# ECK120000854                 687                       8           rph
# ECK120000799/ECK120000854     94                       4      pyrE/rph
# ECK120000886                4224                       3          rpoC
# ECK120000233                1746                       1          dnaG
# ECK120000306/ECK120000302    481                       1     fimE/fimA
# ECK120003856                1227                       1          eutH
# ECK120000884                 990                       1          rpoA
# ECK120000836                1260                       2           rho
# ECK120002968                 879                       1          ybeX
# ECK120001482/ECK120003236    367                       1     fabI/ycjD
# ECK120003419                 753                       1          ydfT
# ECK120003483                1257                       1          ydhQ
# ECK120003517                 291                       1          ydiZ
# ECK120000314/ECK120023915    320                       1  flhD/insAB-5
# ECK120003650                7077                       1          yeeJ
# ECK120003717                 819                       1          yegX
# ECK120000151                1992                       1          cirA
# ECK120001303                 627                       1           upp
# ECK120000618                2562                       1          mutS
# ECK120004006/ECK120048867    138                       1     queE/yqcG
# ECK120004153                2352                       1          ygjK
# ECK120004210                 987                       1          kdsD
# ECK120004250                1197                       1          gspF
# ECK120000534                1278                       1          livM
# ECK120001473/ECK120000838    202                       1     nikR/rhsB
# ECK120000838                4236                       3          rhsB
# ECK120001887                1656                       1          lldP
# ECK120001669                1452                       1          viaA
# ECK120002818                 834                       1          mhpR
# ECK120002823/ECK120002824    187                       1     frmR/yaiO
# ECK120001769                 711                       1          yihL
# ECK120001866                1587                       1          pdeC
# ECK120002314                1026                       1          ytfT
# ECK120001368                1656                       1          treC
# ECK120002326                2292                       1          opgB
# ECK120002019/ECK120002018     90                       2     yjjG/prfC
# ECK120000840                4281                       1          rhsD

# %%
for _, r in assoc_muts_df.iterrows():
    for feat_d in r["genetic features"]:
        feat_d["mutation set count"] = comp_mut_df.loc[feat_d["RegulonDB ID"]]["observed mutation count"]

# %%
mutated_seq_len = np.sum(comp_mut_df["length"])

TOTAL_GENOME_LEN = 4641652
genome_remainder_len = TOTAL_GENOME_LEN - mutated_seq_len
df = pd.DataFrame([[0, genome_remainder_len]], columns=["observed mutation count", "length"], index=["genome remainder"])
comp_mut_df = comp_mut_df.append(df, sort=False)
total_seq_len = TOTAL_GENOME_LEN


comp_mut_df["proportion"] = comp_mut_df["length"].apply(lambda comp_len: comp_len/total_seq_len)
comp_mut_df.head()
# Out:
#                           length observed mutation count      name  proportion
# ECK120002449                1179                       2      xylR    0.000254
# ECK120000854                 687                       8       rph    0.000148
# ECK120000799/ECK120000854     94                       4  pyrE/rph    0.000020
# ECK120000886                4224                       3      rpoC    0.000910
# ECK120000233                1746                       1      dnaG    0.000376

# %%
from collections import Counter
comp_mut_df['equal or larger count'] = 0
component_l = comp_mut_df.index.tolist()
proportion_l = comp_mut_df["proportion"].tolist()
num_muts = np.sum(comp_mut_df["observed mutation count"])

# slides from UW speak about the relationship of permutations and precision.
# should read through them to get a sense of what is the least iterations that should execute.
num_itr = 10000
for i in range(0, num_itr):
    random_mut_comp_a = np.random.choice(
        a=component_l,
        size=num_muts,
        replace=True,
        p=proportion_l
    )
    random_mut_comp_count_d = Counter(random_mut_comp_a)
    for component in random_mut_comp_count_d.keys():
        if random_mut_comp_count_d[component] >= comp_mut_df.loc[component, 'observed mutation count']:
            comp_mut_df.loc[component, 'equal or larger count'] += 1

comp_mut_df["p value"] = comp_mut_df["equal or larger count"].apply(
    lambda count: count/num_itr)

comp_mut_df["significant"] = comp_mut_df["p value"].apply(lambda p_val: True if p_val < ENRICH_ALPHA else False)

display(comp_mut_df.head())
# Out:
#                           length observed mutation count      name  \
# ECK120002449                1179                       2      xylR
# ECK120000854                 687                       8       rph
# ECK120000799/ECK120000854     94                       4  pyrE/rph
# ECK120000886                4224                       3      rpoC
# ECK120000233                1746                       1      dnaG
#
#                            proportion  equal or larger count  p value  \
# ECK120002449                 0.000254                      1   0.0001
# ECK120000854                 0.000148                      0   0.0000
# ECK120000799/ECK120000854    0.000020                      0   0.0000
# ECK120000886                 0.000910                      0   0.0000
# ECK120000233                 0.000376                    198   0.0198
#
#                            significant
# ECK120002449                      True
# ECK120000854                      True
# ECK120000799/ECK120000854         True
# ECK120000886                      True
# ECK120000233                      True

# %%
from statsmodels.stats import multitest
pvals = comp_mut_df["p value"]
rejects, pvals_corrected, alphacSidak, alphacBonf = multitest.multipletests(
    pvals=pvals,
    alpha=ENRICH_ALPHA,
    method=MULTI_HYP_CORR_METHOD)

pd.options.display.max_rows = 500
comp_mut_df["corrected p value"] = pvals_corrected
comp_mut_df["corrected significance"] = rejects
comp_mut_df.head()
# Out:
#                           length observed mutation count      name  \
# ECK120002449                1179                       2      xylR
# ECK120000854                 687                       8       rph
# ECK120000799/ECK120000854     94                       4  pyrE/rph
# ECK120000886                4224                       3      rpoC
# ECK120000233                1746                       1      dnaG
#
#                            proportion  equal or larger count  p value  \
# ECK120002449                 0.000254                      1   0.0001
# ECK120000854                 0.000148                      0   0.0000
# ECK120000799/ECK120000854    0.000020                      0   0.0000
# ECK120000886                 0.000910                      0   0.0000
# ECK120000233                 0.000376                    198   0.0198
#
#                            significant  corrected p value  \
# ECK120002449                      True             0.0039
# ECK120000854                      True             0.0000
# ECK120000799/ECK120000854         True             0.0000
# ECK120000886                      True             0.0000
# ECK120000233                      True             0.7722
#
#                            corrected significance
# ECK120002449                                 True
# ECK120000854                                 True
# ECK120000799/ECK120000854                    True
# ECK120000886                                 True
# ECK120000233                                False

# %%
# # not wanting to consider mutation events with only 1 features as being significant
# comp_mut_df["final significance"] = comp_mut_df.apply(lambda r: r["corrected significance"] if r["observed mutation count"] > 1 else False, axis=1)
# comp_mut_df.head()

# %%
for i, r in assoc_muts_df.iterrows():
    for d in r["genetic features"]:
        if d["RegulonDB ID"] in comp_mut_df.index:
            d["significantly enriched"] = comp_mut_df.loc[d["RegulonDB ID"]]["corrected significance"]
#             d["significant"] = comp_mut_df.loc[d["RegulonDB ID"]]["final significance"]

# %% [markdown]
# # Outputting dataframe for the next step in the pipeline

# %%
assoc_muts_df.to_pickle("./data/7_df.pkl")

# %%
# import seaborn as sns
# import matplotlib
# import matplotlib.pyplot as plt
# %matplotlib inline
# plt.rcParams["figure.dpi"] = 100
# sns.set_context("talk")
# sns.set_style("ticks")


# def _get_name_signif_from_ID(RegulonDB_ID, json):
#     name = ""
#     is_signif = False
#     for d in json:
#         if d["RegulonDB ID"] == RegulonDB_ID:
#             name = d["name"]
#             is_signif = d["significant"]
#             break
#     return (name, is_signif)


# # The reason we're using the links dictionary is because we want to count how genomic features were mutated for the genetic target.
# targ_cnt_d = dict()
# for _, r in assoc_muts_df.iterrows():
#     link_d = r["genetic feature links"]
#     for targ_ID, hits in link_d.items():
#         t, is_signif = _get_name_signif_from_ID(targ_ID, r["genetic features"])
#         t = str(t)
#         if is_signif:
#             t = '*' + t
#         if t not in targ_cnt_d.keys():
#             targ_cnt_d[t] = 0
#         targ_cnt_d[t] += len(hits)
        
# df = pd.DataFrame.from_dict(targ_cnt_d, orient='index', columns=["mutated feature count"])
# df = df.sort_values("mutated feature count")
# df = df[-20:]
# ax = df.plot.barh(y='mutated feature count',
# #                   figsize=(10,25),
#                   figsize=(5,10),
#                   color="#4C72B0",
#                   width=1
#                  )
# for i, v in enumerate(df["mutated feature count"]):
#     ax.text(v, i - 0.2, str(v))
# sns.despine(ax=ax, top=True, right=True)
# ax.set_title("Top 20 genetic mutated feature count")
# ax.get_legend().remove()
