# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
all_muts_df = pd.read_pickle("./data/4_df.pkl")
all_muts_df.shape
# Out:
# (3252, 43)

# %%
muts_df = all_muts_df[all_muts_df["mutation target annotation"].str.contains("hns")]
muts_df
# Out:
#      index                 Details mutation target annotation     Mut ID  \
# 89      87   intergenic (‑22/‑583)                    hns/tdk        NaN
# 137     87   intergenic (‑22/‑583)                    hns/tdk        NaN
# 191    156  intergenic (‑111/‑486)                    hns/tdk        NaN
# 218     20  intergenic (‑112/‑486)                    hns/tdk        NaN
# 226     26  intergenic (‑258/‑344)                    hns/tdk        NaN
# 231     31   intergenic (‑75/‑526)                    hns/tdk        NaN
# 1689   130   intergenic (‑93/‑505)                    hns/tdk  1105393.0
# 1720     4  intergenic (‑110/‑487)                    hns/tdk  1105412.0
# 1766    56   intergenic (‑66/‑531)                    hns/tdk  1103989.0
# 1781    97   intergenic (‑84/‑513)                    hns/tdk  1104819.0
# 1782   130   intergenic (‑93/‑505)                    hns/tdk  1105393.0
# 1804    20  intergenic (‑274/‑328)                    hns/tdk  1103648.0
# ...

# %%
for _, mut in muts_df.iterrows():
    for f in mut["genomic features"]:
        print(f['significantly associated conditions'])
# Out:
# set()
# set()
# set()
# {'U-13C glucose(2)'}
# {'U-13C glucose(2)'}
# {'U-13C glucose(2)'}
# set()
# {'glycerol(2.5)'}
# set()
# {'glycerol(2.5)'}
# {'glycerol(2.5)'}
# {'glycerol(2.5)'}
# set()
# set()
