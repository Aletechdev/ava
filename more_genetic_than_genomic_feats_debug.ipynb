# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = 100

# %%
all_muts_df = pd.read_pickle("./data/4_6_df.pkl")
display(all_muts_df.shape)
# Out:
# (1278, 41)

# %%
ssw_ac_mut_df = all_muts_df[all_muts_df["exp"]=="SSW_AC"]
ssw_ac_mut_df
# Out:
#     index                     Details mutation target annotation  \
# 869     1     coding (115‑120/360 nt)                       yeaR
# 870     2             V359I (GTC→ATC)                       fliK
# 871     3             D108E (GAT→GAA)                        glf
# 872     5       intergenic (+117/‑67)                  ebgR/ebgA
# 873     7  coding (1346‑1349/1416 nt)                       tnaA
# 874     8             R102C (CGC→TGC)                        rho
# 875    10     coding (494‑499/549 nt)                       fimA
# 876    12              E71* (GAA→TAA)                       flgD
# 877    13         intergenic (‑12/+1)                  cspC/yobF
# 878    15          coding (39/462 nt)                       yegJ
# 879    16             W124* (TGG→TAG)                       gcvT
# 880    17                        None                        rph
# 881    18             E298* (GAG→TAG)                       rsmC
# ...

# %%
for _, r in ssw_ac_mut_df.iterrows():
#     display(r)
    print("genomic", len(r["genomic features"]))
    for f in r["genomic features"]:
        print(f["name"])
        
    print("genetic", len(r["genetic features"]))
    for f in r["genetic features"]:
        print(f["name"],)
    print(r["genetic feature links"])
        
    print()
# Out:
# genomic 1
# yeaR
# genetic 1
# yeaR
# {'ECK120003570': ['ECK120003570']}
#
# genomic 1
# fliK
# genetic 1
# fliK
# {'ECK120002694': ['ECK120002694']}
#
# genomic 1
# glf
# genetic 1
# glf
# {'ECK120001906': ['ECK120001906']}
#
# genomic 1
# ebgAp
# genetic 1
# ebgR/ebgA
# {'ECK120000248/ECK120000246': ['ECK120011034']}
#
# genomic 1
# tnaA
# genetic 1
# tnaA
# {'ECK120000994': ['ECK120000994']}
#
# genomic 2
# rhoL-rho terminator
# rho
# genetic 1
# rho
# {'ECK120000836': ['ECK120034955', 'ECK120000836']}
#
# genomic 1
# fimA
# genetic 1
# fimA
# {'ECK120000302': ['ECK120000302']}
#
# genomic 1
# flgD
# genetic 1
# flgD
# {'ECK120002682': ['ECK120002682']}
#
# genomic 1
# cspC/yobF
# genetic 1
# cspC/yobF
# {'ECK120002092/ECK120003587': ['ECK120002092/ECK120003587']}
#
# genomic 1
# yegJ
# genetic 1
# yegJ
# {'ECK120003696': ['ECK120003696']}
#
# genomic 1
# gcvT
# genetic 1
# gcvT
# {'ECK120001406': ['ECK120001406']}
#
# genomic 2
# rph-pyrE attenuator terminator
# rph
# genetic 2
# ...
