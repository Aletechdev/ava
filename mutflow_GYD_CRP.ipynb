# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
# FUNC_ANNOT = "pathway"
# FUNC_ANNOT = "COG"
FUNC_ANNOT = "regulon"

# %%
muts_df = pd.read_pickle("./data/GYD_df.pkl")
display(len(muts_df),
#         muts_df.head()
       )


# out_df = pd.DataFrame()
# df = muts_df.copy()
# for _, r in df.iterrows():
#     for c in r["operons"]:
#         try:
#             # GYD
#             if "rpoB" in c["name"] or "rpoC" in c["name"] or "rph" in c["name"]:
#                 out_df = out_df.append(r, ignore_index=True)
#                 break
# #             if "ptsHI-crr" in c["name"]:
# #                 out_df = out_df.append(r, ignore_index=True)
# #                 break
#             # PGI
# #             if "pnt" in c["name"]:
# #                 out_df = out_df.append(r, ignore_index=True)
# #                 break
#         except:
#             print("feature annotation bug with", c)

# muts_df = out_df
# display(len(muts_df))
# Out:
# 163

# %%
# processing to help a cleaner order of features.
# sorts mutations by position so that mutations to proximal features will be inserted into flow_df next to each other.
muts_df = muts_df.sort_values(by="Position")
muts_df.head()
# Out:
#      index                  Details mutation target annotation     Mut ID  \
# 1133     7    intergenic (+74/‑188)                  carB/caiF  1105159.0
# 1151    27     intergenic (‑58/+35)                  leuA/leuL   317489.0
# 1125    27     intergenic (‑58/+35)                  leuA/leuL   317489.0
# 1126    28     intergenic (‑61/+32)                  leuA/leuL   317490.0
# 1114    44  coding (314‑317/597 nt)                       yadK  1108569.0
#
#      Mutation Type  Position Reference Seq Sequence Change  ale  exp  flask  \
# 1133           DEL     34112     NC_000913           Δ1 bp   12  GYD    114
# 1151           SNP     83587     NC_000913             A→C   14  GYD     68
# 1125           SNP     83587     NC_000913             A→C   10  GYD    106
# 1126           SNP     83590     NC_000913             G→T   10  GYD    106
# 1114           MOB    151283     NC_000913   IS5 (–) +4 bp    7  GYD    106
#
#       isolate  presence  tech_rep  coding             range gene RegulonDB ID  \
# 1133        0      1.00         1   False    (34112, 34112)                {}
# 1151        0      0.50         1   False    (83587, 83587)                {}
# 1125        0      0.59         1   False    (83587, 83587)                {}
# 1126        0      0.59         1   False    (83590, 83590)                {}
# 1114        1      1.00         1    True  (151283, 151283)    {ECK120002200}
#
#                                        genetic features   oriC  pseudogene  \
# 1133  [{'RegulonDB ID': 'ECK120000131/ECK120002708',...  False       False
# 1151  [{'RegulonDB ID': 'ECK120001204/ECK120001253',...  False       False
# 1125  [{'RegulonDB ID': 'ECK120001204/ECK120001253',...  False       False
# 1126  [{'RegulonDB ID': 'ECK120001204/ECK120001253',...  False       False
# 1114  [{'name': 'yadK', 'RegulonDB ID': 'ECK12000220...  False       False
#
#      TFBS promoter TSS RBS cis-regulatory RNA attenuator terminator  \
# 1133   {}       {}  {}  {}                 {}                    {}
# 1151   {}       {}  {}  {}     {ECK120001253}        {ECK125143560}
# 1125   {}       {}  {}  {}     {ECK120001253}        {ECK125143560}
# 1126   {}       {}  {}  {}     {ECK120001253}        {ECK125143560}
# 1114   {}       {}  {}  {}                 {}                    {}
#
#           terminator  genetic  \
# 1133  {ECK125257016}    False
# 1151  {ECK120034959}    False
# 1125  {ECK120034959}    False
# 1126  {ECK120034959}    False
# 1114              {}     True
#
#                                        genomic features  \
# 1133  [{'name': 'carAB terminator', 'RegulonDB ID': ...
# 1151  [{'name': 'leuLABCD attenuator terminator', 'R...
# 1125  [{'name': 'leuLABCD attenuator terminator', 'R...
# 1126  [{'name': 'leuLABCD attenuator terminator', 'R...
# 1114  [{'name': 'yadK', 'RegulonDB ID': 'ECK12000220...
#
#                                              regulators RegulonDB Gene  \
# 1133  [{'name': 'IHF', 'significantly associated con...      carB/caiF
# 1151  [{'name': 'LeuO', 'significantly associated co...      leuA/leuL
# 1125  [{'name': 'LeuO', 'significantly associated co...      leuA/leuL
# 1126  [{'name': 'LeuO', 'significantly associated co...      leuA/leuL
# 1114                                                 []           yadK
#
#       mutation size  gene count  disrupt  repaired taxonomy-id  \
# 1133              1           1    False     False      511145
# 1151              1           1    False     False      511145
# 1125              1           1    False     False      511145
# 1126              1           1    False     False      511145
# 1114              0           1     True     False      511145
#
#      strain-description base-media temperature  carbon-source nitrogen-source  \
# 1133              BOP27         M9  37 celsius  glycerol(2.5)        NH4Cl(1)
# 1151              BOP27         M9  37 celsius  glycerol(2.5)        NH4Cl(1)
# 1125              BOP27         M9  37 celsius  glycerol(2.5)        NH4Cl(1)
# 1126              BOP27         M9  37 celsius  glycerol(2.5)        NH4Cl(1)
# 1114              BOP27         M9  37 celsius  glycerol(2.5)        NH4Cl(1)
#
#      phosphorous-source sulfur-source      supplement  \
# 1133          KH2PO4(3)   MgSO4(0.24)  trace elements
# 1151          KH2PO4(3)   MgSO4(0.24)  trace elements
# 1125          KH2PO4(3)   MgSO4(0.24)  trace elements
# 1126          KH2PO4(3)   MgSO4(0.24)  trace elements
# 1114          KH2PO4(3)   MgSO4(0.24)  trace elements
#
#                                 genetic feature links  \
# 1133  {'ECK120000131/ECK120002708': ['ECK125257016']}
# 1151  {'ECK120001204/ECK120001253': ['ECK125143560']}
# 1125  {'ECK120001204/ECK120001253': ['ECK125143560']}
# 1126  {'ECK120001204/ECK120001253': ['ECK125143560']}
# 1114               {'ECK120002200': ['ECK120002200']}
#
#                                                 operons  \
# 1133  [{'name': 'carAB', 'RegulonDB ID': 'ECK1200149...
# 1151  [{'name': 'leuLABCD', 'RegulonDB ID': 'ECK1200...
# 1125  [{'name': 'leuLABCD', 'RegulonDB ID': 'ECK1200...
# 1126  [{'name': 'leuLABCD', 'RegulonDB ID': 'ECK1200...
# 1114  [{'name': 'yadMLKC', 'RegulonDB ID': 'ECK12003...
#
#                                          operon links  \
# 1133  {'ECK120014911': ['ECK120000131/ECK120002708']}
# 1151  {'ECK120014726': ['ECK120001204/ECK120001253']}
# 1125  {'ECK120014726': ['ECK120001204/ECK120001253']}
# 1126  {'ECK120014726': ['ECK120001204/ECK120001253']}
# 1114               {'ECK120030520': ['ECK120002200']}
#
#                                               imodulons  \
# 1133  [{'name': 'PurR-2', 'mutation set count': 2.0,...
# 1151  [{'name': 'Leu/Ile', 'mutation set count': 3.0...
# 1125  [{'name': 'Leu/Ile', 'mutation set count': 3.0...
# 1126  [{'name': 'Leu/Ile', 'mutation set count': 3.0...
# 1114                                                 []
#
#                                 imodulon links  \
# 1133  {'PurR-2': ['carAB'], 'ArgR': ['carAB']}
# 1151                 {'Leu/Ile': ['leuLABCD']}
# 1125                 {'Leu/Ile': ['leuLABCD']}
# 1126                 {'Leu/Ile': ['leuLABCD']}
# 1114                                        {}
#
#                                                    COGs  \
# 1133  [{'name': 'Amino acid transport and metabolism...
# 1151  [{'name': 'Amino acid transport and metabolism...
# 1125  [{'name': 'Amino acid transport and metabolism...
# 1126  [{'name': 'Amino acid transport and metabolism...
# 1114  [{'name': 'Cell motility', 'mutation set count...
#
#                                               COG links  \
# 1133  {'Amino acid transport and metabolism': ['ECK1...
# 1151  {'Amino acid transport and metabolism': ['ECK1...
# 1125  {'Amino acid transport and metabolism': ['ECK1...
# 1126  {'Amino acid transport and metabolism': ['ECK1...
# 1114                {'Cell motility': ['ECK120030520']}
#
#                                         regulator links  \
# 1133  {'PurR': ['carAB'], 'PepA': ['carAB'], 'Fis': ...
# 1151                             {'LeuO': ['leuLABCD']}
# 1125                             {'LeuO': ['leuLABCD']}
# 1126                             {'LeuO': ['leuLABCD']}
# 1114                                                 {}
#
#                                                pathways  \
# 1133  [{'name': 'Pyrimidine metabolism', 'mutation s...
# 1151  [{'name': 'Valine, leucine and isoleucine bios...
# 1125  [{'name': 'Valine, leucine and isoleucine bios...
# 1126  [{'name': 'Valine, leucine and isoleucine bios...
# 1114                                                 []
#
#                                           pathway links
# 1133  {'Pyrimidine metabolism': ['ECK120014911', 'EC...
# 1151  {'Valine, leucine and isoleucine biosynthesis'...
# 1125  {'Valine, leucine and isoleucine biosynthesis'...
# 1126  {'Valine, leucine and isoleucine biosynthesis'...
# 1114                                                 {}

# %%
# # Specific to the AVA publication
# muts_df = muts_df[muts_df["mutation target annotation"].str.contains("pnt")]
# muts_df

# %%
# Specific to the AVA publication
temp_df = pd.DataFrame()
for i, r in muts_df.iterrows():
    if "CRP" in r["regulator links"].keys():
        temp_df = temp_df.append(r)
muts_df = temp_df

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
#     if "GlpR" in r["regulator links"].keys():
#         temp_df = temp_df.append(r)
# muts_df = temp_df
# len(muts_df)

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
#     if "Mlc" in r["regulator links"].keys():
#         temp_df = temp_df.append(r)
# muts_df = temp_df
# len(muts_df)

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
# #     if "Nucleotide transport and metabolism" in r["COG links"].keys() \
#     if "cyaA" in r["RegulonDB Gene"]:
#         temp_df = temp_df.append(r)
# muts_df = temp_df
# len(muts_df)

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
#     if "Glycerolipid metabolism" in r["pathway links"].keys():
#         temp_df = temp_df.append(r)
# muts_df = temp_df
# len(muts_df)

# %%
# df = muts_df.copy()
# df["significantly associated condition set"] = df["significantly associated condition set"].apply(
#     lambda x: str(x))
# display(df["significantly associated condition set"].unique())


# # GYD
# muts_df = muts_df[
#     (muts_df["significantly associated condition set"]=={'glycerol(2.5)'})
#     | (muts_df["significantly associated condition set"]=={'glycerol(2.5)', "BOP27"})
# ]

# # SER
# # muts_df = muts_df[
# #     muts_df["significantly associated condition set"] == {'ΔsdaA ΔsdaB ΔtdcG ΔglyA', 'L-Serine'}]

# # # GLU
# # muts_df = muts_df[
# #     muts_df["significantly associated condition set"]=={'glucose(2)'}]



# # muts_df = muts_df[
# #     muts_df["significantly associated condition set"]==set()]


# # muts_df = muts_df[
# #     muts_df["significantly associated condition set"]=={'log', '511145', 'M9'}]


# display(len(muts_df), muts_df.head())

# %%
col_l = [
    "Mutation Type",
    "disrupt",
    "repaired",
    "genomic features",
    "genetic features",
    "genetic feature links",
    "operons",
    "operon links",
    "regulators",
    "regulator links",
    "COGs",
    "COG links",
    "pathways",
    "pathway links",
    "RegulonDB Gene"  # for debugging
]

annot_df = muts_df.copy()
annot_df = annot_df[col_l]
# annot_df["mutation effect"] = annot_df.apply(lambda mut_row:"repaired" if mut_row["repaired"] else ("disrupt" if mut_row["disrupt"] else "unknown"), axis=1)


display(annot_df.shape, annot_df.head())
# Out:
# (70, 15)
#      Mutation Type  disrupt  repaired  \
# 1075           SNP      0.0       0.0
# 1083           SNP      0.0       0.0
# 1085           SNP      0.0       0.0
# 1076           SNP      0.0       0.0
# 1189           SNP      0.0       0.0
#
#                                        genomic features  \
# 1075  [{'RegulonDB ID': 'ECK120001044/ECK120003456',...
# 1083  [{'name': 'flhCp3', 'RegulonDB ID': 'ECK125137...
# 1085  [{'name': 'cdd', 'RegulonDB ID': 'ECK120000133...
# 1076  [{'name': 'crr', 'RegulonDB ID': 'ECK120000161...
# 1189  [{'name': 'crr', 'RegulonDB ID': 'ECK120000161...
#
#                                        genetic features  \
# 1075  [{'RegulonDB ID': 'ECK120001044/ECK120003456',...
# 1083  [{'name': 'flhD', 'RegulonDB ID': 'ECK12000031...
# 1085  [{'name': 'cdd', 'RegulonDB ID': 'ECK120000133...
# 1076  [{'name': 'crr', 'RegulonDB ID': 'ECK120000161...
# 1189  [{'name': 'crr', 'RegulonDB ID': 'ECK120000161...
#
#                                   genetic feature links  \
# 1075  {'ECK120001044/ECK120003456': ['ECK120001044/E...
# 1083  {'ECK120000314': ['ECK125137156', 'ECK12000031...
# 1085                 {'ECK120000133': ['ECK120000133']}
# 1076                 {'ECK120000161': ['ECK120000161']}
# 1189                 {'ECK120000161': ['ECK120000161']}
#
#                                                 operons  \
# 1075  [{'name': 'uidABC', 'RegulonDB ID': 'ECK120026...
# 1083  [{'name': 'flhDC', 'RegulonDB ID': 'ECK1200149...
# 1085  [{'name': 'cdd', 'RegulonDB ID': 'ECK120014505...
# 1076  [{'name': 'ptsHI-crr', 'RegulonDB ID': 'ECK120...
# 1189  [{'name': 'ptsHI-crr', 'RegulonDB ID': 'ECK120...
#
#                                          operon links  \
# 1075  {'ECK120026438': ['ECK120001044/ECK120003456']}
# 1083               {'ECK120014934': ['ECK120000314']}
# 1085               {'ECK120014505': ['ECK120000133']}
# 1076               {'ECK120014520': ['ECK120000161']}
# 1189               {'ECK120014520': ['ECK120000161']}
#
#                                              regulators  \
# 1075  [{'name': 'UidR', 'significantly associated co...
# 1083  [{'name': 'CRP', 'significantly associated con...
# 1085  [{'name': 'CRP', 'significantly associated con...
# 1076  [{'name': 'CRP', 'significantly associated con...
# 1189  [{'name': 'CRP', 'significantly associated con...
#
#                                         regulator links  \
# 1075  {'UxuR': ['uidABC'], 'CRP': ['uidABC'], 'UidR'...
# 1083  {'RcsAB': ['flhDC'], 'FliZ': ['flhDC'], 'MatA'...
# 1085  {'CytR': ['cdd'], 'CRP': ['cdd'], 'NsrR': ['cd...
# 1076  {'Mlc': ['ptsHI-crr'], 'CRP': ['ptsHI-crr'], '...
# 1189  {'Mlc': ['ptsHI-crr'], 'CRP': ['ptsHI-crr'], '...
#
#                                                    COGs  \
# 1075                                                 []
# 1083                                                 []
# 1085  [{'name': 'Nucleotide transport and metabolism...
# 1076  [{'name': 'Carbohydrate transport and metaboli...
# 1189  [{'name': 'Carbohydrate transport and metaboli...
#
#                                               COG links  \
# 1075                                                 {}
# 1083                                                 {}
# 1085  {'Nucleotide transport and metabolism': ['ECK1...
# 1076  {'Carbohydrate transport and metabolism': ['EC...
# 1189  {'Carbohydrate transport and metabolism': ['EC...
#
#                                                pathways  \
# 1075                                                 []
# 1083                                                 []
# 1085  [{'name': 'Pyrimidine metabolism', 'mutation s...
# 1076                                                 []
# 1189                                                 []
#
#                                           pathway links RegulonDB Gene
# 1075                                                 {}      uidA/uidR
# 1083                                                 {}           flhD
# 1085  {'Pyrimidine metabolism': ['ECK120014505'], 'D...            cdd
# 1076                                                 {}            crr
# 1189                                                 {}            crr

# %%
# Just removing all "Function unknown" links since connections to this COG isn't useful.
for i, r in annot_df.iterrows():
    if "Function unknown" in r["COG links"].keys():
        del r["COG links"]["Function unknown"]

# %%
mut_type_feat_effect_counts = dict()
genomic_feat_counts = dict()
genetic_feat_counts = dict()
operon_counts = dict()
COG_counts = dict()
regulator_counts = dict()
pathway_counts = dict()
# Using the individual feature columns rather than link columns because this guarantees considering all linked and non-linked features
# for each of these levels, except genomic features.
for _, r in annot_df.iterrows():
    
    for genomic_feat in r["genomic features"]:
        
        # These are usually exclusive of each other per feature.
        # There is a design problem here: A multi-feature mutation could disrupt feature (gene) and repair another. Need to measure the predicted effect per feature rather than mutation to enable this (considering a design bug fix).
        effect = ""
#         if r["disrupt"]: effect = "disrupt"
#         if r["repaired"]: effect = "repair"
            
        mut_type_feat_effect = genomic_feat["name"] + ' ' + r["Mutation Type"] + ' ' + effect
        if mut_type_feat_effect not in mut_type_feat_effect_counts.keys():
            mut_type_feat_effect_counts[mut_type_feat_effect] = 0
        mut_type_feat_effect_counts[mut_type_feat_effect] += 1
    
    for genomic_feat in r["genomic features"]:
        genomic_feat_annot = genomic_feat["RegulonDB ID"] #+ ' ' + r["Mutation Type"]
        if genomic_feat_annot not in genomic_feat_counts.keys():
            genomic_feat_counts[genomic_feat_annot] = 0
        genomic_feat_counts[genomic_feat_annot] += 1

    for genetic_feat, links in r["genetic feature links"].items():
        if genetic_feat not in genetic_feat_counts.keys():
            genetic_feat_counts[genetic_feat] = 0
        genetic_feat_counts[genetic_feat] += len(links)

    # count the operons according to the amount of links from genes since an operon is only included if its gene is hit.
    for operon, links in r["operon links"].items():
        if operon not in operon_counts.keys():
            operon_counts[operon] = 0
        operon_counts[operon] += len(links)

    # count the COGs according to the amount of links from operons since a COG is only included if linked to a mutated operon (its genes)
    for COG, links in r["COG links"].items():
        if COG not in COG_counts.keys():
            COG_counts[COG] = 0
        COG_counts[COG] += len(links)
        
    for reg, links in r["regulator links"].items():
        if reg not in regulator_counts.keys():
            regulator_counts[reg] = 0
        regulator_counts[reg] += len(links)
        
    for pathway, links in r["pathway links"].items():
        if pathway not in pathway_counts.keys():
            pathway_counts[pathway] = 0
        pathway_counts[pathway] += len(links)

# %%
operon_df = pd.read_csv("./data/RegulonDB10/operon.txt", sep="\t", comment='#', header=None)
operon_df.columns = [
    "OPERON_ID",
    "OPERON_NAME",
    "FIRSTGENEPOSLEFT",
    "LASTGENEPOSRIGHT",
    "REGULATIONPOSLEFT",
    "REGULATIONPOSRIGHT",
    "OPERON_STRAND",
    "OPERON_INTERNAL_COMMENT",
    "KEY_ID_ORG"]
operon_df["range"] = operon_df.apply(lambda row: (row["REGULATIONPOSLEFT"], row["REGULATIONPOSRIGHT"]), axis=1)

# %%
# # For development. Delete when NB is stable.
# for _, r in annot_df.iterrows():
#     for genomic_feat_d in r["genomic features"]:
        
#         effect = ""
#         if r["disrupt"]: effect = "disrupt"
#         if r["repaired"]: effect = "repair"
            
#         mut_type_feat_effect = genomic_feat_d["name"] + ' ' + r["Mutation Type"] + ' ' + effect
#         mut_type_feat_effect = str(mut_type_feat_effect_counts[mut_type_feat_effect]) + ' ' + mut_type_feat_effect
            
#         genomic_feat_annot = ""
#         if genomic_feat_d["significant"]: genomic_feat_annot += "*"
#         genomic_feat_annot += str(genomic_feat_counts[genomic_feat_d["RegulonDB ID"]]) + ' '
#         genomic_feat_annot += str(genomic_feat_d["name"])
    
            
#         display(genomic_feat_annot + ' #### ' + mut_type_feat_effect)
# #         display(mut_type_feat_effect, "################################", r)

# %%
# operon names can be the same as a gene, which is problemmatic for floweaver
def _adjust_name_for_floweaver(operon):
    return operon + ' '


def _adjust_name_len_for_floweaver(feat_name):
    if len(feat_name) > 7: 
        feat_name = feat_name[:7] + "..."
    return feat_name


def _get_feat_d(json, RegulonDB_ID=None, name=None):
    feat_d = dict()
    for d in json:
        if (RegulonDB_ID and d["RegulonDB ID"] == RegulonDB_ID) or (name and d["name"] == name):
            feat_d = d
            break
    return feat_d


# Will probably have to put elsewhere at some point due to annotation work (count, significance)
mut_feat_effects = list()
genomic_feats = list()
genetic_feats = list()
operons = list()
COGs = list()
regulators = list()
pathways = list()


flow_df = pd.DataFrame()
for _, r in annot_df.iterrows():
    

    for genomic_feat_d in r["genomic features"]:
        
        effect = ""
#         if r["disrupt"]: effect = "disrupt"
#         if r["repaired"]: effect = "repair"
        mut_type_feat_effect = genomic_feat_d["name"] + ' ' + r["Mutation Type"] + ' ' + effect
        mut_type_feat_effect = str(mut_type_feat_effect_counts[mut_type_feat_effect]) + ' ' + mut_type_feat_effect
        mut_feat_effects.append(mut_type_feat_effect)
            
        genomic_feat_annot = ""
        mut_count = genomic_feat_counts[genomic_feat_d["RegulonDB ID"]]
        if genomic_feat_d["significant"] and mut_count > 1: genomic_feat_annot += "*"
        genomic_feat_annot += str(mut_count) + ' '
        genomic_feat_annot += str(genomic_feat_d["name"])
        flow_row = {
            "source": genomic_feat_annot,
            "target": mut_type_feat_effect,
            "type": "unknown",
            "value": 1
        }
        flow_df = flow_df.append(flow_row, ignore_index=True)
        
    
    
    for genetic_feat_ID, genomic_feat_set in r["genetic feature links"].items():
        genetic_feat_d = _get_feat_d(RegulonDB_ID=genetic_feat_ID, json=r["genetic features"])
        genetic_feat_annot = ""
        mut_count = genetic_feat_counts[genetic_feat_ID]
        if genetic_feat_d["significant"] and mut_count > 1: genetic_feat_annot += "*"
        genetic_feat_annot += str(mut_count) + ' '
        genetic_feat_annot += str(genetic_feat_d["name"])
        genetic_feats.append(genetic_feat_annot)
        for genomic_feat_ID in genomic_feat_set:
            genomic_feat_d = _get_feat_d(RegulonDB_ID=genomic_feat_ID, json=r["genomic features"])
            k = genomic_feat_ID #+ ' ' + r["Mutation Type"]
            genomic_feat_annot = ""
            mut_count = genomic_feat_counts[k]
            if genomic_feat_d["significant"] and mut_count > 1: genomic_feat_annot += "*"
            genomic_feat_annot += str(mut_count) + ' '
            genomic_feat_annot += str(genomic_feat_d["name"]) #+ ' ' + r["Mutation Type"]
            genomic_feats.append(genomic_feat_annot)
            flow_row = {
                "source": genetic_feat_annot,
                "target": genomic_feat_annot,
                "type": "unknown",
                "value": 1
            }
            flow_df = flow_df.append(flow_row, ignore_index=True)
    
    
    for operon_id, gen_targs in r["operon links"].items():
        operon_d = _get_feat_d(RegulonDB_ID=operon_id, json=r["operons"])
        operon_name = _adjust_name_for_floweaver(operon_d["name"])
        operon_annot = ""
        mut_count = operon_counts[operon_id]
        if operon_d["significant"] and mut_count > 1: operon_annot += "*"
        operon_annot += str(mut_count) + ' '
        operon_annot += operon_name
        operons.append(operon_annot)
        for genetic_feat_ID in gen_targs:
            genetic_feat_d = _get_feat_d(RegulonDB_ID=genetic_feat_ID, json=r["genetic features"])
            genetic_feat_annot = ""
            mut_count = genetic_feat_counts[genetic_feat_ID]
            if genetic_feat_d["significant"] and mut_count > 1: genetic_feat_annot += "*"
            genetic_feat_annot += str(mut_count) + ' '
            genetic_feat_annot += str(genetic_feat_d["name"])
            genetic_feats.append(genetic_feat_annot)
            flow_row = {
                "source": operon_annot,
                "target": genetic_feat_annot,
                "type": "unknown",
                "value": 1
            }
            flow_df = flow_df.append(flow_row, ignore_index=True)
            
            
    if FUNC_ANNOT == "regulon":
        for regulator, ops in r["regulator links"].items():
            if regulator == "CRP":  # for GYD CRP fig
#             if regulator == "GlpR":  # for GYD GlpR fig
#             if regulator == "Mlc":  # for GYD Mlc fig
                reg_feat_d = _get_feat_d(name=regulator, json=r["regulators"])
                reg_annot = ""
                mut_count = regulator_counts[regulator]
                if reg_feat_d["significant"] and mut_count > 1: reg_annot += "*"
                reg_annot += str(mut_count) + ' ' + reg_feat_d["name"]
                regulators.append(reg_annot)
                for operon_name in ops:
                    op_feat_d = _get_feat_d(name=operon_name, json=r["operons"])
                    operon_name = _adjust_name_for_floweaver(op_feat_d["name"])
                    operon_annot = ""
                    mut_count = operon_counts[op_feat_d["RegulonDB ID"]]
                    if op_feat_d["significant"] and mut_count > 1: operon_annot += "*"
                    operon_annot += str(mut_count) + ' '
                    operon_annot += operon_name
                    operons.append(operon_annot)
                    flow_row = {
                        "source": reg_annot,
                        "target": operon_annot,
                        "type": "unknown",
                        "value": 1
                    }
                    flow_df = flow_df.append(flow_row, ignore_index=True)


display(flow_df[:20])
# Out:
#             source            target     type  value
# 0      1 uidA/uidR  1 uidA/uidR SNP   unknown    1.0
# 1      1 uidA/uidR       1 uidA/uidR  unknown    1.0
# 2        1 uidABC        1 uidA/uidR  unknown    1.0
# 3          *72 CRP         1 uidABC   unknown    1.0
# 4         1 flhCp3     1 flhCp3 SNP   unknown    1.0
# 5           1 flhD       1 flhD SNP   unknown    1.0
# 6           2 flhD          1 flhCp3  unknown    1.0
# 7           2 flhD            1 flhD  unknown    1.0
# 8         1 flhDC             2 flhD  unknown    1.0
# 9          *72 CRP          1 flhDC   unknown    1.0
# 10           1 cdd        1 cdd SNP   unknown    1.0
# 11           1 cdd             1 cdd  unknown    1.0
# 12          1 cdd              1 cdd  unknown    1.0
# 13         *72 CRP            1 cdd   unknown    1.0
# 14         *10 crr       10 crr SNP   unknown    1.0
# 15         *10 crr           *10 crr  unknown    1.0
# 16  *11 ptsHI-crr            *10 crr  unknown    1.0
# 17         *72 CRP    *11 ptsHI-crr   unknown    1.0
# 18         *10 crr       10 crr SNP   unknown    1.0
# 19         *10 crr           *10 crr  unknown    1.0

# %%
# Specific to the GYD fig of the AVA paper.
flow_df = flow_df[~(flow_df["target"].str.contains("1 pdxK"))]

# %%
# processing to help a cleaner order of features.
# remove duplicates but maintains the order established above
def remove_duplicates(feats):
    l = list()
    for x in feats:
        if x not in l:
            l.append(x)
    return l

mut_feat_effects = remove_duplicates(mut_feat_effects)
genomic_feats = remove_duplicates(genomic_feats)
genetic_feats = remove_duplicates(genetic_feats)
operons = remove_duplicates(operons)
pathways = remove_duplicates(pathways)
regulators = remove_duplicates(regulators)
COGs = remove_duplicates(COGs)

# %%
from ipysankeywidget import SankeyWidget
from floweaver import *


nodes = {
    "mutation": ProcessGroup(mut_feat_effects, title="mutation"),
    "genomic feature": ProcessGroup(genomic_feats, title="genomic feature"),
    "genetic feature": ProcessGroup(genetic_feats, title="genetic feature"),
    "operon": ProcessGroup(operons, title="operon"),
}

l = []
if FUNC_ANNOT == "pathway":
    l = pathways
if FUNC_ANNOT == "regulon":
    l = regulators
if FUNC_ANNOT == "COG":
    l = COGs
nodes[FUNC_ANNOT] = ProcessGroup(l, title=FUNC_ANNOT)


# !!! These partition DFs need to have accessible variables (ex: mut_type_partition) accessible external to the nodes
# otherwise floweaver will crash during its rendering step.
mutation_partition = Partition.Simple("process", mut_feat_effects)
nodes["mutation"].partition = mutation_partition

genomic_feat_partition = Partition.Simple("process", genomic_feats)
nodes["genomic feature"].partition = genomic_feat_partition

genetic_feat_partition = Partition.Simple("process", genetic_feats)
nodes["genetic feature"].partition = genetic_feat_partition

operon_partition = Partition.Simple("process", operons)
nodes["operon"].partition = operon_partition

nodes[FUNC_ANNOT].partition = Partition.Simple("process", l)


# The order that the labels is entered into the bundles is explicit. Don't arbitrarily give an order.
bundles = [
    Bundle(
        "genomic feature",
        "mutation"
    ),
    Bundle(
        "genetic feature",
        "genomic feature",
    ),
    Bundle(
        "operon",
        "genetic feature",
    ),
    Bundle(
        FUNC_ANNOT,
        "operon",
    ),
]


ordering = [
    [FUNC_ANNOT],
    ["operon"],
    ["genetic feature"],
    ["genomic feature"],
    ["mutation"]
]

#
# mut_effect_partition = Partition.Simple(
#     "type", ["unknown", "disrupt", "repaired"])
sdd = SankeyDefinition(nodes,
                       bundles,
                       ordering,
#                        flow_partition=mut_effect_partition
                      )


# p_d = {"disrupt": "#C44E52", "unknown": "#6BAAD3", "repaired": "#55A868"}
p_d = {"disrupt": "#6BAAD3", "unknown": "#6BAAD3", "repaired": "#6BAAD3"}
size = dict(width=3000, height=4000)
# size = dict(width=2000, height=2500)
size = dict(width=1500, height=800)

results = weave(sdd,
                flow_df,
                palette=p_d,
                ).to_widget(
    margins=dict(left=400, right=350),
    **size)
results.auto_save_svg("mutflow.svg")
results.auto_save_png("mutflow.png")
results
# Out:
# SankeyWidget(groups=[{'id': 'regulon', 'type': 'process', 'title': 'regulon', 'nodes': ['regulon^*72 CRP']}, {…
