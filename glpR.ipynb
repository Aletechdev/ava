# %% [markdown]
# The starting strain glpR mutation: +G inseration @ 3560455

# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
all_muts_df = pd.read_pickle("./data/4_7_df.pkl")
all_muts_df.shape
# Out:
# (1278, 40)

# %%
all_muts_df[all_muts]
# Out:
#   index                   Details mutation target annotation Mutation Type  \
# 0     2           R110G (CGT→GGT)                       clsA           SNP
# 1     6                      None                        rph           DEL
# 2     7           A734V (GCG→GTG)                       rpoC           SNP
# 3     8             D9A (GAT→GCT)                        hfq           SNP
# 4     0  coding (380‑400/1149 nt)                       nagA           DEL
#
#    Position Reference Seq Sequence Change  ale  exp  flask  isolate  presence  \
# 0   1308318           NaN             G→C    1  42C    124        1       1.0
# 1   3815859           NaN          Δ82 bp    1  42C    124        1       1.0
# 2   4187550           NaN             C→T    1  42C    124        1       1.0
# 3   4400313           NaN             A→C    1  42C    124        1       1.0
# 4    702352           NaN          Δ21 bp    1  42C    124        1       1.0
#
# ...

# %%
all_muts_df[all_muts_df["mutation target annotation"].str.contains("glpR")]
# Out:
#     index                      Details mutation target annotation  \
# 975    18  pseudogene (382‑383/606 nt)                       glpR
# 976     6      pseudogene (125/606 nt)                       glpR
# 985    25                         None             [rtcR], [glpR]
#
#     Mutation Type  Position Reference Seq Sequence Change  ale          exp  \
# 975           DEL   3560071                         Δ2 bp    4  SSW_GLU_GLY
# 976           SNP   3560329                           G→T    4  SSW_GLU_GLY
# 985           DEL   3558995                     Δ1,040 bp    5  SSW_GLU_GLY
#
#      flask  isolate  presence  tech_rep  coding               range  \
# 975    165        1       1.0         1   False  (3560071, 3560072)
# 976    165        2       1.0         1   False  (3560329, 3560329)
# 985    160        1       1.0         1    True  (3558995, 3560034)
#
#                 gene RegulonDB ID  \
# 975                {ECK120000393}
# 976                {ECK120000393}
# ...
