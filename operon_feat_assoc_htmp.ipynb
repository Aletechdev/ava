# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
muts_df = pd.read_pickle("./data/4_7_df.pkl")
muts_df.shape
# Out:
# (1278, 41)

# %%
FEAT_ANNOT = "operons"

# %%
cond_cnt_d = {"none": 0}
feat_cnt = 0
for _, mut in muts_df.iterrows():
    for feat in mut[FEAT_ANNOT]:
        feat_cnt += 1
        if len(feat["significantly associated conditions"]) > 0:
            for cond in feat["significantly associated conditions"]:
                if cond in cond_cnt_d.keys():                   
                    cond_cnt_d[cond] += 1
                else:
                    cond_cnt_d[cond] = 1
        else:
            cond_cnt_d["none"] += 1

cond_cnt_d
# Out:
# {'none': 926,
#  'glucose(4)': 119,
#  '42 celsius': 32,
#  'U-13C glucose(2)': 14,
#  'Δpts': 22,
#  'GMOS': 2,
#  'Δgnd': 15,
#  'Δpgi': 120,
#  'Δsdh': 17,
#  'Δtpi': 36,
#  'glycerol(2.5)': 76,
#  'NaCl(1g/L) trace elements': 41,
#  'KH2PO4(6) Na2HPO4(13.6)': 41,
#  'MgSO4(24)': 41,
#  'glucose(2)': 47,
#  'NH4Cl(2)': 41,
#  'ΔsdaA ΔsdaB ΔtdcG ΔglyA': 11,
#  "glycine(2mM)  L-Serine(varying concentration)  trace elements(X1)  Wolfe's vitamin solution.": 11,
#  'acetate(4)': 15,
#  'glucose(4) or acetate(4)': 42,
#  'glucose(4) or glycerol(2.5)': 5,
#  'glucose(4) or xylose(4)': 29,
#  'xylose(4)': 5}

# %%
import pickle
f = open("./data/signif_operon_cond_json.pkl", 'rb')
signif_genomic_feat_cond_json = pickle.load(f)
signif_genomic_feat_cond_json[0:5]
# Out:
# [{'mutated features': 'ackA-pta',
#   'condition': 'Δpgi',
#   'odd ratio': 5.972613458528952,
#   'p value': 0.006179565252087326},
#  {'mutated features': 'agrA',
#   'condition': '42 celsius',
#   'odd ratio': 7.405797101449275,
#   'p value': 0.009936831699202816},
#  {'mutated features': 'araBAD',
#   'condition': 'Δpts',
#   'odd ratio': 43.111111111111114,
#   'p value': 7.533647964671958e-05},
#  {'mutated features': 'cpxRA',
#   'condition': 'KH2PO4(6) Na2HPO4(13.6)',
#   'odd ratio': 17.294642857142858,
#   'p value': 0.007113545266015673},
#  {'mutated features': 'cpxRA',
#   'condition': 'MgSO4(24)',
#   'odd ratio': 17.294642857142858,
#   'p value': 0.007113545266015673}]

# %%
def get_signif_mut_conds(feat_name):
    signif_mut_conds = []
    for signif_mut_cond in signif_genomic_feat_cond_json:
        if signif_mut_cond['mutated features'] == feat_name:
            signif_mut_conds.append(signif_mut_cond)
    return signif_mut_conds
    
    

cond_mut_feat_assoc_df = pd.DataFrame()
for _, mut in muts_df.iterrows():
    for feat in mut[FEAT_ANNOT]:
        signif_mut_conds = get_signif_mut_conds(feat["name"])
        for d in signif_mut_conds:
            cond_mut_feat_assoc_df = cond_mut_feat_assoc_df.append(d, ignore_index=True)

cond_mut_feat_assoc_df.head()
# Out:
#     condition mutated features  odd ratio   p value
# 0  glucose(4)         rph-pyrE   1.576479  0.000002
# 1        Δgnd         rph-pyrE   3.980373  0.000457
# 2        Δpgi         rph-pyrE   1.502605  0.006650
# 3        Δpts         rph-pyrE   3.557038  0.000234
# 4        Δsdh         rph-pyrE   5.688771  0.000042

# %%
gyd_cond_mut_feat_assoc_df = cond_mut_feat_assoc_df[cond_mut_feat_assoc_df["condition"].isin(cond_cnt_d.keys())].copy()

cross_counts_df = pd.crosstab(
    gyd_cond_mut_feat_assoc_df["mutated features"],
    gyd_cond_mut_feat_assoc_df["condition"]
)

cross_counts_df.head()
# Out:
# condition         42 celsius  GMOS  KH2PO4(6) Na2HPO4(13.6)  MgSO4(24)  \
# mutated features
# ackA-pta                   0     0                        0          0
# agrA                       3     0                        0          0
# araBAD                     0     0                        0          0
# cpxRA                      0     0                        3          3
# csgDEFG                    4     0                        0          0
#
# condition         NH4Cl(2)  NaCl(1g/L) trace elements  U-13C glucose(2)  \
# mutated features
# ackA-pta                 0                          0                 0
# agrA                     0                          0                 0
# araBAD                   0                          0                 0
# cpxRA                    3                          3                 0
# csgDEFG                  0                          0                 0
#
# condition         acetate(4)  glucose(2)  glucose(4)  \
# mutated features
# ackA-pta                   0           0           0
# agrA                       0           0           0
# araBAD                     0           0           0
# cpxRA                      0           0           0
# csgDEFG                    0           0           0
#
# condition         glucose(4) or acetate(4)  glucose(4) or glycerol(2.5)  \
# mutated features
# ackA-pta                                 0                            0
# agrA                                     0                            0
# araBAD                                   0                            0
# cpxRA                                    0                            0
# csgDEFG                                  0                            0
#
# condition         glucose(4) or xylose(4)  glycerol(2.5)  \
# mutated features
# ackA-pta                                0              0
# agrA                                    0              0
# araBAD                                  0              0
# cpxRA                                   0              0
# csgDEFG                                 0              0
#
# condition         glycine(2mM)  L-Serine(varying concentration)  trace elements(X1)  Wolfe's vitamin solution.  \
# mutated features
# ackA-pta                                                          0
# agrA                                                              0
# araBAD                                                            0
# cpxRA                                                             0
# csgDEFG                                                           0
#
# condition         xylose(4)  Δgnd  Δpgi  Δpts  ΔsdaA ΔsdaB ΔtdcG ΔglyA  Δsdh  \
# mutated features
# ackA-pta                  0     0     4     0                        0     0
# agrA                      0     0     0     0                        0     0
# araBAD                    0     0     0     3                        0     0
# cpxRA                     0     0     0     0                        0     0
# csgDEFG                   0     0     0     0                        0     0
#
# condition         Δtpi
# mutated features
# ackA-pta             0
# agrA                 0
# araBAD               0
# cpxRA                0
# csgDEFG              0

# %%
bin_df = cross_counts_df.copy()
for ir, r in bin_df.iterrows():
    for ic, c in r.items():
        if bin_df.loc[ir, ic] > 0:
            bin_df.loc[ir, ic] = 1
display(bin_df.head())
# Out:
# condition         42 celsius  GMOS  KH2PO4(6) Na2HPO4(13.6)  MgSO4(24)  \
# mutated features
# ackA-pta                   0     0                        0          0
# agrA                       1     0                        0          0
# araBAD                     0     0                        0          0
# cpxRA                      0     0                        1          1
# csgDEFG                    1     0                        0          0
#
# condition         NH4Cl(2)  NaCl(1g/L) trace elements  U-13C glucose(2)  \
# mutated features
# ackA-pta                 0                          0                 0
# agrA                     0                          0                 0
# araBAD                   0                          0                 0
# cpxRA                    1                          1                 0
# csgDEFG                  0                          0                 0
#
# condition         acetate(4)  glucose(2)  glucose(4)  \
# mutated features
# ackA-pta                   0           0           0
# agrA                       0           0           0
# araBAD                     0           0           0
# cpxRA                      0           0           0
# csgDEFG                    0           0           0
#
# condition         glucose(4) or acetate(4)  glucose(4) or glycerol(2.5)  \
# mutated features
# ackA-pta                                 0                            0
# agrA                                     0                            0
# araBAD                                   0                            0
# cpxRA                                    0                            0
# csgDEFG                                  0                            0
#
# condition         glucose(4) or xylose(4)  glycerol(2.5)  \
# mutated features
# ackA-pta                                0              0
# agrA                                    0              0
# araBAD                                  0              0
# cpxRA                                   0              0
# csgDEFG                                 0              0
#
# condition         glycine(2mM)  L-Serine(varying concentration)  trace elements(X1)  Wolfe's vitamin solution.  \
# mutated features
# ackA-pta                                                          0
# agrA                                                              0
# araBAD                                                            0
# cpxRA                                                             0
# csgDEFG                                                           0
#
# condition         xylose(4)  Δgnd  Δpgi  Δpts  ΔsdaA ΔsdaB ΔtdcG ΔglyA  Δsdh  \
# mutated features
# ackA-pta                  0     0     1     0                        0     0
# agrA                      0     0     0     0                        0     0
# araBAD                    0     0     0     1                        0     0
# cpxRA                     0     0     0     0                        0     0
# csgDEFG                   0     0     0     0                        0     0
#
# condition         Δtpi
# mutated features
# ackA-pta             0
# agrA                 0
# araBAD               0
# cpxRA                0
# csgDEFG              0

# %% [markdown]
# I actually wan to consider all mutated features, not just those that are significant

# %%
odds_df = bin_df.copy()
for feat, r in bin_df.iterrows():
    for cond, c in r.items():
        if bin_df.loc[feat, cond] > 0:
            odd_ratio = 0
            df = cond_mut_feat_assoc_df[
                (cond_mut_feat_assoc_df["condition"]==cond)
                & (cond_mut_feat_assoc_df["mutated features"]==feat)]["odd ratio"]
            if len(df):
                odd_ratio = df.unique()
            odds_df.loc[feat, cond] = odd_ratio
            
# odds_df = odds_df[odds_df.index.isin(signif_gen_targ_s)]
# odds_df.index = '*'+odds_df.index
odds_df.head()
# Out:
# condition         42 celsius  GMOS  KH2PO4(6) Na2HPO4(13.6)  MgSO4(24)  \
# mutated features
# ackA-pta            0.000000   0.0                 0.000000   0.000000
# agrA                7.405797   0.0                 0.000000   0.000000
# araBAD              0.000000   0.0                 0.000000   0.000000
# cpxRA               0.000000   0.0                17.294643  17.294643
# csgDEFG             7.433770   0.0                 0.000000   0.000000
#
# condition          NH4Cl(2)  NaCl(1g/L) trace elements  U-13C glucose(2)  \
# mutated features
# ackA-pta           0.000000                   0.000000               0.0
# agrA               0.000000                   0.000000               0.0
# araBAD             0.000000                   0.000000               0.0
# cpxRA             17.294643                  17.294643               0.0
# csgDEFG            0.000000                   0.000000               0.0
#
# condition         acetate(4)  glucose(2)  glucose(4)  \
# mutated features
# ackA-pta                 0.0         0.0         0.0
# agrA                     0.0         0.0         0.0
# araBAD                   0.0         0.0         0.0
# cpxRA                    0.0         0.0         0.0
# csgDEFG                  0.0         0.0         0.0
#
# condition         glucose(4) or acetate(4)  glucose(4) or glycerol(2.5)  \
# mutated features
# ackA-pta                               0.0                          0.0
# agrA                                   0.0                          0.0
# araBAD                                 0.0                          0.0
# cpxRA                                  0.0                          0.0
# csgDEFG                                0.0                          0.0
#
# condition         glucose(4) or xylose(4)  glycerol(2.5)  \
# mutated features
# ackA-pta                              0.0            0.0
# agrA                                  0.0            0.0
# araBAD                                0.0            0.0
# cpxRA                                 0.0            0.0
# csgDEFG                               0.0            0.0
#
# condition         glycine(2mM)  L-Serine(varying concentration)  trace elements(X1)  Wolfe's vitamin solution.  \
# mutated features
# ackA-pta                                                        0.0
# agrA                                                            0.0
# araBAD                                                          0.0
# cpxRA                                                           0.0
# csgDEFG                                                         0.0
#
# condition         xylose(4)  Δgnd      Δpgi       Δpts  \
# mutated features
# ackA-pta                0.0   0.0  5.972613   0.000000
# agrA                    0.0   0.0  0.000000   0.000000
# araBAD                  0.0   0.0  0.000000  43.111111
# cpxRA                   0.0   0.0  0.000000   0.000000
# csgDEFG                 0.0   0.0  0.000000   0.000000
#
# condition         ΔsdaA ΔsdaB ΔtdcG ΔglyA  Δsdh  Δtpi
# mutated features
# ackA-pta                              0.0   0.0   0.0
# agrA                                  0.0   0.0   0.0
# araBAD                                0.0   0.0   0.0
# cpxRA                                 0.0   0.0   0.0
# csgDEFG                               0.0   0.0   0.0

# %%
import os, sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from util.metadata_categories_for_associations import METADATA_CATEGORIES_FOR_ASSOCIATIONS

exp_conds_df = muts_df[METADATA_CATEGORIES_FOR_ASSOCIATIONS].drop_duplicates()
exp_conds_df
# Out:
#      temperature                carbon-source  \
# 0     42 celsius                   glucose(4)
# 204   37 celsius             U-13C glucose(2)
# 240   37 celsius                   glucose(4)
# 271   37 celsius                   glucose(4)
# 284   37 celsius                   glucose(4)
# 306   37 celsius                   glucose(4)
# 408   37 celsius                   glucose(4)
# 427   37 celsius                   glucose(4)
# 478   37 celsius                   glucose(4)
# 630   37 celsius                glycerol(2.5)
# 778   37 celsius                   glucose(2)
# 842   37 celsius                   glucose(2)
# 869   37 celsius                   acetate(4)
# 894   37 celsius     glucose(4) or acetate(4)
# 973   37 celsius  glucose(4) or glycerol(2.5)
# 997   37 celsius      glucose(4) or xylose(4)
# 1232  37 celsius                    xylose(4)
#
#                                              supplement  \
# 0                           NaCl(0.5g/L) trace elements
# 204                         NaCl(0.5g/L) trace elements
# 240                         NaCl(0.5g/L) trace elements
# 271                         NaCl(0.5g/L) trace elements
# 284                         NaCl(0.5g/L) trace elements
# 306                         NaCl(0.5g/L) trace elements
# 408                         NaCl(0.5g/L) trace elements
# 427                         NaCl(0.5g/L) trace elements
# 478                         NaCl(0.5g/L) trace elements
# 630                         NaCl(0.5g/L) trace elements
# 778                           NaCl(1g/L) trace elements
# 842   glycine(2mM)  L-Serine(varying concentration) ...
# 869                         NaCl(0.5g/L) trace elements
# 894                         NaCl(0.5g/L) trace elements
# 973                         NaCl(0.5g/L) trace elements
# 997                         NaCl(0.5g/L) trace elements
# 1232                        NaCl(0.5g/L) trace elements
#
#            strain-description taxonomy-id base-media nitrogen-source  \
# 0                          WT      511145         M9        NH4Cl(1)
# 204                        WT      511145         M9        NH4Cl(1)
# 240                      Δpts      511145         M9        NH4Cl(1)
# 271                      GMOS      511145         M9        NH4Cl(1)
# 284                      Δgnd      511145         M9        NH4Cl(1)
# 306                      Δpgi      511145         M9        NH4Cl(1)
# 408                      Δsdh      511145         M9        NH4Cl(1)
# 427                      Δtpi      511145         M9        NH4Cl(1)
# 478                        WT      511145         M9        NH4Cl(1)
# 630                        WT      511145         M9        NH4Cl(1)
# 778                      Δpgi      511145         M9        NH4Cl(2)
# 842   ΔsdaA ΔsdaB ΔtdcG ΔglyA      511145         M9        NH4Cl(1)
# 869                        WT      511145         M9        NH4Cl(1)
# 894                        WT      511145         M9        NH4Cl(1)
# 973                        WT      511145         M9        NH4Cl(1)
# 997                        WT      511145         M9        NH4Cl(1)
# 1232                       WT      511145         M9        NH4Cl(1)
#
#            phosphorous-source sulfur-source calcium-source
# 0      KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)     CaCl2(0.1)
# 204    KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)     CaCl2(0.1)
# 240    KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)     CaCl2(0.1)
# 271    KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)     CaCl2(0.1)
# 284    KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)     CaCl2(0.1)
# 306    KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)     CaCl2(0.1)
# 408    KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)     CaCl2(0.1)
# 427    KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)     CaCl2(0.1)
# 478    KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)     CaCl2(0.1)
# 630    KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)     CaCl2(0.1)
# 778   KH2PO4(6) Na2HPO4(13.6)     MgSO4(24)     CaCl2(0.1)
# 842    KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)     CaCl2(0.1)
# 869    KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)     CaCl2(0.1)
# 894    KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)     CaCl2(0.1)
# 973    KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)     CaCl2(0.1)
# 997    KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)     CaCl2(0.1)
# 1232   KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)     CaCl2(0.1)

# %%
# Adding zeros to other condition categories possibly to represented to ensure all are in the following headmaps
for i in exp_conds_df.columns:
    c = exp_conds_df.at[exp_conds_df.index[0], i]
    if c not in odds_df.columns:
        odds_df[c] = 0

odds_df.head()
# Out:
# condition         42 celsius  GMOS  KH2PO4(6) Na2HPO4(13.6)  MgSO4(24)  \
# mutated features
# ackA-pta            0.000000   0.0                 0.000000   0.000000
# agrA                7.405797   0.0                 0.000000   0.000000
# araBAD              0.000000   0.0                 0.000000   0.000000
# cpxRA               0.000000   0.0                17.294643  17.294643
# csgDEFG             7.433770   0.0                 0.000000   0.000000
#
# condition          NH4Cl(2)  NaCl(1g/L) trace elements  U-13C glucose(2)  \
# mutated features
# ackA-pta           0.000000                   0.000000               0.0
# agrA               0.000000                   0.000000               0.0
# araBAD             0.000000                   0.000000               0.0
# cpxRA             17.294643                  17.294643               0.0
# csgDEFG            0.000000                   0.000000               0.0
#
# condition         acetate(4)  glucose(2)  glucose(4)  \
# mutated features
# ackA-pta                 0.0         0.0         0.0
# agrA                     0.0         0.0         0.0
# araBAD                   0.0         0.0         0.0
# cpxRA                    0.0         0.0         0.0
# csgDEFG                  0.0         0.0         0.0
#
# condition         glucose(4) or acetate(4)  glucose(4) or glycerol(2.5)  \
# mutated features
# ackA-pta                               0.0                          0.0
# agrA                                   0.0                          0.0
# araBAD                                 0.0                          0.0
# cpxRA                                  0.0                          0.0
# csgDEFG                                0.0                          0.0
#
# condition         glucose(4) or xylose(4)  glycerol(2.5)  \
# mutated features
# ackA-pta                              0.0            0.0
# agrA                                  0.0            0.0
# araBAD                                0.0            0.0
# cpxRA                                 0.0            0.0
# csgDEFG                               0.0            0.0
#
# condition         glycine(2mM)  L-Serine(varying concentration)  trace elements(X1)  Wolfe's vitamin solution.  \
# mutated features
# ackA-pta                                                        0.0
# agrA                                                            0.0
# araBAD                                                          0.0
# cpxRA                                                           0.0
# csgDEFG                                                         0.0
#
# condition         xylose(4)  Δgnd      Δpgi       Δpts  \
# mutated features
# ackA-pta                0.0   0.0  5.972613   0.000000
# agrA                    0.0   0.0  0.000000   0.000000
# araBAD                  0.0   0.0  0.000000  43.111111
# cpxRA                   0.0   0.0  0.000000   0.000000
# csgDEFG                 0.0   0.0  0.000000   0.000000
#
# condition         ΔsdaA ΔsdaB ΔtdcG ΔglyA  Δsdh  Δtpi  \
# mutated features
# ackA-pta                              0.0   0.0   0.0
# agrA                                  0.0   0.0   0.0
# araBAD                                0.0   0.0   0.0
# cpxRA                                 0.0   0.0   0.0
# csgDEFG                               0.0   0.0   0.0
#
# condition         NaCl(0.5g/L) trace elements  WT  511145  M9  NH4Cl(1)  \
# mutated features
# ackA-pta                                    0   0       0   0         0
# agrA                                        0   0       0   0         0
# araBAD                                      0   0       0   0         0
# cpxRA                                       0   0       0   0         0
# csgDEFG                                     0   0       0   0         0
#
# condition         KH2PO4(3) Na2HPO4(6.8)  MgSO4(0.24)  CaCl2(0.1)
# mutated features
# ackA-pta                               0            0           0
# agrA                                   0            0           0
# araBAD                                 0            0           0
# cpxRA                                  0            0           0
# csgDEFG                                0            0           0

# %%
from util.metadata import get_all_exp_cond_d

all_exp_cond_d = get_all_exp_cond_d("./data/metadata/")
all_exp_cond_d
# Out:
# {'TEE': {'taxonomy-id': '413997',
#   'strain-description': 'REL7000',
#   'base-media': 'DM25',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(0.025)',
#   'nitrogen-source': 'NH4Cl',
#   'phosphorous-source': 'KH2PO4',
#   'sulfur-source': 'MgSO4',
#   'supplement': ''},
#  'LTEE_Ara': {'taxonomy-id': '413997',
#   'strain-description': 'REL606',
#   'base-media': 'DM',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(0.025)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'trace elements'},
#  'SSW_XYL': {'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'xylose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  '42C_Tenaillon': {'taxonomy-id': '413997',
#   'strain-description': 'Ara- LTEE strain from generation 2000',
#   'base-media': 'DM25',
#   'temperature': '42.2 celsius',
#   'carbon-source': 'glucose(0.025)',
#   'nitrogen-source': '(NH4)2SO4(1)',
#   'phosphorous-source': 'KH2PO4(9)',
#   'sulfur-source': 'MgSO4(0.5)',
#   'supplement': 'vitamin-B1(0.01)'},
#  'Central_carbon_knockout_gnd': {'taxonomy-id': '511145',
#   'strain-description': 'Δgnd',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'TEE_Ara': {'taxonomy-id': '413997',
#   'strain-description': 'REL7003',
#   'base-media': 'DM25',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(0.025)',
#   'nitrogen-source': 'NH4Cl',
#   'phosphorous-source': 'KH2PO4',
#   'sulfur-source': 'MgSO4',
#   'supplement': ''},
#  'TM Glu': {'taxonomy-id': '243274',
#   'strain-description': 'Thermotoga maritima',
#   'base-media': 'LB',
#   'temperature': '80 celsius',
#   'carbon-source': 'glucose(1.8016)',
#   'nitrogen-source': 'NH4Cl(15)',
#   'phosphorous-source': 'K2HPO4(0.14)',
#   'sulfur-source': 'NaSO4(2)',
#   'supplement': 'trace elements'},
#  'Central_carbon_knockout_pgi': {'taxonomy-id': '511145',
#   'strain-description': 'Δpgi',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'Central_carbon_knockout_PTS': {'taxonomy-id': '511145',
#   'strain-description': 'Δpts',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'SSW_GLU_XYL': {'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(4) or xylose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'GYD': {'organism': 'eco',
#   'strain-description': 'WT',
#   'base-media': 'M9',
#   'carbon-source': 'glycerol(2.5)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'antibiotic-resistance': '',
#   'illumina-kit': '300 Cycle',
#   'expertiment-details': '',
#   'taxonomy-id': '511145',
#   'temperature': '37 celsius',
#   'calcium-source': 'CaCl2(0.1)'},
#  'Central_carbon_knockout_tpiA': {'taxonomy-id': '511145',
#   'strain-description': 'Δtpi',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'Auxotrophic_strains_hisD_gltB': {'taxonomy-id': '679895',
#   'strain-description': 'ΔhisD & ΔgdhAΔgltB co-culture',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(1)',
#   'nitrogen-source': 'NH4Cl(4)',
#   'phosphorous-source': 'KH2PO4(5)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'trace elements',
#   'file-checksum': ''},
#  'SSW_GLY': {'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glycerol(2.5)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'PGI': {'taxonomy-id': '511145',
#   'strain-description': 'Δpgi',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(2)',
#   'phosphorous-source': 'KH2PO4(6) Na2HPO4(13.6)',
#   'sulfur-source': 'MgSO4(24)',
#   'supplement': 'NaCl(1g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'Central_carbon_knockout_glucose_evolution': {'taxonomy-id': '511145',
#   'strain-description': 'GMOS',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'LTEE': {'taxonomy-id': '413997',
#   'strain-description': 'REL606',
#   'base-media': 'DM',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(0.025)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'trace elements'},
#  'SSW_GLU_AC': {'strain-description': 'WT',
#   'taxonomy-id': '511145',
#   'nitrogen-source': 'NH4Cl(1)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'base-media': 'M9',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'carbon-source': 'glucose(4) or acetate(4)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'temperature': '37 celsius',
#   'calcium-source': 'CaCl2(0.1)'},
#  '42C': {'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '42 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'GLU': {'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'SSW_GLU_GLY': {'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(4) or glycerol(2.5)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'Central_carbon_knockout_sdh': {'taxonomy-id': '511145',
#   'strain-description': 'Δsdh',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'Auxotrophic_strains_hisD_gltA': {'taxonomy-id': '679895',
#   'strain-description': 'ΔhisD & ΔgltAΔprpC co-culture',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(1)',
#   'nitrogen-source': 'NH4Cl(4)',
#   'phosphorous-source': 'KH2PO4(5)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'trace elements',
#   'file-checksum': ''},
#  'TM Gly': {'taxonomy-id': '243274',
#   'strain-description': 'Thermotoga maritima',
#   'base-media': 'LB',
#   'temperature': '80 celsius',
#   'carbon-source': 'glycerol(1.8016)',
#   'nitrogen-source': 'NH4Cl(15)',
#   'phosphorous-source': 'K2HPO4(0.14)',
#   'sulfur-source': 'NaSO4(2)',
#   'supplement': 'trace elements'},
#  'SER': {'taxonomy-id': '511145',
#   'strain-description': 'ΔsdaA ΔsdaB ΔtdcG ΔglyA',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': "glycine(2mM)  L-Serine(varying concentration)  trace elements(X1)  Wolfe's vitamin solution.",
#   'calcium-source': 'CaCl2(0.1)'},
#  'C13': {'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'U-13C glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'SSW_AC': {'strain-description': 'WT',
#   'taxonomy-id': '511145',
#   'nitrogen-source': 'NH4Cl(1)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'base-media': 'M9',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'carbon-source': 'acetate(4)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'temperature': '37 celsius',
#   'calcium-source': 'CaCl2(0.1)'},
#  'Auxotrophic_strains_hisD_pyrC': {'taxonomy-id': '679895',
#   'strain-description': 'ΔhisD & ΔpyrC co-culture',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(1)',
#   'nitrogen-source': 'NH4Cl(4)',
#   'phosphorous-source': 'KH2PO4(5)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'trace elements',
#   'file-checksum': ''}}

# %%
units_replace_d = {
    "acetate(4)": "acetate(4g/L)",
    "glucose(4) or glycerol(2.5)": "glucose(4g/L) or glycerol(2.5g/L)",
    "glucose(4) or acetate(4)": "glucose(4g/L) or acetate(4g/L)",
    "glucose(4) or xylose(4)": "glucose(4g/L) or xylose(4g/L)",
    "CaCl2(0.1)": "CaCl2(0.1mM)",
    "U-13C glucose(2)": "U-13C glucose(2g/L)",
    "glycerol(2.5)": "glycerol(2.5g/L)",
    "glucose(2)": "glucose(2g/L)",
    "glucose(4)": "glucose(4g/L)",
    "NH4Cl(2)": "NH4Cl(2g/L)",
    "NH4Cl(1)": "NH4Cl(1g/L)",
    "KH2PO4(6) Na2HPO4(13.6)": "KH2PO4(6g/L), Na2HPO4(13.6g/L)",
    "MgSO4(24)": "MgSO4(24g/L)",
    "MgSO4(0.24)": "MgSO4(0.24g/L)",
    "KH2PO4(3)": "KH2PO4(3g/L)"
}


rename_col_d = dict()
for d in all_exp_cond_d.values():
    for cond_type, cond in d.items():

        if cond not in rename_col_d.keys():
            t = cond_type

            if t == "strain-description":
                t = "strain"
            elif t == "taxonomy-id":
                t = "organism"
            t = t.replace('-', ' ')

            c = cond
            if "celsius" in cond:
                c = cond.replace("celsius", "Celsius")
            elif cond == "511145":
                c = "$\it{E. coli}$ K-12 MG1655'"
            elif cond == "glycine(2mM)  L-Serine(varying concentration)  trace elements(X1)  Wolfe's vitamin solution.":
                c = "glycine(2mM), L-serine"
            elif cond in units_replace_d.keys():
                c = units_replace_d[cond]

            rename_col_d[cond] = c + " " + t

odds_df = odds_df.rename(columns=rename_col_d)
odds_df
# Out:
# condition         42 Celsius temperature  GMOS strain  \
# mutated features
# ackA-pta                        0.000000          0.0
# agrA                            7.405797          0.0
# araBAD                          0.000000          0.0
# cpxRA                           0.000000          0.0
# csgDEFG                         7.433770          0.0
# ...                                  ...          ...
# ynaA-lomR_1                     0.000000          0.0
# ynaI                            0.000000          0.0
# ynaK-ydaY                       0.000000          0.0
# yobF-cspC                       0.000000          0.0
# yrfF                            0.000000          0.0
#
# condition         KH2PO4(6g/L), Na2HPO4(13.6g/L) phosphorous source  \
# mutated features
# ackA-pta                                                   0.000000
# agrA                                                       0.000000
# araBAD                                                     0.000000
# cpxRA                                                     17.294643
# csgDEFG                                                    0.000000
# ...                                                             ...
# ynaA-lomR_1                                                0.000000
# ynaI                                                       0.000000
# ynaK-ydaY                                                  0.000000
# yobF-cspC                                                  0.000000
# yrfF                                                       0.000000
#
# condition         MgSO4(24g/L) sulfur source  NH4Cl(2g/L) nitrogen source  \
# mutated features
# ackA-pta                            0.000000                     0.000000
# agrA                                0.000000                     0.000000
# araBAD                              0.000000                     0.000000
# cpxRA                              17.294643                    17.294643
# csgDEFG                             0.000000                     0.000000
# ...                                      ...                          ...
# ynaA-lomR_1                         0.000000                     0.000000
# ynaI                                0.000000                     0.000000
# ynaK-ydaY                           0.000000                     0.000000
# yobF-cspC                           0.000000                     0.000000
# yrfF                                0.000000                     0.000000
#
# condition         NaCl(1g/L) trace elements supplement  \
# mutated features
# ackA-pta                                      0.000000
# agrA                                          0.000000
# araBAD                                        0.000000
# cpxRA                                        17.294643
# csgDEFG                                       0.000000
# ...                                                ...
# ynaA-lomR_1                                   0.000000
# ynaI                                          0.000000
# ynaK-ydaY                                     0.000000
# yobF-cspC                                     0.000000
# yrfF                                          0.000000
#
# condition         U-13C glucose(2g/L) carbon source  \
# mutated features
# ackA-pta                                        0.0
# agrA                                            0.0
# araBAD                                          0.0
# cpxRA                                           0.0
# csgDEFG                                         0.0
# ...                                             ...
# ynaA-lomR_1                                     0.0
# ynaI                                            0.0
# ynaK-ydaY                                       0.0
# yobF-cspC                                       0.0
# yrfF                                            0.0
#
# condition         acetate(4g/L) carbon source  glucose(2g/L) carbon source  \
# mutated features
# ackA-pta                                  0.0                          0.0
# agrA                                      0.0                          0.0
# araBAD                                    0.0                          0.0
# cpxRA                                     0.0                          0.0
# csgDEFG                                   0.0                          0.0
# ...                                       ...                          ...
# ynaA-lomR_1                               0.0                          0.0
# ynaI                                      0.0                          0.0
# ynaK-ydaY                                 0.0                          0.0
# yobF-cspC                                 0.0                          0.0
# yrfF                                      0.0                          0.0
#
# condition         glucose(4g/L) carbon source  \
# mutated features
# ackA-pta                                  0.0
# agrA                                      0.0
# araBAD                                    0.0
# cpxRA                                     0.0
# csgDEFG                                   0.0
# ...                                       ...
# ynaA-lomR_1                               0.0
# ynaI                                      0.0
# ynaK-ydaY                                 0.0
# yobF-cspC                                 0.0
# yrfF                                      0.0
#
# condition         glucose(4g/L) or acetate(4g/L) carbon source  \
# mutated features
# ackA-pta                                              0.000000
# agrA                                                  0.000000
# araBAD                                                0.000000
# cpxRA                                                 0.000000
# csgDEFG                                               0.000000
# ...                                                        ...
# ynaA-lomR_1                                           0.000000
# ynaI                                                  0.000000
# ynaK-ydaY                                             0.000000
# yobF-cspC                                            12.155057
# yrfF                                                  0.000000
#
# condition         glucose(4g/L) or glycerol(2.5g/L) carbon source  \
# mutated features
# ackA-pta                                                      0.0
# agrA                                                          0.0
# araBAD                                                        0.0
# cpxRA                                                         0.0
# csgDEFG                                                       0.0
# ...                                                           ...
# ynaA-lomR_1                                                   0.0
# ynaI                                                          0.0
# ynaK-ydaY                                                     0.0
# yobF-cspC                                                     0.0
# yrfF                                                          0.0
#
# condition         glucose(4g/L) or xylose(4g/L) carbon source  \
# mutated features
# ackA-pta                                                  0.0
# agrA                                                      0.0
# araBAD                                                    0.0
# cpxRA                                                     0.0
# csgDEFG                                                   0.0
# ...                                                       ...
# ynaA-lomR_1                                               0.0
# ynaI                                                      0.0
# ynaK-ydaY                                                 0.0
# yobF-cspC                                                 0.0
# yrfF                                                      0.0
#
# condition         glycerol(2.5g/L) carbon source  \
# mutated features
# ackA-pta                                 0.00000
# agrA                                     0.00000
# araBAD                                   0.00000
# cpxRA                                    0.00000
# csgDEFG                                  0.00000
# ...                                          ...
# ynaA-lomR_1                              0.00000
# ynaI                                    10.90092
# ynaK-ydaY                                0.00000
# yobF-cspC                                0.00000
# yrfF                                     0.00000
#
# condition         glycine(2mM), L-serine supplement  xylose(4) carbon source  \
# mutated features
# ackA-pta                                        0.0                      0.0
# agrA                                            0.0                      0.0
# araBAD                                          0.0                      0.0
# cpxRA                                           0.0                      0.0
# csgDEFG                                         0.0                      0.0
# ...                                             ...                      ...
# ynaA-lomR_1                                     0.0                      0.0
# ynaI                                            0.0                      0.0
# ynaK-ydaY                                       0.0                      0.0
# yobF-cspC                                       0.0                      0.0
# yrfF                                            0.0                      0.0
#
# condition         Δgnd strain  Δpgi strain  Δpts strain  \
# mutated features
# ackA-pta                  0.0     5.972613     0.000000
# agrA                      0.0     0.000000     0.000000
# araBAD                    0.0     0.000000    43.111111
# cpxRA                     0.0     0.000000     0.000000
# csgDEFG                   0.0     0.000000     0.000000
# ...                       ...          ...          ...
# ynaA-lomR_1               0.0     5.990185     0.000000
# ynaI                      0.0     0.000000     0.000000
# ynaK-ydaY                 0.0     6.007880     0.000000
# yobF-cspC                 0.0     0.000000     0.000000
# yrfF                      0.0     0.000000    15.751016
#
# condition         ΔsdaA ΔsdaB ΔtdcG ΔglyA strain  Δsdh strain  Δtpi strain  \
# mutated features
# ackA-pta                                     0.0          0.0          0.0
# agrA                                         0.0          0.0          0.0
# araBAD                                       0.0          0.0          0.0
# cpxRA                                        0.0          0.0          0.0
# csgDEFG                                      0.0          0.0          0.0
# ...                                          ...          ...          ...
# ynaA-lomR_1                                  0.0          0.0          0.0
# ynaI                                         0.0          0.0          0.0
# ynaK-ydaY                                    0.0          0.0          0.0
# yobF-cspC                                    0.0          0.0          0.0
# yrfF                                         0.0          0.0          0.0
#
# condition         NaCl(0.5g/L) trace elements supplement  WT strain  \
# mutated features
# ackA-pta                                               0          0
# agrA                                                   0          0
# araBAD                                                 0          0
# cpxRA                                                  0          0
# csgDEFG                                                0          0
# ...                                                  ...        ...
# ynaA-lomR_1                                            0          0
# ynaI                                                   0          0
# ynaK-ydaY                                              0          0
# yobF-cspC                                              0          0
# yrfF                                                   0          0
#
# condition         $\it{E. coli}$ K-12 MG1655' organism  M9 base media  \
# mutated features
# ackA-pta                                             0              0
# agrA                                                 0              0
# araBAD                                               0              0
# cpxRA                                                0              0
# csgDEFG                                              0              0
# ...                                                ...            ...
# ynaA-lomR_1                                          0              0
# ynaI                                                 0              0
# ynaK-ydaY                                            0              0
# yobF-cspC                                            0              0
# yrfF                                                 0              0
#
# condition         NH4Cl(1g/L) nitrogen source  \
# mutated features
# ackA-pta                                    0
# agrA                                        0
# araBAD                                      0
# cpxRA                                       0
# csgDEFG                                     0
# ...                                       ...
# ynaA-lomR_1                                 0
# ynaI                                        0
# ynaK-ydaY                                   0
# yobF-cspC                                   0
# yrfF                                        0
#
# condition         KH2PO4(3) Na2HPO4(6.8) phosphorous source  \
# mutated features
# ackA-pta                                                  0
# agrA                                                      0
# araBAD                                                    0
# cpxRA                                                     0
# csgDEFG                                                   0
# ...                                                     ...
# ynaA-lomR_1                                               0
# ynaI                                                      0
# ynaK-ydaY                                                 0
# yobF-cspC                                                 0
# yrfF                                                      0
#
# condition         MgSO4(0.24g/L) sulfur source  CaCl2(0.1mM) calcium source
# mutated features
# ackA-pta                                     0                            0
# agrA                                         0                            0
# araBAD                                       0                            0
# cpxRA                                        0                            0
# csgDEFG                                      0                            0
# ...                                        ...                          ...
# ynaA-lomR_1                                  0                            0
# ynaI                                         0                            0
# ynaK-ydaY                                    0                            0
# yobF-cspC                                    0                            0
# yrfF                                         0                            0
#
# [75 rows x 30 columns]

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 100
plt.rcParams['font.sans-serif'] = ["Helvetica"]
sns.set_context("paper")
sns.set_style("white")

g = sns.clustermap(
    odds_df,
    linewidths=0.1,
    cmap="coolwarm",
#     xticklabels=False,
#     yticklabels=False,
    figsize=(7,8)
)

# Fix for recent matplotlib/seaborn issue
g.ax_heatmap.set_ylim(len(odds_df)+0, -0)

# g.cax.set_visible(False)
# g.ax_row_dendrogram.set_visible(False)
# g.ax_col_dendrogram.set_visible(False)
g.fig.suptitle("Mutated operons\nand their significantly associated conditions")
g.cax.set_title("odds\nratio")
# g.cax.yaxis.set_ticks_position("left")
# g.ax_heatmap.set_title(
#     "Overlap of associated conditions\nwith mutated genetic features",
# #     loc='top'
# )
# ax.yaxis.set_ticks_position('left')
# ax.yaxis.set_label_position("left")

# dendro_box = g.ax_row_dendrogram.get_position()
# dendro_box.x0-=0.2
# dendro_box.x1-=0.2
# g.cax.set_position(dendro_box)

# g.clustermap.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')
# set_xticklabels(rotation=30)
# g.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')
# plt.setp(g.ax_heatmap.get_xticklabels(), rotation=45)
plt.savefig("fig.svg", format="svg")

# %% [markdown]
# The above shows assocs, though with large differences in orders of magnitude, which can hide other assocs.
# Therefore will also show the log odds ratio, which uses the natural log.

# %%
log_odds_df = odds_df.copy()
import numpy as np
log_odds_df = log_odds_df.applymap(lambda c: np.log(c) if c > 0 else c)
log_odds_df.head()
# Out:
# condition         42 Celsius temperature  GMOS strain  \
# mutated features
# ackA-pta                        0.000000          0.0
# agrA                            2.002263          0.0
# araBAD                          0.000000          0.0
# cpxRA                           0.000000          0.0
# csgDEFG                         2.006033          0.0
#
# condition         KH2PO4(6g/L), Na2HPO4(13.6g/L) phosphorous source  \
# mutated features
# ackA-pta                                                   0.000000
# agrA                                                       0.000000
# araBAD                                                     0.000000
# cpxRA                                                      2.850397
# csgDEFG                                                    0.000000
#
# condition         MgSO4(24g/L) sulfur source  NH4Cl(2g/L) nitrogen source  \
# mutated features
# ackA-pta                            0.000000                     0.000000
# agrA                                0.000000                     0.000000
# araBAD                              0.000000                     0.000000
# cpxRA                               2.850397                     2.850397
# csgDEFG                             0.000000                     0.000000
#
# condition         NaCl(1g/L) trace elements supplement  \
# mutated features
# ackA-pta                                      0.000000
# agrA                                          0.000000
# araBAD                                        0.000000
# cpxRA                                         2.850397
# csgDEFG                                       0.000000
#
# condition         U-13C glucose(2g/L) carbon source  \
# mutated features
# ackA-pta                                        0.0
# agrA                                            0.0
# araBAD                                          0.0
# cpxRA                                           0.0
# csgDEFG                                         0.0
#
# condition         acetate(4g/L) carbon source  glucose(2g/L) carbon source  \
# mutated features
# ackA-pta                                  0.0                          0.0
# agrA                                      0.0                          0.0
# araBAD                                    0.0                          0.0
# cpxRA                                     0.0                          0.0
# csgDEFG                                   0.0                          0.0
#
# condition         glucose(4g/L) carbon source  \
# mutated features
# ackA-pta                                  0.0
# agrA                                      0.0
# araBAD                                    0.0
# cpxRA                                     0.0
# csgDEFG                                   0.0
#
# condition         glucose(4g/L) or acetate(4g/L) carbon source  \
# mutated features
# ackA-pta                                                   0.0
# agrA                                                       0.0
# araBAD                                                     0.0
# cpxRA                                                      0.0
# csgDEFG                                                    0.0
#
# condition         glucose(4g/L) or glycerol(2.5g/L) carbon source  \
# mutated features
# ackA-pta                                                      0.0
# agrA                                                          0.0
# araBAD                                                        0.0
# cpxRA                                                         0.0
# csgDEFG                                                       0.0
#
# condition         glucose(4g/L) or xylose(4g/L) carbon source  \
# mutated features
# ackA-pta                                                  0.0
# agrA                                                      0.0
# araBAD                                                    0.0
# cpxRA                                                     0.0
# csgDEFG                                                   0.0
#
# condition         glycerol(2.5g/L) carbon source  \
# mutated features
# ackA-pta                                     0.0
# agrA                                         0.0
# araBAD                                       0.0
# cpxRA                                        0.0
# csgDEFG                                      0.0
#
# condition         glycine(2mM), L-serine supplement  xylose(4) carbon source  \
# mutated features
# ackA-pta                                        0.0                      0.0
# agrA                                            0.0                      0.0
# araBAD                                          0.0                      0.0
# cpxRA                                           0.0                      0.0
# csgDEFG                                         0.0                      0.0
#
# condition         Δgnd strain  Δpgi strain  Δpts strain  \
# mutated features
# ackA-pta                  0.0     1.787185     0.000000
# agrA                      0.0     0.000000     0.000000
# araBAD                    0.0     0.000000     3.763781
# cpxRA                     0.0     0.000000     0.000000
# csgDEFG                   0.0     0.000000     0.000000
#
# condition         ΔsdaA ΔsdaB ΔtdcG ΔglyA strain  Δsdh strain  Δtpi strain  \
# mutated features
# ackA-pta                                     0.0          0.0          0.0
# agrA                                         0.0          0.0          0.0
# araBAD                                       0.0          0.0          0.0
# cpxRA                                        0.0          0.0          0.0
# csgDEFG                                      0.0          0.0          0.0
#
# condition         NaCl(0.5g/L) trace elements supplement  WT strain  \
# mutated features
# ackA-pta                                               0          0
# agrA                                                   0          0
# araBAD                                                 0          0
# cpxRA                                                  0          0
# csgDEFG                                                0          0
#
# condition         $\it{E. coli}$ K-12 MG1655' organism  M9 base media  \
# mutated features
# ackA-pta                                             0              0
# agrA                                                 0              0
# araBAD                                               0              0
# cpxRA                                                0              0
# csgDEFG                                              0              0
#
# condition         NH4Cl(1g/L) nitrogen source  \
# mutated features
# ackA-pta                                    0
# agrA                                        0
# araBAD                                      0
# cpxRA                                       0
# csgDEFG                                     0
#
# condition         KH2PO4(3) Na2HPO4(6.8) phosphorous source  \
# mutated features
# ackA-pta                                                  0
# agrA                                                      0
# araBAD                                                    0
# cpxRA                                                     0
# csgDEFG                                                   0
#
# condition         MgSO4(0.24g/L) sulfur source  CaCl2(0.1mM) calcium source
# mutated features
# ackA-pta                                     0                            0
# agrA                                         0                            0
# araBAD                                       0                            0
# cpxRA                                        0                            0
# csgDEFG                                      0                            0

# %%
d = {
    "temperature": "(T)",
    "phosphorous source": "(P)",
    "sulfur source": "(S)",
    "nitrogen source": "(N)",
    "calcium source": "(Ca)",
    "supplement": "(Sp)",
    "carbon source": "(C)",
    "organism": "(O)",
}
rename_col_d = dict()
for c in log_odds_df.columns:
    for k, v in d.items():
        if k in c:
            rename_col_d[c]=c.replace(k, v)
log_odds_df = log_odds_df.rename(columns=rename_col_d)

# %%
leg = '(C) carbon source\n' + \
    '(T) temperature\n' + \
    '(N) nitrogen source\n' + \
    '(P) phosphorus source\n' + \
    '(S) sulfur source\n' + \
    '(Ca) calcium source\n' + \
    '(O) organism\n' + \
    '(Sp) supplement'
leg
# Out:
# '(C) carbon source\n(T) temperature\n(N) nitrogen source\n(P) phosphorus source\n(S) sulfur source\n(Ca) calcium source\n(O) organism\n(Sp) supplement'

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 300
plt.rcParams['font.sans-serif'] = ["Helvetica"]
sns.set_context("paper")
sns.set_style("white")

g = sns.clustermap(
    log_odds_df,
    linewidths=0.1,
    cmap="coolwarm",
#     xticklabels=False,
#     yticklabels=False,
    figsize=(7,16)
)

# Fix for recent matplotlib/seaborn issue
g.ax_heatmap.set_ylim(len(log_odds_df)+0, -0)

# g.ax_row_dendrogram.set_visible(False)
# g.ax_col_dendrogram.set_visible(False)

g.fig.suptitle(
    "Mutated operons\nand their significantly associated conditions",
    fontname="Helvetica", 
    y=0.9,
    x=0.6
)
# g.cax.set_visible(False)
g.cax.set_title("log\nodds\nratio", fontname="Helvetica")

for tick in g.cax.get_xticklabels():
    tick.set_fontname("Helvetica")
for tick in g.cax.get_yticklabels():
    tick.set_fontname("Helvetica")
    
ax = g.ax_heatmap
ax.set_xlabel("conditions", fontname="Helvetica")
ax.set_ylabel("mutated features with associations", fontname="Helvetica")


bbox_props = dict(
    boxstyle="round",
    fc="w",
    ec="0.5",
    #     alpha=0.9
)
ax.annotate(
    leg,
    xy=(1.01, -0.15),
    xycoords='axes fraction',
    #             textcoords='offset points',
    #             size=14,
    bbox=bbox_props
)

ax.tick_params(axis='both', which='both', length=0)

# g.cax.yaxis.set_ticks_position("left")
# g.ax_heatmap.set_title(
#     "Overlap of associated conditions\nwith mutated genetic features",
# )
# ax.yaxis.set_ticks_position('left')
# ax.yaxis.set_label_position("left")

# dendro_box = g.ax_row_dendrogram.get_position()
# dendro_box.x0-=0.2
# dendro_box.x1-=0.2
# g.cax.set_position(dendro_box)

# g.clustermap.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')
# set_xticklabels(rotation=30)
# g.set_xticklabels(g.get_xticklabels(), rotation=45, horizontalalignment='right')
# plt.setp(g.ax_heatmap.get_xticklabels(), rotation=45)
plt.savefig("fig.svg", format="svg")
