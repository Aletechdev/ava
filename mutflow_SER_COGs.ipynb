# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
FUNC_ANNOT = "COG"

# %%
exp_muts_df = pd.read_pickle("./data/SER_df.pkl")
display(len(exp_muts_df))
# Out:
# 27

# %%
# processing to help a cleaner order of features.
# sorts mutations by position so that mutations to proximal features will be inserted into flow_df next to each other.
exp_muts_df = exp_muts_df.sort_values(by="Position")
exp_muts_df.head()
# Out:
#      index                 Details mutation target annotation Mutation Type  \
# 1680    27         Y356C (TAC→TGC)                       thrA           SNP
# 1662     0         S357R (AGC→CGC)                       thrA           SNP
# 1672    19         S359R (AGT→AGA)                       thrA           SNP
# 1664     1  coding (31‑34/1374 nt)                       aroP           MOB
# 1687    28          L26L (TTG→TTA)                       ybhN           SNP
#
#       Position Reference Seq Sequence Change  ale  exp  flask  isolate  \
# 1680      1403           NaN             A→G    5  SER     50        1
# 1662      1405           NaN             A→C    3  SER     50        1
# 1672      1413           NaN             T→A    4  SER     50        1
# 1664    121518           NaN   IS5 (+) +4 bp    3  SER     50        1
# 1687    822421           NaN             C→T    5  SER     50        1
#
#       presence  tech_rep  coding             range gene RegulonDB ID  \
# 1680       1.0         1    True      (1403, 1403)    {ECK120000987}
# 1662       1.0         1    True      (1405, 1405)    {ECK120000987}
# 1672       1.0         1    True      (1413, 1413)    {ECK120000987}
# 1664       1.0         1    True  (121518, 121518)    {ECK120000080}
# 1687       1.0         1    True  (822421, 822421)    {ECK120003005}
#
#                                        genetic features   oriC  pseudogene  \
# 1680  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...  False       False
# 1662  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...  False       False
# 1672  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...  False       False
# 1664  [{'name': 'aroP', 'RegulonDB ID': 'ECK12000008...  False       False
# 1687  [{'name': 'ybhN', 'RegulonDB ID': 'ECK12000300...  False       False
#
#      TFBS promoter TSS RBS attenuator terminator terminator  genetic  \
# 1680   {}       {}  {}  {}                    {}         {}     True
# 1662   {}       {}  {}  {}                    {}         {}     True
# 1672   {}       {}  {}  {}                    {}         {}     True
# 1664   {}       {}  {}  {}                    {}         {}     True
# 1687   {}       {}  {}  {}                    {}         {}     True
#
#                                        genomic features  \
# 1680  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...
# 1662  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...
# 1672  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...
# 1664  [{'name': 'aroP', 'RegulonDB ID': 'ECK12000008...
# 1687  [{'name': 'ybhN', 'RegulonDB ID': 'ECK12000300...
#
#                    genetic feature links  \
# 1680  {'ECK120000987': ['ECK120000987']}
# 1662  {'ECK120000987': ['ECK120000987']}
# 1672  {'ECK120000987': ['ECK120000987']}
# 1664  {'ECK120000080': ['ECK120000080']}
# 1687  {'ECK120003005': ['ECK120003005']}
#
#                                                 operons  \
# 1680  [{'name': 'thrLABC', 'RegulonDB ID': 'ECK12001...
# 1662  [{'name': 'thrLABC', 'RegulonDB ID': 'ECK12001...
# 1672  [{'name': 'thrLABC', 'RegulonDB ID': 'ECK12001...
# 1664  [{'name': 'aroP', 'RegulonDB ID': 'ECK12001447...
# 1687  [{'name': 'ybhP-clsB-ybhN', 'RegulonDB ID': 'E...
#
#                             operon links  \
# 1680  {'ECK120014725': ['ECK120000987']}
# 1662  {'ECK120014725': ['ECK120000987']}
# 1672  {'ECK120014725': ['ECK120000987']}
# 1664  {'ECK120014477': ['ECK120000080']}
# 1687  {'ECK125160624': ['ECK120003005']}
#
#                                              regulators  \
# 1680                                                 []
# 1662                                                 []
# 1672                                                 []
# 1664  [{'name': 'TyrR', 'significantly associated co...
# 1687                                                 []
#
#                           regulator links taxonomy-id  \
# 1680             {'unknown': ['thrLABC']}      511145
# 1662             {'unknown': ['thrLABC']}      511145
# 1672             {'unknown': ['thrLABC']}      511145
# 1664  {'TyrR': ['aroP'], 'Cra': ['aroP']}      511145
# 1687      {'unknown': ['ybhP-clsB-ybhN']}      511145
#
#            strain-description base-media temperature carbon-source  \
# 1680  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1662  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1672  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1664  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1687  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
#
#      nitrogen-source phosphorous-source sulfur-source supplement  \
# 1680        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1662        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1672        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1664        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1687        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
#
#                                                    COGs  \
# 1680  [{'name': 'Amino acid transport and metabolism...
# 1662  [{'name': 'Amino acid transport and metabolism...
# 1672  [{'name': 'Amino acid transport and metabolism...
# 1664  [{'name': 'Amino acid transport and metabolism...
# 1687  [{'name': 'Function unknown', 'mutation set co...
#
#                                               COG links
# 1680  {'Amino acid transport and metabolism': ['ECK1...
# 1662  {'Amino acid transport and metabolism': ['ECK1...
# 1672  {'Amino acid transport and metabolism': ['ECK1...
# 1664  {'Amino acid transport and metabolism': ['ECK1...
# 1687             {'Function unknown': ['ECK125160624']}

# %%
exp_muts_df
# Out:
#      index                   Details mutation target annotation Mutation Type  \
# 1680    27           Y356C (TAC→TGC)                       thrA           SNP
# 1662     0           S357R (AGC→CGC)                       thrA           SNP
# 1672    19           S359R (AGT→AGA)                       thrA           SNP
# 1664     1    coding (31‑34/1374 nt)                       aroP           MOB
# 1687    28            L26L (TTG→TTA)                       ybhN           SNP
# 1679    21    intergenic (‑271/‑274)                   trxB/lrp           SNP
# 1688    29           D143G (GAC→GGC)                        lrp           SNP
# 1663     4           E250* (GAA→TAA)                       pykF           SNP
# 1665     8             S8R (AGC→CGC)                       yodD           SNP
# 1673    22           D334H (GAT→CAT)                       yojI           SNP
# 1681    30  coding (924‑932/1251 nt)                        frc           MOB
# 1674    10     intergenic (‑101/‑45)                  dapA/gcvR           DEL
# 1666    10     intergenic (‑101/‑45)                  dapA/gcvR           DEL
# 1667    17           A178V (GCG→GTG)                       gshA           SNP
# 1682    31           V164L (GTT→CTT)                        eno           SNP
# 1675    23     intergenic (‑68/+283)                  gcvA/ygdI           DEL
# 1668    12     intergenic (‑311/+28)                  gcvA/ygdI           MOB
# 1683    32           Q132K (CAG→AAG)                       argP           SNP
# 1684    33            G19V (GGC→GTC)                       tufA           SNP
# 1676    24           I202T (ATC→ACC)                        rpe           SNP
# 1669    13           Q420* (CAA→TAA)                       malT           SNP
# 1685    34     intergenic (+84/‑235)                   trxA/rho           MOB
# 1677    25            R87L (CGC→CTC)                        rho           SNP
# 1670    15           P520L (CCG→CTG)                       rpoB           SNP
# 1671    18           Q112* (CAG→TAG)                       lamB           SNP
# 1678    26     intergenic (‑154/‑64)                  ytfB/fklB           SNP
# 1686    35           I220V (ATA→GTA)                       cycA           SNP
#
#       Position Reference Seq Sequence Change  ale  exp  flask  isolate  \
# 1680      1403           NaN             A→G    5  SER     50        1
# 1662      1405           NaN             A→C    3  SER     50        1
# 1672      1413           NaN             T→A    4  SER     50        1
# 1664    121518           NaN   IS5 (+) +4 bp    3  SER     50        1
# 1687    822421           NaN             C→T    5  SER     50        1
# 1679    932321           NaN             C→T    4  SER     50        1
# 1688    933022           NaN             A→G    5  SER     50        1
# 1663   1756445           NaN             G→T    3  SER     50        1
# 1665   2025007           NaN             A→C    3  SER     50        1
# 1673   2307616           NaN             C→G    4  SER     50        2
# 1681   2492323           NaN   IS1 (–) +9 bp    5  SER     50        1
# 1674   2599861           NaN          (T)8→7    4  SER     50        1
# 1666   2599861           NaN          (T)8→7    3  SER     50        1
# 1667   2815907           NaN             G→A    3  SER     50        2
# 1682   2907452           NaN             C→G    5  SER     50        1
# 1675   2942635           NaN          (T)7→6    4  SER     50        1
# 1668   2942878           NaN  IS4 (+) +13 bp    3  SER     50        1
# 1683   3060146           NaN             C→A    5  SER     50        1
# 1684   3471274           NaN             C→A    5  SER     50        1
# 1676   3514455           NaN             A→G    4  SER     50        1
# 1669   3554342           NaN             C→T    3  SER     50        1
# 1685   3966174           NaN   IS1 (–) +9 bp    5  SER     50        1
# 1677   3966676           NaN             G→T    4  SER     50        1
# 1670   4182803           NaN             C→T    3  SER     50        1
# 1671   4248304           NaN             C→T    3  SER     50        2
# 1678   4428871           NaN             T→C    4  SER     50        1
# 1686   4430521           NaN             A→G    5  SER     50        1
#
#       presence  tech_rep  coding               range gene RegulonDB ID  \
# 1680       1.0         1    True        (1403, 1403)    {ECK120000987}
# 1662       1.0         1    True        (1405, 1405)    {ECK120000987}
# 1672       1.0         1    True        (1413, 1413)    {ECK120000987}
# 1664       1.0         1    True    (121518, 121518)    {ECK120000080}
# 1687       1.0         1    True    (822421, 822421)    {ECK120003005}
# 1679       1.0         1   False    (932321, 932321)                {}
# 1688       1.0         1    True    (933022, 933022)    {ECK120000540}
# 1663       1.0         1    True  (1756445, 1756445)    {ECK120000795}
# 1665       1.0         1    True  (2025007, 2025007)    {ECK120003632}
# 1673       1.0         1    True  (2307616, 2307616)    {ECK120001979}
# 1681       1.0         1    True  (2492323, 2492323)    {ECK120003812}
# 1674       1.0         1   False  (2599861, 2599861)                {}
# 1666       1.0         1   False  (2599861, 2599861)                {}
# 1667       1.0         1    True  (2815907, 2815907)    {ECK120000411}
# 1682       1.0         1    True  (2907452, 2907452)    {ECK120000252}
# 1675       1.0         1   False  (2942635, 2942635)                {}
# 1668       1.0         1   False  (2942878, 2942878)    {ECK120002579}
# 1683       1.0         1    True  (3060146, 3060146)    {ECK120000483}
# 1684       1.0         1    True  (3471274, 3471274)    {ECK120001025}
# 1676       1.0         1    True  (3514455, 3514455)    {ECK120004466}
# 1669       1.0         1    True  (3554342, 3554342)    {ECK120000555}
# 1685       1.0         1   False  (3966174, 3966174)                {}
# 1677       1.0         1    True  (3966676, 3966676)    {ECK120000836}
# 1670       1.0         1    True  (4182803, 4182803)    {ECK120000885}
# 1671       1.0         1    True  (4248304, 4248304)    {ECK120000521}
# 1678       1.0         1   False  (4428871, 4428871)                {}
# 1686       1.0         1    True  (4430521, 4430521)    {ECK120002311}
#
#                                        genetic features   oriC  pseudogene  \
# 1680  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...  False       False
# 1662  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...  False       False
# 1672  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...  False       False
# 1664  [{'name': 'aroP', 'RegulonDB ID': 'ECK12000008...  False       False
# 1687  [{'name': 'ybhN', 'RegulonDB ID': 'ECK12000300...  False       False
# 1679  [{'RegulonDB ID': 'ECK120001021/ECK120000540',...  False       False
# 1688  [{'name': 'lrp', 'RegulonDB ID': 'ECK120000540...  False       False
# 1663  [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...  False       False
# 1665  [{'name': 'yodD', 'RegulonDB ID': 'ECK12000363...  False       False
# 1673  [{'name': 'yojI', 'RegulonDB ID': 'ECK12000197...  False       False
# 1681  [{'name': 'frc', 'RegulonDB ID': 'ECK120003812...  False       False
# 1674  [{'RegulonDB ID': 'ECK120000199/ECK120001132',...  False       False
# 1666  [{'RegulonDB ID': 'ECK120000199/ECK120001132',...  False       False
# 1667  [{'name': 'gshA', 'RegulonDB ID': 'ECK12000041...  False       False
# 1682  [{'name': 'eno', 'RegulonDB ID': 'ECK120000252...  False       False
# 1675  [{'RegulonDB ID': 'ECK120001729/ECK120002579',...  False       False
# 1668  [{'name': 'gcvB', 'RegulonDB ID': 'ECK12000257...  False       False
# 1683  [{'name': 'argP', 'RegulonDB ID': 'ECK12000048...  False       False
# 1684  [{'name': 'tufA', 'RegulonDB ID': 'ECK12000102...  False       False
# 1676  [{'name': 'rpe', 'RegulonDB ID': 'ECK120004466...  False       False
# 1669  [{'name': 'malT', 'RegulonDB ID': 'ECK12000055...  False       False
# 1685  [{'RegulonDB ID': 'ECK120001020/ECK120002284',...  False       False
# 1677  [{'name': 'rho', 'RegulonDB ID': 'ECK120000836...  False       False
# 1670  [{'name': 'rpoB', 'RegulonDB ID': 'ECK12000088...  False       False
# 1671  [{'name': 'lamB', 'RegulonDB ID': 'ECK12000052...  False       False
# 1678  [{'RegulonDB ID': 'ECK120004359/ECK120004360',...  False       False
# 1686  [{'name': 'cycA', 'RegulonDB ID': 'ECK12000231...  False       False
#
#                 TFBS                      promoter TSS RBS  \
# 1680              {}                            {}  {}  {}
# 1662              {}                            {}  {}  {}
# 1672              {}                            {}  {}  {}
# 1664              {}                            {}  {}  {}
# 1687              {}                            {}  {}  {}
# 1679              {}                {ECK120010239}  {}  {}
# 1688              {}                            {}  {}  {}
# 1663              {}                            {}  {}  {}
# 1665              {}                            {}  {}  {}
# 1673              {}                            {}  {}  {}
# 1681              {}                            {}  {}  {}
# 1674              {}                {ECK120010677}  {}  {}
# 1666              {}                {ECK120010677}  {}  {}
# 1667              {}                            {}  {}  {}
# 1682              {}                            {}  {}  {}
# 1675  {ECK125141479}                {ECK120010229}  {}  {}
# 1668              {}                            {}  {}  {}
# 1683              {}                            {}  {}  {}
# 1684              {}  {ECK125239105, ECK125239106}  {}  {}
# 1676              {}                            {}  {}  {}
# 1669              {}                            {}  {}  {}
# 1685              {}                {ECK120010425}  {}  {}
# 1677              {}                            {}  {}  {}
# 1670              {}  {ECK125239959, ECK125239960}  {}  {}
# 1671              {}                            {}  {}  {}
# 1678              {}  {ECK125240223, ECK120034373}  {}  {}
# 1686              {}                            {}  {}  {}
#
#      attenuator terminator terminator  genetic  \
# 1680                    {}         {}     True
# 1662                    {}         {}     True
# 1672                    {}         {}     True
# 1664                    {}         {}     True
# 1687                    {}         {}     True
# 1679                    {}         {}    False
# 1688                    {}         {}     True
# 1663                    {}         {}     True
# 1665                    {}         {}     True
# 1673                    {}         {}     True
# 1681                    {}         {}     True
# 1674                    {}         {}    False
# 1666                    {}         {}    False
# 1667                    {}         {}     True
# 1682                    {}         {}     True
# 1675                    {}         {}    False
# 1668                    {}         {}    False
# 1683                    {}         {}     True
# 1684                    {}         {}     True
# 1676                    {}         {}     True
# 1669                    {}         {}     True
# 1685                    {}         {}    False
# 1677                    {}         {}     True
# 1670                    {}         {}     True
# 1671                    {}         {}     True
# 1678                    {}         {}    False
# 1686                    {}         {}     True
#
#                                        genomic features  \
# 1680  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...
# 1662  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...
# 1672  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...
# 1664  [{'name': 'aroP', 'RegulonDB ID': 'ECK12000008...
# 1687  [{'name': 'ybhN', 'RegulonDB ID': 'ECK12000300...
# 1679  [{'name': 'lrpp', 'RegulonDB ID': 'ECK12001023...
# 1688  [{'name': 'lrp', 'RegulonDB ID': 'ECK120000540...
# 1663  [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...
# 1665  [{'name': 'yodD', 'RegulonDB ID': 'ECK12000363...
# 1673  [{'name': 'yojI', 'RegulonDB ID': 'ECK12000197...
# 1681  [{'name': 'frc', 'RegulonDB ID': 'ECK120003812...
# 1674  [{'name': 'gcvRp', 'RegulonDB ID': 'ECK1200106...
# 1666  [{'name': 'gcvRp', 'RegulonDB ID': 'ECK1200106...
# 1667  [{'name': 'gshA', 'RegulonDB ID': 'ECK12000041...
# 1682  [{'name': 'eno', 'RegulonDB ID': 'ECK120000252...
# 1675  [{'name': 'gcvB gcvA TFBS', 'RegulonDB ID': 'E...
# 1668  [{'name': 'gcvB', 'RegulonDB ID': 'ECK12000257...
# 1683  [{'name': 'argP', 'RegulonDB ID': 'ECK12000048...
# 1684  [{'name': 'tufA', 'RegulonDB ID': 'ECK12000102...
# 1676  [{'name': 'rpe', 'RegulonDB ID': 'ECK120004466...
# 1669  [{'name': 'malT', 'RegulonDB ID': 'ECK12000055...
# 1685  [{'name': 'rhoLp', 'RegulonDB ID': 'ECK1200104...
# 1677  [{'name': 'rho', 'RegulonDB ID': 'ECK120000836...
# 1670  [{'name': 'rpoB', 'RegulonDB ID': 'ECK12000088...
# 1671  [{'name': 'lamB', 'RegulonDB ID': 'ECK12000052...
# 1678  [{'name': 'ytfBp', 'RegulonDB ID': 'ECK1200343...
# 1686  [{'name': 'cycA', 'RegulonDB ID': 'ECK12000231...
#
#                                   genetic feature links  \
# 1680                 {'ECK120000987': ['ECK120000987']}
# 1662                 {'ECK120000987': ['ECK120000987']}
# 1672                 {'ECK120000987': ['ECK120000987']}
# 1664                 {'ECK120000080': ['ECK120000080']}
# 1687                 {'ECK120003005': ['ECK120003005']}
# 1679    {'ECK120001021/ECK120000540': ['ECK120010239']}
# 1688                 {'ECK120000540': ['ECK120000540']}
# 1663                 {'ECK120000795': ['ECK120000795']}
# 1665                 {'ECK120003632': ['ECK120003632']}
# 1673                 {'ECK120001979': ['ECK120001979']}
# 1681                 {'ECK120003812': ['ECK120003812']}
# 1674    {'ECK120000199/ECK120001132': ['ECK120010677']}
# 1666    {'ECK120000199/ECK120001132': ['ECK120010677']}
# 1667                 {'ECK120000411': ['ECK120000411']}
# 1682                 {'ECK120000252': ['ECK120000252']}
# 1675  {'ECK120001729/ECK120002579': ['ECK125141479',...
# 1668                 {'ECK120002579': ['ECK120002579']}
# 1683                 {'ECK120000483': ['ECK120000483']}
# 1684                 {'ECK120001025': ['ECK120001025']}
# 1676                 {'ECK120004466': ['ECK120004466']}
# 1669                 {'ECK120000555': ['ECK120000555']}
# 1685    {'ECK120001020/ECK120002284': ['ECK120010425']}
# 1677                 {'ECK120000836': ['ECK120000836']}
# 1670                 {'ECK120000885': ['ECK120000885']}
# 1671                 {'ECK120000521': ['ECK120000521']}
# 1678    {'ECK120004359/ECK120004360': ['ECK120034373']}
# 1686                 {'ECK120002311': ['ECK120002311']}
#
#                                                 operons  \
# 1680  [{'name': 'thrLABC', 'RegulonDB ID': 'ECK12001...
# 1662  [{'name': 'thrLABC', 'RegulonDB ID': 'ECK12001...
# 1672  [{'name': 'thrLABC', 'RegulonDB ID': 'ECK12001...
# 1664  [{'name': 'aroP', 'RegulonDB ID': 'ECK12001447...
# 1687  [{'name': 'ybhP-clsB-ybhN', 'RegulonDB ID': 'E...
# 1679  [{'name': 'lrp', 'RegulonDB ID': 'ECK120011629...
# 1688  [{'name': 'lrp', 'RegulonDB ID': 'ECK120011629...
# 1663  [{'name': 'pykF', 'RegulonDB ID': 'ECK12001456...
# 1665  [{'name': 'yodD', 'RegulonDB ID': 'ECK12002385...
# 1673  [{'name': 'yojI', 'RegulonDB ID': 'ECK12002867...
# 1681  [{'name': 'yfdX-frc-oxc-yfdVE', 'RegulonDB ID'...
# 1674  [{'name': 'gcvR', 'RegulonDB ID': 'ECK12001498...
# 1666  [{'name': 'gcvR', 'RegulonDB ID': 'ECK12001498...
# 1667  [{'name': 'gshA', 'RegulonDB ID': 'ECK12002858...
# 1682  [{'name': 'pyrG-eno', 'RegulonDB ID': 'ECK1200...
# 1675  [{'name': 'gcvA', 'RegulonDB ID': 'ECK12001472...
# 1668  [{'name': 'gcvB', 'RegulonDB ID': 'ECK12001496...
# 1683  [{'name': 'argP', 'RegulonDB ID': 'ECK12001120...
# 1684  [{'name': 'rpsLG-fusA-tufA', 'RegulonDB ID': '...
# 1676  [{'name': 'aroKB-damX-dam-rpe-gph-trpS', 'Regu...
# 1669  [{'name': 'malT', 'RegulonDB ID': 'ECK12001489...
# 1685  [{'name': 'rhoL-rho', 'RegulonDB ID': 'ECK1200...
# 1677  [{'name': 'rhoL-rho', 'RegulonDB ID': 'ECK1200...
# 1670  [{'name': 'rplKAJL-rpoBC', 'RegulonDB ID': 'EC...
# 1671  [{'name': 'malK-lamB-malM', 'RegulonDB ID': 'E...
# 1678  [{'name': 'ytfB', 'RegulonDB ID': 'ECK12002386...
# 1686  [{'name': 'cycA', 'RegulonDB ID': 'ECK12002810...
#
#                                            operon links  \
# 1680                 {'ECK120014725': ['ECK120000987']}
# 1662                 {'ECK120014725': ['ECK120000987']}
# 1672                 {'ECK120014725': ['ECK120000987']}
# 1664                 {'ECK120014477': ['ECK120000080']}
# 1687                 {'ECK125160624': ['ECK120003005']}
# 1679    {'ECK120011629': ['ECK120001021/ECK120000540']}
# 1688                 {'ECK120011629': ['ECK120000540']}
# 1663                 {'ECK120014561': ['ECK120000795']}
# 1665                 {'ECK120023851': ['ECK120003632']}
# 1673                 {'ECK120028677': ['ECK120001979']}
# 1681                 {'ECK125162051': ['ECK120003812']}
# 1674    {'ECK120014989': ['ECK120000199/ECK120001132']}
# 1666    {'ECK120014989': ['ECK120000199/ECK120001132']}
# 1667                 {'ECK120028585': ['ECK120000411']}
# 1682                 {'ECK120027987': ['ECK120000252']}
# 1675  {'ECK120014721': ['ECK120001729/ECK120002579',...
# 1668                 {'ECK120014960': ['ECK120002579']}
# 1683                 {'ECK120011203': ['ECK120000483']}
# 1684                 {'ECK120014637': ['ECK120001025']}
# 1676                 {'ECK120014512': ['ECK120004466']}
# 1669                 {'ECK120014899': ['ECK120000555']}
# 1685    {'ECK120016920': ['ECK120001020/ECK120002284']}
# 1677                 {'ECK120016920': ['ECK120000836']}
# 1670                 {'ECK120016992': ['ECK120000885']}
# 1671                 {'ECK120014922': ['ECK120000521']}
# 1678    {'ECK120023865': ['ECK120004359/ECK120004360']}
# 1686                 {'ECK120028102': ['ECK120002311']}
#
#                                              regulators  \
# 1680                                                 []
# 1662                                                 []
# 1672                                                 []
# 1664  [{'name': 'TyrR', 'significantly associated co...
# 1687                                                 []
# 1679  [{'name': 'GadE', 'significantly associated co...
# 1688  [{'name': 'GadE', 'significantly associated co...
# 1663  [{'name': 'Cra', 'significantly associated con...
# 1665                                                 []
# 1673  [{'name': 'Lrp', 'significantly associated con...
# 1681  [{'name': 'EvgA', 'significantly associated co...
# 1674                                                 []
# 1666                                                 []
# 1667                                                 []
# 1682  [{'name': 'Cra', 'significantly associated con...
# 1675  [{'name': 'GcvA', 'significantly associated co...
# 1668  [{'name': 'GcvA', 'significantly associated co...
# 1683  [{'name': 'PhoB', 'significantly associated co...
# 1684                                                 []
# 1676                                                 []
# 1669  [{'name': 'CRP', 'significantly associated con...
# 1685                                                 []
# 1677                                                 []
# 1670                                                 []
# 1671  [{'name': 'CRP', 'significantly associated con...
# 1678                                                 []
# 1686                                                 []
#
#                                         regulator links taxonomy-id  \
# 1680                           {'unknown': ['thrLABC']}      511145
# 1662                           {'unknown': ['thrLABC']}      511145
# 1672                           {'unknown': ['thrLABC']}      511145
# 1664                {'TyrR': ['aroP'], 'Cra': ['aroP']}      511145
# 1687                    {'unknown': ['ybhP-clsB-ybhN']}      511145
# 1679  {'H-NS': ['lrp'], 'NsrR': ['lrp'], 'Lrp': ['lr...      511145
# 1688  {'H-NS': ['lrp'], 'NsrR': ['lrp'], 'Lrp': ['lr...      511145
# 1663                                  {'Cra': ['pykF']}      511145
# 1665                              {'unknown': ['yodD']}      511145
# 1673                                  {'Lrp': ['yojI']}      511145
# 1681                   {'EvgA': ['yfdX-frc-oxc-yfdVE']}      511145
# 1674                              {'unknown': ['gcvR']}      511145
# 1666                              {'unknown': ['gcvR']}      511145
# 1667                              {'unknown': ['gshA']}      511145
# 1682                              {'Cra': ['pyrG-eno']}      511145
# 1675                 {'GcvA': ['gcvA', 'gcvB', 'gcvA']}      511145
# 1668                                 {'GcvA': ['gcvB']}      511145
# 1683               {'PhoB': ['argP'], 'ArgP': ['argP']}      511145
# 1684                   {'unknown': ['rpsLG-fusA-tufA']}      511145
# 1676       {'unknown': ['aroKB-damX-dam-rpe-gph-trpS']}      511145
# 1669  {'CRP': ['malT'], 'Lrp': ['malT'], 'Mlc': ['ma...      511145
# 1685                          {'unknown': ['rhoL-rho']}      511145
# 1677                          {'unknown': ['rhoL-rho']}      511145
# 1670                     {'unknown': ['rplKAJL-rpoBC']}      511145
# 1671  {'CRP': ['malK-lamB-malM'], 'MalT': ['malK-lam...      511145
# 1678                              {'unknown': ['ytfB']}      511145
# 1686                              {'unknown': ['cycA']}      511145
#
#            strain-description base-media temperature carbon-source  \
# 1680  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1662  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1672  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1664  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1687  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1679  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1688  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1663  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1665  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1673  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1681  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1674  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1666  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1667  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1682  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1675  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1668  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1683  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1684  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1676  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1669  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1685  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1677  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1670  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1671  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1678  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
# 1686  ΔsdaA ΔsdaB ΔtdcG ΔglyA         M9  37 celsius    glucose(4)
#
#      nitrogen-source phosphorous-source sulfur-source supplement  \
# 1680        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1662        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1672        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1664        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1687        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1679        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1688        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1663        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1665        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1673        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1681        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1674        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1666        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1667        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1682        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1675        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1668        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1683        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1684        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1676        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1669        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1685        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1677        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1670        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1671        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1678        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
# 1686        NH4Cl(1)          KH2PO4(3)   MgSO4(0.24)   L-Serine
#
#                                                    COGs  \
# 1680  [{'name': 'Amino acid transport and metabolism...
# 1662  [{'name': 'Amino acid transport and metabolism...
# 1672  [{'name': 'Amino acid transport and metabolism...
# 1664  [{'name': 'Amino acid transport and metabolism...
# 1687  [{'name': 'Function unknown', 'mutation set co...
# 1679  [{'name': 'Transcription', 'mutation set count...
# 1688  [{'name': 'Transcription', 'mutation set count...
# 1663  [{'name': 'Carbohydrate transport and metaboli...
# 1665                                                 []
# 1673  [{'name': 'Inorganic ion transport and metabol...
# 1681  [{'name': 'Lipid transport and metabolism', 'm...
# 1674  [{'name': 'Amino acid transport and metabolism...
# 1666  [{'name': 'Amino acid transport and metabolism...
# 1667  [{'name': 'Coenzyme transport and metabolism',...
# 1682  [{'name': 'Carbohydrate transport and metaboli...
# 1675  [{'name': 'Transcription', 'mutation set count...
# 1668                                                 []
# 1683  [{'name': 'Transcription', 'mutation set count...
# 1684  [{'name': 'Translation, ribosomal structure an...
# 1676  [{'name': 'Carbohydrate transport and metaboli...
# 1669  [{'name': 'Transcription', 'mutation set count...
# 1685  [{'name': 'Transcription', 'mutation set count...
# 1677  [{'name': 'Transcription', 'mutation set count...
# 1670  [{'name': 'Transcription', 'mutation set count...
# 1671  [{'name': 'Carbohydrate transport and metaboli...
# 1678  [{'name': 'Function unknown', 'mutation set co...
# 1686  [{'name': 'Amino acid transport and metabolism...
#
#                                               COG links
# 1680  {'Amino acid transport and metabolism': ['ECK1...
# 1662  {'Amino acid transport and metabolism': ['ECK1...
# 1672  {'Amino acid transport and metabolism': ['ECK1...
# 1664  {'Amino acid transport and metabolism': ['ECK1...
# 1687             {'Function unknown': ['ECK125160624']}
# 1679                {'Transcription': ['ECK120011629']}
# 1688                {'Transcription': ['ECK120011629']}
# 1663  {'Carbohydrate transport and metabolism': ['EC...
# 1665             {'Function unknown': ['ECK120023851']}
# 1673  {'Inorganic ion transport and metabolism': ['E...
# 1681  {'Lipid transport and metabolism': ['ECK125162...
# 1674  {'Amino acid transport and metabolism': ['ECK1...
# 1666  {'Amino acid transport and metabolism': ['ECK1...
# 1667  {'Coenzyme transport and metabolism': ['ECK120...
# 1682  {'Carbohydrate transport and metabolism': ['EC...
# 1675  {'Transcription': ['ECK120014721', 'ECK1200147...
# 1668             {'Function unknown': ['ECK120014960']}
# 1683                {'Transcription': ['ECK120011203']}
# 1684  {'Translation, ribosomal structure and biogene...
# 1676  {'Carbohydrate transport and metabolism': ['EC...
# 1669                {'Transcription': ['ECK120014899']}
# 1685  {'Function unknown': ['ECK120016920'], 'Transc...
# 1677                {'Transcription': ['ECK120016920']}
# 1670                {'Transcription': ['ECK120016992']}
# 1671  {'Carbohydrate transport and metabolism': ['EC...
# 1678             {'Function unknown': ['ECK120023865']}
# 1686  {'Amino acid transport and metabolism': ['ECK1...

# %%
col_l = [
    "Mutation Type",
    "genomic features",
    "genetic features",
    "genetic feature links",
    "operons",
    "operon links",
    "COGs",
    "COG links",
]

annot_df = exp_muts_df.copy()
annot_df = annot_df[col_l]


display(annot_df.shape, annot_df.head())
# Out:
# (27, 8)
#      Mutation Type                                   genomic features  \
# 1680           SNP  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...
# 1662           SNP  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...
# 1672           SNP  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...
# 1664           MOB  [{'name': 'aroP', 'RegulonDB ID': 'ECK12000008...
# 1687           SNP  [{'name': 'ybhN', 'RegulonDB ID': 'ECK12000300...
#
#                                        genetic features  \
# 1680  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...
# 1662  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...
# 1672  [{'name': 'thrA', 'RegulonDB ID': 'ECK12000098...
# 1664  [{'name': 'aroP', 'RegulonDB ID': 'ECK12000008...
# 1687  [{'name': 'ybhN', 'RegulonDB ID': 'ECK12000300...
#
#                    genetic feature links  \
# 1680  {'ECK120000987': ['ECK120000987']}
# 1662  {'ECK120000987': ['ECK120000987']}
# 1672  {'ECK120000987': ['ECK120000987']}
# 1664  {'ECK120000080': ['ECK120000080']}
# 1687  {'ECK120003005': ['ECK120003005']}
#
#                                                 operons  \
# 1680  [{'name': 'thrLABC', 'RegulonDB ID': 'ECK12001...
# 1662  [{'name': 'thrLABC', 'RegulonDB ID': 'ECK12001...
# 1672  [{'name': 'thrLABC', 'RegulonDB ID': 'ECK12001...
# 1664  [{'name': 'aroP', 'RegulonDB ID': 'ECK12001447...
# 1687  [{'name': 'ybhP-clsB-ybhN', 'RegulonDB ID': 'E...
#
#                             operon links  \
# 1680  {'ECK120014725': ['ECK120000987']}
# 1662  {'ECK120014725': ['ECK120000987']}
# 1672  {'ECK120014725': ['ECK120000987']}
# 1664  {'ECK120014477': ['ECK120000080']}
# 1687  {'ECK125160624': ['ECK120003005']}
#
#                                                    COGs  \
# 1680  [{'name': 'Amino acid transport and metabolism...
# 1662  [{'name': 'Amino acid transport and metabolism...
# 1672  [{'name': 'Amino acid transport and metabolism...
# 1664  [{'name': 'Amino acid transport and metabolism...
# 1687  [{'name': 'Function unknown', 'mutation set co...
#
#                                               COG links
# 1680  {'Amino acid transport and metabolism': ['ECK1...
# 1662  {'Amino acid transport and metabolism': ['ECK1...
# 1672  {'Amino acid transport and metabolism': ['ECK1...
# 1664  {'Amino acid transport and metabolism': ['ECK1...
# 1687             {'Function unknown': ['ECK125160624']}

# %%
# Just removing all "Function unknown" links since connections to this COG isn't useful.
# for i, r in annot_df.iterrows():
#     if "Function unknown" in r["COG links"].keys():
#         del r["COG links"]["Function unknown"]

# %%
mut_type_feat_effect_counts = dict()
genomic_feat_counts = dict()
genetic_feat_counts = dict()
operon_counts = dict()
COG_counts = dict()
regulator_counts = dict()
pathway_counts = dict()
imodulon_counts = dict()

for _, r in annot_df.iterrows():
    
    for genomic_feat in r["genomic features"]:
        
        # These are usually exclusive of each other per feature.
        # There is a design problem here: A multi-feature mutation could disrupt feature (gene) and repair another.
        # Need to measure the predicted effect per feature rather than mutation to enable this (considering a design bug fix).
        effect = ""
#         if r["disrupt"]: effect = "disrupt"
#         if r["repaired"]: effect = "repair"
            
        mut_type_feat_effect = genomic_feat["name"] + ' ' + r["Mutation Type"] + ' ' + effect
        if mut_type_feat_effect not in mut_type_feat_effect_counts.keys():
            mut_type_feat_effect_counts[mut_type_feat_effect] = 0
        mut_type_feat_effect_counts[mut_type_feat_effect] += 1
    
    for genomic_feat in r["genomic features"]:
        genomic_feat_annot = genomic_feat["RegulonDB ID"] #+ ' ' + r["Mutation Type"]
        if genomic_feat_annot not in genomic_feat_counts.keys():
            genomic_feat_counts[genomic_feat_annot] = 0
        genomic_feat_counts[genomic_feat_annot] += 1

    for genetic_feat, links in r["genetic feature links"].items():
        if genetic_feat not in genetic_feat_counts.keys():
            genetic_feat_counts[genetic_feat] = 0
        genetic_feat_counts[genetic_feat] += len(links)

    for operon, links in r["operon links"].items():
        if operon not in operon_counts.keys():
            operon_counts[operon] = 0
        operon_counts[operon] += len(links)

    for COG, links in r["COG links"].items():
        if COG not in COG_counts.keys():
            COG_counts[COG] = 0
        COG_counts[COG] += len(links)

# %%
operon_df = pd.read_pickle("./data/operon_df.pkl")
operon_df.head()
# Out:
#       OPERON_ID OPERON_NAME  FIRSTGENEPOSLEFT  LASTGENEPOSRIGHT  \
# 0  ECK120011191         rob           4634441           4635310
# 1  ECK120011203        argP           3059753           3060646
# 2  ECK120011329        lrhA           2405703           2406641
# 3  ECK120011490        rtcR           3558268           3559866
# 4  ECK120011629         lrp            932595            933089
#
#    REGULATIONPOSLEFT  REGULATIONPOSRIGHT OPERON_STRAND  \
# 0            4634441             4635382       reverse
# 1            3059684             3060680       forward
# 2            2405703             2406866       reverse
# 3            3558268             3559866       forward
# 4             932265              933089       forward
#
#    OPERON_INTERNAL_COMMENT KEY_ID_ORG               range
# 0                      NaN      ECK12  (4634441, 4635382)
# 1                      NaN      ECK12  (3059684, 3060680)
# 2                      NaN      ECK12  (2405703, 2406866)
# 3                      NaN      ECK12  (3558268, 3559866)
# 4                      NaN      ECK12    (932265, 933089)

# %%
from util.feature import get_feat_d

# %%
# operon names can be the same as a gene, which is problemmatic for floweaver
def _adjust_name_for_floweaver(operon):
    return operon + ' '


# Will probably have to put elsewhere at some point due to annotation work (count, significance)
mut_feat_effects = list()
genomic_feats = list()
genetic_feats = list()
operons = list()
COGs = list()


flow_df = pd.DataFrame()
for _, r in annot_df.iterrows():
    

    for genomic_feat_d in r["genomic features"]:
        
        effect = ""
#         if r["disrupt"]: effect = "disrupt"
#         if r["repaired"]: effect = "repair"    
        mut_type_feat_effect = genomic_feat_d["name"] + ' ' + r["Mutation Type"] + ' ' + effect
        mut_type_feat_effect = str(mut_type_feat_effect_counts[mut_type_feat_effect]) + ' ' + mut_type_feat_effect
        mut_feat_effects.append(mut_type_feat_effect)
            
        genomic_feat_annot = ""
        mut_count = genomic_feat_counts[genomic_feat_d["RegulonDB ID"]]
        if genomic_feat_d["significant"] and mut_count > 1: genomic_feat_annot += "*"
        genomic_feat_annot += str(mut_count) + ' '
        genomic_feat_annot += str(genomic_feat_d["name"])
        flow_row = {
            "source": genomic_feat_annot,
            "target": mut_type_feat_effect,
#                 "type": r["mutation effect"],
            "type": "unknown",
            "value": 1
        }
        flow_df = flow_df.append(flow_row, ignore_index=True)
        
    
    
    for genetic_feat_ID, genomic_feat_set in r["genetic feature links"].items():
        genetic_feat_d = get_feat_d(RegulonDB_ID=genetic_feat_ID, json=r["genetic features"])
        genetic_feat_annot = ""
        mut_count = genetic_feat_counts[genetic_feat_ID]
        if genetic_feat_d["significant"] and mut_count > 1: genetic_feat_annot += "*"
        genetic_feat_annot += str(mut_count) + ' '
        genetic_feat_annot += str(genetic_feat_d["name"])
        genetic_feats.append(genetic_feat_annot)
        for genomic_feat_ID in genomic_feat_set:
            genomic_feat_d = get_feat_d(RegulonDB_ID=genomic_feat_ID, json=r["genomic features"])
            k = genomic_feat_ID #+ ' ' + r["Mutation Type"]
            genomic_feat_annot = ""
            mut_count = genomic_feat_counts[k]
            if genomic_feat_d["significant"] and mut_count > 1: genomic_feat_annot += "*"
            genomic_feat_annot += str(mut_count) + ' '
            genomic_feat_annot += str(genomic_feat_d["name"]) #+ ' ' + r["Mutation Type"]
#             if r["disrupt"]: genomic_feat_annot += " disrupt"
#             if r["repaired"]: genomic_feat_annot += " repair"
            genomic_feats.append(genomic_feat_annot)
            flow_row = {
                "source": genetic_feat_annot,
                "target": genomic_feat_annot,
#                 "type": r["mutation effect"],
                "type": "unknown",
                "value": 1
            }
            flow_df = flow_df.append(flow_row, ignore_index=True)
    
    
    for operon_id, gen_targs in r["operon links"].items():
        operon_d = get_feat_d(RegulonDB_ID=operon_id, json=r["operons"])
        operon_name = _adjust_name_for_floweaver(operon_d["name"])
        operon_annot = ""
        mut_count = operon_counts[operon_id]
        if operon_d["significant"] and mut_count > 1: operon_annot += "*"
        operon_annot += str(mut_count) + ' '
        operon_annot += operon_name
        operons.append(operon_annot)
        for genetic_feat_ID in gen_targs:
            genetic_feat_d = get_feat_d(RegulonDB_ID=genetic_feat_ID, json=r["genetic features"])
            genetic_feat_annot = ""
            mut_count = genetic_feat_counts[genetic_feat_ID]
            if genetic_feat_d["significant"] and mut_count > 1: genetic_feat_annot += "*"
            genetic_feat_annot += str(mut_count) + ' '
            genetic_feat_annot += str(genetic_feat_d["name"])
            genetic_feats.append(genetic_feat_annot)
            flow_row = {
                "source": operon_annot,
                "target": genetic_feat_annot,
#                 "type": r["mutation effect"],
                "type": "unknown",
                "value": 1
            }
            flow_df = flow_df.append(flow_row, ignore_index=True)
            
                
    if FUNC_ANNOT == "COG":
        for COG, ops in r["COG links"].items():
            COG_feat_d = get_feat_d(name=COG, json=r["COGs"])
            COG_annot = ""
            mut_count = COG_counts[COG]
            if COG_feat_d["significant"] and mut_count > 1: COG_annot += "*"
            COG_annot += str(mut_count) + ' ' + COG_feat_d["name"]
            COGs.append(COG_annot)
            for operon_id in ops:
                op_feat_d = get_feat_d(RegulonDB_ID=operon_id, json=r["operons"])
                operon_name = operon_df[operon_df["OPERON_ID"]==operon].iloc[0]["OPERON_NAME"]
                operon_name = _adjust_name_for_floweaver(op_feat_d["name"])
                operon_annot = ""
                mut_count = operon_counts[op_feat_d["RegulonDB ID"]]
                if op_feat_d["significant"] and mut_count > 1: operon_annot += "*"
                operon_annot += str(mut_count) + ' '
                operon_annot += operon_name
                operons.append(operon_annot)
                flow_row = {
                    "source": COG_annot,
                    "target": operon_annot,
#                     "type": r["mutation effect"],
                    "type": "unknown",
                    "value": 1
                }
                flow_df = flow_df.append(flow_row, ignore_index=True)
    
display(flow_df[:20])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-e9b84ad775a3> in <module>
#     103             COG_annot = ""
#     104             mut_count = COG_counts[COG]
# --> 105             if COG_feat_d["significant"] and mut_count > 1: COG_annot += "*"
#     106             COG_annot += str(mut_count) + ' ' + COG_feat_d["name"]
#     107             COGs.append(COG_annot)
#
# KeyError: 'significant'

# %%
# processing to help a cleaner order of features.
# remove duplicates but maintains the order established above
def remove_duplicates(feats):
    l = list()
    for x in feats:
        if x not in l:
            l.append(x)
    return l

mut_feat_effects = remove_duplicates(mut_feat_effects)
genomic_feats = remove_duplicates(genomic_feats)
genetic_feats = remove_duplicates(genetic_feats)
operons = remove_duplicates(operons)
COGs = remove_duplicates(COGs)

# %%
from ipysankeywidget import SankeyWidget
from floweaver import *


nodes = {
    "mutation": ProcessGroup(mut_feat_effects, title="mutation"),
    "genomic feature": ProcessGroup(genomic_feats, title="genomic feature"),
    "genetic feature": ProcessGroup(genetic_feats, title="genetic feature"),
    "operon": ProcessGroup(operons, title="operon"),
}

l = []
if FUNC_ANNOT == "COG": l = COGs
nodes[FUNC_ANNOT] = ProcessGroup(l, title=FUNC_ANNOT)


# !!! These partition DFs need to have accessible variables (ex: mut_type_partition) accessible external to the nodes
# otherwise floweaver will crash during its rendering step.
mutation_partition = Partition.Simple("process", mut_feat_effects)
nodes["mutation"].partition = mutation_partition

genomic_feat_partition = Partition.Simple("process", genomic_feats)
nodes["genomic feature"].partition = genomic_feat_partition

genetic_feat_partition = Partition.Simple("process", genetic_feats)
nodes["genetic feature"].partition = genetic_feat_partition

operon_partition = Partition.Simple("process", operons)
nodes["operon"].partition = operon_partition

nodes[FUNC_ANNOT].partition = Partition.Simple("process", l)


# The order that the labels is entered into the bundles is explicit. Don't arbitrarily give an order.
bundles = [
    Bundle(
        "genomic feature",
        "mutation"
    ),
    Bundle(
        "genetic feature",
        "genomic feature",
    ),
    Bundle(
        "operon",
        "genetic feature",
    ),
    Bundle(
        FUNC_ANNOT,
        "operon",
    ),
]

ordering = [
    [FUNC_ANNOT],
    ["operon"],
    ["genetic feature"],
    ["genomic feature"],
    ["mutation"]
]

#
# mut_effect_partition = Partition.Simple(
#     "type", ["unknown", "disrupt", "repaired"])
sdd = SankeyDefinition(nodes,
                       bundles,
                       ordering,
#                        flow_partition=mut_effect_partition
                      )


# p_d = {"disrupt": "#C44E52", "unknown": "#6BAAD3", "repaired": "#55A868"}
p_d = {"disrupt": "#6BAAD3", "unknown": "#6BAAD3", "repaired": "#6BAAD3"}
# size = dict(width=3000, height=4000)
# size = dict(width=2000, height=2500)
# size = dict(width=1600, height=1000)
size = dict(width=1250, height=400)
# size = dict(width=1600, height=500)
# size = dict(width=1100, height=300)
# size = dict(width=1350, height=300)
# size = dict(width=1000, height=200)
results = weave(sdd,
                flow_df,
                palette=p_d,
                ).to_widget(
    margins=dict(left=400, right=350),
    **size)
results.auto_save_svg("mutflow.svg")
results.auto_save_png("mutflow.png")
results
