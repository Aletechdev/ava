# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
# FUNC_ANNOT = "pathway"
# FUNC_ANNOT = "COG"
FUNC_ANNOT = "regulon"
# FUNC_ANNOT = "imodulon"

# %%
muts_df = pd.read_pickle("./data/PGI_df.pkl")
display(len(muts_df),
       )
# Out:
# 64

# %%
muts_df = muts_df[
    (muts_df["mutation target annotation"].str.contains("sthA"))
    | (muts_df["mutation target annotation"].str.contains("pnt"))
]
muts_df
# Out:
#      index                   Details mutation target annotation Mutation Type  \
# 961      1     intergenic (‑75/‑446)                  pntA/ydgH           MOB
# 964      3           S317G (AGC→GGC)                       sthA           SNP
# 971     10            S66* (TCA→TAA)                       pntA           SNP
# 975     14     intergenic (‑64/‑270)                  sthA/fabR           SNP
# 980     19     intergenic (‑64/‑270)                  sthA/fabR           SNP
# 981     21      coding (430/1389 nt)                       pntB           DEL
# 1003    39  coding (677‑687/1533 nt)                       pntA           DEL
# 1006    14     intergenic (‑64/‑270)                  sthA/fabR           SNP
# 1011    45            G20S (GGC→AGC)                       sthA           SNP
# 1012    14     intergenic (‑64/‑270)                  sthA/fabR           SNP
# 1016    45            G20S (GGC→AGC)                       sthA           SNP
# 1017    14     intergenic (‑64/‑270)                  sthA/fabR           SNP
# 1020    50      coding (682/1389 nt)                       pntB           INS
#
#       Position Reference Seq Sequence Change  ale  exp  flask  isolate  \
# 961    1677978           NaN   IS5 (+) +4 bp    1  PGI     50        1
# 964    4159842           NaN             T→C    1  PGI     50        1
# 971    1677707           NaN             G→T    2  PGI     50        1
# 975    4160854           NaN             C→T    2  PGI     50        1
# 980    4160854           NaN             C→A    3  PGI     50        1
# 981    1675931           NaN           Δ1 bp    4  PGI     50        1
# 1003   1677217           NaN          Δ11 bp    7  PGI     50        1
# 1006   4160854           NaN             C→T    7  PGI     50        1
# 1011   4160733           NaN             C→T    8  PGI     50        1
# 1012   4160854           NaN             C→T    8  PGI     50        1
# 1016   4160733           NaN             C→T    9  PGI     50        1
# 1017   4160854           NaN             C→T    9  PGI     50        1
# 1020   1675679           NaN     (AGCCGC)2→3   10  PGI     50        1
#
#       presence  tech_rep  coding               range gene RegulonDB ID  \
# 961        1.0         1   False  (1677978, 1677978)                {}
# 964        1.0         1    True  (4159842, 4159842)    {ECK120001392}
# 971        1.0         1    True  (1677707, 1677707)    {ECK120000735}
# 975        1.0         1   False  (4160854, 4160854)                {}
# 980        1.0         1   False  (4160854, 4160854)                {}
# 981        1.0         1    True  (1675931, 1675931)    {ECK120000736}
# 1003       1.0         1    True  (1677217, 1677227)    {ECK120000735}
# 1006       1.0         1   False  (4160854, 4160854)                {}
# 1011       1.0         1    True  (4160733, 4160733)    {ECK120001392}
# 1012       1.0         1   False  (4160854, 4160854)                {}
# 1016       1.0         1    True  (4160733, 4160733)    {ECK120001392}
# 1017       1.0         1   False  (4160854, 4160854)                {}
# 1020       1.0         1    True  (1675679, 1675679)    {ECK120000736}
#
#                                        genetic features   oriC  pseudogene  \
# 961   [{'RegulonDB ID': 'ECK120000735/ECK120003449',...  False       False
# 964   [{'name': 'sthA', 'RegulonDB ID': 'ECK12000139...  False       False
# 971   [{'name': 'pntA', 'RegulonDB ID': 'ECK12000073...  False       False
# 975   [{'RegulonDB ID': 'ECK120001392/ECK120001361',...  False       False
# 980   [{'RegulonDB ID': 'ECK120001392/ECK120001361',...  False       False
# 981   [{'name': 'pntB', 'RegulonDB ID': 'ECK12000073...  False       False
# 1003  [{'name': 'pntA', 'RegulonDB ID': 'ECK12000073...  False       False
# 1006  [{'RegulonDB ID': 'ECK120001392/ECK120001361',...  False       False
# 1011  [{'name': 'sthA', 'RegulonDB ID': 'ECK12000139...  False       False
# 1012  [{'RegulonDB ID': 'ECK120001392/ECK120001361',...  False       False
# 1016  [{'name': 'sthA', 'RegulonDB ID': 'ECK12000139...  False       False
# 1017  [{'RegulonDB ID': 'ECK120001392/ECK120001361',...  False       False
# 1020  [{'name': 'pntB', 'RegulonDB ID': 'ECK12000073...  False       False
#
#      TFBS        promoter RBS attenuator terminator terminator  genetic  \
# 961    {}  {ECK120010629}  {}                    {}         {}    False
# 964    {}              {}  {}                    {}         {}     True
# 971    {}              {}  {}                    {}         {}     True
# 975    {}  {ECK120015386}  {}                    {}         {}    False
# 980    {}  {ECK120015386}  {}                    {}         {}    False
# 981    {}              {}  {}                    {}         {}     True
# 1003   {}              {}  {}                    {}         {}     True
# 1006   {}  {ECK120015386}  {}                    {}         {}    False
# 1011   {}              {}  {}                    {}         {}     True
# 1012   {}  {ECK120015386}  {}                    {}         {}    False
# 1016   {}              {}  {}                    {}         {}     True
# 1017   {}  {ECK120015386}  {}                    {}         {}    False
# 1020   {}              {}  {}                    {}         {}     True
#
#                                        genomic features  \
# 961   [{'name': 'pntAp', 'RegulonDB ID': 'ECK1200106...
# 964   [{'name': 'sthA', 'RegulonDB ID': 'ECK12000139...
# 971   [{'name': 'pntA', 'RegulonDB ID': 'ECK12000073...
# 975   [{'name': 'sthAp', 'RegulonDB ID': 'ECK1200153...
# 980   [{'name': 'sthAp', 'RegulonDB ID': 'ECK1200153...
# 981   [{'name': 'pntB', 'RegulonDB ID': 'ECK12000073...
# 1003  [{'name': 'pntA', 'RegulonDB ID': 'ECK12000073...
# 1006  [{'name': 'sthAp', 'RegulonDB ID': 'ECK1200153...
# 1011  [{'name': 'sthA', 'RegulonDB ID': 'ECK12000139...
# 1012  [{'name': 'sthAp', 'RegulonDB ID': 'ECK1200153...
# 1016  [{'name': 'sthA', 'RegulonDB ID': 'ECK12000139...
# 1017  [{'name': 'sthAp', 'RegulonDB ID': 'ECK1200153...
# 1020  [{'name': 'pntB', 'RegulonDB ID': 'ECK12000073...
#
#                                 genetic feature links  \
# 961   {'ECK120000735/ECK120003449': ['ECK120010629']}
# 964                {'ECK120001392': ['ECK120001392']}
# 971                {'ECK120000735': ['ECK120000735']}
# 975   {'ECK120001392/ECK120001361': ['ECK120015386']}
# 980   {'ECK120001392/ECK120001361': ['ECK120015386']}
# 981                {'ECK120000736': ['ECK120000736']}
# 1003               {'ECK120000735': ['ECK120000735']}
# 1006  {'ECK120001392/ECK120001361': ['ECK120015386']}
# 1011               {'ECK120001392': ['ECK120001392']}
# 1012  {'ECK120001392/ECK120001361': ['ECK120015386']}
# 1016               {'ECK120001392': ['ECK120001392']}
# 1017  {'ECK120001392/ECK120001361': ['ECK120015386']}
# 1020               {'ECK120000736': ['ECK120000736']}
#
#                                                 operons  \
# 961   [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...
# 964   [{'name': 'sthA', 'RegulonDB ID': 'ECK12001592...
# 971   [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...
# 975   [{'name': 'sthA', 'RegulonDB ID': 'ECK12001592...
# 980   [{'name': 'sthA', 'RegulonDB ID': 'ECK12001592...
# 981   [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...
# 1003  [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...
# 1006  [{'name': 'sthA', 'RegulonDB ID': 'ECK12001592...
# 1011  [{'name': 'sthA', 'RegulonDB ID': 'ECK12001592...
# 1012  [{'name': 'sthA', 'RegulonDB ID': 'ECK12001592...
# 1016  [{'name': 'sthA', 'RegulonDB ID': 'ECK12001592...
# 1017  [{'name': 'sthA', 'RegulonDB ID': 'ECK12001592...
# 1020  [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...
#
#                                          operon links regulators  \
# 961   {'ECK120014614': ['ECK120000735/ECK120003449']}         []
# 964                {'ECK120015926': ['ECK120001392']}         []
# 971                {'ECK120014614': ['ECK120000735']}         []
# 975   {'ECK120015926': ['ECK120001392/ECK120001361']}         []
# 980   {'ECK120015926': ['ECK120001392/ECK120001361']}         []
# 981                {'ECK120014614': ['ECK120000736']}         []
# 1003               {'ECK120014614': ['ECK120000735']}         []
# 1006  {'ECK120015926': ['ECK120001392/ECK120001361']}         []
# 1011               {'ECK120015926': ['ECK120001392']}         []
# 1012  {'ECK120015926': ['ECK120001392/ECK120001361']}         []
# 1016               {'ECK120015926': ['ECK120001392']}         []
# 1017  {'ECK120015926': ['ECK120001392/ECK120001361']}         []
# 1020               {'ECK120014614': ['ECK120000736']}         []
#
#      regulator links                                           pathways  \
# 961               {}  [{'name': 'Nicotinate and nicotinamide metabol...
# 964               {}  [{'name': 'Nicotinate and nicotinamide metabol...
# 971               {}  [{'name': 'Nicotinate and nicotinamide metabol...
# 975               {}  [{'name': 'Nicotinate and nicotinamide metabol...
# 980               {}  [{'name': 'Nicotinate and nicotinamide metabol...
# 981               {}  [{'name': 'Nicotinate and nicotinamide metabol...
# 1003              {}  [{'name': 'Nicotinate and nicotinamide metabol...
# 1006              {}  [{'name': 'Nicotinate and nicotinamide metabol...
# 1011              {}  [{'name': 'Nicotinate and nicotinamide metabol...
# 1012              {}  [{'name': 'Nicotinate and nicotinamide metabol...
# 1016              {}  [{'name': 'Nicotinate and nicotinamide metabol...
# 1017              {}  [{'name': 'Nicotinate and nicotinamide metabol...
# 1020              {}  [{'name': 'Nicotinate and nicotinamide metabol...
#
#                                           pathway links  \
# 961   {'Nicotinate and nicotinamide metabolism': ['E...
# 964   {'Nicotinate and nicotinamide metabolism': ['E...
# 971   {'Nicotinate and nicotinamide metabolism': ['E...
# 975   {'Nicotinate and nicotinamide metabolism': ['E...
# 980   {'Nicotinate and nicotinamide metabolism': ['E...
# 981   {'Nicotinate and nicotinamide metabolism': ['E...
# 1003  {'Nicotinate and nicotinamide metabolism': ['E...
# 1006  {'Nicotinate and nicotinamide metabolism': ['E...
# 1011  {'Nicotinate and nicotinamide metabolism': ['E...
# 1012  {'Nicotinate and nicotinamide metabolism': ['E...
# 1016  {'Nicotinate and nicotinamide metabolism': ['E...
# 1017  {'Nicotinate and nicotinamide metabolism': ['E...
# 1020  {'Nicotinate and nicotinamide metabolism': ['E...
#
#                                                    COGs  \
# 961   [{'name': 'Energy production and conversion', ...
# 964   [{'name': 'Energy production and conversion', ...
# 971   [{'name': 'Energy production and conversion', ...
# 975   [{'name': 'Energy production and conversion', ...
# 980   [{'name': 'Energy production and conversion', ...
# 981   [{'name': 'Energy production and conversion', ...
# 1003  [{'name': 'Energy production and conversion', ...
# 1006  [{'name': 'Energy production and conversion', ...
# 1011  [{'name': 'Energy production and conversion', ...
# 1012  [{'name': 'Energy production and conversion', ...
# 1016  [{'name': 'Energy production and conversion', ...
# 1017  [{'name': 'Energy production and conversion', ...
# 1020  [{'name': 'Energy production and conversion', ...
#
#                                               COG links temperature  \
# 961   {'Energy production and conversion': ['ECK1200...  37 celsius
# 964   {'Energy production and conversion': ['ECK1200...  37 celsius
# 971   {'Energy production and conversion': ['ECK1200...  37 celsius
# 975   {'Energy production and conversion': ['ECK1200...  37 celsius
# 980   {'Energy production and conversion': ['ECK1200...  37 celsius
# 981   {'Energy production and conversion': ['ECK1200...  37 celsius
# 1003  {'Energy production and conversion': ['ECK1200...  37 celsius
# 1006  {'Energy production and conversion': ['ECK1200...  37 celsius
# 1011  {'Energy production and conversion': ['ECK1200...  37 celsius
# 1012  {'Energy production and conversion': ['ECK1200...  37 celsius
# 1016  {'Energy production and conversion': ['ECK1200...  37 celsius
# 1017  {'Energy production and conversion': ['ECK1200...  37 celsius
# 1020  {'Energy production and conversion': ['ECK1200...  37 celsius
#
#      carbon-source                   supplement strain-description  \
# 961     glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
# 964     glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
# 971     glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
# 975     glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
# 980     glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
# 981     glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
# 1003    glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
# 1006    glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
# 1011    glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
# 1012    glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
# 1016    glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
# 1017    glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
# 1020    glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
#
#      taxonomy-id base-media nitrogen-source      phosphorous-source  \
# 961       511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 964       511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 971       511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 975       511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 980       511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 981       511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 1003      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 1006      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 1011      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 1012      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 1016      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 1017      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 1020      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
#
#      sulfur-source calcium-source
# 961    MgSO4(0.24)     CaCl2(0.1)
# 964    MgSO4(0.24)     CaCl2(0.1)
# 971    MgSO4(0.24)     CaCl2(0.1)
# 975    MgSO4(0.24)     CaCl2(0.1)
# 980    MgSO4(0.24)     CaCl2(0.1)
# 981    MgSO4(0.24)     CaCl2(0.1)
# 1003   MgSO4(0.24)     CaCl2(0.1)
# 1006   MgSO4(0.24)     CaCl2(0.1)
# 1011   MgSO4(0.24)     CaCl2(0.1)
# 1012   MgSO4(0.24)     CaCl2(0.1)
# 1016   MgSO4(0.24)     CaCl2(0.1)
# 1017   MgSO4(0.24)     CaCl2(0.1)
# 1020   MgSO4(0.24)     CaCl2(0.1)

# %%
# processing to help a cleaner order of features.
# sorts mutations by position so that mutations to proximal features will be inserted into flow_df next to each other.
muts_df = muts_df.sort_values(by="Position")
muts_df.head()
# Out:
#      index                   Details mutation target annotation Mutation Type  \
# 1020    50      coding (682/1389 nt)                       pntB           INS
# 981     21      coding (430/1389 nt)                       pntB           DEL
# 1003    39  coding (677‑687/1533 nt)                       pntA           DEL
# 971     10            S66* (TCA→TAA)                       pntA           SNP
# 961      1     intergenic (‑75/‑446)                  pntA/ydgH           MOB
#
#       Position Reference Seq Sequence Change  ale  exp  flask  isolate  \
# 1020   1675679           NaN     (AGCCGC)2→3   10  PGI     50        1
# 981    1675931           NaN           Δ1 bp    4  PGI     50        1
# 1003   1677217           NaN          Δ11 bp    7  PGI     50        1
# 971    1677707           NaN             G→T    2  PGI     50        1
# 961    1677978           NaN   IS5 (+) +4 bp    1  PGI     50        1
#
#       presence  tech_rep  coding               range gene RegulonDB ID  \
# 1020       1.0         1    True  (1675679, 1675679)    {ECK120000736}
# 981        1.0         1    True  (1675931, 1675931)    {ECK120000736}
# 1003       1.0         1    True  (1677217, 1677227)    {ECK120000735}
# 971        1.0         1    True  (1677707, 1677707)    {ECK120000735}
# 961        1.0         1   False  (1677978, 1677978)                {}
#
#                                        genetic features   oriC  pseudogene  \
# 1020  [{'name': 'pntB', 'RegulonDB ID': 'ECK12000073...  False       False
# 981   [{'name': 'pntB', 'RegulonDB ID': 'ECK12000073...  False       False
# 1003  [{'name': 'pntA', 'RegulonDB ID': 'ECK12000073...  False       False
# 971   [{'name': 'pntA', 'RegulonDB ID': 'ECK12000073...  False       False
# 961   [{'RegulonDB ID': 'ECK120000735/ECK120003449',...  False       False
#
#      TFBS        promoter RBS attenuator terminator terminator  genetic  \
# 1020   {}              {}  {}                    {}         {}     True
# 981    {}              {}  {}                    {}         {}     True
# 1003   {}              {}  {}                    {}         {}     True
# 971    {}              {}  {}                    {}         {}     True
# 961    {}  {ECK120010629}  {}                    {}         {}    False
#
#                                        genomic features  \
# 1020  [{'name': 'pntB', 'RegulonDB ID': 'ECK12000073...
# 981   [{'name': 'pntB', 'RegulonDB ID': 'ECK12000073...
# 1003  [{'name': 'pntA', 'RegulonDB ID': 'ECK12000073...
# 971   [{'name': 'pntA', 'RegulonDB ID': 'ECK12000073...
# 961   [{'name': 'pntAp', 'RegulonDB ID': 'ECK1200106...
#
#                                 genetic feature links  \
# 1020               {'ECK120000736': ['ECK120000736']}
# 981                {'ECK120000736': ['ECK120000736']}
# 1003               {'ECK120000735': ['ECK120000735']}
# 971                {'ECK120000735': ['ECK120000735']}
# 961   {'ECK120000735/ECK120003449': ['ECK120010629']}
#
#                                                 operons  \
# 1020  [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...
# 981   [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...
# 1003  [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...
# 971   [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...
# 961   [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...
#
#                                          operon links regulators  \
# 1020               {'ECK120014614': ['ECK120000736']}         []
# 981                {'ECK120014614': ['ECK120000736']}         []
# 1003               {'ECK120014614': ['ECK120000735']}         []
# 971                {'ECK120014614': ['ECK120000735']}         []
# 961   {'ECK120014614': ['ECK120000735/ECK120003449']}         []
#
#      regulator links                                           pathways  \
# 1020              {}  [{'name': 'Nicotinate and nicotinamide metabol...
# 981               {}  [{'name': 'Nicotinate and nicotinamide metabol...
# 1003              {}  [{'name': 'Nicotinate and nicotinamide metabol...
# 971               {}  [{'name': 'Nicotinate and nicotinamide metabol...
# 961               {}  [{'name': 'Nicotinate and nicotinamide metabol...
#
#                                           pathway links  \
# 1020  {'Nicotinate and nicotinamide metabolism': ['E...
# 981   {'Nicotinate and nicotinamide metabolism': ['E...
# 1003  {'Nicotinate and nicotinamide metabolism': ['E...
# 971   {'Nicotinate and nicotinamide metabolism': ['E...
# 961   {'Nicotinate and nicotinamide metabolism': ['E...
#
#                                                    COGs  \
# 1020  [{'name': 'Energy production and conversion', ...
# 981   [{'name': 'Energy production and conversion', ...
# 1003  [{'name': 'Energy production and conversion', ...
# 971   [{'name': 'Energy production and conversion', ...
# 961   [{'name': 'Energy production and conversion', ...
#
#                                               COG links temperature  \
# 1020  {'Energy production and conversion': ['ECK1200...  37 celsius
# 981   {'Energy production and conversion': ['ECK1200...  37 celsius
# 1003  {'Energy production and conversion': ['ECK1200...  37 celsius
# 971   {'Energy production and conversion': ['ECK1200...  37 celsius
# 961   {'Energy production and conversion': ['ECK1200...  37 celsius
#
#      carbon-source                   supplement strain-description  \
# 1020    glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
# 981     glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
# 1003    glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
# 971     glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
# 961     glucose(2)  NaCl(0.5g/L) trace elements               Δpgi
#
#      taxonomy-id base-media nitrogen-source      phosphorous-source  \
# 1020      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 981       511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 1003      511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 971       511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
# 961       511145         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)
#
#      sulfur-source calcium-source
# 1020   MgSO4(0.24)     CaCl2(0.1)
# 981    MgSO4(0.24)     CaCl2(0.1)
# 1003   MgSO4(0.24)     CaCl2(0.1)
# 971    MgSO4(0.24)     CaCl2(0.1)
# 961    MgSO4(0.24)     CaCl2(0.1)

# %%
# # Specific to the AVA publication
# muts_df = muts_df[muts_df["mutation target annotation"].str.contains("pnt")]
# muts_df

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
#     if "CRP" in r["regulator links"].keys():
#         temp_df = temp_df.append(r)
# muts_df = temp_df

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
#     if "GlpR" in r["regulator links"].keys():
#         temp_df = temp_df.append(r)
# muts_df = temp_df
# len(muts_df)

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
#     if "Mlc" in r["regulator links"].keys():
#         temp_df = temp_df.append(r)
# muts_df = temp_df
# len(muts_df)

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
# #     if "Nucleotide transport and metabolism" in r["COG links"].keys() \
#     if "cyaA" in r["RegulonDB Gene"]:
#         temp_df = temp_df.append(r)
# muts_df = temp_df
# len(muts_df)

# %%
# # Specific to the AVA publication
# temp_df = pd.DataFrame()
# for i, r in muts_df.iterrows():
#     if "Glycerolipid metabolism" in r["pathway links"].keys():
#         temp_df = temp_df.append(r)
# muts_df = temp_df
# len(muts_df)

# %%
# df = muts_df.copy()
# df["significantly associated condition set"] = df["significantly associated condition set"].apply(
#     lambda x: str(x))
# display(df["significantly associated condition set"].unique())


# # GYD
# muts_df = muts_df[
#     (muts_df["significantly associated condition set"]=={'glycerol(2.5)'})
#     | (muts_df["significantly associated condition set"]=={'glycerol(2.5)', "BOP27"})
# ]

# # SER
# # muts_df = muts_df[
# #     muts_df["significantly associated condition set"] == {'ΔsdaA ΔsdaB ΔtdcG ΔglyA', 'L-Serine'}]

# # # GLU
# # muts_df = muts_df[
# #     muts_df["significantly associated condition set"]=={'glucose(2)'}]



# # muts_df = muts_df[
# #     muts_df["significantly associated condition set"]==set()]


# # muts_df = muts_df[
# #     muts_df["significantly associated condition set"]=={'log', '511145', 'M9'}]


# display(len(muts_df), muts_df.head())

# %%
col_l = [
    "Mutation Type",
#     "disrupt",
#     "repaired",
    "genomic features",
    "genetic features",
    "genetic feature links",
    "operons",
    "operon links",
    "regulators",
    "regulator links",
#     "COGs",
#     "COG links",
#     "pathways",
#     "pathway links",
#     "imodulons",
#     "imodulon links",
#     "RegulonDB Gene"  # for debugging
]

annot_df = muts_df.copy()
annot_df = annot_df[col_l]
# annot_df["mutation effect"] = annot_df.apply(lambda mut_row:"repaired" if mut_row["repaired"] else ("disrupt" if mut_row["disrupt"] else "unknown"), axis=1)


display(annot_df.shape, annot_df.head())
# Out:
# (13, 8)
#      Mutation Type                                   genomic features  \
# 1020           INS  [{'name': 'pntB', 'RegulonDB ID': 'ECK12000073...
# 981            DEL  [{'name': 'pntB', 'RegulonDB ID': 'ECK12000073...
# 1003           DEL  [{'name': 'pntA', 'RegulonDB ID': 'ECK12000073...
# 971            SNP  [{'name': 'pntA', 'RegulonDB ID': 'ECK12000073...
# 961            MOB  [{'name': 'pntAp', 'RegulonDB ID': 'ECK1200106...
#
#                                        genetic features  \
# 1020  [{'name': 'pntB', 'RegulonDB ID': 'ECK12000073...
# 981   [{'name': 'pntB', 'RegulonDB ID': 'ECK12000073...
# 1003  [{'name': 'pntA', 'RegulonDB ID': 'ECK12000073...
# 971   [{'name': 'pntA', 'RegulonDB ID': 'ECK12000073...
# 961   [{'RegulonDB ID': 'ECK120000735/ECK120003449',...
#
#                                 genetic feature links  \
# 1020               {'ECK120000736': ['ECK120000736']}
# 981                {'ECK120000736': ['ECK120000736']}
# 1003               {'ECK120000735': ['ECK120000735']}
# 971                {'ECK120000735': ['ECK120000735']}
# 961   {'ECK120000735/ECK120003449': ['ECK120010629']}
#
#                                                 operons  \
# 1020  [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...
# 981   [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...
# 1003  [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...
# 971   [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...
# 961   [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...
#
#                                          operon links regulators  \
# 1020               {'ECK120014614': ['ECK120000736']}         []
# 981                {'ECK120014614': ['ECK120000736']}         []
# 1003               {'ECK120014614': ['ECK120000735']}         []
# 971                {'ECK120014614': ['ECK120000735']}         []
# 961   {'ECK120014614': ['ECK120000735/ECK120003449']}         []
#
#      regulator links
# 1020              {}
# 981               {}
# 1003              {}
# 971               {}
# 961               {}

# %%
# Just removing all "Function unknown" links since connections to this COG isn't useful.
# for i, r in annot_df.iterrows():
#     if "Function unknown" in r["COG links"].keys():
#         del r["COG links"]["Function unknown"]

# %%
mut_type_feat_effect_counts = dict()
genomic_feat_counts = dict()
genetic_feat_counts = dict()
operon_counts = dict()
COG_counts = dict()
regulator_counts = dict()
pathway_counts = dict()
imodulon_counts = dict()

for _, r in annot_df.iterrows():
    
    for genomic_feat in r["genomic features"]:
        
        # These are usually exclusive of each other per feature.
        # There is a design problem here: A multi-feature mutation could disrupt feature (gene) and repair another.
        # Need to measure the predicted effect per feature rather than mutation to enable this (considering a design bug fix).
        effect = ""
#         if r["disrupt"]: effect = "disrupt"
#         if r["repaired"]: effect = "repair"
            
        mut_type_feat_effect = genomic_feat["name"] + ' ' + r["Mutation Type"] + ' ' + effect
        if mut_type_feat_effect not in mut_type_feat_effect_counts.keys():
            mut_type_feat_effect_counts[mut_type_feat_effect] = 0
        mut_type_feat_effect_counts[mut_type_feat_effect] += 1
    
    for genomic_feat in r["genomic features"]:
        genomic_feat_annot = genomic_feat["RegulonDB ID"] #+ ' ' + r["Mutation Type"]
        if genomic_feat_annot not in genomic_feat_counts.keys():
            genomic_feat_counts[genomic_feat_annot] = 0
        genomic_feat_counts[genomic_feat_annot] += 1

    for genetic_feat, links in r["genetic feature links"].items():
        if genetic_feat not in genetic_feat_counts.keys():
            genetic_feat_counts[genetic_feat] = 0
        genetic_feat_counts[genetic_feat] += len(links)

    for operon, links in r["operon links"].items():
        if operon not in operon_counts.keys():
            operon_counts[operon] = 0
        operon_counts[operon] += len(links)

#     for COG, links in r["COG links"].items():
#         if COG not in COG_counts.keys():
#             COG_counts[COG] = 0
#         COG_counts[COG] += len(links)
        
    for reg, links in r["regulator links"].items():
        if reg not in regulator_counts.keys():
            regulator_counts[reg] = 0
        regulator_counts[reg] += len(links)
        
#     for pathway, links in r["pathway links"].items():
#         if pathway not in pathway_counts.keys():
#             pathway_counts[pathway] = 0
#         pathway_counts[pathway] += len(links)
        
#     for imodulon, links in r["imodulon links"].items():
#         if imodulon not in imodulon_counts.keys():
#             imodulon_counts[imodulon] = 0
#         imodulon_counts[imodulon] += len(links)

# %%
operon_df = pd.read_csv("./data/RegulonDB10/operon.txt", sep="\t", comment='#', header=None)
operon_df.columns = [
    "OPERON_ID",
    "OPERON_NAME",
    "FIRSTGENEPOSLEFT",
    "LASTGENEPOSRIGHT",
    "REGULATIONPOSLEFT",
    "REGULATIONPOSRIGHT",
    "OPERON_STRAND",
    "OPERON_INTERNAL_COMMENT",
    "KEY_ID_ORG"]
operon_df["range"] = operon_df.apply(lambda row: (row["REGULATIONPOSLEFT"], row["REGULATIONPOSRIGHT"]), axis=1)

# %%
# # For development. Delete when NB is stable.
# for _, r in annot_df.iterrows():
#     for genomic_feat_d in r["genomic features"]:
        
#         effect = ""
#         if r["disrupt"]: effect = "disrupt"
#         if r["repaired"]: effect = "repair"
            
#         mut_type_feat_effect = genomic_feat_d["name"] + ' ' + r["Mutation Type"] + ' ' + effect
#         mut_type_feat_effect = str(mut_type_feat_effect_counts[mut_type_feat_effect]) + ' ' + mut_type_feat_effect
            
#         genomic_feat_annot = ""
#         if genomic_feat_d["significant"]: genomic_feat_annot += "*"
#         genomic_feat_annot += str(genomic_feat_counts[genomic_feat_d["RegulonDB ID"]]) + ' '
#         genomic_feat_annot += str(genomic_feat_d["name"])
    
            
#         display(genomic_feat_annot + ' #### ' + mut_type_feat_effect)
# #         display(mut_type_feat_effect, "################################", r)

# %%
from util.feature import get_feat_d

# %%
# operon names can be the same as a gene, which is problemmatic for floweaver
def _adjust_name_for_floweaver(operon):
    return operon + ' '


# Will probably have to put elsewhere at some point due to annotation work (count, significance)
mut_feat_effects = list()
genomic_feats = list()
genetic_feats = list()
operons = list()
# COGs = list()
regulators = list()
# pathways = list()
# imodulons = list()


flow_df = pd.DataFrame()
for _, r in annot_df.iterrows():
    

    for genomic_feat_d in r["genomic features"]:
        
        effect = ""
#         if r["disrupt"]: effect = "disrupt"
#         if r["repaired"]: effect = "repair"    
        mut_type_feat_effect = genomic_feat_d["name"] + ' ' + r["Mutation Type"] + ' ' + effect
        mut_type_feat_effect = str(mut_type_feat_effect_counts[mut_type_feat_effect]) + ' ' + mut_type_feat_effect
        mut_feat_effects.append(mut_type_feat_effect)
            
        genomic_feat_annot = ""
        mut_count = genomic_feat_counts[genomic_feat_d["RegulonDB ID"]]
#         if genomic_feat_d["significant"] and mut_count > 1: genomic_feat_annot += "*"
        genomic_feat_annot += str(mut_count) + ' '
        genomic_feat_annot += str(genomic_feat_d["name"])
        flow_row = {
            "source": genomic_feat_annot,
            "target": mut_type_feat_effect,
#                 "type": r["mutation effect"],
            "type": "unknown",
            "value": 1
        }
        flow_df = flow_df.append(flow_row, ignore_index=True)
        
    
    
    for genetic_feat_ID, genomic_feat_set in r["genetic feature links"].items():
        genetic_feat_d = get_feat_d(RegulonDB_ID=genetic_feat_ID, json=r["genetic features"])
        genetic_feat_annot = ""
        mut_count = genetic_feat_counts[genetic_feat_ID]
#         if genetic_feat_d["significant"] and mut_count > 1: genetic_feat_annot += "*"
        genetic_feat_annot += str(mut_count) + ' '
        genetic_feat_annot += str(genetic_feat_d["name"])
        genetic_feats.append(genetic_feat_annot)
        for genomic_feat_ID in genomic_feat_set:
            genomic_feat_d = get_feat_d(RegulonDB_ID=genomic_feat_ID, json=r["genomic features"])
            k = genomic_feat_ID #+ ' ' + r["Mutation Type"]
            genomic_feat_annot = ""
            mut_count = genomic_feat_counts[k]
#             if genomic_feat_d["significant"] and mut_count > 1: genomic_feat_annot += "*"
            genomic_feat_annot += str(mut_count) + ' '
            genomic_feat_annot += str(genomic_feat_d["name"]) #+ ' ' + r["Mutation Type"]
#             if r["disrupt"]: genomic_feat_annot += " disrupt"
#             if r["repaired"]: genomic_feat_annot += " repair"
            genomic_feats.append(genomic_feat_annot)
            flow_row = {
                "source": genetic_feat_annot,
                "target": genomic_feat_annot,
#                 "type": r["mutation effect"],
                "type": "unknown",
                "value": 1
            }
            flow_df = flow_df.append(flow_row, ignore_index=True)
    
    
    for operon_id, gen_targs in r["operon links"].items():
        operon_d = get_feat_d(RegulonDB_ID=operon_id, json=r["operons"])
        operon_name = _adjust_name_for_floweaver(operon_d["name"])
        operon_annot = ""
        mut_count = operon_counts[operon_id]
#         if operon_d["significant"] and mut_count > 1: operon_annot += "*"
        operon_annot += str(mut_count) + ' '
        operon_annot += operon_name
        operons.append(operon_annot)
        for genetic_feat_ID in gen_targs:
            genetic_feat_d = get_feat_d(RegulonDB_ID=genetic_feat_ID, json=r["genetic features"])
            genetic_feat_annot = ""
            mut_count = genetic_feat_counts[genetic_feat_ID]
#             if genetic_feat_d["significant"] and mut_count > 1: genetic_feat_annot += "*"
            genetic_feat_annot += str(mut_count) + ' '
            genetic_feat_annot += str(genetic_feat_d["name"])
            genetic_feats.append(genetic_feat_annot)
            flow_row = {
                "source": operon_annot,
                "target": genetic_feat_annot,
#                 "type": r["mutation effect"],
                "type": "unknown",
                "value": 1
            }
            flow_df = flow_df.append(flow_row, ignore_index=True)
            
            
#     if FUNC_ANNOT == "pathway":
#         for pathway, ops in r["pathway links"].items():
# #             if pathway == "Glycerolipid metabolism":  # for GYD Glycerolipid metabolism.
#             pathway_feat_d = get_feat_d(name=pathway, json=r["pathways"])
#             pathway_annot = ""
#             mut_count = pathway_counts[pathway]
#             if pathway_feat_d["significant"] and mut_count > 1: pathway_annot += "*"
#             pathway_annot += str(mut_count) + ' ' + pathway_feat_d["name"]
#             pathways.append(pathway_annot)
#             for operon_id in ops:
#                 op_feat_d = get_feat_d(RegulonDB_ID=operon_id, json=r["operons"])
#                 operon_name = operon_df[operon_df["OPERON_ID"]==operon].iloc[0]["OPERON_NAME"]
#                 operon_name = _adjust_name_for_floweaver(op_feat_d["name"])
#                 operon_annot = ""
#                 mut_count = operon_counts[op_feat_d["RegulonDB ID"]]
#                 if op_feat_d["significant"] and mut_count > 1: operon_annot += "*"
#                 operon_annot += str(mut_count) + ' '
#                 operon_annot += operon_name
#                 operons.append(operon_annot)
#                 flow_row = {
#                     "source": pathway_annot,
#                     "target": operon_annot,
# #                     "type": r["mutation effect"],
#                     "type": "unknown",
#                     "value": 1
#                 }
#                 flow_df = flow_df.append(flow_row, ignore_index=True)
            
            
    if FUNC_ANNOT == "regulon":
        for regulator, ops in r["regulator links"].items():
#             if regulator == "CRP":  # for GYD CRP fig
#             if regulator == "GlpR":  # for GYD GlpR fig
#             if regulator == "Mlc":  # for GYD Mlc fig
            reg_feat_d = get_feat_d(name=regulator, json=r["regulators"])
            reg_annot = ""
            mut_count = regulator_counts[regulator]
#             if reg_feat_d["significant"] and mut_count > 1: reg_annot += "*"
            reg_annot += str(mut_count) + ' ' + reg_feat_d["name"]
            regulators.append(reg_annot)
            for operon_name in ops:
                op_feat_d = get_feat_d(name=operon_name, json=r["operons"])
                operon_name = _adjust_name_for_floweaver(op_feat_d["name"])
                operon_annot = ""
                mut_count = operon_counts[op_feat_d["RegulonDB ID"]]
#                 if op_feat_d["significant"] and mut_count > 1: operon_annot += "*"
                operon_annot += str(mut_count) + ' '
                operon_annot += operon_name
                operons.append(operon_annot)
                flow_row = {
                    "source": reg_annot,
                    "target": operon_annot,
#                     "type": r["mutation effect"],
                    "type": "unknown",
                    "value": 1
                }
                flow_df = flow_df.append(flow_row, ignore_index=True)

                
#     if FUNC_ANNOT == "COG":
#         for COG, ops in r["COG links"].items():
# #             if COG == "Nucleotide transport and metabolism":
#             COG_feat_d = get_feat_d(name=COG, json=r["COGs"])
#             COG_annot = ""
#             mut_count = COG_counts[COG]
#             if COG_feat_d["significant"] and mut_count > 1: COG_annot += "*"
#             COG_annot += str(mut_count) + ' ' + COG_feat_d["name"]
#             COGs.append(COG_annot)
#             for operon_id in ops:
#                 op_feat_d = get_feat_d(RegulonDB_ID=operon_id, json=r["operons"])
#                 operon_name = operon_df[operon_df["OPERON_ID"]==operon].iloc[0]["OPERON_NAME"]
#                 operon_name = _adjust_name_for_floweaver(op_feat_d["name"])
#                 operon_annot = ""
#                 mut_count = operon_counts[op_feat_d["RegulonDB ID"]]
#                 if op_feat_d["significant"] and mut_count > 1: operon_annot += "*"
#                 operon_annot += str(mut_count) + ' '
#                 operon_annot += operon_name
#                 operons.append(operon_annot)
#                 flow_row = {
#                     "source": COG_annot,
#                     "target": operon_annot,
# #                     "type": r["mutation effect"],
#                     "type": "unknown",
#                     "value": 1
#                 }
#                 flow_df = flow_df.append(flow_row, ignore_index=True)
                
                
#     if FUNC_ANNOT == "imodulon":
#         for imodulon, ops in r["imodulon links"].items():
#             reg_feat_d = get_feat_d(name=imodulon, json=r["imodulons"])
#             reg_annot = ""
#             mut_count = imodulon_counts[imodulon]
#             if reg_feat_d["significant"] and mut_count > 1: reg_annot += "*"
#             reg_annot += str(mut_count) + ' ' + reg_feat_d["name"]
#             imodulons.append(reg_annot)
#             for operon_name in ops:
#                 op_feat_d = get_feat_d(name=operon_name, json=r["operons"])
#                 operon_name = _adjust_name_for_floweaver(op_feat_d["name"])
#                 operon_annot = ""
#                 mut_count = operon_counts[op_feat_d["RegulonDB ID"]]
#                 if op_feat_d["significant"] and mut_count > 1: operon_annot += "*"
#                 operon_annot += str(mut_count) + ' '
#                 operon_annot += operon_name
#                 operons.append(operon_annot)
#                 flow_row = {
#                     "source": reg_annot,
#                     "target": operon_annot,
#                     "type": "unknown",
#                     "value": 1
#                 }
#                 flow_df = flow_df.append(flow_row, ignore_index=True)
                
    
display(flow_df[:20])
# Out:
#          source        target     type  value
# 0        2 pntB   1 pntB INS   unknown    1.0
# 1        2 pntB        2 pntB  unknown    1.0
# 2      5 pntAB         2 pntB  unknown    1.0
# 3        2 pntB   1 pntB DEL   unknown    1.0
# 4        2 pntB        2 pntB  unknown    1.0
# 5      5 pntAB         2 pntB  unknown    1.0
# 6        2 pntA   1 pntA DEL   unknown    1.0
# 7        2 pntA        2 pntA  unknown    1.0
# 8      5 pntAB         2 pntA  unknown    1.0
# 9        2 pntA   1 pntA SNP   unknown    1.0
# 10       2 pntA        2 pntA  unknown    1.0
# 11     5 pntAB         2 pntA  unknown    1.0
# 12      1 pntAp  1 pntAp MOB   unknown    1.0
# 13  1 pntA/ydgH       1 pntAp  unknown    1.0
# 14     5 pntAB    1 pntA/ydgH  unknown    1.0
# 15       3 sthA   3 sthA SNP   unknown    1.0
# 16       3 sthA        3 sthA  unknown    1.0
# 17      8 sthA         3 sthA  unknown    1.0
# 18       3 sthA   3 sthA SNP   unknown    1.0
# 19       3 sthA        3 sthA  unknown    1.0

# %%
# processing to help a cleaner order of features.
# remove duplicates but maintains the order established above
def remove_duplicates(feats):
    l = list()
    for x in feats:
        if x not in l:
            l.append(x)
    return l

mut_feat_effects = remove_duplicates(mut_feat_effects)
genomic_feats = remove_duplicates(genomic_feats)
genetic_feats = remove_duplicates(genetic_feats)
operons = remove_duplicates(operons)
# pathways = remove_duplicates(pathways)
regulators = remove_duplicates(regulators)
# COGs = remove_duplicates(COGs)
# imodulons = remove_duplicates(imodulons)

# %%
from ipysankeywidget import SankeyWidget
from floweaver import *


nodes = {
    "mutation": ProcessGroup(mut_feat_effects, title="mutation"),
    "genomic feature": ProcessGroup(genomic_feats, title="genomic feature"),
    "genetic feature": ProcessGroup(genetic_feats, title="genetic feature"),
    "operon": ProcessGroup(operons, title="operon"),
}

l = []
# if FUNC_ANNOT == "pathway": l = pathways
if FUNC_ANNOT == "regulon": l = regulators
# if FUNC_ANNOT == "COG": l = COGs
# if FUNC_ANNOT == "imodulon": l = imodulons
nodes[FUNC_ANNOT] = ProcessGroup(l, title=FUNC_ANNOT)


# !!! These partition DFs need to have accessible variables (ex: mut_type_partition) accessible external to the nodes
# otherwise floweaver will crash during its rendering step.
mutation_partition = Partition.Simple("process", mut_feat_effects)
nodes["mutation"].partition = mutation_partition

genomic_feat_partition = Partition.Simple("process", genomic_feats)
nodes["genomic feature"].partition = genomic_feat_partition

genetic_feat_partition = Partition.Simple("process", genetic_feats)
nodes["genetic feature"].partition = genetic_feat_partition

operon_partition = Partition.Simple("process", operons)
nodes["operon"].partition = operon_partition

nodes[FUNC_ANNOT].partition = Partition.Simple("process", l)


# The order that the labels is entered into the bundles is explicit. Don't arbitrarily give an order.
bundles = [
    Bundle(
        "genomic feature",
        "mutation"
    ),
    Bundle(
        "genetic feature",
        "genomic feature",
    ),
    Bundle(
        "operon",
        "genetic feature",
    ),
    Bundle(
        FUNC_ANNOT,
        "operon",
    ),
]

ordering = [
    [FUNC_ANNOT],
    ["operon"],
    ["genetic feature"],
    ["genomic feature"],
    ["mutation"]
]

#
# mut_effect_partition = Partition.Simple(
#     "type", ["unknown", "disrupt", "repaired"])
sdd = SankeyDefinition(nodes,
                       bundles,
                       ordering,
#                        flow_partition=mut_effect_partition
                      )


# p_d = {"disrupt": "#C44E52", "unknown": "#6BAAD3", "repaired": "#55A868"}
p_d = {"disrupt": "#6BAAD3", "unknown": "#6BAAD3", "repaired": "#6BAAD3"}
# size = dict(width=3000, height=4000)
# size = dict(width=2000, height=2500)
# size = dict(width=1600, height=1000)
size = dict(width=1000, height=300)
# size = dict(width=1600, height=500)
# size = dict(width=1100, height=300)
# size = dict(width=1350, height=300)
# size = dict(width=1000, height=200)
results = weave(sdd,
                flow_df,
                palette=p_d,
                ).to_widget(
    margins=dict(left=400, right=350),
    **size)
results.auto_save_svg("mutflow.svg")
results.auto_save_png("mutflow.png")
results
# Out:
# SankeyWidget(groups=[{'id': 'operon', 'type': 'process', 'title': 'operon', 'nodes': ['operon^5 pntAB ', 'oper…
