# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.max_columns = 100
import pickle

# %%
# The reason for the below is because only the fulled processed experiment mutation sets contain the data necessary for the below plots.
# The mutation set here will also be less than that of 4_df because we've removed GLU's hypermutators before execute NB6-12 on GLU.
all_mut_df = pd.DataFrame()
exp_data_files = [
    "./data/PGI_df.pkl",
    "./data/GLU_df.pkl",
    "./data/GYD_df.pkl",
    "./data/42C_df.pkl",
    "./data/SER_df.pkl",
    "./data/C13_df.pkl",
    "./data/SSW_AC_df.pkl",
    "./data/SSW_GLY_df.pkl",
    "./data/SSW_XYL_df.pkl",
    "./data/SSW_GLU_AC_df.pkl",
    "./data/SSW_GLU_GLY_df.pkl",
    "./data/SSW_GLU_XYL_df.pkl",
    "./data/Central_carbon_knockout_tpiA_df.pkl",
    "./data/Central_carbon_knockout_PTS_df.pkl",
    "./data/Central_carbon_knockout_pgi_df.pkl",
    "./data/Central_carbon_knockout_sdh_df.pkl",
    "./data/Central_carbon_knockout_gnd_df.pkl",
    "./data/Central_carbon_knockout_glucose_evolution_df.pkl",
]
for exp_data_file in exp_data_files:
    all_mut_df = all_mut_df.append(pd.read_pickle(exp_data_file), sort=True)
display(len(all_mut_df), all_mut_df.head())
# Out:
# 1278
#                                              COG links  \
# 778  {'Energy production and conversion': ['ECK1200...
# 779  {'Lipid transport and metabolism': ['ECK125166...
# 780  {'Replication, recombination and repair': ['EC...
# 781  {'Energy production and conversion': ['ECK1200...
# 782                {'Transcription': ['ECK120016992']}
#
#                                                   COGs                Details  \
# 778  [{'name': 'Energy production and conversion', ...  intergenic (‑75/‑446)
# 779  [{'name': 'Lipid transport and metabolism', 'm...         P56L (CCT→CTT)
# 780  [{'name': 'Replication, recombination and repa...         I81S (ATC→AGC)
# 781  [{'name': 'Energy production and conversion', ...        S317G (AGC→GGC)
# 782  [{'name': 'Transcription', 'mutation set count...       K1242Q (AAG→CAG)
#
#     Mutation Type  Position RBS Reference Seq Sequence Change TFBS  ale  \
# 778           MOB   1677978  {}           NaN   IS5 (+) +4 bp   {}    1
# 779           SNP    202267  {}           NaN             C→T   {}    1
# 780           SNP   3960918  {}           NaN             T→G   {}    1
# 781           SNP   4159842  {}           NaN             T→C   {}    1
# 782           SNP   4184968  {}           NaN             A→C   {}    1
#
#     attenuator terminator base-media calcium-source carbon-source  coding  \
# 778                    {}         M9     CaCl2(0.1)    glucose(2)   False
# 779                    {}         M9     CaCl2(0.1)    glucose(2)    True
# 780                    {}         M9     CaCl2(0.1)    glucose(2)    True
# 781                    {}         M9     CaCl2(0.1)    glucose(2)    True
# 782                    {}         M9     CaCl2(0.1)    glucose(2)    True
#
#      exp  flask gene RegulonDB ID  genetic  \
# 778  PGI     50                {}    False
# 779  PGI     50    {ECK120001257}     True
# 780  PGI     50    {ECK120000828}     True
# 781  PGI     50    {ECK120001392}     True
# 782  PGI     50    {ECK120000885}     True
#
#                                genetic feature links  \
# 778  {'ECK120000735/ECK120003449': ['ECK120010629']}
# 779               {'ECK120001257': ['ECK120001257']}
# 780               {'ECK120000828': ['ECK120000828']}
# 781               {'ECK120001392': ['ECK120001392']}
# 782               {'ECK120000885': ['ECK120000885']}
#
#                                       genetic features  \
# 778  [{'RegulonDB ID': 'ECK120000735/ECK120003449',...
# 779  [{'name': 'fabZ', 'RegulonDB ID': 'ECK12000125...
# 780  [{'name': 'rep', 'RegulonDB ID': 'ECK120000828...
# 781  [{'name': 'sthA', 'RegulonDB ID': 'ECK12000139...
# 782  [{'name': 'rpoB', 'RegulonDB ID': 'ECK12000088...
#
#                                       genomic features index  isolate  \
# 778  [{'name': 'pntAp', 'RegulonDB ID': 'ECK1200106...     1        1
# 779  [{'name': 'fabZ', 'RegulonDB ID': 'ECK12000125...     0        1
# 780  [{'name': 'rep', 'RegulonDB ID': 'ECK120000828...     2        1
# 781  [{'name': 'sthA', 'RegulonDB ID': 'ECK12000139...     3        1
# 782  [{'name': 'rpoB', 'RegulonDB ID': 'ECK12000088...     4        1
#
#     mutation target annotation nitrogen-source  \
# 778                  pntA/ydgH        NH4Cl(2)
# 779                       fabZ        NH4Cl(2)
# 780                        rep        NH4Cl(2)
# 781                       sthA        NH4Cl(2)
# 782                       rpoB        NH4Cl(2)
#
#                                         operon links  \
# 778  {'ECK120014614': ['ECK120000735/ECK120003449']}
# 779               {'ECK125166138': ['ECK120001257']}
# 780               {'ECK120014997': ['ECK120000828']}
# 781               {'ECK120015926': ['ECK120001392']}
# 782               {'ECK120016992': ['ECK120000885']}
#
#                                                operons   oriC  \
# 778  [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...  False
# 779  [{'name': 'bamA-skp-lpxD-fabZ-lpxAB-rnhB-dnaE'...  False
# 780  [{'name': 'rep', 'RegulonDB ID': 'ECK120014997...  False
# 781  [{'name': 'sthA', 'RegulonDB ID': 'ECK12001592...  False
# 782  [{'name': 'rplKAJL-rpoBC', 'RegulonDB ID': 'EC...  False
#
#                                          pathway links  \
# 778  {'Nicotinate and nicotinamide metabolism': ['E...
# 779  {'Fatty acid biosynthesis': ['ECK125166138'], ...
# 780                                                 {}
# 781  {'Nicotinate and nicotinamide metabolism': ['E...
# 782  {'Purine metabolism': ['ECK120016992'], 'Pyrim...
#
#                                               pathways  \
# 778  [{'name': 'Nicotinate and nicotinamide metabol...
# 779  [{'name': 'Fatty acid biosynthesis', 'mutation...
# 780                                                 []
# 781  [{'name': 'Nicotinate and nicotinamide metabol...
# 782  [{'name': 'Purine metabolism', 'mutation set c...
#
#           phosphorous-source  presence        promoter  pseudogene  \
# 778  KH2PO4(6) Na2HPO4(13.6)       1.0  {ECK120010629}       False
# 779  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
# 780  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
# 781  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
# 782  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
#
#                   range                                    regulator links  \
# 778  (1677978, 1677978)                                                 {}
# 779    (202267, 202267)  {'CpxR': ['bamA-skp-lpxD-fabZ-lpxAB-rnhB-dnaE'...
# 780  (3960918, 3960918)                                                 {}
# 781  (4159842, 4159842)                                                 {}
# 782  (4184968, 4184968)                                                 {}
#
#                                             regulators strain-description  \
# 778                                                 []               Δpgi
# 779  [{'name': 'CpxR', 'significantly associated co...               Δpgi
# 780                                                 []               Δpgi
# 781                                                 []               Δpgi
# 782                                                 []               Δpgi
#
#     sulfur-source                 supplement taxonomy-id  tech_rep  \
# 778     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 779     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 780     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 781     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 782     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
#
#     temperature terminator
# 778  37 celsius         {}
# 779  37 celsius         {}
# 780  37 celsius         {}
# 781  37 celsius         {}
# 782  37 celsius         {}

# %%
for _, r in all_mut_df.iterrows():
    for f in r["genomic features"]:
        display(f)
# Out:
# {'name': 'pntAp',
#  'RegulonDB ID': 'ECK120010629',
#  'range': (1677955, 1678035),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'pntAB',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'fabZ',
#  'RegulonDB ID': 'ECK120001257',
#  'range': (202101, 202556),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'bamA-skp-lpxD-fabZ-lpxAB-rnhB-dnaE',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'rep',
#  'RegulonDB ID': 'ECK120000828',
#  'range': (3960677, 3962698),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rep',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'sthA',
#  'RegulonDB ID': 'ECK120001392',
#  'range': (4159390, 4160790),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'sthA',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 3,
#  'significantly enriched': True}
# {'name': 'rpoB',
#  'RegulonDB ID': 'ECK120000885',
#  'range': (4181245, 4185273),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rplKAJL-rpoBC',
#  'significantly associated conditions': {'Δpgi'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'rpoC',
#  'RegulonDB ID': 'ECK120000886',
#  'range': (4185350, 4189573),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rplKAJL-rpoBC',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'icd',
#  'RegulonDB ID': 'ECK120000482',
#  'range': (1195123, 1196373),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'icd',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 8,
#  'significantly enriched': True}
# {'name': 'icd',
#  'RegulonDB ID': 'ECK120000482',
#  'range': (1195123, 1196373),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'icd',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 8,
#  'significantly enriched': True}
# {'name': 'icd',
#  'RegulonDB ID': 'ECK120000482',
#  'range': (1195123, 1196373),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'icd',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 8,
#  'significantly enriched': True}
# {'name': 'icd',
#  'RegulonDB ID': 'ECK120000482',
#  'range': (1195123, 1196373),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'icd',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 8,
#  'significantly enriched': True}
# {'name': 'pntA',
#  'RegulonDB ID': 'ECK120000735',
#  'range': (1676371, 1677903),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'pntAB',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'crr',
#  'RegulonDB ID': 'ECK120000161',
#  'range': (2535834, 2536343),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ptsHI-crr',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 5,
#  'significantly enriched': True}
# {'name': 'rpoS',
#  'RegulonDB ID': 'ECK120000503',
#  'range': (2866559, 2867551),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'nlpD-rpoS',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 6,
#  'significantly enriched': True}
# {'name': 'rph-pyrE attenuator terminator',
#  'RegulonDB ID': 'ECK125144791',
#  'range': (3815799, 3815911),
#  'genetic': False,
#  'feature type': 'attenuator terminator',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph-pyrE terminator'},
#  'significantly associated conditions': set(),
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'sthAp',
#  'RegulonDB ID': 'ECK120015386',
#  'range': (4160782, 4160862),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'sthA',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 5,
#  'significantly enriched': True}
# {'name': 'rpoS',
#  'RegulonDB ID': 'ECK120000503',
#  'range': (2866559, 2867551),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'nlpD-rpoS',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 6,
#  'significantly enriched': True}
# {'name': 'rpoA',
#  'RegulonDB ID': 'ECK120000884',
#  'range': (3440040, 3441029),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rpsMKD-rpoA-rplQ',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 3,
#  'significantly enriched': True}
# {'name': 'yiiD',
#  'RegulonDB ID': 'ECK120001784',
#  'range': (4077449, 4078438),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yihXY-dtd-yiiD',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'cpxR',
#  'RegulonDB ID': 'ECK120000017',
#  'range': (4104972, 4105670),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'cpxRA',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'sthAp',
#  'RegulonDB ID': 'ECK120015386',
#  'range': (4160782, 4160862),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'sthA',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 5,
#  'significantly enriched': True}
# {'name': 'pntB',
#  'RegulonDB ID': 'ECK120000736',
#  'range': (1674972, 1676360),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'pntAB',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'yfeH',
#  'RegulonDB ID': 'ECK120002244',
#  'range': (2526946, 2527944),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yfeH',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'crr',
#  'RegulonDB ID': 'ECK120000161',
#  'range': (2535834, 2536343),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ptsHI-crr',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 5,
#  'significantly enriched': True}
# {'name': 'rpoS',
#  'RegulonDB ID': 'ECK120000503',
#  'range': (2866559, 2867551),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'nlpD-rpoS',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 6,
#  'significantly enriched': True}
# {'name': 'cpxAp1',
#  'RegulonDB ID': 'ECK125137971',
#  'range': (4105081, 4105161),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'unknown',
#  'overlap': {'cpxR'},
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'cpxR',
#  'RegulonDB ID': 'ECK120000017',
#  'range': (4104972, 4105670),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'cpxRA',
#  'overlap': {'cpxAp1'},
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'RegulonDB ID': 'ECK120001021/ECK120000540',
#  'name': 'trxB/lrp',
#  'range': (932051, 932594),
#  'feature type': 'unknown',
#  'genetic': False,
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'icd',
#  'RegulonDB ID': 'ECK120000482',
#  'range': (1195123, 1196373),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'icd',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 8,
#  'significantly enriched': True}
# {'name': 'icd',
#  'RegulonDB ID': 'ECK120000482',
#  'range': (1195123, 1196373),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'icd',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 8,
#  'significantly enriched': True}
# {'name': 'icd',
#  'RegulonDB ID': 'ECK120000482',
#  'range': (1195123, 1196373),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'icd',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 8,
#  'significantly enriched': True}
# {'name': 'icd',
#  'RegulonDB ID': 'ECK120000482',
#  'range': (1195123, 1196373),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'icd',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 8,
#  'significantly enriched': True}
# {'name': 'acnB',
#  'RegulonDB ID': 'ECK120002193',
#  'range': (131615, 134212),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'acnB',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'fruK',
#  'RegulonDB ID': 'ECK120000331',
#  'range': (2261427, 2262365),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'fruBKA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'crr',
#  'RegulonDB ID': 'ECK120000161',
#  'range': (2535834, 2536343),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ptsHI-crr',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 5,
#  'significantly enriched': True}
# {'name': 'rpoS',
#  'RegulonDB ID': 'ECK120000503',
#  'range': (2866559, 2867551),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'nlpD-rpoS',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 6,
#  'significantly enriched': True}
# {'RegulonDB ID': 'ECK120002523/ECK120002516',
#  'name': 'rrlE/rrfE',
#  'range': (4212947, 4213039),
#  'feature type': 'unknown',
#  'genetic': False,
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'RegulonDB ID': 'ECK120002523/ECK120002516',
#  'name': 'rrlE/rrfE',
#  'range': (4212947, 4213039),
#  'feature type': 'unknown',
#  'genetic': False,
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'RegulonDB ID': 'ECK120001021/ECK120000540',
#  'name': 'trxB/lrp',
#  'range': (932051, 932594),
#  'feature type': 'unknown',
#  'genetic': False,
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'rpoS',
#  'RegulonDB ID': 'ECK120000503',
#  'range': (2866559, 2867551),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'nlpD-rpoS',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 6,
#  'significantly enriched': True}
# {'name': 'rpoA',
#  'RegulonDB ID': 'ECK120000884',
#  'range': (3440040, 3441029),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rpsMKD-rpoA-rplQ',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 3,
#  'significantly enriched': True}
# {'name': 'rph-pyrE attenuator terminator',
#  'RegulonDB ID': 'ECK125144791',
#  'range': (3815799, 3815911),
#  'genetic': False,
#  'feature type': 'attenuator terminator',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph-pyrE terminator'},
#  'significantly associated conditions': set(),
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'hfq',
#  'RegulonDB ID': 'ECK120000431',
#  'range': (4400288, 4400596),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yjeF-tsaE-amiB-mutL-miaA-hfq-hflXKC',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'fimD',
#  'RegulonDB ID': 'ECK120000305',
#  'range': (4545096, 4547732),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'fimAICDFGH',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'pntA',
#  'RegulonDB ID': 'ECK120000735',
#  'range': (1676371, 1677903),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'pntAB',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'crr',
#  'RegulonDB ID': 'ECK120000161',
#  'range': (2535834, 2536343),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ptsHI-crr',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 5,
#  'significantly enriched': True}
# {'name': 'rpoS',
#  'RegulonDB ID': 'ECK120000503',
#  'range': (2866559, 2867551),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'nlpD-rpoS',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 6,
#  'significantly enriched': True}
# {'name': 'sthAp',
#  'RegulonDB ID': 'ECK120015386',
#  'range': (4160782, 4160862),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'sthA',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 5,
#  'significantly enriched': True}
# {'name': 'mrdB',
#  'RegulonDB ID': 'ECK120000600',
#  'range': (665201, 666313),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rsfS-rlmH-mrdAB-rlpA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'fis',
#  'RegulonDB ID': 'ECK120000311',
#  'range': (3411271, 3411567),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'dusB-fis',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'cyaA',
#  'RegulonDB ID': 'ECK120000166',
#  'range': (3991153, 3993699),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'cyaA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'bipA',
#  'RegulonDB ID': 'ECK120001768',
#  'range': (4058407, 4060230),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'bipA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'sthA',
#  'RegulonDB ID': 'ECK120001392',
#  'range': (4159390, 4160790),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'sthA',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 3,
#  'significantly enriched': True}
# {'name': 'sthAp',
#  'RegulonDB ID': 'ECK120015386',
#  'range': (4160782, 4160862),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'sthA',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 5,
#  'significantly enriched': True}
# {'name': 'nagC',
#  'RegulonDB ID': 'ECK120000629',
#  'range': (700374, 701594),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'nagBAC-umpH',
#  'significantly associated conditions': set(),
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'zwf',
#  'RegulonDB ID': 'ECK120001199',
#  'range': (1934839, 1936314),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'zwf',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'menC',
#  'RegulonDB ID': 'ECK120001486',
#  'range': (2375000, 2375962),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'menFDHBCE',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'sthA',
#  'RegulonDB ID': 'ECK120001392',
#  'range': (4159390, 4160790),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'sthA',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 3,
#  'significantly enriched': True}
# {'name': 'sthAp',
#  'RegulonDB ID': 'ECK120015386',
#  'range': (4160782, 4160862),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'sthA',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)',
#   'Δpgi'},
#  'mutation set count': 5,
#  'significantly enriched': True}
# {'name': 'rpoB',
#  'RegulonDB ID': 'ECK120000885',
#  'range': (4181245, 4185273),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rplKAJL-rpoBC',
#  'significantly associated conditions': {'Δpgi'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'nagC',
#  'RegulonDB ID': 'ECK120000629',
#  'range': (700374, 701594),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'nagBAC-umpH',
#  'significantly associated conditions': set(),
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'pntB',
#  'RegulonDB ID': 'ECK120000736',
#  'range': (1674972, 1676360),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'pntAB',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'cdsAp3',
#  'RegulonDB ID': 'ECK125136393',
#  'range': (195495, 195575),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'unknown',
#  'overlap': {'cdsAp2', 'ispU'},
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': True}
# {'name': 'cdsAp2',
#  'RegulonDB ID': 'ECK125136392',
#  'range': (195501, 195581),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'unknown',
#  'overlap': {'cdsAp3', 'ispU'},
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': True}
# {'name': 'ispU',
#  'RegulonDB ID': 'ECK120002712',
#  'range': (194903, 195664),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ispU',
#  'overlap': {'cdsAp2', 'cdsAp3'},
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'crr',
#  'RegulonDB ID': 'ECK120000161',
#  'range': (2535834, 2536343),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ptsHI-crr',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 5,
#  'significantly enriched': True}
# {'name': 'rpoA',
#  'RegulonDB ID': 'ECK120000884',
#  'range': (3440040, 3441029),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rpsMKD-rpoA-rplQ',
#  'significantly associated conditions': {'KH2PO4(6) Na2HPO4(13.6)',
#   'MgSO4(24)',
#   'NH4Cl(2)',
#   'NaCl(1g/L) trace elements',
#   'glucose(2)'},
#  'mutation set count': 3,
#  'significantly enriched': True}
# {'name': 'ysgA',
#  'RegulonDB ID': 'ECK120004313',
#  'range': (4015354, 4016169),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ysgA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'putA',
#  'RegulonDB ID': 'ECK120000792',
#  'range': (1074920, 1078882),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'putA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'opgC',
#  'RegulonDB ID': 'ECK120003148',
#  'range': (1107784, 1108941),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'opgC',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'hns TFBS',
#  'RegulonDB ID': 'ECK120011932',
#  'range': (1293022, 1293036),
#  'genetic': False,
#  'feature type': 'TFBS',
#  'operon': 'hns',
#  'significantly associated conditions': set(),
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'paaJ',
#  'RegulonDB ID': 'ECK120003312',
#  'range': (1460893, 1462098),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'paaABCDEFGHIJK',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'RegulonDB ID': 'ECK120001587/ECK120001588',
#  'name': 'dgcZ/ydeI',
#  'range': (1623851, 1624104),
#  'feature type': 'unknown',
#  'genetic': False,
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'dtpA',
#  'RegulonDB ID': 'ECK120003466',
#  'range': (1712769, 1714271),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'dtpA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'RegulonDB ID': 'ECK120003561/ECK120003562',
#  'name': 'yoaI/yeaL',
#  'range': (1874183, 1874351),
#  'feature type': 'unknown',
#  'genetic': False,
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'nimR',
#  'RegulonDB ID': 'ECK120003563',
#  'range': (1874755, 1875576),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'nimR',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'yeaV',
#  'RegulonDB ID': 'ECK120003574',
#  'range': (1883188, 1884633),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yeaVW',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'yoaA',
#  'RegulonDB ID': 'ECK120003579',
#  'range': (1891325, 1893235),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yoaA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'yoaE',
#  'RegulonDB ID': 'ECK120003584',
#  'range': (1900029, 1901585),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yoaE',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'edd',
#  'RegulonDB ID': 'ECK120000251',
#  'range': (1932793, 1934604),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'edd-eda',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'cheR',
#  'RegulonDB ID': 'ECK120000144',
#  'range': (1968504, 1969364),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'tar-tap-cheRBYZ',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'murC',
#  'RegulonDB ID': 'ECK120000612',
#  'range': (100765, 102240),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'mraZ-rsmH-ftsLI-murEF-mraY-murD-ftsW-murGC-ddlB-ftsQAZ-lpxC',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'dnaK',
#  'RegulonDB ID': 'ECK120000235',
#  'range': (12163, 14079),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'dnaK-tpke11-dnaJ',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'yadE',
#  'RegulonDB ID': 'ECK120001687',
#  'range': (145081, 146310),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yadE',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'fhuD',
#  'RegulonDB ID': 'ECK120000299',
#  'range': (170575, 171465),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'fhuACDB',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'fliZ',
#  'RegulonDB ID': 'ECK120001325',
#  'range': (2000473, 2001024),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'fliAZ-tcyJ',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'shiA',
#  'RegulonDB ID': 'ECK120003653',
#  'range': (2053643, 2054959),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'shiA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'hisLGDCBHAFI attenuator terminator',
#  'RegulonDB ID': 'ECK125144241',
#  'range': (2090050, 2090146),
#  'genetic': False,
#  'feature type': 'attenuator terminator',
#  'operon': 'hisLGDCBHAFI',
#  'overlap': {'hisLGDCBHAFI terminator'},
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'yehA',
#  'RegulonDB ID': 'ECK120001912',
#  'range': (2187380, 2188414),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yehDCBA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'cirA',
#  'RegulonDB ID': 'ECK120000151',
#  'range': (2244778, 2246769),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'cirA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'setB',
#  'RegulonDB ID': 'ECK120001951',
#  'range': (2263863, 2265044),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'setB',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'yeiQ',
#  'RegulonDB ID': 'ECK120001953',
#  'range': (2266245, 2267711),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yeiQ',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'RegulonDB ID': 'ECK120000249/ECK120001978',
#  'name': 'eco/mqo',
#  'range': (2304394, 2305107),
#  'feature type': 'unknown',
#  'genetic': False,
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'rcsD',
#  'RegulonDB ID': 'ECK120002250',
#  'range': (2313488, 2316160),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rcsDB',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'nrdA',
#  'RegulonDB ID': 'ECK120000653',
#  'range': (2344865, 2347150),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'nrdAB-yfaE',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'yfcJ',
#  'RegulonDB ID': 'ECK120003773',
#  'range': (2438942, 2440120),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yfcJ',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'aroC',
#  'RegulonDB ID': 'ECK120000071',
#  'range': (2446388, 2447473),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'prmB-aroC-mepA-yfcA-epmC-yfcL',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'yfdV',
#  'RegulonDB ID': 'ECK120003810',
#  'range': (2489242, 2490186),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yfdX-frc-oxc-yfdVE',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'eutA',
#  'RegulonDB ID': 'ECK120003855',
#  'range': (2565481, 2566884),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'eutHA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'eutH',
#  'RegulonDB ID': 'ECK120003856',
#  'range': (2566881, 2568107),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'eutHA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'hyfG',
#  'RegulonDB ID': 'ECK120003876',
#  'range': (2608487, 2610154),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'hyfABCDEFGHIJR-focB',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'yfhM',
#  'RegulonDB ID': 'ECK120003895',
#  'range': (2647326, 2652287),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yfhM-pbpC',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'mstA',
#  'RegulonDB ID': 'ECK120001548',
#  'range': (2652494, 2653339),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'mstA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'hcaE',
#  'RegulonDB ID': 'ECK120004468',
#  'range': (2669032, 2670393),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'hcaEFCBD',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'ypjA',
#  'RegulonDB ID': 'ECK120003950',
#  'range': (2778146, 2782726),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ypjA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'ygaZ',
#  'RegulonDB ID': 'ECK120003972',
#  'range': (2809617, 2810354),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ygaZH',
#  'significantly associated conditions': set(),
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'ygaZ',
#  'RegulonDB ID': 'ECK120003972',
#  'range': (2809617, 2810354),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ygaZH',
#  'significantly associated conditions': set(),
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'ygeR',
#  'RegulonDB ID': 'ECK120004047',
#  'range': (2999136, 2999891),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ygeR',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'fadE',
#  'RegulonDB ID': 'ECK120002725',
#  'range': (240859, 243303),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'fadE',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'pepDp1',
#  'RegulonDB ID': 'ECK120010290',
#  'range': (255789, 255869),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'pepD',
#  'overlap': {'gptp'},
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'gptp',
#  'RegulonDB ID': 'ECK120034547',
#  'range': (255854, 255934),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'gpt',
#  'overlap': {'pepDp1'},
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'mmuP',
#  'RegulonDB ID': 'ECK120002755',
#  'range': (275325, 276728),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'mmuPM',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'rihC',
#  'RegulonDB ID': 'ECK120001070',
#  'range': (27293, 28207),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rihC',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'xanQ',
#  'RegulonDB ID': 'ECK120004064',
#  'range': (3024351, 3025751),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'xanQ-guaD-ghxQ',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'prfB',
#  'RegulonDB ID': 'ECK120000753',
#  'range': (3035184, 3036282),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'xerD-dsbC-recJ-prfB-lysS',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'yggN',
#  'RegulonDB ID': 'ECK120002364',
#  'range': (3100904, 3101623),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yggN',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'gss',
#  'RegulonDB ID': 'ECK120002421',
#  'range': (3136663, 3138522),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'gss',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'parE',
#  'RegulonDB ID': 'ECK120000680',
#  'range': (3173504, 3175396),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'nudF-yqiB-cpdA-yqiA-parE',
#  'significantly associated conditions': set(),
#  'mutation set count': 2,
#  'significantly enriched': False}
# {'name': 'parE',
#  'RegulonDB ID': 'ECK120000680',
#  'range': (3173504, 3175396),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'nudF-yqiB-cpdA-yqiA-parE',
#  'significantly associated conditions': set(),
#  'mutation set count': 2,
#  'significantly enriched': False}
# {'name': 'sstT',
#  'RegulonDB ID': 'ECK120002374',
#  'range': (3239944, 3241188),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'sstT',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'RegulonDB ID': 'ECK120001156/ECK120002511',
#  'name': 'yhaC/rnpB',
#  'range': (3269603, 3270215),
#  'feature type': 'unknown',
#  'genetic': False,
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'kbaZ',
#  'RegulonDB ID': 'ECK120004181',
#  'range': (3278914, 3280194),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'kbaZ-agaVWA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'mtr',
#  'RegulonDB ID': 'ECK120000610',
#  'range': (3304573, 3305817),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'mtr',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'gltF',
#  'RegulonDB ID': 'ECK120001469',
#  'range': (3361176, 3361940),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'gltBDF',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'zapE',
#  'RegulonDB ID': 'ECK120004227',
#  'range': (3378870, 3379997),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'zapE',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'glgC',
#  'RegulonDB ID': 'ECK120000372',
#  'range': (3568033, 3569328),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'glgBXCAP',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'mdtF',
#  'RegulonDB ID': 'ECK120002124',
#  'range': (3660414, 3663527),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'gadEF-mdtEF',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'gadW',
#  'RegulonDB ID': 'ECK120002125',
#  'range': (3663890, 3664618),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'gadAXW',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'rph-pyrE attenuator terminator',
#  'RegulonDB ID': 'ECK125144791',
#  'range': (3815799, 3815911),
#  'genetic': False,
#  'feature type': 'attenuator terminator',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph'},
#  'significantly associated conditions': set(),
#  'mutation set count': 6,
#  'significantly enriched': True}
# {'name': 'rph',
#  'RegulonDB ID': 'ECK120000854',
#  'range': (3815863, 3816549),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph-pyrE attenuator terminator'},
#  'significantly associated conditions': {'glucose(4)'},
#  'mutation set count': 6,
#  'significantly enriched': True}
# {'name': 'atpD',
#  'RegulonDB ID': 'ECK120000097',
#  'range': (3915993, 3917375),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'atpIBEFHAGDC',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'asnA',
#  'RegulonDB ID': 'ECK120000087',
#  'range': (3927155, 3928147),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'asnA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'wecB',
#  'RegulonDB ID': 'ECK120001414',
#  'range': (3970133, 3971263),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rfe-wzzE-wecBC-rffGHC-wecE-wzxE-rffT-wzyE-rffM',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'RegulonDB ID': 'ECK120002807/ECK120002808',
#  'name': 'yahJ/yahK',
#  'range': (342508, 342883),
#  'feature type': 'unknown',
#  'genetic': False,
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'yahN',
#  'RegulonDB ID': 'ECK120002811',
#  'range': (345666, 346337),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yahN',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'mhpR',
#  'RegulonDB ID': 'ECK120002818',
#  'range': (367587, 368420),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'mhpR-lacI',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'RegulonDB ID': 'ECK120002823/ECK120002824',
#  'name': 'frmR/yaiO',
#  'range': (379882, 380068),
#  'feature type': 'unknown',
#  'genetic': False,
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'katG',
#  'RegulonDB ID': 'ECK120000504',
#  'range': (4133835, 4136015),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'katG',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'yijEp5',
#  'RegulonDB ID': 'ECK125137977',
#  'range': (4136029, 4136109),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'unknown',
#  'overlap': {'yijE attenuator terminator'},
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'yijE attenuator terminator',
#  'RegulonDB ID': 'ECK125145604',
#  'range': (4135963, 4136063),
#  'genetic': False,
#  'feature type': 'attenuator terminator',
#  'operon': 'yijE',
#  'overlap': {'yijEp5'},
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'rpoB',
#  'RegulonDB ID': 'ECK120000885',
#  'range': (4181245, 4185273),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rplKAJL-rpoBC',
#  'significantly associated conditions': set(),
#  'mutation set count': 6,
#  'significantly enriched': True}
# {'name': 'yjcF',
#  'RegulonDB ID': 'ECK120001869',
#  'range': (4281783, 4283075),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yjcF',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'RegulonDB ID': 'ECK120001869/ECK120001870',
#  'name': 'yjcF/actP',
#  'range': (4283076, 4283252),
#  'feature type': 'unknown',
#  'genetic': False,
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'mutL',
#  'RegulonDB ID': 'ECK120001254',
#  'range': (4397412, 4399259),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yjeF-tsaE-amiB-mutL-miaA-hfq-hflXKC',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'ytfJ',
#  'RegulonDB ID': 'ECK120004366',
#  'range': (4438708, 4439262),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ytfJ',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'ytfR',
#  'RegulonDB ID': 'ECK120002313',
#  'range': (4451058, 4452560),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ytfQRT-yjfF',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'argI',
#  'RegulonDB ID': 'ECK120000065',
#  'range': (4477307, 4478311),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'argI',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'yjhC',
#  'RegulonDB ID': 'ECK120004396',
#  'range': (4505287, 4506405),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yjhBC',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'lgoR',
#  'RegulonDB ID': 'ECK120004437',
#  'range': (4594937, 4595851),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'lgoR',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'RegulonDB ID': 'ECK120001024/ECK120002413',
#  'name': 'tsx/yajI',
#  'range': (432014, 432311),
#  'feature type': 'unknown',
#  'genetic': False,
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'lon',
#  'RegulonDB ID': 'ECK120000535',
#  'range': (458888, 461242),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'clpPX-lon',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'acrB',
#  'RegulonDB ID': 'ECK120001647',
#  'range': (481254, 484403),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'acrAB',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'fepC',
#  'RegulonDB ID': 'ECK120000289',
#  'range': (619384, 620199),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'fepDGC',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'dsbG',
#  'RegulonDB ID': 'ECK120002940',
#  'range': (637827, 638573),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'dsbG',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'djlC',
#  'RegulonDB ID': 'ECK120002963',
#  'range': (680212, 681663),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ybeU-djlC',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'ubiF',
#  'RegulonDB ID': 'ECK120002972',
#  'range': (695101, 696276),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ubiF',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'glnS',
#  'RegulonDB ID': 'ECK120000383',
#  'range': (706093, 707757),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'glnS',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'pgm',
#  'RegulonDB ID': 'ECK120002045',
#  'range': (713558, 715198),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'seqA-pgm',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'kdpD',
#  'RegulonDB ID': 'ECK120000509',
#  'range': (721730, 724414),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'kdpDE',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'abrB',
#  'RegulonDB ID': 'ECK120002984',
#  'range': (746723, 747769),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'abrB',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'sdhA',
#  'RegulonDB ID': 'ECK120000920',
#  'range': (755907, 757673),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'sdhCDAB-sucABCD',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'ybhR',
#  'RegulonDB ID': 'ECK120003009',
#  'range': (825002, 826108),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'cecR-ybhGFSR',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'dinG',
#  'RegulonDB ID': 'ECK120001326',
#  'range': (833070, 835220),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'dinG-ybiB',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'rlmC',
#  'RegulonDB ID': 'ECK120003049',
#  'range': (898518, 899645),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ybjO-rlmC',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'elfC',
#  'RegulonDB ID': 'ECK120003082',
#  'range': (999216, 1001816),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'elfDCG-ycbUVF',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'hns TFBS',
#  'RegulonDB ID': 'ECK120011932',
#  'range': (1293022, 1293036),
#  'genetic': False,
#  'feature type': 'TFBS',
#  'operon': 'hns',
#  'significantly associated conditions': set(),
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'rph-pyrE attenuator terminator',
#  'RegulonDB ID': 'ECK125144791',
#  'range': (3815799, 3815911),
#  'genetic': False,
#  'feature type': 'attenuator terminator',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph'},
#  'significantly associated conditions': set(),
#  'mutation set count': 6,
#  'significantly enriched': True}
# {'name': 'rph',
#  'RegulonDB ID': 'ECK120000854',
#  'range': (3815863, 3816549),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph-pyrE attenuator terminator'},
#  'significantly associated conditions': {'glucose(4)'},
#  'mutation set count': 6,
#  'significantly enriched': True}
# {'name': 'corA',
#  'RegulonDB ID': 'ECK120001425',
#  'range': (4001426, 4002376),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'corA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'rpoB',
#  'RegulonDB ID': 'ECK120000885',
#  'range': (4181245, 4185273),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rplKAJL-rpoBC',
#  'significantly associated conditions': set(),
#  'mutation set count': 6,
#  'significantly enriched': True}
# {'name': 'rpoC',
#  'RegulonDB ID': 'ECK120000886',
#  'range': (4185350, 4189573),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rplKAJL-rpoBC',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'pgaB',
#  'RegulonDB ID': 'ECK120003128',
# ...
#  'range': (758464, 758724),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'unknown',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': True}
# {'name': 'sucB',
#  'RegulonDB ID': 'ECK120000969',
#  'range': (761522, 762739),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'sdhCDAB-sucABCD',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'cysDp',
#  'RegulonDB ID': 'ECK120010206',
#  'range': (2876348, 2876428),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'cysDNC',
#  'significantly associated conditions': {'Δsdh'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'rph-pyrE attenuator terminator',
#  'RegulonDB ID': 'ECK125144791',
#  'range': (3815799, 3815911),
#  'genetic': False,
#  'feature type': 'attenuator terminator',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph'},
#  'significantly associated conditions': set(),
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'rph',
#  'RegulonDB ID': 'ECK120000854',
#  'range': (3815863, 3816549),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph-pyrE attenuator terminator'},
#  'significantly associated conditions': {'glucose(4)'},
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'rpoB',
#  'RegulonDB ID': 'ECK120000885',
#  'range': (4181245, 4185273),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rplKAJL-rpoBC',
#  'significantly associated conditions': set(),
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'sucA',
#  'RegulonDB ID': 'ECK120000968',
#  'range': (758706, 761507),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'sdhCDAB-sucABCD',
#  'significantly associated conditions': {'Δsdh'},
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'sucA',
#  'RegulonDB ID': 'ECK120000968',
#  'range': (758706, 761507),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'sdhCDAB-sucABCD',
#  'significantly associated conditions': {'Δsdh'},
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'sucA',
#  'RegulonDB ID': 'ECK120000968',
#  'range': (758706, 761507),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'sdhCDAB-sucABCD',
#  'significantly associated conditions': {'Δsdh'},
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'glnD',
#  'RegulonDB ID': 'ECK120001377',
#  'range': (185978, 188650),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'map-glnD-dapD',
#  'significantly associated conditions': {'Δsdh'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'cysDp',
#  'RegulonDB ID': 'ECK120010206',
#  'range': (2876348, 2876428),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'cysDNC',
#  'significantly associated conditions': {'Δsdh'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'rph-pyrE attenuator terminator',
#  'RegulonDB ID': 'ECK125144791',
#  'range': (3815799, 3815911),
#  'genetic': False,
#  'feature type': 'attenuator terminator',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph'},
#  'significantly associated conditions': set(),
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'rph',
#  'RegulonDB ID': 'ECK120000854',
#  'range': (3815863, 3816549),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph-pyrE attenuator terminator'},
#  'significantly associated conditions': {'glucose(4)'},
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'rpoB',
#  'RegulonDB ID': 'ECK120000885',
#  'range': (4181245, 4185273),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rplKAJL-rpoBC',
#  'significantly associated conditions': set(),
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'sucA',
#  'RegulonDB ID': 'ECK120000968',
#  'range': (758706, 761507),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'sdhCDAB-sucABCD',
#  'significantly associated conditions': {'Δsdh'},
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'rph-pyrE attenuator terminator',
#  'RegulonDB ID': 'ECK125144791',
#  'range': (3815799, 3815911),
#  'genetic': False,
#  'feature type': 'attenuator terminator',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph'},
#  'significantly associated conditions': set(),
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'rph',
#  'RegulonDB ID': 'ECK120000854',
#  'range': (3815863, 3816549),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph-pyrE attenuator terminator'},
#  'significantly associated conditions': {'glucose(4)'},
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'rpoB',
#  'RegulonDB ID': 'ECK120000885',
#  'range': (4181245, 4185273),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rplKAJL-rpoBC',
#  'significantly associated conditions': set(),
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'pntA RBS',
#  'RegulonDB ID': 'ECK120014306',
#  'range': (1677909, 1677914),
#  'genetic': False,
#  'feature type': 'RBS',
#  'operon': 'unknown',
#  'significantly associated conditions': {'Δgnd'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'rph-pyrE attenuator terminator',
#  'RegulonDB ID': 'ECK125144791',
#  'range': (3815799, 3815911),
#  'genetic': False,
#  'feature type': 'attenuator terminator',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph'},
#  'significantly associated conditions': set(),
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'rph',
#  'RegulonDB ID': 'ECK120000854',
#  'range': (3815863, 3816549),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph-pyrE attenuator terminator'},
#  'significantly associated conditions': {'glucose(4)'},
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'ilvLXG_1G_2MEDA terminator',
#  'RegulonDB ID': 'ECK120033263',
#  'range': (3950320, 3950471),
#  'genetic': False,
#  'feature type': 'terminator',
#  'operon': 'ilvLXG_1G_2MEDA',
#  'overlap': {'ilvL'},
#  'significantly associated conditions': {'Δgnd'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'ilvL',
#  'RegulonDB ID': 'ECK120001244',
#  'range': (3950322, 3950420),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ilvLXG_1G_2MEDA',
#  'overlap': {'ilvLXG_1G_2MEDA terminator'},
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': True}
# {'name': 'rpoB',
#  'RegulonDB ID': 'ECK120000885',
#  'range': (4181245, 4185273),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rplKAJL-rpoBC',
#  'significantly associated conditions': set(),
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'sulA TFBS',
#  'RegulonDB ID': 'ECK120012890',
#  'range': (1020939, 1020958),
#  'genetic': False,
#  'feature type': 'TFBS',
#  'operon': 'sulA',
#  'overlap': {'sulAp'},
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': True}
# {'name': 'sulAp',
#  'RegulonDB ID': 'ECK120010143',
#  'range': (1020927, 1021007),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'sulA',
#  'overlap': {'sulA TFBS'},
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': True}
# {'name': 'fdnG',
#  'RegulonDB ID': 'ECK120001205',
#  'range': (1547401, 1550448),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'fdnGHI',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'pntA RBS',
#  'RegulonDB ID': 'ECK120014306',
#  'range': (1677909, 1677914),
#  'genetic': False,
#  'feature type': 'RBS',
#  'operon': 'unknown',
#  'significantly associated conditions': {'Δgnd'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'rph-pyrE attenuator terminator',
#  'RegulonDB ID': 'ECK125144791',
#  'range': (3815799, 3815911),
#  'genetic': False,
#  'feature type': 'attenuator terminator',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph'},
#  'significantly associated conditions': set(),
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'rph',
#  'RegulonDB ID': 'ECK120000854',
#  'range': (3815863, 3816549),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph-pyrE attenuator terminator'},
#  'significantly associated conditions': {'glucose(4)'},
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'ilvLXG_1G_2MEDA terminator',
#  'RegulonDB ID': 'ECK120033263',
#  'range': (3950320, 3950471),
#  'genetic': False,
#  'feature type': 'terminator',
#  'operon': 'ilvLXG_1G_2MEDA',
#  'significantly associated conditions': {'Δgnd'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'rpoB',
#  'RegulonDB ID': 'ECK120000885',
#  'range': (4181245, 4185273),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rplKAJL-rpoBC',
#  'significantly associated conditions': set(),
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'rpsA',
#  'RegulonDB ID': 'ECK120000891',
#  'range': (961995, 963668),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'cmk-rpsA-ihfB',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'pntAp',
#  'RegulonDB ID': 'ECK120010629',
#  'range': (1677955, 1678035),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'pntAB',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': True}
# {'name': 'hdhA',
#  'RegulonDB ID': 'ECK120000418',
#  'range': (1697273, 1698040),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'hdhA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'yhjV',
#  'RegulonDB ID': 'ECK120002147',
#  'range': (3700563, 3701834),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'yhjV',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'rph-pyrE attenuator terminator',
#  'RegulonDB ID': 'ECK125144791',
#  'range': (3815799, 3815911),
#  'genetic': False,
#  'feature type': 'attenuator terminator',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph'},
#  'significantly associated conditions': set(),
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'rph',
#  'RegulonDB ID': 'ECK120000854',
#  'range': (3815863, 3816549),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph-pyrE attenuator terminator'},
#  'significantly associated conditions': {'glucose(4)'},
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'ilvG_2',
#  'RegulonDB ID': 'ECK120000491',
#  'range': (3951623, 3952204),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ilvLXG_1G_2MEDA',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'rfe',
#  'RegulonDB ID': 'ECK120000831',
#  'range': (3967916, 3969019),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rfe-wzzE-wecBC-rffGHC-wecE-wzxE-rffT-wzyE-rffM',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'rpoB',
#  'RegulonDB ID': 'ECK120000885',
#  'range': (4181245, 4185273),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rplKAJL-rpoBC',
#  'significantly associated conditions': set(),
#  'mutation set count': 4,
#  'significantly enriched': True}
# {'name': 'malG',
#  'RegulonDB ID': 'ECK120000549',
#  'range': (4242626, 4243516),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'malEFG',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'RegulonDB ID': 'ECK120000088/ECK120000627',
#  'name': 'asnB/umpH',
#  'range': (699178, 699573),
#  'feature type': 'unknown',
#  'genetic': False,
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': True}
# {'name': 'rph-pyrE attenuator terminator',
#  'RegulonDB ID': 'ECK125144791',
#  'range': (3815799, 3815911),
#  'genetic': False,
#  'feature type': 'attenuator terminator',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph'},
#  'significantly associated conditions': set(),
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'rph',
#  'RegulonDB ID': 'ECK120000854',
#  'range': (3815863, 3816549),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph-pyrE attenuator terminator'},
#  'significantly associated conditions': {'glucose(4)'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'ilvG_1',
#  'RegulonDB ID': 'ECK120004461',
#  'range': (3950560, 3951543),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ilvLXG_1G_2MEDA',
#  'significantly associated conditions': {'GMOS'},
#  'mutation set count': 1,
#  'significantly enriched': True}
# {'name': 'rpoB',
#  'RegulonDB ID': 'ECK120000885',
#  'range': (4181245, 4185273),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rplKAJL-rpoBC',
#  'significantly associated conditions': set(),
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'cyoAp',
#  'RegulonDB ID': 'ECK120010169',
#  'range': (451633, 451713),
#  'genetic': False,
#  'feature type': 'promoter',
#  'operon': 'cyoABCDE',
#  'significantly associated conditions': {'GMOS'},
#  'mutation set count': 1,
#  'significantly enriched': True}
# {'name': 'cysB',
#  'RegulonDB ID': 'ECK120000179',
#  'range': (1333855, 1334829),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'cysB',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': True}
# {'name': 'ydfV',
#  'RegulonDB ID': 'ECK120003421',
#  'range': (1645897, 1646202),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'ydfV',
#  'significantly associated conditions': {'GMOS'},
#  'mutation set count': 1,
#  'significantly enriched': True}
# {'name': 'glnD',
#  'RegulonDB ID': 'ECK120001377',
#  'range': (185978, 188650),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'map-glnD-dapD',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'parC',
#  'RegulonDB ID': 'ECK120000679',
#  'range': (3163715, 3165973),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'parC',
#  'significantly associated conditions': {'GMOS'},
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'rph-pyrE attenuator terminator',
#  'RegulonDB ID': 'ECK125144791',
#  'range': (3815799, 3815911),
#  'genetic': False,
#  'feature type': 'attenuator terminator',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph'},
#  'significantly associated conditions': set(),
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'rph',
#  'RegulonDB ID': 'ECK120000854',
#  'range': (3815863, 3816549),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rph-pyrE',
#  'overlap': {'rph-pyrE attenuator terminator'},
#  'significantly associated conditions': {'glucose(4)'},
#  'mutation set count': 2,
#  'significantly enriched': True}
# {'name': 'rfe',
#  'RegulonDB ID': 'ECK120000831',
#  'range': (3967916, 3969019),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rfe-wzzE-wecBC-rffGHC-wecE-wzxE-rffT-wzyE-rffM',
#  'significantly associated conditions': set(),
#  'mutation set count': 1,
#  'significantly enriched': True}
# {'name': 'wecE',
#  'RegulonDB ID': 'ECK120001419',
#  'range': (3975146, 3976276),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rfe-wzzE-wecBC-rffGHC-wecE-wzxE-rffT-wzyE-rffM',
#  'significantly associated conditions': {'GMOS'},
#  'mutation set count': 1,
#  'significantly enriched': False}
# {'name': 'rplL',
#  'RegulonDB ID': 'ECK120000864',
#  'range': (4180560, 4180925),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rplKAJL-rpoBC',
#  'significantly associated conditions': {'GMOS'},
#  'mutation set count': 1,
#  'significantly enriched': True}
# {'name': 'rpoB',
#  'RegulonDB ID': 'ECK120000885',
#  'range': (4181245, 4185273),
#  'genetic': True,
#  'feature type': 'gene',
#  'operon': 'rplKAJL-rpoBC',
#  'significantly associated conditions': set(),
#  'mutation set count': 2,
#  'significantly enriched': True}

# %%
# The intention is to demonstrate the cumulative convergence FOR MUTATIONS up to a certain resolution of annotation.
# Therefore, even if current level doesn't show convergence, possibly to due not being able to map with current level,
# if previously level demonstrated convergence, then going to annotate as convergence.
def is_converging_up_to_annot(mut_row, curr_feat_col, prev_feat_col=None):
    is_converging = False
    if prev_feat_col:  # if previous annotation type is found to converge, continue considering the mutation as converging.
        is_converging = mut_row[prev_feat_col]
    if not is_converging:  # if the previous column was not found to converge, the upcoming column could be found to converge.
        for feat_d in mut_row[curr_feat_col]:
            if feat_d["mutation set count"] > 1:
                is_converging = True
                break
    return is_converging

all_mut_df["genomic feature converging mutation"] = all_mut_df.apply(lambda r: is_converging_up_to_annot(r, "genomic features"), axis=1)
all_mut_df["genetic feature converging mutation"] = all_mut_df.apply(lambda r: is_converging_up_to_annot(r, "genetic features", "genomic feature converging mutation"), axis=1)
all_mut_df["operon converging mutation"] = all_mut_df.apply(lambda r: is_converging_up_to_annot(r, "operons", "genetic feature converging mutation"), axis=1)
all_mut_df["regulator converging mutation"] = all_mut_df.apply(lambda r: is_converging_up_to_annot(r, "regulators", "operon converging mutation"), axis=1)
all_mut_df["COG converging mutation"] = all_mut_df.apply(lambda r: is_converging_up_to_annot(r, "COGs", "operon converging mutation"), axis=1)
all_mut_df["pathway converging mutation"] = all_mut_df.apply(lambda r: is_converging_up_to_annot(r, "pathways", "operon converging mutation"), axis=1)
all_mut_df.head()
# Out:
#                                              COG links  \
# 778  {'Energy production and conversion': ['ECK1200...
# 779  {'Lipid transport and metabolism': ['ECK125166...
# 780  {'Replication, recombination and repair': ['EC...
# 781  {'Energy production and conversion': ['ECK1200...
# 782                {'Transcription': ['ECK120016992']}
#
#                                                   COGs                Details  \
# 778  [{'name': 'Energy production and conversion', ...  intergenic (‑75/‑446)
# 779  [{'name': 'Lipid transport and metabolism', 'm...         P56L (CCT→CTT)
# 780  [{'name': 'Replication, recombination and repa...         I81S (ATC→AGC)
# 781  [{'name': 'Energy production and conversion', ...        S317G (AGC→GGC)
# 782  [{'name': 'Transcription', 'mutation set count...       K1242Q (AAG→CAG)
#
#     Mutation Type  Position RBS Reference Seq Sequence Change TFBS  ale  \
# 778           MOB   1677978  {}           NaN   IS5 (+) +4 bp   {}    1
# 779           SNP    202267  {}           NaN             C→T   {}    1
# 780           SNP   3960918  {}           NaN             T→G   {}    1
# 781           SNP   4159842  {}           NaN             T→C   {}    1
# 782           SNP   4184968  {}           NaN             A→C   {}    1
#
#     attenuator terminator base-media calcium-source carbon-source  coding  \
# 778                    {}         M9     CaCl2(0.1)    glucose(2)   False
# 779                    {}         M9     CaCl2(0.1)    glucose(2)    True
# 780                    {}         M9     CaCl2(0.1)    glucose(2)    True
# 781                    {}         M9     CaCl2(0.1)    glucose(2)    True
# 782                    {}         M9     CaCl2(0.1)    glucose(2)    True
#
#      exp  flask gene RegulonDB ID  genetic  \
# 778  PGI     50                {}    False
# 779  PGI     50    {ECK120001257}     True
# 780  PGI     50    {ECK120000828}     True
# 781  PGI     50    {ECK120001392}     True
# 782  PGI     50    {ECK120000885}     True
#
#                                genetic feature links  \
# 778  {'ECK120000735/ECK120003449': ['ECK120010629']}
# 779               {'ECK120001257': ['ECK120001257']}
# 780               {'ECK120000828': ['ECK120000828']}
# 781               {'ECK120001392': ['ECK120001392']}
# 782               {'ECK120000885': ['ECK120000885']}
#
#                                       genetic features  \
# 778  [{'RegulonDB ID': 'ECK120000735/ECK120003449',...
# 779  [{'name': 'fabZ', 'RegulonDB ID': 'ECK12000125...
# 780  [{'name': 'rep', 'RegulonDB ID': 'ECK120000828...
# 781  [{'name': 'sthA', 'RegulonDB ID': 'ECK12000139...
# 782  [{'name': 'rpoB', 'RegulonDB ID': 'ECK12000088...
#
#                                       genomic features index  isolate  \
# 778  [{'name': 'pntAp', 'RegulonDB ID': 'ECK1200106...     1        1
# 779  [{'name': 'fabZ', 'RegulonDB ID': 'ECK12000125...     0        1
# 780  [{'name': 'rep', 'RegulonDB ID': 'ECK120000828...     2        1
# 781  [{'name': 'sthA', 'RegulonDB ID': 'ECK12000139...     3        1
# 782  [{'name': 'rpoB', 'RegulonDB ID': 'ECK12000088...     4        1
#
#     mutation target annotation nitrogen-source  \
# 778                  pntA/ydgH        NH4Cl(2)
# 779                       fabZ        NH4Cl(2)
# 780                        rep        NH4Cl(2)
# 781                       sthA        NH4Cl(2)
# 782                       rpoB        NH4Cl(2)
#
#                                         operon links  \
# 778  {'ECK120014614': ['ECK120000735/ECK120003449']}
# 779               {'ECK125166138': ['ECK120001257']}
# 780               {'ECK120014997': ['ECK120000828']}
# 781               {'ECK120015926': ['ECK120001392']}
# 782               {'ECK120016992': ['ECK120000885']}
#
#                                                operons   oriC  \
# 778  [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...  False
# 779  [{'name': 'bamA-skp-lpxD-fabZ-lpxAB-rnhB-dnaE'...  False
# 780  [{'name': 'rep', 'RegulonDB ID': 'ECK120014997...  False
# 781  [{'name': 'sthA', 'RegulonDB ID': 'ECK12001592...  False
# 782  [{'name': 'rplKAJL-rpoBC', 'RegulonDB ID': 'EC...  False
#
#                                          pathway links  \
# 778  {'Nicotinate and nicotinamide metabolism': ['E...
# 779  {'Fatty acid biosynthesis': ['ECK125166138'], ...
# 780                                                 {}
# 781  {'Nicotinate and nicotinamide metabolism': ['E...
# 782  {'Purine metabolism': ['ECK120016992'], 'Pyrim...
#
#                                               pathways  \
# 778  [{'name': 'Nicotinate and nicotinamide metabol...
# 779  [{'name': 'Fatty acid biosynthesis', 'mutation...
# 780                                                 []
# 781  [{'name': 'Nicotinate and nicotinamide metabol...
# 782  [{'name': 'Purine metabolism', 'mutation set c...
#
#           phosphorous-source  presence        promoter  pseudogene  \
# 778  KH2PO4(6) Na2HPO4(13.6)       1.0  {ECK120010629}       False
# 779  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
# 780  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
# 781  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
# 782  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
#
#                   range                                    regulator links  \
# 778  (1677978, 1677978)                                                 {}
# 779    (202267, 202267)  {'CpxR': ['bamA-skp-lpxD-fabZ-lpxAB-rnhB-dnaE'...
# 780  (3960918, 3960918)                                                 {}
# 781  (4159842, 4159842)                                                 {}
# 782  (4184968, 4184968)                                                 {}
#
#                                             regulators strain-description  \
# 778                                                 []               Δpgi
# 779  [{'name': 'CpxR', 'significantly associated co...               Δpgi
# 780                                                 []               Δpgi
# 781                                                 []               Δpgi
# 782                                                 []               Δpgi
#
#     sulfur-source                 supplement taxonomy-id  tech_rep  \
# 778     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 779     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 780     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 781     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 782     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
#
#     temperature terminator  genomic feature converging mutation  \
# 778  37 celsius         {}                                False
# 779  37 celsius         {}                                False
# 780  37 celsius         {}                                False
# 781  37 celsius         {}                                 True
# 782  37 celsius         {}                                 True
#
#      genetic feature converging mutation  operon converging mutation  \
# 778                                False                        True
# 779                                False                       False
# 780                                False                       False
# 781                                 True                        True
# 782                                 True                        True
#
#      regulator converging mutation  COG converging mutation  \
# 778                           True                     True
# 779                           True                     True
# 780                          False                    False
# 781                           True                     True
# 782                           True                     True
#
#      pathway converging mutation
# 778                         True
# 779                        False
# 780                        False
# 781                         True
# 782                         True

# %%
# The intention is to demonstrate the cumulative significant convergence FOR MUTATIONS up to a certain resolution of annotation.
# Therefore, even if current level doesn't show convergence, possibly to due not being able to map with current level,
# if previously level demonstrated convergence, then going to annotate as convergence.
def is_significant_up_to_annot(mut_row, curr_feat_col, prev_feat_col=None):
    is_converging = False
    if prev_feat_col:  # if previous annotation type is found to converge, continue considering the mutation as converging.
        is_converging = mut_row[prev_feat_col]
    if not is_converging:  # if the previous column was not found to converge, the upcoming column could be found to converge.
        for feat_d in mut_row[curr_feat_col]:
            if feat_d["significant"]:
                is_converging = True
                break
    return is_converging


all_mut_df["genomic feature significant mutation"] = all_mut_df.apply(lambda r: is_significant_up_to_annot(r, "genomic features"), axis=1)
all_mut_df["genetic feature significant mutation"] = all_mut_df.apply(lambda r: is_significant_up_to_annot(r, "genetic features", "genomic feature significant mutation"), axis=1)
all_mut_df["operon significant mutation"] = all_mut_df.apply(lambda r: is_significant_up_to_annot(r, "operons", "genetic feature significant mutation"), axis=1)
all_mut_df["regulator significant mutation"] = all_mut_df.apply(lambda r: is_significant_up_to_annot(r, "regulators", "operon significant mutation"), axis=1)
all_mut_df["COG significant mutation"] = all_mut_df.apply(lambda r: is_significant_up_to_annot(r, "COGs", "operon significant mutation"), axis=1)
all_mut_df["pathway significant mutation"] = all_mut_df.apply(lambda r: is_significant_up_to_annot(r, "pathways", "operon significant mutation"), axis=1)
all_mut_df.head()
# Out:
#                                              COG links  \
# 778  {'Energy production and conversion': ['ECK1200...
# 779  {'Lipid transport and metabolism': ['ECK125166...
# 780  {'Replication, recombination and repair': ['EC...
# 781  {'Energy production and conversion': ['ECK1200...
# 782                {'Transcription': ['ECK120016992']}
#
#                                                   COGs                Details  \
# 778  [{'name': 'Energy production and conversion', ...  intergenic (‑75/‑446)
# 779  [{'name': 'Lipid transport and metabolism', 'm...         P56L (CCT→CTT)
# 780  [{'name': 'Replication, recombination and repa...         I81S (ATC→AGC)
# 781  [{'name': 'Energy production and conversion', ...        S317G (AGC→GGC)
# 782  [{'name': 'Transcription', 'mutation set count...       K1242Q (AAG→CAG)
#
#     Mutation Type  Position RBS Reference Seq Sequence Change TFBS  ale  \
# 778           MOB   1677978  {}           NaN   IS5 (+) +4 bp   {}    1
# 779           SNP    202267  {}           NaN             C→T   {}    1
# 780           SNP   3960918  {}           NaN             T→G   {}    1
# 781           SNP   4159842  {}           NaN             T→C   {}    1
# 782           SNP   4184968  {}           NaN             A→C   {}    1
#
#     attenuator terminator base-media calcium-source carbon-source  coding  \
# 778                    {}         M9     CaCl2(0.1)    glucose(2)   False
# 779                    {}         M9     CaCl2(0.1)    glucose(2)    True
# 780                    {}         M9     CaCl2(0.1)    glucose(2)    True
# 781                    {}         M9     CaCl2(0.1)    glucose(2)    True
# 782                    {}         M9     CaCl2(0.1)    glucose(2)    True
#
#      exp  flask gene RegulonDB ID  genetic  \
# 778  PGI     50                {}    False
# 779  PGI     50    {ECK120001257}     True
# 780  PGI     50    {ECK120000828}     True
# 781  PGI     50    {ECK120001392}     True
# 782  PGI     50    {ECK120000885}     True
#
#                                genetic feature links  \
# 778  {'ECK120000735/ECK120003449': ['ECK120010629']}
# 779               {'ECK120001257': ['ECK120001257']}
# 780               {'ECK120000828': ['ECK120000828']}
# 781               {'ECK120001392': ['ECK120001392']}
# 782               {'ECK120000885': ['ECK120000885']}
#
#                                       genetic features  \
# 778  [{'RegulonDB ID': 'ECK120000735/ECK120003449',...
# 779  [{'name': 'fabZ', 'RegulonDB ID': 'ECK12000125...
# 780  [{'name': 'rep', 'RegulonDB ID': 'ECK120000828...
# 781  [{'name': 'sthA', 'RegulonDB ID': 'ECK12000139...
# 782  [{'name': 'rpoB', 'RegulonDB ID': 'ECK12000088...
#
#                                       genomic features index  isolate  \
# 778  [{'name': 'pntAp', 'RegulonDB ID': 'ECK1200106...     1        1
# 779  [{'name': 'fabZ', 'RegulonDB ID': 'ECK12000125...     0        1
# 780  [{'name': 'rep', 'RegulonDB ID': 'ECK120000828...     2        1
# 781  [{'name': 'sthA', 'RegulonDB ID': 'ECK12000139...     3        1
# 782  [{'name': 'rpoB', 'RegulonDB ID': 'ECK12000088...     4        1
#
#     mutation target annotation nitrogen-source  \
# 778                  pntA/ydgH        NH4Cl(2)
# 779                       fabZ        NH4Cl(2)
# 780                        rep        NH4Cl(2)
# 781                       sthA        NH4Cl(2)
# 782                       rpoB        NH4Cl(2)
#
#                                         operon links  \
# 778  {'ECK120014614': ['ECK120000735/ECK120003449']}
# 779               {'ECK125166138': ['ECK120001257']}
# 780               {'ECK120014997': ['ECK120000828']}
# 781               {'ECK120015926': ['ECK120001392']}
# 782               {'ECK120016992': ['ECK120000885']}
#
#                                                operons   oriC  \
# 778  [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...  False
# 779  [{'name': 'bamA-skp-lpxD-fabZ-lpxAB-rnhB-dnaE'...  False
# 780  [{'name': 'rep', 'RegulonDB ID': 'ECK120014997...  False
# 781  [{'name': 'sthA', 'RegulonDB ID': 'ECK12001592...  False
# 782  [{'name': 'rplKAJL-rpoBC', 'RegulonDB ID': 'EC...  False
#
#                                          pathway links  \
# 778  {'Nicotinate and nicotinamide metabolism': ['E...
# 779  {'Fatty acid biosynthesis': ['ECK125166138'], ...
# 780                                                 {}
# 781  {'Nicotinate and nicotinamide metabolism': ['E...
# 782  {'Purine metabolism': ['ECK120016992'], 'Pyrim...
#
#                                               pathways  \
# 778  [{'name': 'Nicotinate and nicotinamide metabol...
# 779  [{'name': 'Fatty acid biosynthesis', 'mutation...
# 780                                                 []
# 781  [{'name': 'Nicotinate and nicotinamide metabol...
# 782  [{'name': 'Purine metabolism', 'mutation set c...
#
#           phosphorous-source  presence        promoter  pseudogene  \
# 778  KH2PO4(6) Na2HPO4(13.6)       1.0  {ECK120010629}       False
# 779  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
# 780  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
# 781  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
# 782  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
#
#                   range                                    regulator links  \
# 778  (1677978, 1677978)                                                 {}
# 779    (202267, 202267)  {'CpxR': ['bamA-skp-lpxD-fabZ-lpxAB-rnhB-dnaE'...
# 780  (3960918, 3960918)                                                 {}
# 781  (4159842, 4159842)                                                 {}
# 782  (4184968, 4184968)                                                 {}
#
#                                             regulators strain-description  \
# 778                                                 []               Δpgi
# 779  [{'name': 'CpxR', 'significantly associated co...               Δpgi
# 780                                                 []               Δpgi
# 781                                                 []               Δpgi
# 782                                                 []               Δpgi
#
#     sulfur-source                 supplement taxonomy-id  tech_rep  \
# 778     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 779     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 780     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 781     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 782     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
#
#     temperature terminator  genomic feature converging mutation  \
# 778  37 celsius         {}                                False
# 779  37 celsius         {}                                False
# 780  37 celsius         {}                                False
# 781  37 celsius         {}                                 True
# 782  37 celsius         {}                                 True
#
#      genetic feature converging mutation  operon converging mutation  \
# 778                                False                        True
# 779                                False                       False
# 780                                False                       False
# 781                                 True                        True
# 782                                 True                        True
#
#      regulator converging mutation  COG converging mutation  \
# 778                           True                     True
# 779                           True                     True
# 780                          False                    False
# 781                           True                     True
# 782                           True                     True
#
#      pathway converging mutation  genomic feature significant mutation  \
# 778                         True                                 False
# 779                        False                                 False
# 780                        False                                 False
# 781                         True                                  True
# 782                         True                                 False
#
#      genetic feature significant mutation  operon significant mutation  \
# 778                                 False                         True
# 779                                 False                        False
# 780                                 False                        False
# 781                                  True                         True
# 782                                  True                         True
#
#      regulator significant mutation  COG significant mutation  \
# 778                            True                      True
# 779                           False                     False
# 780                           False                     False
# 781                            True                      True
# 782                            True                      True
#
#      pathway significant mutation
# 778                          True
# 779                         False
# 780                         False
# 781                          True
# 782                          True

# %%
import numpy as np


all_exp_prop_df = pd.DataFrame()
for exp, exp_mut_df in all_mut_df.groupby(["exp"]):
        
    df = pd.DataFrame(
        [
            [exp, "genomic", "convergent", np.sum(exp_mut_df["genomic feature converging mutation"]/len(exp_mut_df))],
            [exp, "genomic", "significant", np.sum(exp_mut_df["genomic feature significant mutation"]/len(exp_mut_df))],
            [exp, "genetic", "convergent", np.sum(exp_mut_df["genetic feature converging mutation"]/len(exp_mut_df))],
            [exp, "genetic", "significant", np.sum(exp_mut_df["genetic feature significant mutation"]/len(exp_mut_df))],
            [exp, "operon", "convergent", np.sum(exp_mut_df["operon converging mutation"]/len(exp_mut_df))],
            [exp, "operon", "significant", np.sum(exp_mut_df["operon significant mutation"]/len(exp_mut_df))],
            [exp, "pathway", "convergent", np.sum(exp_mut_df["pathway converging mutation"]/len(exp_mut_df))],
            [exp, "pathway", "significant", np.sum(exp_mut_df["pathway significant mutation"]/len(exp_mut_df))],
            [exp, "regulon", "convergent", np.sum(exp_mut_df["regulator converging mutation"]/len(exp_mut_df))],
            [exp, "regulon", "significant", np.sum(exp_mut_df["regulator significant mutation"]/len(exp_mut_df))],
            [exp, "COG", "convergent", np.sum(exp_mut_df["COG converging mutation"]/len(exp_mut_df))],
            [exp, "COG", "significant", np.sum(exp_mut_df["COG significant mutation"]/len(exp_mut_df))],
        ],
        columns=["experiment", "convergence level", 'convergence type', "proportion"]
    )
    all_exp_prop_df = all_exp_prop_df.append(df)
all_exp_prop_df.head()
# Out:
#   experiment convergence level convergence type  proportion
# 0        42C           genomic       convergent    0.470588
# 1        42C           genomic      significant    0.294118
# 2        42C           genetic       convergent    0.529412
# 3        42C           genetic      significant    0.362745
# 4        42C            operon       convergent    0.549020

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 200
sns.set_context("paper")
sns.set_style("whitegrid")
sns.set_palette("Set2")


boxplot_kwargs = {
    'boxprops': {'edgecolor': 'k', 'linewidth': 0.75},
    'whiskerprops': {'color': 'k', 'linewidth': 0.75},
    'medianprops': {'color': 'k', 'linewidth': 0.75},
    'capprops': {'color': 'k', 'linewidth': 0.75},
    'flierprops': {'marker': 'o', 'markerfacecolor': 'white', 'markeredgecolor': 'black'}
}
ax = sns.boxplot(data=all_exp_prop_df,
                 x="proportion",
                 y="convergence level",
                 hue="convergence type",
                 width=0.5,
                 **boxplot_kwargs)

ax.set_title("The proportion of experiment mutations\nthat converge or are significant\nwhen considering up to a feature annotation type")
ax.yaxis.label.set_visible(False)
ax.set_xlabel("proportion")
ax.legend().set_title('')
plt.xlim(0, 1.1)
# Out:
# (0, 1.1)

# %%
all_exp_signif_prop_df = all_exp_prop_df[all_exp_prop_df["convergence type"]=="significant"]
all_exp_signif_prop_df.head()
# Out:
#   experiment convergence level convergence type  proportion
# 1        42C           genomic      significant    0.294118
# 3        42C           genetic      significant    0.362745
# 5        42C            operon      significant    0.382353
# 7        42C           pathway      significant    0.397059
# 9        42C           regulon      significant    0.387255

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 300
sns.set_context("paper")
sns.set_style("whitegrid")
# sns.set_palette("Set2")


boxplot_kwargs = {
    'boxprops': {'edgecolor': 'k', 'linewidth': 0.75},
    'whiskerprops': {'color': 'k', 'linewidth': 0.75},
    'medianprops': {'color': 'k', 'linewidth': 0.75},
    'capprops': {'color': 'k', 'linewidth': 0.75},
    'flierprops': {'marker': '.', 'markerfacecolor': 'black', 'markeredgecolor': None}
}
plt.figure(figsize=(4,3))
ax = sns.boxplot(data=all_exp_signif_prop_df,
                 x="proportion",
                 y="convergence level",
                 width=0.5,
                 color="white",
                 **boxplot_kwargs)

# ax.set_title("The proportion of mutated features that significant\nwhen considering up to a feature annotation type")
# ax.set_title("The increase in mutated features\ninvolved in significant convergence\nwhen considering up to an annotation type")
# ax.yaxis.label.set_visible(False)

# Hack, just to get COG's spelled out
new_yticks = ["genomic", "genetic", "operon", "pathway", "regulon", "clusters of\northologous groups"]
ax.set_yticklabels(new_yticks)

for tick in ax.get_xticklabels():
    tick.set_fontname("Helvetica")
for tick in ax.get_yticklabels():
    tick.set_fontname("Helvetica")

ax.set_ylabel("annotation type", fontname="Helvetica")
ax.set_xlabel("proportion of mutations per ALE experiment\ninvolved in significant convergence", fontname="Helvetica")
plt.xlim(0, 1)
plt.savefig("fig.svg", format="svg")

# %%
np.median(all_exp_signif_prop_df[all_exp_signif_prop_df["convergence level"]=="genomic"]["proportion"])
# Out:
# 0.5634920634920635

# %%
np.median(all_exp_signif_prop_df[all_exp_signif_prop_df["convergence level"]=="genetic"]["proportion"])
# Out:
# 0.628992628992629

# %%
np.median(all_exp_signif_prop_df[all_exp_signif_prop_df["convergence level"]=="operon"]["proportion"])
# Out:
# 0.6644144144144144

# %%
np.median(all_exp_signif_prop_df[all_exp_signif_prop_df["convergence level"]=="regulon"]["proportion"])
# Out:
# 0.672043010752688

# %%
np.median(all_exp_signif_prop_df[all_exp_signif_prop_df["convergence level"]=="pathway"]["proportion"])
# Out:
# 0.6677927927927927

# %%
np.median(all_exp_signif_prop_df[all_exp_signif_prop_df["convergence level"]=="COG"]["proportion"])
# Out:
# 0.6950757575757575

# %%
ax = sns.swarmplot(data=all_exp_signif_prop_df,
                   x="proportion",
                   y="convergence level",
                   hue="experiment",
                   palette="tab20"
                   )
plt.xlim(0, 1.1)
plt.ylabel("annotation type")
plt.title("Proportion of features in significant events\nby experiment and annotation type")
plt.legend(loc=9, bbox_to_anchor=(0.5, -0.2))

# %%
with open("./data/COG_genome_coverage.pkl", 'rb') as f:
    COG_genome_cov = pickle.load(f)
print(COG_genome_cov)
# Out:
# 0.8388373710831034

# %%
with open("./data/pathway_genome_coverage.pkl", 'rb') as f:
    pathway_genome_cov = pickle.load(f)
print(pathway_genome_cov)
# Out:
# 0.2376325847709857

# %%
with open("./data/regulon_genome_coverage.pkl", 'rb') as f:
    regulon_genome_cov = pickle.load(f)
print(regulon_genome_cov)
# Out:
# 0.42346961308826836

# %%
COG_len_df = pd.read_pickle("./data/COG_len_df.pkl")
median_COG_feat_len = np.median(COG_len_df["COG length"])
pathway_len_df = pd.read_pickle("./data/pathway_len_df.pkl")
median_pathway_feat_len = np.median(pathway_len_df["pathway length"])
regulon_len_df = pd.read_pickle("./data/regulon_len_df.pkl")
median_regulon_feat_len = np.median(regulon_len_df["regulon length"])

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 300
sns.set_context("talk")
sns.set_style("ticks")


col = "genome coverage"
df = pd.DataFrame({"COGs": [COG_genome_cov], "regulons": [regulon_genome_cov], "pathways": [pathway_genome_cov]}, index=[col]).T
df = df.sort_values(col)
ax = df.plot.barh(
    figsize=(4, 2),
    color="#4C72B0",
    width=1
)
for i, v in enumerate(df["genome coverage"]):
    ax.text(v, i - 0.2, "%.2f" % round(v,2))
ax.set_title("Annotation type genome coverage")
ax.get_legend().remove()
plt.xlim(0, 1)
sns.despine(ax=ax, top=True, right=True)

# %%
col = "median feature length"
df = pd.DataFrame({"COGs": [median_COG_feat_len], "regulons": [median_pathway_feat_len], "pathways": [median_regulon_feat_len]}, index=[col]).T
df = df.sort_values(col)
ax = df.plot.barh(
    figsize=(4, 2),
    color="#4C72B0",
    width=1
)
for i, v in enumerate(df[col]):
    ax.text(v, i - 0.2, str(int(v)))
ax.set_title("Annotation type "+col)
ax.get_legend().remove()
plt.xscale('log')
sns.despine(ax=ax, top=True, right=True)

# %%
COG_feat_count = len(COG_len_df.index)
pathway_feat_count = len(pathway_len_df.index)
regulon_feat_count = len(regulon_len_df.index)


col = "feature count"
df = pd.DataFrame({"COGs": [COG_feat_count], "regulons": [pathway_feat_count], "pathways": [regulon_feat_count]}, index=[col]).T
df = df.sort_values(col)
ax = df.plot.barh(
    figsize=(4, 2),
    color="#4C72B0",
    width=1
)
for i, v in enumerate(df[col]):
    ax.text(v, i - 0.2, str(int(v)))
ax.set_title("Annotation type "+col)
ax.get_legend().remove()
sns.despine(ax=ax, top=True, right=True)

# %%
def is_converging(mut_row, curr_feat_col):
    is_converging = False
    for feat_d in mut_row[curr_feat_col]:
        if feat_d["mutation set count"] > 1:
            is_converging = True
            break
    return is_converging


# !!! This overwrites previously written results, therefore I want want to regenerate plots @ the beginning of the NB, I need to re-run the whole NB.
all_mut_df["genomic feature converging mutation"] = all_mut_df.apply(lambda r: is_converging(r, "genomic features"), axis=1)
all_mut_df["genetic feature converging mutation"] = all_mut_df.apply(lambda r: is_converging(r, "genetic features"), axis=1)
all_mut_df["operon converging mutation"] = all_mut_df.apply(lambda r: is_converging(r, "operons"), axis=1)
all_mut_df["regulator converging mutation"] = all_mut_df.apply(lambda r: is_converging(r, "regulators"), axis=1)
all_mut_df["COG converging mutation"] = all_mut_df.apply(lambda r: is_converging(r, "COGs"), axis=1)
all_mut_df["pathway converging mutation"] = all_mut_df.apply(lambda r: is_converging(r, "pathways"), axis=1)
all_mut_df.head()
# Out:
#                                              COG links  \
# 778  {'Energy production and conversion': ['ECK1200...
# 779  {'Lipid transport and metabolism': ['ECK125166...
# 780  {'Replication, recombination and repair': ['EC...
# 781  {'Energy production and conversion': ['ECK1200...
# 782                {'Transcription': ['ECK120016992']}
#
#                                                   COGs                Details  \
# 778  [{'name': 'Energy production and conversion', ...  intergenic (‑75/‑446)
# 779  [{'name': 'Lipid transport and metabolism', 'm...         P56L (CCT→CTT)
# 780  [{'name': 'Replication, recombination and repa...         I81S (ATC→AGC)
# 781  [{'name': 'Energy production and conversion', ...        S317G (AGC→GGC)
# 782  [{'name': 'Transcription', 'mutation set count...       K1242Q (AAG→CAG)
#
#     Mutation Type  Position RBS Reference Seq Sequence Change TFBS  ale  \
# 778           MOB   1677978  {}           NaN   IS5 (+) +4 bp   {}    1
# 779           SNP    202267  {}           NaN             C→T   {}    1
# 780           SNP   3960918  {}           NaN             T→G   {}    1
# 781           SNP   4159842  {}           NaN             T→C   {}    1
# 782           SNP   4184968  {}           NaN             A→C   {}    1
#
#     attenuator terminator base-media calcium-source carbon-source  coding  \
# 778                    {}         M9     CaCl2(0.1)    glucose(2)   False
# 779                    {}         M9     CaCl2(0.1)    glucose(2)    True
# 780                    {}         M9     CaCl2(0.1)    glucose(2)    True
# 781                    {}         M9     CaCl2(0.1)    glucose(2)    True
# 782                    {}         M9     CaCl2(0.1)    glucose(2)    True
#
#      exp  flask gene RegulonDB ID  genetic  \
# 778  PGI     50                {}    False
# 779  PGI     50    {ECK120001257}     True
# 780  PGI     50    {ECK120000828}     True
# 781  PGI     50    {ECK120001392}     True
# 782  PGI     50    {ECK120000885}     True
#
#                                genetic feature links  \
# 778  {'ECK120000735/ECK120003449': ['ECK120010629']}
# 779               {'ECK120001257': ['ECK120001257']}
# 780               {'ECK120000828': ['ECK120000828']}
# 781               {'ECK120001392': ['ECK120001392']}
# 782               {'ECK120000885': ['ECK120000885']}
#
#                                       genetic features  \
# 778  [{'RegulonDB ID': 'ECK120000735/ECK120003449',...
# 779  [{'name': 'fabZ', 'RegulonDB ID': 'ECK12000125...
# 780  [{'name': 'rep', 'RegulonDB ID': 'ECK120000828...
# 781  [{'name': 'sthA', 'RegulonDB ID': 'ECK12000139...
# 782  [{'name': 'rpoB', 'RegulonDB ID': 'ECK12000088...
#
#                                       genomic features index  isolate  \
# 778  [{'name': 'pntAp', 'RegulonDB ID': 'ECK1200106...     1        1
# 779  [{'name': 'fabZ', 'RegulonDB ID': 'ECK12000125...     0        1
# 780  [{'name': 'rep', 'RegulonDB ID': 'ECK120000828...     2        1
# 781  [{'name': 'sthA', 'RegulonDB ID': 'ECK12000139...     3        1
# 782  [{'name': 'rpoB', 'RegulonDB ID': 'ECK12000088...     4        1
#
#     mutation target annotation nitrogen-source  \
# 778                  pntA/ydgH        NH4Cl(2)
# 779                       fabZ        NH4Cl(2)
# 780                        rep        NH4Cl(2)
# 781                       sthA        NH4Cl(2)
# 782                       rpoB        NH4Cl(2)
#
#                                         operon links  \
# 778  {'ECK120014614': ['ECK120000735/ECK120003449']}
# 779               {'ECK125166138': ['ECK120001257']}
# 780               {'ECK120014997': ['ECK120000828']}
# 781               {'ECK120015926': ['ECK120001392']}
# 782               {'ECK120016992': ['ECK120000885']}
#
#                                                operons   oriC  \
# 778  [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...  False
# 779  [{'name': 'bamA-skp-lpxD-fabZ-lpxAB-rnhB-dnaE'...  False
# 780  [{'name': 'rep', 'RegulonDB ID': 'ECK120014997...  False
# 781  [{'name': 'sthA', 'RegulonDB ID': 'ECK12001592...  False
# 782  [{'name': 'rplKAJL-rpoBC', 'RegulonDB ID': 'EC...  False
#
#                                          pathway links  \
# 778  {'Nicotinate and nicotinamide metabolism': ['E...
# 779  {'Fatty acid biosynthesis': ['ECK125166138'], ...
# 780                                                 {}
# 781  {'Nicotinate and nicotinamide metabolism': ['E...
# 782  {'Purine metabolism': ['ECK120016992'], 'Pyrim...
#
#                                               pathways  \
# 778  [{'name': 'Nicotinate and nicotinamide metabol...
# 779  [{'name': 'Fatty acid biosynthesis', 'mutation...
# 780                                                 []
# 781  [{'name': 'Nicotinate and nicotinamide metabol...
# 782  [{'name': 'Purine metabolism', 'mutation set c...
#
#           phosphorous-source  presence        promoter  pseudogene  \
# 778  KH2PO4(6) Na2HPO4(13.6)       1.0  {ECK120010629}       False
# 779  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
# 780  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
# 781  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
# 782  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
#
#                   range                                    regulator links  \
# 778  (1677978, 1677978)                                                 {}
# 779    (202267, 202267)  {'CpxR': ['bamA-skp-lpxD-fabZ-lpxAB-rnhB-dnaE'...
# 780  (3960918, 3960918)                                                 {}
# 781  (4159842, 4159842)                                                 {}
# 782  (4184968, 4184968)                                                 {}
#
#                                             regulators strain-description  \
# 778                                                 []               Δpgi
# 779  [{'name': 'CpxR', 'significantly associated co...               Δpgi
# 780                                                 []               Δpgi
# 781                                                 []               Δpgi
# 782                                                 []               Δpgi
#
#     sulfur-source                 supplement taxonomy-id  tech_rep  \
# 778     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 779     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 780     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 781     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 782     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
#
#     temperature terminator  genomic feature converging mutation  \
# 778  37 celsius         {}                                False
# 779  37 celsius         {}                                False
# 780  37 celsius         {}                                False
# 781  37 celsius         {}                                 True
# 782  37 celsius         {}                                 True
#
#      genetic feature converging mutation  operon converging mutation  \
# 778                                False                        True
# 779                                False                       False
# 780                                False                       False
# 781                                 True                        True
# 782                                 True                        True
#
#      regulator converging mutation  COG converging mutation  \
# 778                          False                     True
# 779                           True                     True
# 780                          False                    False
# 781                          False                     True
# 782                          False                     True
#
#      pathway converging mutation  genomic feature significant mutation  \
# 778                         True                                 False
# 779                        False                                 False
# 780                        False                                 False
# 781                         True                                  True
# 782                         True                                 False
#
#      genetic feature significant mutation  operon significant mutation  \
# 778                                 False                         True
# 779                                 False                        False
# 780                                 False                        False
# 781                                  True                         True
# 782                                  True                         True
#
#      regulator significant mutation  COG significant mutation  \
# 778                            True                      True
# 779                           False                     False
# 780                           False                     False
# 781                            True                      True
# 782                            True                      True
#
#      pathway significant mutation
# 778                          True
# 779                         False
# 780                         False
# 781                          True
# 782                          True

# %%
# The intention is to demonstrate the cumulative significant convergence FOR MUTATIONS up to a certain resolution of annotation.
# Therefore, even if current level doesn't show convergence, possibly to due not being able to map with current level,
# if previously level demonstrated convergence, then going to annotate as convergence.
def is_significant(mut_row, curr_feat_col):
    is_converging = False
    for feat_d in mut_row[curr_feat_col]:
        if feat_d["significant"]:
            is_converging = True
            break
    return is_converging


all_mut_df["genomic feature significant mutation"] = all_mut_df.apply(lambda r: is_significant(r, "genomic features"), axis=1)
all_mut_df["genetic feature significant mutation"] = all_mut_df.apply(lambda r: is_significant(r, "genetic features"), axis=1)
all_mut_df["operon significant mutation"] = all_mut_df.apply(lambda r: is_significant(r, "operons"), axis=1)
all_mut_df["regulator significant mutation"] = all_mut_df.apply(lambda r: is_significant(r, "regulators"), axis=1)
all_mut_df["COG significant mutation"] = all_mut_df.apply(lambda r: is_significant(r, "COGs"), axis=1)
all_mut_df["pathway significant mutation"] = all_mut_df.apply(lambda r: is_significant(r, "pathways"), axis=1)
all_mut_df.head()
# Out:
#                                              COG links  \
# 778  {'Energy production and conversion': ['ECK1200...
# 779  {'Lipid transport and metabolism': ['ECK125166...
# 780  {'Replication, recombination and repair': ['EC...
# 781  {'Energy production and conversion': ['ECK1200...
# 782                {'Transcription': ['ECK120016992']}
#
#                                                   COGs                Details  \
# 778  [{'name': 'Energy production and conversion', ...  intergenic (‑75/‑446)
# 779  [{'name': 'Lipid transport and metabolism', 'm...         P56L (CCT→CTT)
# 780  [{'name': 'Replication, recombination and repa...         I81S (ATC→AGC)
# 781  [{'name': 'Energy production and conversion', ...        S317G (AGC→GGC)
# 782  [{'name': 'Transcription', 'mutation set count...       K1242Q (AAG→CAG)
#
#     Mutation Type  Position RBS Reference Seq Sequence Change TFBS  ale  \
# 778           MOB   1677978  {}           NaN   IS5 (+) +4 bp   {}    1
# 779           SNP    202267  {}           NaN             C→T   {}    1
# 780           SNP   3960918  {}           NaN             T→G   {}    1
# 781           SNP   4159842  {}           NaN             T→C   {}    1
# 782           SNP   4184968  {}           NaN             A→C   {}    1
#
#     attenuator terminator base-media calcium-source carbon-source  coding  \
# 778                    {}         M9     CaCl2(0.1)    glucose(2)   False
# 779                    {}         M9     CaCl2(0.1)    glucose(2)    True
# 780                    {}         M9     CaCl2(0.1)    glucose(2)    True
# 781                    {}         M9     CaCl2(0.1)    glucose(2)    True
# 782                    {}         M9     CaCl2(0.1)    glucose(2)    True
#
#      exp  flask gene RegulonDB ID  genetic  \
# 778  PGI     50                {}    False
# 779  PGI     50    {ECK120001257}     True
# 780  PGI     50    {ECK120000828}     True
# 781  PGI     50    {ECK120001392}     True
# 782  PGI     50    {ECK120000885}     True
#
#                                genetic feature links  \
# 778  {'ECK120000735/ECK120003449': ['ECK120010629']}
# 779               {'ECK120001257': ['ECK120001257']}
# 780               {'ECK120000828': ['ECK120000828']}
# 781               {'ECK120001392': ['ECK120001392']}
# 782               {'ECK120000885': ['ECK120000885']}
#
#                                       genetic features  \
# 778  [{'RegulonDB ID': 'ECK120000735/ECK120003449',...
# 779  [{'name': 'fabZ', 'RegulonDB ID': 'ECK12000125...
# 780  [{'name': 'rep', 'RegulonDB ID': 'ECK120000828...
# 781  [{'name': 'sthA', 'RegulonDB ID': 'ECK12000139...
# 782  [{'name': 'rpoB', 'RegulonDB ID': 'ECK12000088...
#
#                                       genomic features index  isolate  \
# 778  [{'name': 'pntAp', 'RegulonDB ID': 'ECK1200106...     1        1
# 779  [{'name': 'fabZ', 'RegulonDB ID': 'ECK12000125...     0        1
# 780  [{'name': 'rep', 'RegulonDB ID': 'ECK120000828...     2        1
# 781  [{'name': 'sthA', 'RegulonDB ID': 'ECK12000139...     3        1
# 782  [{'name': 'rpoB', 'RegulonDB ID': 'ECK12000088...     4        1
#
#     mutation target annotation nitrogen-source  \
# 778                  pntA/ydgH        NH4Cl(2)
# 779                       fabZ        NH4Cl(2)
# 780                        rep        NH4Cl(2)
# 781                       sthA        NH4Cl(2)
# 782                       rpoB        NH4Cl(2)
#
#                                         operon links  \
# 778  {'ECK120014614': ['ECK120000735/ECK120003449']}
# 779               {'ECK125166138': ['ECK120001257']}
# 780               {'ECK120014997': ['ECK120000828']}
# 781               {'ECK120015926': ['ECK120001392']}
# 782               {'ECK120016992': ['ECK120000885']}
#
#                                                operons   oriC  \
# 778  [{'name': 'pntAB', 'RegulonDB ID': 'ECK1200146...  False
# 779  [{'name': 'bamA-skp-lpxD-fabZ-lpxAB-rnhB-dnaE'...  False
# 780  [{'name': 'rep', 'RegulonDB ID': 'ECK120014997...  False
# 781  [{'name': 'sthA', 'RegulonDB ID': 'ECK12001592...  False
# 782  [{'name': 'rplKAJL-rpoBC', 'RegulonDB ID': 'EC...  False
#
#                                          pathway links  \
# 778  {'Nicotinate and nicotinamide metabolism': ['E...
# 779  {'Fatty acid biosynthesis': ['ECK125166138'], ...
# 780                                                 {}
# 781  {'Nicotinate and nicotinamide metabolism': ['E...
# 782  {'Purine metabolism': ['ECK120016992'], 'Pyrim...
#
#                                               pathways  \
# 778  [{'name': 'Nicotinate and nicotinamide metabol...
# 779  [{'name': 'Fatty acid biosynthesis', 'mutation...
# 780                                                 []
# 781  [{'name': 'Nicotinate and nicotinamide metabol...
# 782  [{'name': 'Purine metabolism', 'mutation set c...
#
#           phosphorous-source  presence        promoter  pseudogene  \
# 778  KH2PO4(6) Na2HPO4(13.6)       1.0  {ECK120010629}       False
# 779  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
# 780  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
# 781  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
# 782  KH2PO4(6) Na2HPO4(13.6)       1.0              {}       False
#
#                   range                                    regulator links  \
# 778  (1677978, 1677978)                                                 {}
# 779    (202267, 202267)  {'CpxR': ['bamA-skp-lpxD-fabZ-lpxAB-rnhB-dnaE'...
# 780  (3960918, 3960918)                                                 {}
# 781  (4159842, 4159842)                                                 {}
# 782  (4184968, 4184968)                                                 {}
#
#                                             regulators strain-description  \
# 778                                                 []               Δpgi
# 779  [{'name': 'CpxR', 'significantly associated co...               Δpgi
# 780                                                 []               Δpgi
# 781                                                 []               Δpgi
# 782                                                 []               Δpgi
#
#     sulfur-source                 supplement taxonomy-id  tech_rep  \
# 778     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 779     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 780     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 781     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
# 782     MgSO4(24)  NaCl(1g/L) trace elements      511145         1
#
#     temperature terminator  genomic feature converging mutation  \
# 778  37 celsius         {}                                False
# 779  37 celsius         {}                                False
# 780  37 celsius         {}                                False
# 781  37 celsius         {}                                 True
# 782  37 celsius         {}                                 True
#
#      genetic feature converging mutation  operon converging mutation  \
# 778                                False                        True
# 779                                False                       False
# 780                                False                       False
# 781                                 True                        True
# 782                                 True                        True
#
#      regulator converging mutation  COG converging mutation  \
# 778                          False                     True
# 779                           True                     True
# 780                          False                    False
# 781                          False                     True
# 782                          False                     True
#
#      pathway converging mutation  genomic feature significant mutation  \
# 778                         True                                 False
# 779                        False                                 False
# 780                        False                                 False
# 781                         True                                  True
# 782                         True                                 False
#
#      genetic feature significant mutation  operon significant mutation  \
# 778                                 False                         True
# 779                                 False                        False
# 780                                 False                        False
# 781                                  True                         True
# 782                                  True                         True
#
#      regulator significant mutation  COG significant mutation  \
# 778                           False                      True
# 779                           False                     False
# 780                           False                     False
# 781                           False                      True
# 782                           False                      True
#
#      pathway significant mutation
# 778                          True
# 779                         False
# 780                         False
# 781                          True
# 782                         False

# %%
all_exp_prop_df = pd.DataFrame()
for exp, exp_mut_df in all_mut_df.groupby(["exp"]):
        
    df = pd.DataFrame(
        [
            [exp, "genomic", "convergent", np.sum(exp_mut_df["genomic feature converging mutation"]/len(exp_mut_df))],
            [exp, "genomic", "significant", np.sum(exp_mut_df["genomic feature significant mutation"]/len(exp_mut_df))],
            [exp, "genetic", "convergent", np.sum(exp_mut_df["genetic feature converging mutation"]/len(exp_mut_df))],
            [exp, "genetic", "significant", np.sum(exp_mut_df["genetic feature significant mutation"]/len(exp_mut_df))],
            [exp, "operon", "convergent", np.sum(exp_mut_df["operon converging mutation"]/len(exp_mut_df))],
            [exp, "operon", "significant", np.sum(exp_mut_df["operon significant mutation"]/len(exp_mut_df))],
            [exp, "pathway", "convergent", np.sum(exp_mut_df["pathway converging mutation"]/len(exp_mut_df))],
            [exp, "pathway", "significant", np.sum(exp_mut_df["pathway significant mutation"]/len(exp_mut_df))],
            [exp, "regulon", "convergent", np.sum(exp_mut_df["regulator converging mutation"]/len(exp_mut_df))],
            [exp, "regulon", "significant", np.sum(exp_mut_df["regulator significant mutation"]/len(exp_mut_df))],
            [exp, "COG", "convergent", np.sum(exp_mut_df["COG converging mutation"]/len(exp_mut_df))],
            [exp, "COG", "significant", np.sum(exp_mut_df["COG significant mutation"]/len(exp_mut_df))],
        ],
        columns=["experiment", "convergence level", 'convergence type', "proportion"]
    )
    all_exp_prop_df = all_exp_prop_df.append(df)
all_exp_prop_df.head()
# Out:
#   experiment convergence level convergence type  proportion
# 0        42C           genomic       convergent    0.470588
# 1        42C           genomic      significant    0.294118
# 2        42C           genetic       convergent    0.529412
# 3        42C           genetic      significant    0.362745
# 4        42C            operon       convergent    0.500000

# %%
COG_convergence_median = np.median(
    all_exp_prop_df[
    (all_exp_prop_df["convergence type"]=="convergent")
    & (all_exp_prop_df["convergence level"]=="COG")
    ]["proportion"])
print(COG_convergence_median)
COG_signif_median = np.median(
    all_exp_prop_df[
    (all_exp_prop_df["convergence type"]=="significant")
    & (all_exp_prop_df["convergence level"]=="COG")
    ]["proportion"])
print(COG_signif_median)
pathway_convergence_median = np.median(
    all_exp_prop_df[
    (all_exp_prop_df["convergence type"]=="convergent")
    & (all_exp_prop_df["convergence level"]=="pathway")
    ]["proportion"])
print(pathway_convergence_median)
pathway_signif_median = np.median(
    all_exp_prop_df[
    (all_exp_prop_df["convergence type"]=="significant")
    & (all_exp_prop_df["convergence level"]=="pathway")
    ]["proportion"])
print(pathway_signif_median)
regulon_convergence_median = np.median(
    all_exp_prop_df[
    (all_exp_prop_df["convergence type"]=="convergent")
    & (all_exp_prop_df["convergence level"]=="regulon")
    ]["proportion"])
print(regulon_convergence_median)
regulon_signif_median = np.median(
    all_exp_prop_df[
    (all_exp_prop_df["convergence type"]=="significant")
    & (all_exp_prop_df["convergence level"]=="regulon")
    ]["proportion"])
print(regulon_signif_median)
# Out:
# 0.7620137299771167
# 0.1537362188648428
# 0.4006238859180036
# 0.16064516129032258
# 0.3909958720330238
# 0.07870370370370369

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 200
sns.set_context("paper")
sns.set_style("whitegrid")
sns.set_palette("tab20")
colors = ['#aec7e8', '#1f77b4', '#ffbb78', '#ff7f0e','#98df8a','#2ca02c','#ff9896','#d62728','#c5b0d5','#9467bd','#c49c94','#8c564b','#f7b6d2','#e377c2','#c7c7c7','#7f7f7f','#dbdb8d','#bcbd22','#9edae5','#17becf',]

x=[]
x+=[COG_genome_cov]*2
x+=[pathway_genome_cov]*2
x+=[regulon_genome_cov]*2

# Could do all points instead of just median, though median gives better actionable information than all points.
y = [COG_convergence_median, COG_signif_median,
     pathway_convergence_median, pathway_signif_median,
     regulon_convergence_median, regulon_signif_median]
l=[]
for i in range(0, len(x)):
    p = plt.scatter(x[i], y[i], color=colors[i])
    l.append(p)
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.title("Annotation type genome coverage\nversus median % convergence \nand median % significance")
plt.xlabel("% genome coverage")
plt.ylabel("% conergence or significance")
plt.legend(l,
           ["COG median convergence", "COG median significance",
            "pathway median convergence", "pathway median significance",
            "regulon median convergence", "regulon median significance"
           ])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 200
sns.set_context("paper")
sns.set_style("whitegrid")
sns.set_palette("tab20")
colors = ['#aec7e8', '#1f77b4', '#ffbb78', '#ff7f0e','#98df8a','#2ca02c','#ff9896','#d62728','#c5b0d5','#9467bd','#c49c94','#8c564b','#f7b6d2','#e377c2','#c7c7c7','#7f7f7f','#dbdb8d','#bcbd22','#9edae5','#17becf',]

x=[]
x+=[median_COG_feat_len]*2
x+=[median_pathway_feat_len]*2
x+=[median_regulon_feat_len]*2

# Could do all points instead of just median, though median gives better actionable information than all points.
y = [COG_convergence_median, COG_signif_median,
     pathway_convergence_median, pathway_signif_median,
     regulon_convergence_median, regulon_signif_median]
for i in range(0, len(x)):
    plt.scatter(x[i], y[i], color=colors[i])
plt.xscale('log')
plt.ylim(0, 1)
plt.title("Annotation type median length\nversus median % convergence \nand median % significance")
plt.xlabel("median length")
plt.ylabel("% conergence or significance")
plt.legend(l,
           ["COG median convergence", "COG median significance",
            "pathway median convergence", "pathway median significance",
            "regulon median convergence", "regulon median significance"
           ])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 200
sns.set_context("paper")
sns.set_style("whitegrid")
sns.set_palette("tab20")
colors = ['#aec7e8', '#1f77b4', '#ffbb78', '#ff7f0e','#98df8a','#2ca02c','#ff9896','#d62728','#c5b0d5','#9467bd','#c49c94','#8c564b','#f7b6d2','#e377c2','#c7c7c7','#7f7f7f','#dbdb8d','#bcbd22','#9edae5','#17becf',]

x=[]
x+=[COG_feat_count]*2
x+=[pathway_feat_count]*2
x+=[regulon_feat_count]*2

# Could do all points instead of just median, though median gives better actionable information than all points.
y = [COG_convergence_median, COG_signif_median,
     pathway_convergence_median, pathway_signif_median,
     regulon_convergence_median, regulon_signif_median]
for i in range(0, len(x)):
    plt.scatter(x[i], y[i], color=colors[i])
plt.ylim(0, 1)
plt.title("Annotation type feature count\nversus median % convergence \nand median % significance")
plt.xlabel("feature count")
plt.ylabel("% conergence or significance")
plt.legend(l,
           ["COG median convergence", "COG median significance",
            "pathway median convergence", "pathway median significance",
            "regulon median convergence", "regulon median significance"
           ])
