# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display
import os, sys, itertools, csv
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from util.alemutdf import get_all_sample_mut_df, get_multi_exp_max_freq_mut_df
pd.options.display.max_columns = 100

# %%
# All mutations from the GYD experiment. No filter applied.
GYD_muts_df = get_all_sample_mut_df("./data/muts/testing/")
GYD_muts_df.shape
# Out:
#   4%|▍         | 3/67 [00:00<00:02, 21.71it/s]
# ./data/muts/testing//GYD_filt_freq_0.csv
# 100%|██████████| 67/67 [00:03<00:00, 20.43it/s]
# (17737, 13)

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 300
sns.set_context("paper")
sns.set_style("ticks")

ax = GYD_muts_df["presence"].hist(bins=50, color="#4C72B0",
                                  figsize=(3,2.5)
                                 )
ax.set_title("")
ax.set_xlabel("Mutation presense within a sample")
ax.set_ylabel("Mutation count")
sns.despine(ax=ax, top=True, right=True)
